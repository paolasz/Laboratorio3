# %% [markdown]
# LGBM 01 con linear_tree = true
#
# lags 1 al 36 (3 años)
#
# cantidad de clientes que compraron un producto
#
# meses de vida

# %%
# 📦 Importar librerías necesarias
import pandas as pd
import numpy as np
import random

# 🎲 Configurar semillas para reproductibilidad
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

print("✅ Librerías importadas correctamente")
print(f"🎲 Semilla configurada: {SEED} para reproductibilidad total")
# Out:
# ✅ Librerías importadas correctamente
# 🎲 Semilla configurada: 42 para reproductibilidad total

# %%
# 📄 Cargar todos los datasets
print("Cargando datasets...")

# Load the sales data (tab-delimited)
sales = pd.read_csv("datasets/sell-in.txt", sep="\t", dtype={"periodo": str})
print(f"✅ Sales data cargado: {sales.shape}")

# Load the stocks data (tab-delimited) 
stocks = pd.read_csv("datasets/tb_stocks.txt", sep="\t", dtype={"periodo": str})
print(f"✅ Stocks data cargado: {stocks.shape}")

# Load the product information data (tab-delimited)
product_info = pd.read_csv("datasets/tb_productos.txt", sep="\t")
print(f"✅ Product info cargado: {product_info.shape}")

# Carga productos a predecir
product_predict = pd.read_csv("datasets/product_id_apredecir201912.txt", sep="\t", header=0)
print(f"✅ Productos a predecir cargados: {product_predict.shape}")

print("\n🎯 Todos los datasets cargados exitosamente")
# Out:
# Cargando datasets...
# ✅ Sales data cargado: (2945818, 7)
# ✅ Stocks data cargado: (13691, 3)
# ✅ Product info cargado: (1251, 7)
# ✅ Productos a predecir cargados: (780, 1)
#
# 🎯 Todos los datasets cargados exitosamente
# ✅ Sales data cargado: (2945818, 7)
# ✅ Stocks data cargado: (13691, 3)
# ✅ Product info cargado: (1251, 7)
# ✅ Productos a predecir cargados: (780, 1)
#
# 🎯 Todos los datasets cargados exitosamente

# %%
# 🔍 Explorar estructura de los datos
print("EXPLORACIÓN DE DATOS")
print("="*50)

print("\n📊 SALES DATA:")
print(f"Columnas: {list(sales.columns)}")
print(f"Períodos únicos: {sales['periodo'].nunique()}")
print(f"Productos únicos: {sales['product_id'].nunique()}")
print("Primeras filas:")
print(sales.head())

print("\n📦 STOCKS DATA:")
print(f"Columnas: {list(stocks.columns)}")
print(f"Períodos únicos: {stocks['periodo'].nunique()}")
print(f"Productos únicos: {stocks['product_id'].nunique()}")
print("Primeras filas:")
print(stocks.head())

print("\n🏷️ PRODUCT INFO:")
print(f"Columnas: {list(product_info.columns)}")
print(f"Productos únicos: {product_info['product_id'].nunique()}")
print("Primeras filas:")
print(product_info.head())

print("\n🎯 PRODUCTOS A PREDECIR:")
print(f"Columnas: {list(product_predict.columns)}")
print(f"Total productos a predecir: {len(product_predict)}")
print("Primeras filas:")
print(product_predict.head())
# Out:
# EXPLORACIÓN DE DATOS
# ==================================================
#
# 📊 SALES DATA:
# Columnas: ['periodo', 'customer_id', 'product_id', 'plan_precios_cuidados', 'cust_request_qty', 'cust_request_tn', 'tn']
# Períodos únicos: 36
# Productos únicos: 1233
# Primeras filas:
#   periodo  customer_id  product_id  plan_precios_cuidados  cust_request_qty  \
# 0  201701        10234       20524                      0                 2
# 1  201701        10032       20524                      0                 1
# 2  201701        10217       20524                      0                 1
# 3  201701        10125       20524                      0                 1
# 4  201701        10012       20524                      0                11
#
#    cust_request_tn       tn
# 0          0.05300  0.05300
# 1          0.13628  0.13628
# 2          0.03028  0.03028
# 3          0.02271  0.02271
# 4          1.54452  1.54452
#
# 📦 STOCKS DATA:
# Columnas: ['periodo', 'product_id', 'stock_final']
# Períodos únicos: 15
# Productos únicos: 1095
# Primeras filas:
#   periodo  product_id  stock_final
# 0  201810       20524      1.61267
# 1  201810       20311      2.93657
# 2  201810       20654      6.83269
# 3  201810       21005      1.01338
# 4  201810       20974      0.34595
#
# 🏷️ PRODUCT INFO:
# Columnas: ['cat1', 'cat2', 'cat3', 'brand', 'sku_size', 'product_id', 'descripcion']
# Productos únicos: 1251
# Primeras filas:
#     cat1      cat2         cat3   brand  sku_size  product_id  \
# 0  FOODS  ADEREZOS  Aji Picante  NATURA       240       20609
# 1  FOODS  ADEREZOS     Barbacoa  NATURA       250       20266
# 2  FOODS  ADEREZOS     Barbacoa  NATURA       400       20325
# 3  FOODS  ADEREZOS     Barbacoa  NATURA       500       20503
# 4  FOODS  ADEREZOS  Chimichurri  NATURA       350       20797
#
#          descripcion
# 0  Salsa Aji Picante
# 1     Salsa Barbacoa
# 2     Salsa Barbacoa
# 3     Salsa Barbacoa
# 4        Chimichurri
#
# 🎯 PRODUCTOS A PREDECIR:
# Columnas: ['product_id']
# Total productos a predecir: 780
# Primeras filas:
#    product_id
# 0       20001
# 1       20002
# 2       20003
# 3       20004
# 4       20005

# %%
# 🔗 Verificar consistencia entre datasets
print("VERIFICACIÓN DE CONSISTENCIA")
print("="*50)

# Productos únicos en cada dataset
productos_sales = set(sales['product_id'].unique())
productos_stocks = set(stocks['product_id'].unique())
productos_info = set(product_info['product_id'].unique())

# Si product_predict tiene columna product_id
if 'product_id' in product_predict.columns:
    productos_predict = set(product_predict['product_id'].unique())
else:
    # Si la primera columna contiene los product_ids
    primera_columna = product_predict.columns[0]
    productos_predict = set(product_predict[primera_columna].unique())
    print(f"⚠️ Usando columna '{primera_columna}' como product_id")

print(f"📊 Productos en sales: {len(productos_sales)}")
print(f"📦 Productos en stocks: {len(productos_stocks)}")
print(f"🏷️ Productos en product_info: {len(productos_info)}")
print(f"🎯 Productos a predecir: {len(productos_predict)}")

# Verificar intersecciones
print(f"\n🔍 INTERSECCIONES:")
print(f"Sales ∩ Stocks: {len(productos_sales & productos_stocks)}")
print(f"Sales ∩ Product_info: {len(productos_sales & productos_info)}")
print(f"Sales ∩ Productos_predict: {len(productos_sales & productos_predict)}")
print(f"Stocks ∩ Productos_predict: {len(productos_stocks & productos_predict)}")
print(f"Product_info ∩ Productos_predict: {len(productos_info & productos_predict)}")

# Verificar rangos de fechas
print(f"\n📅 RANGOS DE FECHAS:")
print(f"Sales - períodos: {sales['periodo'].min()} a {sales['periodo'].max()}")
print(f"Stocks - períodos: {stocks['periodo'].min()} a {stocks['periodo'].max()}")
# Out:
# VERIFICACIÓN DE CONSISTENCIA
# ==================================================
# 📊 Productos en sales: 1233
# 📦 Productos en stocks: 1095
# 🏷️ Productos en product_info: 1251
# 🎯 Productos a predecir: 780
#
# 🔍 INTERSECCIONES:
# Sales ∩ Stocks: 1095
# Sales ∩ Product_info: 1188
# Sales ∩ Productos_predict: 780
# Stocks ∩ Productos_predict: 779
# Product_info ∩ Productos_predict: 780
#
# 📅 RANGOS DE FECHAS:
# Sales - períodos: 201701 a 201912
# Stocks - períodos: 201810 a 201912
# Sales - períodos: 201701 a 201912
# Stocks - períodos: 201810 a 201912

# %%
# 📦 Instalar e importar LightGBM, Optuna y librerías adicionales
# %pip install lightgbm optuna

import lightgbm as lgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# 🎲 Configurar semillas adicionales para reproductibilidad
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

# Configurar semilla para matplotlib (si se usa)
plt.rcParams['figure.max_open_warning'] = 0

print("✅ LightGBM, Optuna y librerías ML importadas correctamente")
print(f"🎲 Todas las semillas configuradas con SEED={SEED} para reproductibilidad")
# Out:
# ✅ LightGBM, Optuna y librerías ML importadas correctamente
# 🎲 Todas las semillas configuradas con SEED=42 para reproductibilidad

# %%
# 🧹 Preparación de datos para el modelo LightGBM
print("PREPARACIÓN DE DATOS PARA LGBM - GRANULARIDAD POR PRODUCTO")
print("="*60)

# Convertir período a datetime para facilitar manipulación
sales['fecha'] = pd.to_datetime(sales['periodo'], format='%Y%m')
stocks['fecha'] = pd.to_datetime(stocks['periodo'], format='%Y%m')

# Filtrar solo productos que necesitamos predecir
if 'product_id' in product_predict.columns:
    productos_objetivo = product_predict['product_id'].tolist()
else:
    productos_objetivo = product_predict[product_predict.columns[0]].tolist()

print(f"🎯 Productos objetivo: {len(productos_objetivo)}")

# Filtrar sales y stocks para productos objetivo
sales_filtered = sales[sales['product_id'].isin(productos_objetivo)].copy()
stocks_filtered = stocks[stocks['product_id'].isin(productos_objetivo)].copy()

print(f"📊 Sales filtradas: {sales_filtered.shape}")
print(f"📦 Stocks filtradas: {stocks_filtered.shape}")

# AGREGACIÓN POR PRODUCTO: Sumar por producto y período (agregando todos los clientes)
sales_agg = sales_filtered.groupby(['product_id', 'fecha', 'periodo']).agg({
    'tn': 'sum',                    # Total toneladas por producto
    'customer_id': 'nunique',       # Número de clientes únicos
    'cust_request_qty': 'sum',      # Total cantidad solicitada
    'cust_request_tn': 'sum'        # Total toneladas solicitadas
}).reset_index()

# Renombrar columnas para claridad
sales_agg.rename(columns={
    'customer_id': 'num_customers',
    'cust_request_qty': 'total_request_qty', 
    'cust_request_tn': 'total_request_tn'
}, inplace=True)

print(f"📈 Sales agregadas por producto: {sales_agg.shape}")
print("Primeras filas de sales agregadas:")
print(sales_agg.head())

print(f"\n📊 Estadísticas por producto:")
print(f"  Promedio tn por producto-período: {sales_agg['tn'].mean():.2f}")
print(f"  Promedio clientes por producto-período: {sales_agg['num_customers'].mean():.2f}")
print(f"  Productos únicos: {sales_agg['product_id'].nunique()}")
print(f"  Períodos únicos: {sales_agg['periodo'].nunique()}")
# Out:
# PREPARACIÓN DE DATOS PARA LGBM - GRANULARIDAD POR PRODUCTO
# ============================================================
# 🎯 Productos objetivo: 780
#
# ============================================================
# 🎯 Productos objetivo: 780
# 📊 Sales filtradas: (2293481, 8)
# 📦 Stocks filtradas: (10727, 4)
# 📊 Sales filtradas: (2293481, 8)
# 📦 Stocks filtradas: (10727, 4)
# 📈 Sales agregadas por producto: (22349, 7)
# Primeras filas de sales agregadas:
#    product_id      fecha periodo          tn  num_customers  \
# 0       20001 2017-01-01  201701   934.77222            186
# 1       20001 2017-02-01  201702   798.01620            185
# 2       20001 2017-03-01  201703  1303.35771            188
# 3       20001 2017-04-01  201704  1069.96130            104
# 4       20001 2017-05-01  201705  1502.20132            238
#
#    total_request_qty  total_request_tn
# 0                479         937.72717
# 1                432         833.72187
# 2                509        1330.74697
# 3                279        1132.94430
# 4                701        1550.68936
#
# 📊 Estadísticas por producto:
#   Promedio tn por producto-período: 50.23
#   Promedio clientes por producto-período: 102.62
#   Productos únicos: 780
#   Períodos únicos: 36
# 📈 Sales agregadas por producto: (22349, 7)
# Primeras filas de sales agregadas:
#    product_id      fecha periodo          tn  num_customers  \
# 0       20001 2017-01-01  201701   934.77222            186
# 1       20001 2017-02-01  201702   798.01620            185
# 2       20001 2017-03-01  201703  1303.35771            188
# 3       20001 2017-04-01  201704  1069.96130            104
# 4       20001 2017-05-01  201705  1502.20132            238
#
#    total_request_qty  total_request_tn
# 0                479         937.72717
# 1                432         833.72187
# 2                509        1330.74697
# 3                279        1132.94430
# 4                701        1550.68936
#
# 📊 Estadísticas por producto:
#   Promedio tn por producto-período: 50.23
#   Promedio clientes por producto-período: 102.62
#   Productos únicos: 780
#   Períodos únicos: 36

# %%
# 🔧 Crear features de lag y combinar con stocks - GRANULARIDAD POR PRODUCTO
print("CREACIÓN DE FEATURES POR PRODUCTO")
print("="*50)

# Crear features de lag para cada producto
def create_lag_features(df, product_col, value_col, date_col, lags=[1, 2, 3, 6, 12]):
    """Crear features de lag para series temporales por producto"""
    df_features = df.copy()
    df_features = df_features.sort_values([product_col, date_col])
    
    for lag in lags:
        df_features[f'{value_col}_lag_{lag}'] = df_features.groupby(product_col)[value_col].shift(lag)
    
    return df_features

# Crear lags para ventas (tn) por producto - EXPANDIDO HASTA LAG 36
sales_with_lags = create_lag_features(
    sales_agg, 
    'product_id', 
    'tn', 
    'fecha', 
    lags=list(range(1, 37))  # Todos los lags de 1 a 36 meses (3 años completos)
)

# Crear lags para número de clientes por producto
sales_with_lags = create_lag_features(
    sales_with_lags, 
    'product_id', 
    'num_customers', 
    'fecha', 
    lags=[1, 2, 3]
)

# Crear lags para solicitudes de clientes
sales_with_lags = create_lag_features(
    sales_with_lags, 
    'product_id', 
    'total_request_tn', 
    'fecha', 
    lags=[1, 2, 3]
)

print(f"📊 Sales con lags por producto: {sales_with_lags.shape}")

# Agregar datos de stock por producto
stocks_agg = stocks_filtered.groupby(['product_id', 'fecha', 'periodo']).agg({
    'stock_final': ['mean', 'sum', 'std']  # Stock promedio, total y desviación estándar por producto
}).reset_index()

# Aplanar columnas multinivel
stocks_agg.columns = ['product_id', 'fecha', 'periodo', 'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std']
stocks_agg['stock_tn_std'] = stocks_agg['stock_tn_std'].fillna(0)  # Rellenar NaN en std

# Combinar sales y stocks por producto
data_combined = pd.merge(
    sales_with_lags, 
    stocks_agg[['product_id', 'fecha', 'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std']], 
    on=['product_id', 'fecha'], 
    how='left'
)

# Crear lags para stock por producto
data_combined = create_lag_features(
    data_combined, 
    'product_id', 
    'stock_tn_mean', 
    'fecha', 
    lags=[1, 2, 3]
)

data_combined = create_lag_features(
    data_combined, 
    'product_id', 
    'stock_tn_sum', 
    'fecha', 
    lags=[1, 2]
)

print(f"📦 Datos combinados con stock por producto: {data_combined.shape}")
print(f"Columnas disponibles: {len(data_combined.columns)}")
print("\nPrimeras columnas:")
print(data_combined.columns.tolist()[:15])
print("Últimas columnas:")
print(data_combined.columns.tolist()[-10:])
# Out:
# CREACIÓN DE FEATURES POR PRODUCTO
# ==================================================
# 📊 Sales con lags por producto: (22349, 49)
# 📦 Datos combinados con stock por producto: (22349, 57)
# Columnas disponibles: 57
#
# Primeras columnas:
# ['product_id', 'fecha', 'periodo', 'tn', 'num_customers', 'total_request_qty', 'total_request_tn', 'tn_lag_1', 'tn_lag_2', 'tn_lag_3', 'tn_lag_4', 'tn_lag_5', 'tn_lag_6', 'tn_lag_7', 'tn_lag_8']
# Últimas columnas:
# ['total_request_tn_lag_2', 'total_request_tn_lag_3', 'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std', 'stock_tn_mean_lag_1', 'stock_tn_mean_lag_2', 'stock_tn_mean_lag_3', 'stock_tn_sum_lag_1', 'stock_tn_sum_lag_2']

# %%
# 🎯 Crear target y features adicionales
print("CREACIÓN DE TARGET Y FEATURES ADICIONALES")
print("="*50)

# Crear target: tn de 2 períodos a futuro
data_combined = data_combined.sort_values(['product_id', 'fecha'])
data_combined['target'] = data_combined.groupby('product_id')['tn'].shift(-2)

# Crear features temporales
data_combined['mes'] = data_combined['fecha'].dt.month
data_combined['trimestre'] = data_combined['fecha'].dt.quarter
data_combined['año'] = data_combined['fecha'].dt.year

# 🔢 Crear feature de clientes únicos por producto
print(f"\n🔍 Creando feature de clientes únicos por producto...")
# Calcular cantidad total de clientes únicos que compraron cada producto
clientes_unicos_por_producto = sales_filtered.groupby('product_id')['customer_id'].nunique().reset_index()
clientes_unicos_por_producto.rename(columns={'customer_id': 'cant_clientes_unicos'}, inplace=True)

# Agregar esta información a data_combined
data_combined = pd.merge(
    data_combined,
    clientes_unicos_por_producto,
    on='product_id',
    how='left'
)

print(f"✅ Feature 'cant_clientes_unicos' agregada")
print(f"📊 Estadísticas de clientes únicos por producto:")
print(f"   Promedio: {data_combined['cant_clientes_unicos'].mean():.1f}")
print(f"   Mediana:  {data_combined['cant_clientes_unicos'].median():.1f}")
print(f"   Mínimo:   {data_combined['cant_clientes_unicos'].min()}")
print(f"   Máximo:   {data_combined['cant_clientes_unicos'].max()}")

# 🗓️ Crear feature de meses de vida por producto
print(f"\n🔍 Creando feature de meses de vida por producto...")
# Calcular primer y último período de compra para cada producto
vida_producto = sales_filtered.groupby('product_id')['fecha'].agg(['min', 'max']).reset_index()
vida_producto.columns = ['product_id', 'primer_periodo', 'ultimo_periodo']

# Calcular diferencia en meses
vida_producto['meses_vida'] = ((vida_producto['ultimo_periodo'] - vida_producto['primer_periodo']).dt.days / 30.44).round().astype(int)

# Asegurar que el mínimo sea 1 (productos con una sola compra tienen 1 mes de vida)
vida_producto['meses_vida'] = vida_producto['meses_vida'].apply(lambda x: max(1, x))

# Agregar esta información a data_combined
data_combined = pd.merge(
    data_combined,
    vida_producto[['product_id', 'meses_vida']],
    on='product_id',
    how='left'
)

print(f"✅ Feature 'meses_vida' agregada")
print(f"📊 Estadísticas de meses de vida por producto:")
print(f"   Promedio: {data_combined['meses_vida'].mean():.1f} meses")
print(f"   Mediana:  {data_combined['meses_vida'].median():.1f} meses")
print(f"   Mínimo:   {data_combined['meses_vida'].min()} meses")
print(f"   Máximo:   {data_combined['meses_vida'].max()} meses")
print(f"   Productos con > 24 meses: {(data_combined['meses_vida'] > 24).sum()}")
print(f"   Productos con > 36 meses: {(data_combined['meses_vida'] > 36).sum()}")

# 📈 Crear features de deltas temporales (diferencias del target)
print(f"\n🔍 Creando features de deltas temporales del target...")
# Calcular diferencias entre valores actuales y rezagados de toneladas
data_combined = data_combined.sort_values(['product_id', 'fecha'])

# Deltas de corto plazo (1-6 meses)
data_combined['delta_tn_1m'] = data_combined.groupby('product_id')['tn'].diff(1)  # Cambio vs mes anterior
data_combined['delta_tn_3m'] = data_combined.groupby('product_id')['tn'].diff(3)  # Cambio vs 3 meses atrás
data_combined['delta_tn_6m'] = data_combined.groupby('product_id')['tn'].diff(6)  # Cambio vs 6 meses atrás

# Deltas de mediano plazo (12-18 meses)
data_combined['delta_tn_12m'] = data_combined.groupby('product_id')['tn'].diff(12)  # Cambio vs 12 meses atrás (estacional anual)
data_combined['delta_tn_18m'] = data_combined.groupby('product_id')['tn'].diff(18)  # Cambio vs 18 meses atrás

# Deltas de largo plazo (24-36 meses)
data_combined['delta_tn_24m'] = data_combined.groupby('product_id')['tn'].diff(24)  # Cambio vs 24 meses atrás (bi-anual)
data_combined['delta_tn_30m'] = data_combined.groupby('product_id')['tn'].diff(30)  # Cambio vs 30 meses atrás
data_combined['delta_tn_36m'] = data_combined.groupby('product_id')['tn'].diff(36)  # Cambio vs 36 meses atrás (tri-anual)

# Deltas relativos (porcentuales) para capturar cambios relativos
data_combined['delta_tn_1m_pct'] = data_combined.groupby('product_id')['tn'].pct_change(1) * 100  # % cambio vs mes anterior
data_combined['delta_tn_12m_pct'] = data_combined.groupby('product_id')['tn'].pct_change(12) * 100  # % cambio vs año anterior
data_combined['delta_tn_24m_pct'] = data_combined.groupby('product_id')['tn'].pct_change(24) * 100  # % cambio vs 2 años anterior
data_combined['delta_tn_36m_pct'] = data_combined.groupby('product_id')['tn'].pct_change(36) * 100  # % cambio vs 3 años anterior

# Reemplazar infinitos y NaN con 0
delta_features = ['delta_tn_1m', 'delta_tn_3m', 'delta_tn_6m', 'delta_tn_12m', 'delta_tn_18m', 'delta_tn_24m', 'delta_tn_30m', 'delta_tn_36m', 'delta_tn_1m_pct', 'delta_tn_12m_pct', 'delta_tn_24m_pct', 'delta_tn_36m_pct']
for feature in delta_features:
    data_combined[feature] = data_combined[feature].replace([np.inf, -np.inf], 0).fillna(0)

print(f"✅ Features de deltas temporales agregadas")
print(f"📊 Estadísticas de deltas temporales:")
print(f"   Delta 1 mes - promedio: {data_combined['delta_tn_1m'].mean():.2f}")
print(f"   Delta 12 meses - promedio: {data_combined['delta_tn_12m'].mean():.2f}")
print(f"   Delta 24 meses - promedio: {data_combined['delta_tn_24m'].mean():.2f}")
print(f"   Delta 36 meses - promedio: {data_combined['delta_tn_36m'].mean():.2f}")
print(f"   Delta 1 mes % - promedio: {data_combined['delta_tn_1m_pct'].mean():.2f}%")
print(f"   Delta 12 meses % - promedio: {data_combined['delta_tn_12m_pct'].mean():.2f}%")
print(f"   Delta 24 meses % - promedio: {data_combined['delta_tn_24m_pct'].mean():.2f}%")
print(f"   Delta 36 meses % - promedio: {data_combined['delta_tn_36m_pct'].mean():.2f}%")
print(f"   Features creadas: {delta_features}")
print(f"🎯 Deltas expandidos: Captura tendencias hasta 36 meses atrás")

# Crear features estadísticas móviles
def create_rolling_features(df, product_col, value_col, date_col, windows=[3, 6, 12]):
    """Crear features de ventanas móviles"""
    df = df.sort_values([product_col, date_col])
    
    for window in windows:
        df[f'{value_col}_rolling_mean_{window}'] = df.groupby(product_col)[value_col].rolling(window, min_periods=1).mean().reset_index(level=0, drop=True)
        df[f'{value_col}_rolling_std_{window}'] = df.groupby(product_col)[value_col].rolling(window, min_periods=1).std().reset_index(level=0, drop=True)
    
    return df

# Crear rolling features para ventas
data_combined = create_rolling_features(data_combined, 'product_id', 'tn', 'fecha', windows=[3, 6])

# 📊 Verificar features de lags de toneladas creados
print(f"\n📈 FEATURES DE LAGS DE TONELADAS DISPONIBLES:")
tn_lag_features = [col for col in data_combined.columns if col.startswith('tn_lag_')]
tn_lag_features.sort(key=lambda x: int(x.split('_')[-1]))  # Ordenar por número de lag
print(f"   Total de lags de toneladas: {len(tn_lag_features)}")
for i, feature in enumerate(tn_lag_features, 1):
    lag_num = feature.split('_')[-1]
    print(f"   {i:2d}. {feature} (toneladas de {lag_num} mes{'es' if int(lag_num) > 1 else ''} atrás)")

print(f"\n✅ Features expandidas: Lags de toneladas desde 1 hasta 36 meses")
print(f"🎯 Esto permite al modelo capturar patrones estacionales multi-anuales")

# Agregar información de productos si está disponible
if len(product_info) > 0:
    data_combined = pd.merge(
        data_combined, 
        product_info, 
        on='product_id', 
        how='left'
    )
    print(f"✅ Información de productos agregada")

print(f"📊 Dataset final: {data_combined.shape}")
print(f"📈 Registros con target válido: {data_combined['target'].notna().sum()}")

# Mostrar algunas estadísticas del target
target_stats = data_combined['target'].describe()
print(f"\n📊 Estadísticas del target:")
print(target_stats)
# Out:
# CREACIÓN DE TARGET Y FEATURES ADICIONALES
# ==================================================
#
# 🔍 Creando feature de clientes únicos por producto...
# ✅ Feature 'cant_clientes_unicos' agregada
# 📊 Estadísticas de clientes únicos por producto:
#    Promedio: 359.6
#    Mediana:  372.0
#    Mínimo:   22
#    Máximo:   521
#
# 🔍 Creando feature de meses de vida por producto...
# ✅ Feature 'meses_vida' agregada
# 📊 Estadísticas de meses de vida por producto:
#    Promedio: 31.9 meses
#    Mediana:  35.0 meses
#    Mínimo:   3 meses
#    Máximo:   35 meses
#    Productos con > 24 meses: 19798
#    Productos con > 36 meses: 0
#
# 🔍 Creando features de deltas temporales del target...
# ✅ Feature 'cant_clientes_unicos' agregada
# 📊 Estadísticas de clientes únicos por producto:
#    Promedio: 359.6
#    Mediana:  372.0
#    Mínimo:   22
#    Máximo:   521
#
# 🔍 Creando feature de meses de vida por producto...
# ✅ Feature 'meses_vida' agregada
# 📊 Estadísticas de meses de vida por producto:
#    Promedio: 31.9 meses
#    Mediana:  35.0 meses
#    Mínimo:   3 meses
#    Máximo:   35 meses
#    Productos con > 24 meses: 19798
#    Productos con > 36 meses: 0
#
# 🔍 Creando features de deltas temporales del target...
# ✅ Features de deltas temporales agregadas
# 📊 Estadísticas de deltas temporales:
#    Delta 1 mes - promedio: -0.26
#    Delta 12 meses - promedio: -3.92
#    Delta 24 meses - promedio: -3.95
#    Delta 36 meses - promedio: 0.00
#    Delta 1 mes % - promedio: 126.68%
#    Delta 12 meses % - promedio: 49.11%
#    Delta 24 meses % - promedio: 68.49%
#    Delta 36 meses % - promedio: 0.00%
#    Features creadas: ['delta_tn_1m', 'delta_tn_3m', 'delta_tn_6m', 'delta_tn_12m', 'delta_tn_18m', 'delta_tn_24m', 'delta_tn_30m', 'delta_tn_36m', 'delta_tn_1m_pct', 'delta_tn_12m_pct', 'delta_tn_24m_pct', 'delta_tn_36m_pct']
# 🎯 Deltas expandidos: Captura tendencias hasta 36 meses atrás
#
# 📈 FEATURES DE LAGS DE TONELADAS DISPONIBLES:
#    Total de lags de toneladas: 36
#     1. tn_lag_1 (toneladas de 1 mes atrás)
#     2. tn_lag_2 (toneladas de 2 meses atrás)
#     3. tn_lag_3 (toneladas de 3 meses atrás)
#     4. tn_lag_4 (toneladas de 4 meses atrás)
#     5. tn_lag_5 (toneladas de 5 meses atrás)
#     6. tn_lag_6 (toneladas de 6 meses atrás)
#     7. tn_lag_7 (toneladas de 7 meses atrás)
#     8. tn_lag_8 (toneladas de 8 meses atrás)
#     9. tn_lag_9 (toneladas de 9 meses atrás)
#    10. tn_lag_10 (toneladas de 10 meses atrás)
#    11. tn_lag_11 (toneladas de 11 meses atrás)
#    12. tn_lag_12 (toneladas de 12 meses atrás)
#    13. tn_lag_13 (toneladas de 13 meses atrás)
#    14. tn_lag_14 (toneladas de 14 meses atrás)
#    15. tn_lag_15 (toneladas de 15 meses atrás)
#    16. tn_lag_16 (toneladas de 16 meses atrás)
#    17. tn_lag_17 (toneladas de 17 meses atrás)
#    18. tn_lag_18 (toneladas de 18 meses atrás)
#    19. tn_lag_19 (toneladas de 19 meses atrás)
#    20. tn_lag_20 (toneladas de 20 meses atrás)
#    21. tn_lag_21 (toneladas de 21 meses atrás)
#    22. tn_lag_22 (toneladas de 22 meses atrás)
#    23. tn_lag_23 (toneladas de 23 meses atrás)
#    24. tn_lag_24 (toneladas de 24 meses atrás)
#    25. tn_lag_25 (toneladas de 25 meses atrás)
#    26. tn_lag_26 (toneladas de 26 meses atrás)
#    27. tn_lag_27 (toneladas de 27 meses atrás)
#    28. tn_lag_28 (toneladas de 28 meses atrás)
#    29. tn_lag_29 (toneladas de 29 meses atrás)
#    30. tn_lag_30 (toneladas de 30 meses atrás)
#    31. tn_lag_31 (toneladas de 31 meses atrás)
#    32. tn_lag_32 (toneladas de 32 meses atrás)
#    33. tn_lag_33 (toneladas de 33 meses atrás)
#    34. tn_lag_34 (toneladas de 34 meses atrás)
#    35. tn_lag_35 (toneladas de 35 meses atrás)
#    36. tn_lag_36 (toneladas de 36 meses atrás)
#
# ✅ Features expandidas: Lags de toneladas desde 1 hasta 36 meses
# 🎯 Esto permite al modelo capturar patrones estacionales multi-anuales
# ✅ Información de productos agregada
# 📊 Dataset final: (22349, 85)
# 📈 Registros con target válido: 20789
#
# 📊 Estadísticas del target:
# count    20789.000000
# mean        50.931444
# std        127.140873
# min          0.000890
# 25%          3.009870
# 50%         11.928920
# 75%         36.636220
# max       2295.198320
# Name: target, dtype: float64
# ✅ Features de deltas temporales agregadas
# 📊 Estadísticas de deltas temporales:
#    Delta 1 mes - promedio: -0.26
#    Delta 12 meses - promedio: -3.92
#    Delta 24 meses - promedio: -3.95
#    Delta 36 meses - promedio: 0.00
#    Delta 1 mes % - promedio: 126.68%
#    Delta 12 meses % - promedio: 49.11%
#    Delta 24 meses % - promedio: 68.49%
#    Delta 36 meses % - promedio: 0.00%
#    Features creadas: ['delta_tn_1m', 'delta_tn_3m', 'delta_tn_6m', 'delta_tn_12m', 'delta_tn_18m', 'delta_tn_24m', 'delta_tn_30m', 'delta_tn_36m', 'delta_tn_1m_pct', 'delta_tn_12m_pct', 'delta_tn_24m_pct', 'delta_tn_36m_pct']
# 🎯 Deltas expandidos: Captura tendencias hasta 36 meses atrás
#
# 📈 FEATURES DE LAGS DE TONELADAS DISPONIBLES:
#    Total de lags de toneladas: 36
#     1. tn_lag_1 (toneladas de 1 mes atrás)
#     2. tn_lag_2 (toneladas de 2 meses atrás)
#     3. tn_lag_3 (toneladas de 3 meses atrás)
#     4. tn_lag_4 (toneladas de 4 meses atrás)
#     5. tn_lag_5 (toneladas de 5 meses atrás)
#     6. tn_lag_6 (toneladas de 6 meses atrás)
#     7. tn_lag_7 (toneladas de 7 meses atrás)
#     8. tn_lag_8 (toneladas de 8 meses atrás)
#     9. tn_lag_9 (toneladas de 9 meses atrás)
#    10. tn_lag_10 (toneladas de 10 meses atrás)
#    11. tn_lag_11 (toneladas de 11 meses atrás)
#    12. tn_lag_12 (toneladas de 12 meses atrás)
#    13. tn_lag_13 (toneladas de 13 meses atrás)
#    14. tn_lag_14 (toneladas de 14 meses atrás)
#    15. tn_lag_15 (toneladas de 15 meses atrás)
#    16. tn_lag_16 (toneladas de 16 meses atrás)
#    17. tn_lag_17 (toneladas de 17 meses atrás)
#    18. tn_lag_18 (toneladas de 18 meses atrás)
#    19. tn_lag_19 (toneladas de 19 meses atrás)
#    20. tn_lag_20 (toneladas de 20 meses atrás)
#    21. tn_lag_21 (toneladas de 21 meses atrás)
#    22. tn_lag_22 (toneladas de 22 meses atrás)
#    23. tn_lag_23 (toneladas de 23 meses atrás)
#    24. tn_lag_24 (toneladas de 24 meses atrás)
#    25. tn_lag_25 (toneladas de 25 meses atrás)
#    26. tn_lag_26 (toneladas de 26 meses atrás)
#    27. tn_lag_27 (toneladas de 27 meses atrás)
#    28. tn_lag_28 (toneladas de 28 meses atrás)
#    29. tn_lag_29 (toneladas de 29 meses atrás)
#    30. tn_lag_30 (toneladas de 30 meses atrás)
#    31. tn_lag_31 (toneladas de 31 meses atrás)
#    32. tn_lag_32 (toneladas de 32 meses atrás)
#    33. tn_lag_33 (toneladas de 33 meses atrás)
#    34. tn_lag_34 (toneladas de 34 meses atrás)
#    35. tn_lag_35 (toneladas de 35 meses atrás)
#    36. tn_lag_36 (toneladas de 36 meses atrás)
#
# ✅ Features expandidas: Lags de toneladas desde 1 hasta 36 meses
# 🎯 Esto permite al modelo capturar patrones estacionales multi-anuales
# ✅ Información de productos agregada
# 📊 Dataset final: (22349, 85)
# 📈 Registros con target válido: 20789
#
# 📊 Estadísticas del target:
# count    20789.000000
# mean        50.931444
# std        127.140873
# min          0.000890
# 25%          3.009870
# 50%         11.928920
# 75%         36.636220
# max       2295.198320
# Name: target, dtype: float64

# %%
# 📋 Preparar datos para entrenamiento - GRANULARIDAD POR PRODUCTO
print("PREPARACIÓN DE DATOS DE ENTRENAMIENTO POR PRODUCTO")
print("="*60)

# Filtrar registros con target válido
train_data = data_combined[data_combined['target'].notna()].copy()
print(f"📊 Registros válidos para entrenamiento: {len(train_data)}")

# Seleccionar features para el modelo con granularidad por producto
feature_columns = [
    # Lags de ventas (tn) por producto - EXPANDIDO A 36 LAGS (3 AÑOS)
    'tn_lag_1', 'tn_lag_2', 'tn_lag_3', 'tn_lag_4', 'tn_lag_5', 'tn_lag_6',
    'tn_lag_7', 'tn_lag_8', 'tn_lag_9', 'tn_lag_10', 'tn_lag_11', 'tn_lag_12',
    'tn_lag_13', 'tn_lag_14', 'tn_lag_15', 'tn_lag_16', 'tn_lag_17', 'tn_lag_18',
    'tn_lag_19', 'tn_lag_20', 'tn_lag_21', 'tn_lag_22', 'tn_lag_23', 'tn_lag_24',
    'tn_lag_25', 'tn_lag_26', 'tn_lag_27', 'tn_lag_28', 'tn_lag_29', 'tn_lag_30',
    'tn_lag_31', 'tn_lag_32', 'tn_lag_33', 'tn_lag_34', 'tn_lag_35', 'tn_lag_36',
    
    # Lags de clientes por producto
    'num_customers_lag_1', 'num_customers_lag_2', 'num_customers_lag_3',
    
    # Lags de solicitudes por producto
    'total_request_tn_lag_1', 'total_request_tn_lag_2', 'total_request_tn_lag_3',
    
    # Lags de stock por producto
    'stock_tn_mean_lag_1', 'stock_tn_mean_lag_2', 'stock_tn_mean_lag_3',
    'stock_tn_sum_lag_1', 'stock_tn_sum_lag_2',
    
    # Features temporales
    'mes', 'trimestre', 'año',
    
    # Rolling features por producto
    'tn_rolling_mean_3', 'tn_rolling_mean_6',
    'tn_rolling_std_3', 'tn_rolling_std_6',
    
    # Features actuales por producto
    'num_customers', 'total_request_qty', 'total_request_tn',
    'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std',
    
    # Feature de diversidad de clientes
    'cant_clientes_unicos',
    
    # Feature de longevidad del producto
    'meses_vida',
    
    # Features de deltas temporales (expandidas hasta 36 meses)
    'delta_tn_1m', 'delta_tn_3m', 'delta_tn_6m', 'delta_tn_12m', 'delta_tn_18m', 'delta_tn_24m', 'delta_tn_30m', 'delta_tn_36m',
    'delta_tn_1m_pct', 'delta_tn_12m_pct', 'delta_tn_24m_pct', 'delta_tn_36m_pct'
]

# Verificar qué features existen
available_features = [col for col in feature_columns if col in train_data.columns]
missing_features = [col for col in feature_columns if col not in train_data.columns]

print(f"✅ Features disponibles: {len(available_features)}")
print(f"⚠️ Features faltantes: {len(missing_features)}")
if missing_features:
    print(f"Features faltantes: {missing_features}")

# Usar solo features disponibles
feature_columns = available_features

# Preparar X e y
X = train_data[feature_columns].copy()
y = train_data['target'].copy()

# Rellenar valores nulos con 0 (para lags iniciales y stocks faltantes)
X = X.fillna(0)

print(f"📊 Shape de X: {X.shape}")
print(f"📈 Shape de y: {y.shape}")
print(f"🔍 Valores nulos en X: {X.isnull().sum().sum()}")
print(f"🔍 Valores nulos en y: {y.isnull().sum()}")

# División temporal para validación (últimos períodos como validación)
train_data_sorted = train_data.sort_values('fecha')
split_date = train_data_sorted['fecha'].quantile(0.8)  # 80% entrenamiento, 20% validación

train_mask = train_data_sorted['fecha'] <= split_date
X_train = X.loc[train_mask]
X_val = X.loc[~train_mask] 
y_train = y.loc[train_mask]
y_val = y.loc[~train_mask]

print(f"\n📊 DIVISIÓN TEMPORAL:")
print(f"Entrenamiento: {len(X_train)} registros (hasta {split_date.strftime('%Y-%m')})")
print(f"Validación: {len(X_val)} registros (desde {split_date.strftime('%Y-%m')})")

print(f"\n🎯 PRODUCTOS EN ENTRENAMIENTO:")
productos_train = train_data.loc[train_mask, 'product_id'].nunique()
productos_val = train_data.loc[~train_mask, 'product_id'].nunique()
print(f"Productos únicos en entrenamiento: {productos_train}")
print(f"Productos únicos en validación: {productos_val}")

print(f"\nFeatures seleccionadas para granularidad por producto:")
for i, feat in enumerate(feature_columns):
    print(f"  {i+1:2d}. {feat}")
# Out:
# PREPARACIÓN DE DATOS DE ENTRENAMIENTO POR PRODUCTO
# ============================================================
# 📊 Registros válidos para entrenamiento: 20789
# ✅ Features disponibles: 74
# ⚠️ Features faltantes: 0
# 📊 Shape de X: (20789, 74)
# 📈 Shape de y: (20789,)
# 🔍 Valores nulos en X: 0
# 🔍 Valores nulos en y: 0
#
# 📊 DIVISIÓN TEMPORAL:
# Entrenamiento: 16970 registros (hasta 2019-05)
# Validación: 3819 registros (desde 2019-05)
#
# 🎯 PRODUCTOS EN ENTRENAMIENTO:
# Productos únicos en entrenamiento: 718
# Productos únicos en validación: 780
#
# Features seleccionadas para granularidad por producto:
#    1. tn_lag_1
#    2. tn_lag_2
#    3. tn_lag_3
#    4. tn_lag_4
#    5. tn_lag_5
#    6. tn_lag_6
#    7. tn_lag_7
#    8. tn_lag_8
#    9. tn_lag_9
#   10. tn_lag_10
#   11. tn_lag_11
#   12. tn_lag_12
#   13. tn_lag_13
#   14. tn_lag_14
#   15. tn_lag_15
#   16. tn_lag_16
#   17. tn_lag_17
#   18. tn_lag_18
#   19. tn_lag_19
#   20. tn_lag_20
#   21. tn_lag_21
#   22. tn_lag_22
#   23. tn_lag_23
#   24. tn_lag_24
#   25. tn_lag_25
#   26. tn_lag_26
#   27. tn_lag_27
#   28. tn_lag_28
#   29. tn_lag_29
#   30. tn_lag_30
#   31. tn_lag_31
#   32. tn_lag_32
#   33. tn_lag_33
#   34. tn_lag_34
#   35. tn_lag_35
#   36. tn_lag_36
#   37. num_customers_lag_1
#   38. num_customers_lag_2
#   39. num_customers_lag_3
#   40. total_request_tn_lag_1
#   41. total_request_tn_lag_2
#   42. total_request_tn_lag_3
#   43. stock_tn_mean_lag_1
#   44. stock_tn_mean_lag_2
#   45. stock_tn_mean_lag_3
#   46. stock_tn_sum_lag_1
#   47. stock_tn_sum_lag_2
#   48. mes
#   49. trimestre
#   50. año
#   51. tn_rolling_mean_3
#   52. tn_rolling_mean_6
#   53. tn_rolling_std_3
#   54. tn_rolling_std_6
#   55. num_customers
#   56. total_request_qty
#   57. total_request_tn
#   58. stock_tn_mean
#   59. stock_tn_sum
#   60. stock_tn_std
#   61. cant_clientes_unicos
#   62. meses_vida
#   63. delta_tn_1m
#   64. delta_tn_3m
#   65. delta_tn_6m
#   66. delta_tn_12m
#   67. delta_tn_18m
#   68. delta_tn_24m
#   69. delta_tn_30m
#   70. delta_tn_36m
#   71. delta_tn_1m_pct
#   72. delta_tn_12m_pct
#   73. delta_tn_24m_pct
#   74. delta_tn_36m_pct

# %%
# 📊 Resumen detallado de features con lags de toneladas expandidos
print("RESUMEN DETALLADO DE FEATURES CON LAGS EXPANDIDOS")
print("="*60)

# Agrupar features por categoría
tn_lags = [f for f in feature_columns if f.startswith('tn_lag_')]
customer_lags = [f for f in feature_columns if f.startswith('num_customers_lag_')]
request_lags = [f for f in feature_columns if f.startswith('total_request_tn_lag_')]
stock_lags = [f for f in feature_columns if f.startswith('stock_tn_')]
temporal_features = [f for f in feature_columns if f in ['mes', 'trimestre', 'año']]
rolling_features = [f for f in feature_columns if 'rolling' in f]
delta_features = [f for f in feature_columns if f.startswith('delta_tn_')]
current_features = [f for f in feature_columns if f in ['num_customers', 'total_request_qty', 'total_request_tn', 'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std', 'cant_clientes_unicos', 'meses_vida']]

print(f"📈 LAGS DE TONELADAS (EXPANDIDOS A 36): {len(tn_lags)} features")
tn_lags_sorted = sorted(tn_lags, key=lambda x: int(x.split('_')[-1]))
for i, lag in enumerate(tn_lags_sorted, 1):
    lag_num = lag.split('_')[-1]
    print(f"   {i:2d}. {lag} (ventas de {lag_num} mes{'es' if int(lag_num) > 1 else ''} atrás)")

print(f"\n👥 LAGS DE CLIENTES: {len(customer_lags)} features")
for i, lag in enumerate(customer_lags, 1):
    print(f"   {i}. {lag}")

print(f"\n📋 LAGS DE SOLICITUDES: {len(request_lags)} features")
for i, lag in enumerate(request_lags, 1):
    print(f"   {i}. {lag}")

print(f"\n📦 FEATURES DE STOCK: {len(stock_lags)} features")
for i, lag in enumerate(stock_lags, 1):
    print(f"   {i}. {lag}")

print(f"\n📅 FEATURES TEMPORALES: {len(temporal_features)} features")
for i, feat in enumerate(temporal_features, 1):
    print(f"   {i}. {feat}")

print(f"\n📊 FEATURES ROLLING: {len(rolling_features)} features")
for i, feat in enumerate(rolling_features, 1):
    print(f"   {i}. {feat}")

print(f"\n🔄 FEATURES ACTUALES: {len(current_features)} features")
for i, feat in enumerate(current_features, 1):
    print(f"   {i}. {feat}")

print(f"\n📈 FEATURES DE DELTAS TEMPORALES: {len(delta_features)} features")
for i, feat in enumerate(delta_features, 1):
    print(f"   {i}. {feat}")

print(f"\n✅ TOTAL DE FEATURES: {len(feature_columns)}")
print(f"🎯 MEJORA PRINCIPAL: Lags de toneladas expandidos de 12 → 36 features")
print(f"🔢 NUEVA FEATURE: cant_clientes_unicos (diversidad de base de clientes)")
print(f"🗓️ NUEVA FEATURE: meses_vida (longevidad del producto en el mercado)")
print(f"📈 NUEVAS FEATURES: deltas temporales (cambios vs períodos anteriores)")
print(f"📊 Esto permite capturar:")
print(f"   • Patrones estacionales anuales completos (12 meses)")
print(f"   • Patrones estacionales bi-anuales (24 meses)")
print(f"   • Patrones estacionales tri-anuales (36 meses)")
print(f"   • Tendencias de corto plazo (1-6 meses)")
print(f"   • Tendencias de mediano plazo (7-18 meses)")
print(f"   • Tendencias de largo plazo (19-36 meses)")
print(f"   • Ciclos multi-anuales y efectos estacionales profundos")
print(f"   • Diversidad de base de clientes por producto")
print(f"   • Madurez y longevidad del producto en el mercado")
print(f"   • Cambios y tendencias temporales vs períodos anteriores")
print(f"   • Aceleración/desaceleración de ventas")
print(f"   • Volatilidad y cambios porcentuales")
# Out:
# RESUMEN DETALLADO DE FEATURES CON LAGS EXPANDIDOS
# ============================================================
# 📈 LAGS DE TONELADAS (EXPANDIDOS A 36): 36 features
#     1. tn_lag_1 (ventas de 1 mes atrás)
#     2. tn_lag_2 (ventas de 2 meses atrás)
#     3. tn_lag_3 (ventas de 3 meses atrás)
#     4. tn_lag_4 (ventas de 4 meses atrás)
#     5. tn_lag_5 (ventas de 5 meses atrás)
#     6. tn_lag_6 (ventas de 6 meses atrás)
#     7. tn_lag_7 (ventas de 7 meses atrás)
#     8. tn_lag_8 (ventas de 8 meses atrás)
#     9. tn_lag_9 (ventas de 9 meses atrás)
#    10. tn_lag_10 (ventas de 10 meses atrás)
#    11. tn_lag_11 (ventas de 11 meses atrás)
#    12. tn_lag_12 (ventas de 12 meses atrás)
#    13. tn_lag_13 (ventas de 13 meses atrás)
#    14. tn_lag_14 (ventas de 14 meses atrás)
#    15. tn_lag_15 (ventas de 15 meses atrás)
#    16. tn_lag_16 (ventas de 16 meses atrás)
#    17. tn_lag_17 (ventas de 17 meses atrás)
#    18. tn_lag_18 (ventas de 18 meses atrás)
#    19. tn_lag_19 (ventas de 19 meses atrás)
#    20. tn_lag_20 (ventas de 20 meses atrás)
#    21. tn_lag_21 (ventas de 21 meses atrás)
#    22. tn_lag_22 (ventas de 22 meses atrás)
#    23. tn_lag_23 (ventas de 23 meses atrás)
#    24. tn_lag_24 (ventas de 24 meses atrás)
#    25. tn_lag_25 (ventas de 25 meses atrás)
#    26. tn_lag_26 (ventas de 26 meses atrás)
#    27. tn_lag_27 (ventas de 27 meses atrás)
#    28. tn_lag_28 (ventas de 28 meses atrás)
#    29. tn_lag_29 (ventas de 29 meses atrás)
#    30. tn_lag_30 (ventas de 30 meses atrás)
#    31. tn_lag_31 (ventas de 31 meses atrás)
#    32. tn_lag_32 (ventas de 32 meses atrás)
#    33. tn_lag_33 (ventas de 33 meses atrás)
#    34. tn_lag_34 (ventas de 34 meses atrás)
#    35. tn_lag_35 (ventas de 35 meses atrás)
#    36. tn_lag_36 (ventas de 36 meses atrás)
#
# 👥 LAGS DE CLIENTES: 3 features
#    1. num_customers_lag_1
#    2. num_customers_lag_2
#    3. num_customers_lag_3
#
# 📋 LAGS DE SOLICITUDES: 3 features
#    1. total_request_tn_lag_1
#    2. total_request_tn_lag_2
#    3. total_request_tn_lag_3
#
# 📦 FEATURES DE STOCK: 8 features
#    1. stock_tn_mean_lag_1
#    2. stock_tn_mean_lag_2
#    3. stock_tn_mean_lag_3
#    4. stock_tn_sum_lag_1
#    5. stock_tn_sum_lag_2
#    6. stock_tn_mean
#    7. stock_tn_sum
#    8. stock_tn_std
#
# 📅 FEATURES TEMPORALES: 3 features
#    1. mes
#    2. trimestre
#    3. año
#
# 📊 FEATURES ROLLING: 4 features
#    1. tn_rolling_mean_3
#    2. tn_rolling_mean_6
#    3. tn_rolling_std_3
#    4. tn_rolling_std_6
#
# 🔄 FEATURES ACTUALES: 8 features
#    1. num_customers
#    2. total_request_qty
#    3. total_request_tn
#    4. stock_tn_mean
#    5. stock_tn_sum
#    6. stock_tn_std
#    7. cant_clientes_unicos
#    8. meses_vida
#
# 📈 FEATURES DE DELTAS TEMPORALES: 12 features
#    1. delta_tn_1m
#    2. delta_tn_3m
#    3. delta_tn_6m
#    4. delta_tn_12m
#    5. delta_tn_18m
#    6. delta_tn_24m
#    7. delta_tn_30m
#    8. delta_tn_36m
#    9. delta_tn_1m_pct
#    10. delta_tn_12m_pct
#    11. delta_tn_24m_pct
#    12. delta_tn_36m_pct
#
# ✅ TOTAL DE FEATURES: 74
# 🎯 MEJORA PRINCIPAL: Lags de toneladas expandidos de 12 → 36 features
# 🔢 NUEVA FEATURE: cant_clientes_unicos (diversidad de base de clientes)
# 🗓️ NUEVA FEATURE: meses_vida (longevidad del producto en el mercado)
# 📈 NUEVAS FEATURES: deltas temporales (cambios vs períodos anteriores)
# 📊 Esto permite capturar:
#    • Patrones estacionales anuales completos (12 meses)
#    • Patrones estacionales bi-anuales (24 meses)
#    • Patrones estacionales tri-anuales (36 meses)
#    • Tendencias de corto plazo (1-6 meses)
#    • Tendencias de mediano plazo (7-18 meses)
#    • Tendencias de largo plazo (19-36 meses)
#    • Ciclos multi-anuales y efectos estacionales profundos
#    • Diversidad de base de clientes por producto
#    • Madurez y longevidad del producto en el mercado
#    • Cambios y tendencias temporales vs períodos anteriores
#    • Aceleración/desaceleración de ventas
#    • Volatilidad y cambios porcentuales

# %%
# 🔧 Optimización de hiperparámetros con Optuna para LINEAR_TREE
print("OPTIMIZACIÓN DE HIPERPARÁMETROS CON OPTUNA - LINEAR_TREE")
print("="*60)

# 🎲 Configurar semilla para Optuna y reproductibilidad
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

def objective(trial):
    """Función objetivo para optimización con Optuna incluyendo linear_tree"""
    
    # 🎲 Configurar semilla para cada trial
    np.random.seed(SEED + trial.number)
    random.seed(SEED + trial.number)
    
    # Sugerir hiperparámetros optimizados para linear_tree
    params = {
        'objective': 'regression',
        'metric': 'mae',
        'boosting_type': 'gbdt',
        'linear_tree': True,        # FIJO: Característica principal del modelo
        'lambda_l1': trial.suggest_float('lambda_l1', 0.0, 2.0),
        'lambda_l2': trial.suggest_float('lambda_l2', 0.0, 2.0),
        'num_leaves': trial.suggest_int('num_leaves', 20, 120),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.15, log=True),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 40),
        'max_bin': trial.suggest_int('max_bin', 100, 400),
        'verbose': -1,
        'random_state': SEED + trial.number,  # Semilla única por trial
        'bagging_seed': SEED + trial.number,  # Semilla para bagging
        'feature_fraction_seed': SEED + trial.number  # Semilla para feature selection
    }
    
    # Crear datasets de LightGBM
    train_dataset = lgb.Dataset(X_train, label=y_train)
    val_dataset = lgb.Dataset(X_val, label=y_val, reference=train_dataset)
    
    # Entrenar modelo con validación cruzada interna
    model = lgb.train(
        params,
        train_dataset,
        valid_sets=[val_dataset],
        num_boost_round=1000,
        callbacks=[
            lgb.early_stopping(stopping_rounds=50),
            lgb.log_evaluation(0)  # Silenciar logs
        ]
    )
    
    # Predecir en conjunto de validación
    y_pred = model.predict(X_val, num_iteration=model.best_iteration)
    
    # Calcular MAE como métrica a minimizar
    mae = mean_absolute_error(y_val, y_pred)
    
    return mae

# Crear estudio de optimización
print("🔍 Iniciando optimización de hiperparámetros con LINEAR_TREE...")
print(f"🎲 Usando semilla base {SEED} para reproducibilidad completa")

study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=SEED),  # Semilla para el sampler
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=10)
)

# Ejecutar optimización
n_trials = 700 # 500 Número de pruebas
print(f"🚀 Ejecutando {n_trials} trials de optimización para LINEAR_TREE...")
print(f"🎲 Cada trial usa semilla: SEED + trial_number para reproductibilidad")

study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

# Mostrar mejores parámetros
print(f"\n✅ Optimización completada!")
print(f"🏆 Mejor MAE encontrado: {study.best_value:.4f}")
print(f"\n🔧 HIPERPARÁMETROS OPTIMIZADOS PARA LINEAR_TREE:")
best_params = study.best_params
print("="*65)
print(f"   linear_tree:      True (FIJO - Característica principal) ⭐")
print(f"   lambda_l1:        {best_params['lambda_l1']:.4f}")
print(f"   lambda_l2:        {best_params['lambda_l2']:.4f}")
print(f"   num_leaves:       {best_params['num_leaves']}")
print(f"   feature_fraction: {best_params['feature_fraction']:.4f}")
print(f"   learning_rate:    {best_params['learning_rate']:.4f}")
print(f"   bagging_fraction: {best_params['bagging_fraction']:.4f}")
print(f"   bagging_freq:     {best_params['bagging_freq']}")
print(f"   min_child_samples: {best_params['min_child_samples']}")
print(f"   max_bin:          {best_params['max_bin']}")
print("="*65)

# Agregar parámetros fijos
best_params.update({
    'objective': 'regression',
    'metric': 'mae',
    'boosting_type': 'gbdt',
    'linear_tree': True,  # Mantener como característica principal
    'verbose': 0,
    'random_state': SEED,  # Semilla principal para el modelo final
    'bagging_seed': SEED,  # Semilla para bagging
    'feature_fraction_seed': SEED,  # Semilla para feature selection
    'data_seed': SEED  # Semilla para datos
})

print(f"\n📊 Resumen de la optimización:")
print(f"  Trials completados: {len(study.trials)}")
print(f"  Mejor trial: {study.best_trial.number}")
print(f"  Tiempo total: {sum(t.duration.total_seconds() for t in study.trials if t.duration):.1f} segundos")
print(f"🎲 Reproductibilidad garantizada con SEED={SEED}")
# Out:
# [I 2025-08-09 16:50:07,509] A new study created in memory with name: no-name-27377f56-05cc-411b-8ceb-e35723788e6e
# OPTIMIZACIÓN DE HIPERPARÁMETROS CON OPTUNA - LINEAR_TREE
# ============================================================
# 🔍 Iniciando optimización de hiperparámetros con LINEAR_TREE...
# 🎲 Usando semilla base 42 para reproducibilidad completa
# 🚀 Ejecutando 700 trials de optimización para LINEAR_TREE...
# 🎲 Cada trial usa semilla: SEED + trial_number para reproductibilidad
#   0%|          | 0/700 [00:00<?, ?it/s]
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [238]	valid_0's l1: 11.0863
# [I 2025-08-09 16:50:09,007] Trial 0 finished with value: 11.086303419454513 and parameters: {'lambda_l1': 0.749080237694725, 'lambda_l2': 1.9014286128198323, 'num_leaves': 93, 'feature_fraction': 0.8394633936788146, 'learning_rate': 0.015257808482051183, 'bagging_fraction': 0.662397808134481, 'bagging_freq': 1, 'min_child_samples': 36, 'max_bin': 280}. Best is trial 0 with value: 11.086303419454513.
# Early stopping, best iteration is:
# [238]	valid_0's l1: 11.0863
# [I 2025-08-09 16:50:09,007] Trial 0 finished with value: 11.086303419454513 and parameters: {'lambda_l1': 0.749080237694725, 'lambda_l2': 1.9014286128198323, 'num_leaves': 93, 'feature_fraction': 0.8394633936788146, 'learning_rate': 0.015257808482051183, 'bagging_fraction': 0.662397808134481, 'bagging_freq': 1, 'min_child_samples': 36, 'max_bin': 280}. Best is trial 0 with value: 11.086303419454513.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [124]	valid_0's l1: 13.6999
# [I 2025-08-09 16:50:10,185] Trial 1 finished with value: 13.699871974938358 and parameters: {'lambda_l1': 1.416145155592091, 'lambda_l2': 0.041168988591604894, 'num_leaves': 117, 'feature_fraction': 0.9329770563201687, 'learning_rate': 0.01777174904859463, 'bagging_fraction': 0.6727299868828402, 'bagging_freq': 2, 'min_child_samples': 15, 'max_bin': 257}. Best is trial 0 with value: 11.086303419454513.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [124]	valid_0's l1: 13.6999
# [I 2025-08-09 16:50:10,185] Trial 1 finished with value: 13.699871974938358 and parameters: {'lambda_l1': 1.416145155592091, 'lambda_l2': 0.041168988591604894, 'num_leaves': 117, 'feature_fraction': 0.9329770563201687, 'learning_rate': 0.01777174904859463, 'bagging_fraction': 0.6727299868828402, 'bagging_freq': 2, 'min_child_samples': 15, 'max_bin': 257}. Best is trial 0 with value: 11.086303419454513.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [172]	valid_0's l1: 10.7765
# [I 2025-08-09 16:50:11,097] Trial 2 finished with value: 10.776516904880966 and parameters: {'lambda_l1': 0.8638900372842315, 'lambda_l2': 0.5824582803960838, 'num_leaves': 81, 'feature_fraction': 0.6557975442608167, 'learning_rate': 0.022059149678071027, 'bagging_fraction': 0.7465447373174767, 'bagging_freq': 5, 'min_child_samples': 33, 'max_bin': 160}. Best is trial 2 with value: 10.776516904880966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [172]	valid_0's l1: 10.7765
# [I 2025-08-09 16:50:11,097] Trial 2 finished with value: 10.776516904880966 and parameters: {'lambda_l1': 0.8638900372842315, 'lambda_l2': 0.5824582803960838, 'num_leaves': 81, 'feature_fraction': 0.6557975442608167, 'learning_rate': 0.022059149678071027, 'bagging_fraction': 0.7465447373174767, 'bagging_freq': 5, 'min_child_samples': 33, 'max_bin': 160}. Best is trial 2 with value: 10.776516904880966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [340]	valid_0's l1: 10.6767
# [I 2025-08-09 16:50:11,831] Trial 3 finished with value: 10.676695385287566 and parameters: {'lambda_l1': 1.0284688768272232, 'lambda_l2': 1.184829137724085, 'num_leaves': 24, 'feature_fraction': 0.8430179407605753, 'learning_rate': 0.015869086642715014, 'bagging_fraction': 0.6260206371941118, 'bagging_freq': 10, 'min_child_samples': 39, 'max_bin': 343}. Best is trial 3 with value: 10.676695385287566.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [340]	valid_0's l1: 10.6767
# [I 2025-08-09 16:50:11,831] Trial 3 finished with value: 10.676695385287566 and parameters: {'lambda_l1': 1.0284688768272232, 'lambda_l2': 1.184829137724085, 'num_leaves': 24, 'feature_fraction': 0.8430179407605753, 'learning_rate': 0.015869086642715014, 'bagging_fraction': 0.6260206371941118, 'bagging_freq': 10, 'min_child_samples': 39, 'max_bin': 343}. Best is trial 3 with value: 10.676695385287566.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [253]	valid_0's l1: 10.9344
# [I 2025-08-09 16:50:13,220] Trial 4 finished with value: 10.934444197305961 and parameters: {'lambda_l1': 0.6092275383467414, 'lambda_l2': 0.19534422801276774, 'num_leaves': 89, 'feature_fraction': 0.7760609974958406, 'learning_rate': 0.013916438390377948, 'bagging_fraction': 0.798070764044508, 'bagging_freq': 1, 'min_child_samples': 37, 'max_bin': 177}. Best is trial 3 with value: 10.676695385287566.
# Early stopping, best iteration is:
# [253]	valid_0's l1: 10.9344
# [I 2025-08-09 16:50:13,220] Trial 4 finished with value: 10.934444197305961 and parameters: {'lambda_l1': 0.6092275383467414, 'lambda_l2': 0.19534422801276774, 'num_leaves': 89, 'feature_fraction': 0.7760609974958406, 'learning_rate': 0.013916438390377948, 'bagging_fraction': 0.798070764044508, 'bagging_freq': 1, 'min_child_samples': 37, 'max_bin': 177}. Best is trial 3 with value: 10.676695385287566.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [255]	valid_0's l1: 10.7049
# [I 2025-08-09 16:50:14,979] Trial 5 finished with value: 10.704945743270912 and parameters: {'lambda_l1': 1.325044568707964, 'lambda_l2': 0.6234221521788219, 'num_leaves': 72, 'feature_fraction': 0.8186841117373118, 'learning_rate': 0.016497027917250065, 'bagging_fraction': 0.9878338511058234, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 369}. Best is trial 3 with value: 10.676695385287566.
# Early stopping, best iteration is:
# [255]	valid_0's l1: 10.7049
# [I 2025-08-09 16:50:14,979] Trial 5 finished with value: 10.704945743270912 and parameters: {'lambda_l1': 1.325044568707964, 'lambda_l2': 0.6234221521788219, 'num_leaves': 72, 'feature_fraction': 0.8186841117373118, 'learning_rate': 0.016497027917250065, 'bagging_fraction': 0.9878338511058234, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 369}. Best is trial 3 with value: 10.676695385287566.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [232]	valid_0's l1: 12.5179
# [I 2025-08-09 16:50:15,761] Trial 6 finished with value: 12.517887653332592 and parameters: {'lambda_l1': 1.1957999576221703, 'lambda_l2': 1.8437484700462337, 'num_leaves': 28, 'feature_fraction': 0.6783931449676581, 'learning_rate': 0.011302939920362371, 'bagging_fraction': 0.7301321323053057, 'bagging_freq': 4, 'min_child_samples': 14, 'max_bin': 349}. Best is trial 3 with value: 10.676695385287566.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [232]	valid_0's l1: 12.5179
# [I 2025-08-09 16:50:15,761] Trial 6 finished with value: 12.517887653332592 and parameters: {'lambda_l1': 1.1957999576221703, 'lambda_l2': 1.8437484700462337, 'num_leaves': 28, 'feature_fraction': 0.6783931449676581, 'learning_rate': 0.011302939920362371, 'bagging_fraction': 0.7301321323053057, 'bagging_freq': 4, 'min_child_samples': 14, 'max_bin': 349}. Best is trial 3 with value: 10.676695385287566.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	valid_0's l1: 13.7599
# [I 2025-08-09 16:50:16,174] Trial 7 finished with value: 13.759857148407237 and parameters: {'lambda_l1': 0.7135066533871786, 'lambda_l2': 0.5618690193747615, 'num_leaves': 74, 'feature_fraction': 0.6563696899899051, 'learning_rate': 0.08779238696445962, 'bagging_fraction': 0.6298202574719083, 'bagging_freq': 10, 'min_child_samples': 32, 'max_bin': 159}. Best is trial 3 with value: 10.676695385287566.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	valid_0's l1: 13.7599
# [I 2025-08-09 16:50:16,174] Trial 7 finished with value: 13.759857148407237 and parameters: {'lambda_l1': 0.7135066533871786, 'lambda_l2': 0.5618690193747615, 'num_leaves': 74, 'feature_fraction': 0.6563696899899051, 'learning_rate': 0.08779238696445962, 'bagging_fraction': 0.6298202574719083, 'bagging_freq': 10, 'min_child_samples': 32, 'max_bin': 159}. Best is trial 3 with value: 10.676695385287566.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	valid_0's l1: 16.1028
# [I 2025-08-09 16:50:16,796] Trial 8 finished with value: 16.102756520849578 and parameters: {'lambda_l1': 0.011044234247204798, 'lambda_l2': 1.6309228569096683, 'num_leaves': 91, 'feature_fraction': 0.8916028672163949, 'learning_rate': 0.08073917605382007, 'bagging_fraction': 0.6296178606936361, 'bagging_freq': 4, 'min_child_samples': 9, 'max_bin': 359}. Best is trial 3 with value: 10.676695385287566.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	valid_0's l1: 16.1028
# [I 2025-08-09 16:50:16,796] Trial 8 finished with value: 16.102756520849578 and parameters: {'lambda_l1': 0.011044234247204798, 'lambda_l2': 1.6309228569096683, 'num_leaves': 91, 'feature_fraction': 0.8916028672163949, 'learning_rate': 0.08073917605382007, 'bagging_fraction': 0.6296178606936361, 'bagging_freq': 4, 'min_child_samples': 9, 'max_bin': 359}. Best is trial 3 with value: 10.676695385287566.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [219]	valid_0's l1: 10.4247
# [I 2025-08-09 16:50:17,437] Trial 9 finished with value: 10.424677844715966 and parameters: {'lambda_l1': 1.2465962536551158, 'lambda_l2': 0.6617960497052984, 'num_leaves': 26, 'feature_fraction': 0.7243929286862649, 'learning_rate': 0.02412377463500467, 'bagging_fraction': 0.8918424713352255, 'bagging_freq': 7, 'min_child_samples': 36, 'max_bin': 242}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [219]	valid_0's l1: 10.4247
# [I 2025-08-09 16:50:17,437] Trial 9 finished with value: 10.424677844715966 and parameters: {'lambda_l1': 1.2465962536551158, 'lambda_l2': 0.6617960497052984, 'num_leaves': 26, 'feature_fraction': 0.7243929286862649, 'learning_rate': 0.02412377463500467, 'bagging_fraction': 0.8918424713352255, 'bagging_freq': 7, 'min_child_samples': 36, 'max_bin': 242}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [125]	valid_0's l1: 10.8576
# [I 2025-08-09 16:50:18,224] Trial 10 finished with value: 10.857599112266064 and parameters: {'lambda_l1': 1.9148327305591635, 'lambda_l2': 1.1814508513534987, 'num_leaves': 45, 'feature_fraction': 0.7387403565626487, 'learning_rate': 0.03899622544867073, 'bagging_fraction': 0.9407901565064135, 'bagging_freq': 7, 'min_child_samples': 27, 'max_bin': 212}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [125]	valid_0's l1: 10.8576
# [I 2025-08-09 16:50:18,224] Trial 10 finished with value: 10.857599112266064 and parameters: {'lambda_l1': 1.9148327305591635, 'lambda_l2': 1.1814508513534987, 'num_leaves': 45, 'feature_fraction': 0.7387403565626487, 'learning_rate': 0.03899622544867073, 'bagging_fraction': 0.9407901565064135, 'bagging_freq': 7, 'min_child_samples': 27, 'max_bin': 212}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [164]	valid_0's l1: 10.7929
# [I 2025-08-09 16:50:18,750] Trial 11 finished with value: 10.792903200541016 and parameters: {'lambda_l1': 1.6895459953663647, 'lambda_l2': 1.1507674857412398, 'num_leaves': 20, 'feature_fraction': 0.7382135623933878, 'learning_rate': 0.03242221000947164, 'bagging_fraction': 0.8920339412764792, 'bagging_freq': 10, 'min_child_samples': 25, 'max_bin': 307}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [164]	valid_0's l1: 10.7929
# [I 2025-08-09 16:50:18,750] Trial 11 finished with value: 10.792903200541016 and parameters: {'lambda_l1': 1.6895459953663647, 'lambda_l2': 1.1507674857412398, 'num_leaves': 20, 'feature_fraction': 0.7382135623933878, 'learning_rate': 0.03242221000947164, 'bagging_fraction': 0.8920339412764792, 'bagging_freq': 10, 'min_child_samples': 25, 'max_bin': 307}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [127]	valid_0's l1: 12.1606
# [I 2025-08-09 16:50:19,366] Trial 12 finished with value: 12.160621855115197 and parameters: {'lambda_l1': 0.3130547305322815, 'lambda_l2': 0.9149122709140117, 'num_leaves': 46, 'feature_fraction': 0.9983624361463618, 'learning_rate': 0.030948018442204184, 'bagging_fraction': 0.8610724800899925, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 109}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [127]	valid_0's l1: 12.1606
# [I 2025-08-09 16:50:19,366] Trial 12 finished with value: 12.160621855115197 and parameters: {'lambda_l1': 0.3130547305322815, 'lambda_l2': 0.9149122709140117, 'num_leaves': 46, 'feature_fraction': 0.9983624361463618, 'learning_rate': 0.030948018442204184, 'bagging_fraction': 0.8610724800899925, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 109}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [112]	valid_0's l1: 10.8971
# [I 2025-08-09 16:50:19,953] Trial 13 finished with value: 10.89710652982641 and parameters: {'lambda_l1': 1.1063315287495243, 'lambda_l2': 1.3020316063431894, 'num_leaves': 39, 'feature_fraction': 0.6027390120971082, 'learning_rate': 0.04474820684779171, 'bagging_fraction': 0.8476671509616371, 'bagging_freq': 7, 'min_child_samples': 29, 'max_bin': 313}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [112]	valid_0's l1: 10.8971
# [I 2025-08-09 16:50:19,953] Trial 13 finished with value: 10.89710652982641 and parameters: {'lambda_l1': 1.1063315287495243, 'lambda_l2': 1.3020316063431894, 'num_leaves': 39, 'feature_fraction': 0.6027390120971082, 'learning_rate': 0.04474820684779171, 'bagging_fraction': 0.8476671509616371, 'bagging_freq': 7, 'min_child_samples': 29, 'max_bin': 313}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [148]	valid_0's l1: 12.2082
# [I 2025-08-09 16:50:20,745] Trial 14 finished with value: 12.20819104120944 and parameters: {'lambda_l1': 1.5626960162418277, 'lambda_l2': 0.8599673674829228, 'num_leaves': 56, 'feature_fraction': 0.8585163447841954, 'learning_rate': 0.023830316504677693, 'bagging_fraction': 0.8056239626685042, 'bagging_freq': 9, 'min_child_samples': 21, 'max_bin': 217}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [148]	valid_0's l1: 12.2082
# [I 2025-08-09 16:50:20,745] Trial 14 finished with value: 12.20819104120944 and parameters: {'lambda_l1': 1.5626960162418277, 'lambda_l2': 0.8599673674829228, 'num_leaves': 56, 'feature_fraction': 0.8585163447841954, 'learning_rate': 0.023830316504677693, 'bagging_fraction': 0.8056239626685042, 'bagging_freq': 9, 'min_child_samples': 21, 'max_bin': 217}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [88]	valid_0's l1: 11.1576
# [I 2025-08-09 16:50:21,183] Trial 15 finished with value: 11.157553644549338 and parameters: {'lambda_l1': 0.9771141123669267, 'lambda_l2': 1.573255743539997, 'num_leaves': 31, 'feature_fraction': 0.7750042889399262, 'learning_rate': 0.056650220734838636, 'bagging_fraction': 0.9310902778924434, 'bagging_freq': 6, 'min_child_samples': 21, 'max_bin': 394}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [88]	valid_0's l1: 11.1576
# [I 2025-08-09 16:50:21,183] Trial 15 finished with value: 11.157553644549338 and parameters: {'lambda_l1': 0.9771141123669267, 'lambda_l2': 1.573255743539997, 'num_leaves': 31, 'feature_fraction': 0.7750042889399262, 'learning_rate': 0.056650220734838636, 'bagging_fraction': 0.9310902778924434, 'bagging_freq': 6, 'min_child_samples': 21, 'max_bin': 394}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [366]	valid_0's l1: 10.9182
# [I 2025-08-09 16:50:23,057] Trial 16 finished with value: 10.918151635829629 and parameters: {'lambda_l1': 1.7554639505536664, 'lambda_l2': 0.35961624617346866, 'num_leaves': 53, 'feature_fraction': 0.910001998468094, 'learning_rate': 0.010194909823621897, 'bagging_fraction': 0.7228285608617194, 'bagging_freq': 9, 'min_child_samples': 31, 'max_bin': 300}. Best is trial 9 with value: 10.424677844715966.
# Early stopping, best iteration is:
# [366]	valid_0's l1: 10.9182
# [I 2025-08-09 16:50:23,057] Trial 16 finished with value: 10.918151635829629 and parameters: {'lambda_l1': 1.7554639505536664, 'lambda_l2': 0.35961624617346866, 'num_leaves': 53, 'feature_fraction': 0.910001998468094, 'learning_rate': 0.010194909823621897, 'bagging_fraction': 0.7228285608617194, 'bagging_freq': 9, 'min_child_samples': 31, 'max_bin': 300}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [159]	valid_0's l1: 10.9294
# [I 2025-08-09 16:50:23,438] Trial 17 finished with value: 10.929427334529434 and parameters: {'lambda_l1': 0.4265666712622447, 'lambda_l2': 1.4308309369747572, 'num_leaves': 22, 'feature_fraction': 0.716758406977976, 'learning_rate': 0.023080092180752233, 'bagging_fraction': 0.8043211940654708, 'bagging_freq': 6, 'min_child_samples': 40, 'max_bin': 235}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [159]	valid_0's l1: 10.9294
# [I 2025-08-09 16:50:23,438] Trial 17 finished with value: 10.929427334529434 and parameters: {'lambda_l1': 0.4265666712622447, 'lambda_l2': 1.4308309369747572, 'num_leaves': 22, 'feature_fraction': 0.716758406977976, 'learning_rate': 0.023080092180752233, 'bagging_fraction': 0.8043211940654708, 'bagging_freq': 6, 'min_child_samples': 40, 'max_bin': 235}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [95]	valid_0's l1: 10.8884
# [I 2025-08-09 16:50:24,229] Trial 18 finished with value: 10.888286920985744 and parameters: {'lambda_l1': 1.2193403838576484, 'lambda_l2': 0.775850910904858, 'num_leaves': 62, 'feature_fraction': 0.9610628594861361, 'learning_rate': 0.051350607889715835, 'bagging_fraction': 0.97239126287748, 'bagging_freq': 8, 'min_child_samples': 34, 'max_bin': 335}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [95]	valid_0's l1: 10.8884
# [I 2025-08-09 16:50:24,229] Trial 18 finished with value: 10.888286920985744 and parameters: {'lambda_l1': 1.2193403838576484, 'lambda_l2': 0.775850910904858, 'num_leaves': 62, 'feature_fraction': 0.9610628594861361, 'learning_rate': 0.051350607889715835, 'bagging_fraction': 0.97239126287748, 'bagging_freq': 8, 'min_child_samples': 34, 'max_bin': 335}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [167]	valid_0's l1: 10.4407
# [I 2025-08-09 16:50:24,853] Trial 19 finished with value: 10.440662716790722 and parameters: {'lambda_l1': 1.4419748699261006, 'lambda_l2': 1.035446817415704, 'num_leaves': 36, 'feature_fraction': 0.7935866424623772, 'learning_rate': 0.03037082947147069, 'bagging_fraction': 0.6030882676227594, 'bagging_freq': 10, 'min_child_samples': 25, 'max_bin': 260}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [167]	valid_0's l1: 10.4407
# [I 2025-08-09 16:50:24,853] Trial 19 finished with value: 10.440662716790722 and parameters: {'lambda_l1': 1.4419748699261006, 'lambda_l2': 1.035446817415704, 'num_leaves': 36, 'feature_fraction': 0.7935866424623772, 'learning_rate': 0.03037082947147069, 'bagging_fraction': 0.6030882676227594, 'bagging_freq': 10, 'min_child_samples': 25, 'max_bin': 260}. Best is trial 9 with value: 10.424677844715966.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	valid_0's l1: 10.4195
# [I 2025-08-09 16:50:25,124] Trial 20 finished with value: 10.419528345508267 and parameters: {'lambda_l1': 1.4968227083416805, 'lambda_l2': 0.3736467435838362, 'num_leaves': 36, 'feature_fraction': 0.7876730179249167, 'learning_rate': 0.13990724714864636, 'bagging_fraction': 0.8974309903023555, 'bagging_freq': 3, 'min_child_samples': 17, 'max_bin': 265}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	valid_0's l1: 10.4195
# [I 2025-08-09 16:50:25,124] Trial 20 finished with value: 10.419528345508267 and parameters: {'lambda_l1': 1.4968227083416805, 'lambda_l2': 0.3736467435838362, 'num_leaves': 36, 'feature_fraction': 0.7876730179249167, 'learning_rate': 0.13990724714864636, 'bagging_fraction': 0.8974309903023555, 'bagging_freq': 3, 'min_child_samples': 17, 'max_bin': 265}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	valid_0's l1: 11.0042
# [I 2025-08-09 16:50:25,395] Trial 21 finished with value: 11.004185278111024 and parameters: {'lambda_l1': 1.45234598046934, 'lambda_l2': 0.38990688791796524, 'num_leaves': 37, 'feature_fraction': 0.7851527700371244, 'learning_rate': 0.13958588489027327, 'bagging_fraction': 0.8912230190030176, 'bagging_freq': 3, 'min_child_samples': 16, 'max_bin': 269}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [31]	valid_0's l1: 11.0042
# [I 2025-08-09 16:50:25,395] Trial 21 finished with value: 11.004185278111024 and parameters: {'lambda_l1': 1.45234598046934, 'lambda_l2': 0.38990688791796524, 'num_leaves': 37, 'feature_fraction': 0.7851527700371244, 'learning_rate': 0.13958588489027327, 'bagging_fraction': 0.8912230190030176, 'bagging_freq': 3, 'min_child_samples': 16, 'max_bin': 269}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	valid_0's l1: 11.2202
# [I 2025-08-09 16:50:25,650] Trial 22 finished with value: 11.220165903880783 and parameters: {'lambda_l1': 1.645549664060559, 'lambda_l2': 0.7416726934287812, 'num_leaves': 35, 'feature_fraction': 0.7059009129937427, 'learning_rate': 0.1327776727929255, 'bagging_fraction': 0.9247703215150694, 'bagging_freq': 5, 'min_child_samples': 6, 'max_bin': 236}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	valid_0's l1: 11.2202
# [I 2025-08-09 16:50:25,650] Trial 22 finished with value: 11.220165903880783 and parameters: {'lambda_l1': 1.645549664060559, 'lambda_l2': 0.7416726934287812, 'num_leaves': 35, 'feature_fraction': 0.7059009129937427, 'learning_rate': 0.1327776727929255, 'bagging_fraction': 0.9247703215150694, 'bagging_freq': 5, 'min_child_samples': 6, 'max_bin': 236}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [152]	valid_0's l1: 11.31
# [I 2025-08-09 16:50:26,265] Trial 23 finished with value: 11.310022672452153 and parameters: {'lambda_l1': 1.8492947858638424, 'lambda_l2': 0.4184919891098533, 'num_leaves': 46, 'feature_fraction': 0.8008082121233768, 'learning_rate': 0.029679502419171895, 'bagging_fraction': 0.8479506995056052, 'bagging_freq': 3, 'min_child_samples': 19, 'max_bin': 197}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [152]	valid_0's l1: 11.31
# [I 2025-08-09 16:50:26,265] Trial 23 finished with value: 11.310022672452153 and parameters: {'lambda_l1': 1.8492947858638424, 'lambda_l2': 0.4184919891098533, 'num_leaves': 46, 'feature_fraction': 0.8008082121233768, 'learning_rate': 0.029679502419171895, 'bagging_fraction': 0.8479506995056052, 'bagging_freq': 3, 'min_child_samples': 19, 'max_bin': 197}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	valid_0's l1: 11.258
# [I 2025-08-09 16:50:26,643] Trial 24 finished with value: 11.257987412511188 and parameters: {'lambda_l1': 1.44314016441667, 'lambda_l2': 1.0124568672908776, 'num_leaves': 56, 'feature_fraction': 0.7486227209707547, 'learning_rate': 0.07192951998604487, 'bagging_fraction': 0.7649011048051568, 'bagging_freq': 7, 'min_child_samples': 24, 'max_bin': 283}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	valid_0's l1: 11.258
# [I 2025-08-09 16:50:26,643] Trial 24 finished with value: 11.257987412511188 and parameters: {'lambda_l1': 1.44314016441667, 'lambda_l2': 1.0124568672908776, 'num_leaves': 56, 'feature_fraction': 0.7486227209707547, 'learning_rate': 0.07192951998604487, 'bagging_fraction': 0.7649011048051568, 'bagging_freq': 7, 'min_child_samples': 24, 'max_bin': 283}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [59]	valid_0's l1: 11.1101
# [I 2025-08-09 16:50:26,929] Trial 25 finished with value: 11.110123031625116 and parameters: {'lambda_l1': 1.9919127450725649, 'lambda_l2': 0.19901044203694407, 'num_leaves': 32, 'feature_fraction': 0.8751253179724269, 'learning_rate': 0.09984264847651529, 'bagging_fraction': 0.8898987907453187, 'bagging_freq': 4, 'min_child_samples': 11, 'max_bin': 248}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [59]	valid_0's l1: 11.1101
# [I 2025-08-09 16:50:26,929] Trial 25 finished with value: 11.110123031625116 and parameters: {'lambda_l1': 1.9919127450725649, 'lambda_l2': 0.19901044203694407, 'num_leaves': 32, 'feature_fraction': 0.8751253179724269, 'learning_rate': 0.09984264847651529, 'bagging_fraction': 0.8898987907453187, 'bagging_freq': 4, 'min_child_samples': 11, 'max_bin': 248}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [57]	valid_0's l1: 11.2483
# [I 2025-08-09 16:50:27,233] Trial 26 finished with value: 11.248298787286597 and parameters: {'lambda_l1': 1.508476880376343, 'lambda_l2': 0.9678240777940329, 'num_leaves': 41, 'feature_fraction': 0.8123507314381528, 'learning_rate': 0.06220666445595884, 'bagging_fraction': 0.7019065770635395, 'bagging_freq': 9, 'min_child_samples': 18, 'max_bin': 221}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [57]	valid_0's l1: 11.2483
# [I 2025-08-09 16:50:27,233] Trial 26 finished with value: 11.248298787286597 and parameters: {'lambda_l1': 1.508476880376343, 'lambda_l2': 0.9678240777940329, 'num_leaves': 41, 'feature_fraction': 0.8123507314381528, 'learning_rate': 0.06220666445595884, 'bagging_fraction': 0.7019065770635395, 'bagging_freq': 9, 'min_child_samples': 18, 'max_bin': 221}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [118]	valid_0's l1: 10.7798
# [I 2025-08-09 16:50:27,995] Trial 27 finished with value: 10.779816391207218 and parameters: {'lambda_l1': 1.3188072498257077, 'lambda_l2': 0.7167979864725598, 'num_leaves': 65, 'feature_fraction': 0.7017607043203706, 'learning_rate': 0.038513054097920996, 'bagging_fraction': 0.9562006898676285, 'bagging_freq': 3, 'min_child_samples': 28, 'max_bin': 261}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [118]	valid_0's l1: 10.7798
# [I 2025-08-09 16:50:27,995] Trial 27 finished with value: 10.779816391207218 and parameters: {'lambda_l1': 1.3188072498257077, 'lambda_l2': 0.7167979864725598, 'num_leaves': 65, 'feature_fraction': 0.7017607043203706, 'learning_rate': 0.038513054097920996, 'bagging_fraction': 0.9562006898676285, 'bagging_freq': 3, 'min_child_samples': 28, 'max_bin': 261}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [153]	valid_0's l1: 10.6741
# [I 2025-08-09 16:50:28,432] Trial 28 finished with value: 10.67413245044353 and parameters: {'lambda_l1': 1.2476044708833745, 'lambda_l2': 0.48599571837826055, 'num_leaves': 28, 'feature_fraction': 0.7546281675357969, 'learning_rate': 0.027314173187189848, 'bagging_fraction': 0.8683200165742656, 'bagging_freq': 2, 'min_child_samples': 11, 'max_bin': 191}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [153]	valid_0's l1: 10.6741
# [I 2025-08-09 16:50:28,432] Trial 28 finished with value: 10.67413245044353 and parameters: {'lambda_l1': 1.2476044708833745, 'lambda_l2': 0.48599571837826055, 'num_leaves': 28, 'feature_fraction': 0.7546281675357969, 'learning_rate': 0.027314173187189848, 'bagging_fraction': 0.8683200165742656, 'bagging_freq': 2, 'min_child_samples': 11, 'max_bin': 191}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [119]	valid_0's l1: 12.8476
# [I 2025-08-09 16:50:29,407] Trial 29 finished with value: 12.847552225238871 and parameters: {'lambda_l1': 0.924594921700143, 'lambda_l2': 0.19913489693668196, 'num_leaves': 102, 'feature_fraction': 0.8362131967825226, 'learning_rate': 0.019919601927203885, 'bagging_fraction': 0.7749494182369303, 'bagging_freq': 1, 'min_child_samples': 35, 'max_bin': 288}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [119]	valid_0's l1: 12.8476
# [I 2025-08-09 16:50:29,407] Trial 29 finished with value: 12.847552225238871 and parameters: {'lambda_l1': 0.924594921700143, 'lambda_l2': 0.19913489693668196, 'num_leaves': 102, 'feature_fraction': 0.8362131967825226, 'learning_rate': 0.019919601927203885, 'bagging_fraction': 0.7749494182369303, 'bagging_freq': 1, 'min_child_samples': 35, 'max_bin': 288}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	valid_0's l1: 11.4918
# [I 2025-08-09 16:50:29,694] Trial 30 finished with value: 11.491817072768226 and parameters: {'lambda_l1': 1.5955146288755866, 'lambda_l2': 1.0590663534856477, 'num_leaves': 48, 'feature_fraction': 0.6375356427931783, 'learning_rate': 0.1115018176275733, 'bagging_fraction': 0.820637578903432, 'bagging_freq': 6, 'min_child_samples': 23, 'max_bin': 323}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	valid_0's l1: 11.4918
# [I 2025-08-09 16:50:29,694] Trial 30 finished with value: 11.491817072768226 and parameters: {'lambda_l1': 1.5955146288755866, 'lambda_l2': 1.0590663534856477, 'num_leaves': 48, 'feature_fraction': 0.6375356427931783, 'learning_rate': 0.1115018176275733, 'bagging_fraction': 0.820637578903432, 'bagging_freq': 6, 'min_child_samples': 23, 'max_bin': 323}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	valid_0's l1: 22.6209
# [I 2025-08-09 16:50:30,015] Trial 31 finished with value: 22.620865644205338 and parameters: {'lambda_l1': 1.2215407250436323, 'lambda_l2': 0.46098635909010105, 'num_leaves': 29, 'feature_fraction': 0.7594670515445586, 'learning_rate': 0.02617988872198857, 'bagging_fraction': 0.910627281212515, 'bagging_freq': 2, 'min_child_samples': 12, 'max_bin': 189}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	valid_0's l1: 22.6209
# [I 2025-08-09 16:50:30,015] Trial 31 finished with value: 22.620865644205338 and parameters: {'lambda_l1': 1.2215407250436323, 'lambda_l2': 0.46098635909010105, 'num_leaves': 29, 'feature_fraction': 0.7594670515445586, 'learning_rate': 0.02617988872198857, 'bagging_fraction': 0.910627281212515, 'bagging_freq': 2, 'min_child_samples': 12, 'max_bin': 189}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [40]	valid_0's l1: 18.8392
# [I 2025-08-09 16:50:30,223] Trial 32 finished with value: 18.83923840293493 and parameters: {'lambda_l1': 1.3457081931445587, 'lambda_l2': 0.09365431339478475, 'num_leaves': 25, 'feature_fraction': 0.7234457316897998, 'learning_rate': 0.0379107627949812, 'bagging_fraction': 0.8689143277988087, 'bagging_freq': 2, 'min_child_samples': 5, 'max_bin': 134}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [40]	valid_0's l1: 18.8392
# [I 2025-08-09 16:50:30,223] Trial 32 finished with value: 18.83923840293493 and parameters: {'lambda_l1': 1.3457081931445587, 'lambda_l2': 0.09365431339478475, 'num_leaves': 25, 'feature_fraction': 0.7234457316897998, 'learning_rate': 0.0379107627949812, 'bagging_fraction': 0.8689143277988087, 'bagging_freq': 2, 'min_child_samples': 5, 'max_bin': 134}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [162]	valid_0's l1: 16.6633
# [I 2025-08-09 16:50:31,557] Trial 33 finished with value: 16.663294361944864 and parameters: {'lambda_l1': 1.1189106943368414, 'lambda_l2': 0.5355362282081905, 'num_leaves': 119, 'feature_fraction': 0.7646944513303342, 'learning_rate': 0.019832843951602154, 'bagging_fraction': 0.8315272273802667, 'bagging_freq': 2, 'min_child_samples': 8, 'max_bin': 245}. Best is trial 20 with value: 10.419528345508267.
# Early stopping, best iteration is:
# [162]	valid_0's l1: 16.6633
# [I 2025-08-09 16:50:31,557] Trial 33 finished with value: 16.663294361944864 and parameters: {'lambda_l1': 1.1189106943368414, 'lambda_l2': 0.5355362282081905, 'num_leaves': 119, 'feature_fraction': 0.7646944513303342, 'learning_rate': 0.019832843951602154, 'bagging_fraction': 0.8315272273802667, 'bagging_freq': 2, 'min_child_samples': 8, 'max_bin': 245}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [127]	valid_0's l1: 10.9577
# [I 2025-08-09 16:50:31,865] Trial 34 finished with value: 10.957653241244437 and parameters: {'lambda_l1': 1.7447803571717282, 'lambda_l2': 0.3168981800462032, 'num_leaves': 20, 'feature_fraction': 0.6904426045703104, 'learning_rate': 0.029419668521667962, 'bagging_fraction': 0.8732976930833126, 'bagging_freq': 1, 'min_child_samples': 16, 'max_bin': 272}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [127]	valid_0's l1: 10.9577
# [I 2025-08-09 16:50:31,865] Trial 34 finished with value: 10.957653241244437 and parameters: {'lambda_l1': 1.7447803571717282, 'lambda_l2': 0.3168981800462032, 'num_leaves': 20, 'feature_fraction': 0.6904426045703104, 'learning_rate': 0.029419668521667962, 'bagging_fraction': 0.8732976930833126, 'bagging_freq': 1, 'min_child_samples': 16, 'max_bin': 272}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [330]	valid_0's l1: 10.969
# [I 2025-08-09 16:50:32,745] Trial 35 finished with value: 10.968963937947489 and parameters: {'lambda_l1': 1.3698580236858258, 'lambda_l2': 0.6099539818172746, 'num_leaves': 40, 'feature_fraction': 0.8266402508612634, 'learning_rate': 0.01324802903487283, 'bagging_fraction': 0.6553589313598337, 'bagging_freq': 5, 'min_child_samples': 13, 'max_bin': 208}. Best is trial 20 with value: 10.419528345508267.
# Early stopping, best iteration is:
# [330]	valid_0's l1: 10.969
# [I 2025-08-09 16:50:32,745] Trial 35 finished with value: 10.968963937947489 and parameters: {'lambda_l1': 1.3698580236858258, 'lambda_l2': 0.6099539818172746, 'num_leaves': 40, 'feature_fraction': 0.8266402508612634, 'learning_rate': 0.01324802903487283, 'bagging_fraction': 0.6553589313598337, 'bagging_freq': 5, 'min_child_samples': 13, 'max_bin': 208}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [238]	valid_0's l1: 11.2021
# [I 2025-08-09 16:50:33,369] Trial 36 finished with value: 11.202091963131684 and parameters: {'lambda_l1': 1.0694344448608666, 'lambda_l2': 0.29173391269905713, 'num_leaves': 34, 'feature_fraction': 0.7928335355503021, 'learning_rate': 0.018626974710166985, 'bagging_fraction': 0.9996092846350779, 'bagging_freq': 3, 'min_child_samples': 17, 'max_bin': 176}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [238]	valid_0's l1: 11.2021
# [I 2025-08-09 16:50:33,369] Trial 36 finished with value: 11.202091963131684 and parameters: {'lambda_l1': 1.0694344448608666, 'lambda_l2': 0.29173391269905713, 'num_leaves': 34, 'feature_fraction': 0.7928335355503021, 'learning_rate': 0.018626974710166985, 'bagging_fraction': 0.9996092846350779, 'bagging_freq': 3, 'min_child_samples': 17, 'max_bin': 176}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [213]	valid_0's l1: 10.862
# [I 2025-08-09 16:50:33,940] Trial 37 finished with value: 10.86203001816806 and parameters: {'lambda_l1': 0.8494238480999979, 'lambda_l2': 0.00751671445666896, 'num_leaves': 27, 'feature_fraction': 0.7282977034916852, 'learning_rate': 0.025307083742830527, 'bagging_fraction': 0.9025368564291671, 'bagging_freq': 2, 'min_child_samples': 10, 'max_bin': 230}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [213]	valid_0's l1: 10.862
# [I 2025-08-09 16:50:33,940] Trial 37 finished with value: 10.86203001816806 and parameters: {'lambda_l1': 0.8494238480999979, 'lambda_l2': 0.00751671445666896, 'num_leaves': 27, 'feature_fraction': 0.7282977034916852, 'learning_rate': 0.025307083742830527, 'bagging_fraction': 0.9025368564291671, 'bagging_freq': 2, 'min_child_samples': 10, 'max_bin': 230}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [52]	valid_0's l1: 13.5452
# [I 2025-08-09 16:50:34,504] Trial 38 finished with value: 13.545244279819556 and parameters: {'lambda_l1': 1.2784498588128133, 'lambda_l2': 0.6951514065390025, 'num_leaves': 110, 'feature_fraction': 0.803081882931757, 'learning_rate': 0.04336893030852375, 'bagging_fraction': 0.9510985146144737, 'bagging_freq': 4, 'min_child_samples': 20, 'max_bin': 153}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [52]	valid_0's l1: 13.5452
# [I 2025-08-09 16:50:34,504] Trial 38 finished with value: 13.545244279819556 and parameters: {'lambda_l1': 1.2784498588128133, 'lambda_l2': 0.6951514065390025, 'num_leaves': 110, 'feature_fraction': 0.803081882931757, 'learning_rate': 0.04336893030852375, 'bagging_fraction': 0.9510985146144737, 'bagging_freq': 4, 'min_child_samples': 20, 'max_bin': 153}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [224]	valid_0's l1: 15.2583
# [I 2025-08-09 16:50:35,667] Trial 39 finished with value: 15.258332965417353 and parameters: {'lambda_l1': 1.4930967064291787, 'lambda_l2': 0.83135957700803, 'num_leaves': 80, 'feature_fraction': 0.6667066375240855, 'learning_rate': 0.014780316608124306, 'bagging_fraction': 0.6006043036968373, 'bagging_freq': 1, 'min_child_samples': 37, 'max_bin': 255}. Best is trial 20 with value: 10.419528345508267.
# Early stopping, best iteration is:
# [224]	valid_0's l1: 15.2583
# [I 2025-08-09 16:50:35,667] Trial 39 finished with value: 15.258332965417353 and parameters: {'lambda_l1': 1.4930967064291787, 'lambda_l2': 0.83135957700803, 'num_leaves': 80, 'feature_fraction': 0.6667066375240855, 'learning_rate': 0.014780316608124306, 'bagging_fraction': 0.6006043036968373, 'bagging_freq': 1, 'min_child_samples': 37, 'max_bin': 255}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [95]	valid_0's l1: 11.7198
# [I 2025-08-09 16:50:36,193] Trial 40 finished with value: 11.719754758521036 and parameters: {'lambda_l1': 0.7798940317251687, 'lambda_l2': 0.5372209650665299, 'num_leaves': 53, 'feature_fraction': 0.8436473264896194, 'learning_rate': 0.03456832721742936, 'bagging_fraction': 0.7798472377239946, 'bagging_freq': 5, 'min_child_samples': 26, 'max_bin': 288}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [95]	valid_0's l1: 11.7198
# [I 2025-08-09 16:50:36,193] Trial 40 finished with value: 11.719754758521036 and parameters: {'lambda_l1': 0.7798940317251687, 'lambda_l2': 0.5372209650665299, 'num_leaves': 53, 'feature_fraction': 0.8436473264896194, 'learning_rate': 0.03456832721742936, 'bagging_fraction': 0.7798472377239946, 'bagging_freq': 5, 'min_child_samples': 26, 'max_bin': 288}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [294]	valid_0's l1: 10.8791
# [I 2025-08-09 16:50:36,871] Trial 41 finished with value: 10.879078598265325 and parameters: {'lambda_l1': 1.039591550107623, 'lambda_l2': 1.2245234736543495, 'num_leaves': 25, 'feature_fraction': 0.8610790164133377, 'learning_rate': 0.015885221027104407, 'bagging_fraction': 0.6188515168027624, 'bagging_freq': 10, 'min_child_samples': 30, 'max_bin': 392}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [294]	valid_0's l1: 10.8791
# [I 2025-08-09 16:50:36,871] Trial 41 finished with value: 10.879078598265325 and parameters: {'lambda_l1': 1.039591550107623, 'lambda_l2': 1.2245234736543495, 'num_leaves': 25, 'feature_fraction': 0.8610790164133377, 'learning_rate': 0.015885221027104407, 'bagging_fraction': 0.6188515168027624, 'bagging_freq': 10, 'min_child_samples': 30, 'max_bin': 392}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [291]	valid_0's l1: 10.9779
# [I 2025-08-09 16:50:37,587] Trial 42 finished with value: 10.977904291296717 and parameters: {'lambda_l1': 1.198056517445817, 'lambda_l2': 1.2898268078018258, 'num_leaves': 29, 'feature_fraction': 0.7768063766376752, 'learning_rate': 0.012234250807236868, 'bagging_fraction': 0.6456716063491598, 'bagging_freq': 10, 'min_child_samples': 33, 'max_bin': 375}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [291]	valid_0's l1: 10.9779
# [I 2025-08-09 16:50:37,587] Trial 42 finished with value: 10.977904291296717 and parameters: {'lambda_l1': 1.198056517445817, 'lambda_l2': 1.2898268078018258, 'num_leaves': 29, 'feature_fraction': 0.7768063766376752, 'learning_rate': 0.012234250807236868, 'bagging_fraction': 0.6456716063491598, 'bagging_freq': 10, 'min_child_samples': 33, 'max_bin': 375}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [173]	valid_0's l1: 12.2427
# [I 2025-08-09 16:50:38,144] Trial 43 finished with value: 12.242690198012301 and parameters: {'lambda_l1': 0.6927716150253354, 'lambda_l2': 1.0542989540922982, 'num_leaves': 35, 'feature_fraction': 0.8209056461592045, 'learning_rate': 0.018031007137252492, 'bagging_fraction': 0.6765762365273227, 'bagging_freq': 9, 'min_child_samples': 14, 'max_bin': 343}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [173]	valid_0's l1: 12.2427
# [I 2025-08-09 16:50:38,144] Trial 43 finished with value: 12.242690198012301 and parameters: {'lambda_l1': 0.6927716150253354, 'lambda_l2': 1.0542989540922982, 'num_leaves': 35, 'feature_fraction': 0.8209056461592045, 'learning_rate': 0.018031007137252492, 'bagging_fraction': 0.6765762365273227, 'bagging_freq': 9, 'min_child_samples': 14, 'max_bin': 343}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [193]	valid_0's l1: 10.7135
# [I 2025-08-09 16:50:38,546] Trial 44 finished with value: 10.71348376594084 and parameters: {'lambda_l1': 1.1388834477231748, 'lambda_l2': 1.84249661334233, 'num_leaves': 23, 'feature_fraction': 0.7512098354874253, 'learning_rate': 0.02167566082724876, 'bagging_fraction': 0.6812636906180496, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 197}. Best is trial 20 with value: 10.419528345508267.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [193]	valid_0's l1: 10.7135
# ...
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [187]	valid_0's l1: 10.3371
# [I 2025-08-09 16:56:32,211] Trial 686 finished with value: 10.337147147778927 and parameters: {'lambda_l1': 0.4374600867089157, 'lambda_l2': 0.8381999299659725, 'num_leaves': 30, 'feature_fraction': 0.9036447471093194, 'learning_rate': 0.026180458437621724, 'bagging_fraction': 0.7766885530792172, 'bagging_freq': 4, 'min_child_samples': 39, 'max_bin': 197}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [64]	valid_0's l1: 12.2534
# [I 2025-08-09 16:56:32,526] Trial 687 finished with value: 12.253383430646892 and parameters: {'lambda_l1': 0.602377221273127, 'lambda_l2': 0.4225951748564176, 'num_leaves': 28, 'feature_fraction': 0.9400708304142233, 'learning_rate': 0.042254508081191265, 'bagging_fraction': 0.6221451262514739, 'bagging_freq': 5, 'min_child_samples': 28, 'max_bin': 228}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [64]	valid_0's l1: 12.2534
# [I 2025-08-09 16:56:32,526] Trial 687 finished with value: 12.253383430646892 and parameters: {'lambda_l1': 0.602377221273127, 'lambda_l2': 0.4225951748564176, 'num_leaves': 28, 'feature_fraction': 0.9400708304142233, 'learning_rate': 0.042254508081191265, 'bagging_fraction': 0.6221451262514739, 'bagging_freq': 5, 'min_child_samples': 28, 'max_bin': 228}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [145]	valid_0's l1: 10.6065
# [I 2025-08-09 16:56:32,980] Trial 688 finished with value: 10.606503118348998 and parameters: {'lambda_l1': 0.46313041589155635, 'lambda_l2': 0.8826660437994669, 'num_leaves': 24, 'feature_fraction': 0.9308957528821171, 'learning_rate': 0.02868520587885502, 'bagging_fraction': 0.9371921824747542, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 240}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [145]	valid_0's l1: 10.6065
# [I 2025-08-09 16:56:32,980] Trial 688 finished with value: 10.606503118348998 and parameters: {'lambda_l1': 0.46313041589155635, 'lambda_l2': 0.8826660437994669, 'num_leaves': 24, 'feature_fraction': 0.9308957528821171, 'learning_rate': 0.02868520587885502, 'bagging_fraction': 0.9371921824747542, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 240}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [273]	valid_0's l1: 10.3976
# [I 2025-08-09 16:56:33,723] Trial 689 finished with value: 10.397639272133542 and parameters: {'lambda_l1': 0.5765135114950055, 'lambda_l2': 0.9501300816029746, 'num_leaves': 26, 'feature_fraction': 0.9023281218709109, 'learning_rate': 0.023014996704449658, 'bagging_fraction': 0.9485839078875833, 'bagging_freq': 4, 'min_child_samples': 39, 'max_bin': 216}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [273]	valid_0's l1: 10.3976
# [I 2025-08-09 16:56:33,723] Trial 689 finished with value: 10.397639272133542 and parameters: {'lambda_l1': 0.5765135114950055, 'lambda_l2': 0.9501300816029746, 'num_leaves': 26, 'feature_fraction': 0.9023281218709109, 'learning_rate': 0.023014996704449658, 'bagging_fraction': 0.9485839078875833, 'bagging_freq': 4, 'min_child_samples': 39, 'max_bin': 216}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [224]	valid_0's l1: 10.5275
# [I 2025-08-09 16:56:34,315] Trial 690 finished with value: 10.527490204671205 and parameters: {'lambda_l1': 0.4116475377054327, 'lambda_l2': 0.9204667306578523, 'num_leaves': 22, 'feature_fraction': 0.9206909372793464, 'learning_rate': 0.02090820246250718, 'bagging_fraction': 0.9142829557472354, 'bagging_freq': 5, 'min_child_samples': 39, 'max_bin': 235}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [224]	valid_0's l1: 10.5275
# [I 2025-08-09 16:56:34,315] Trial 690 finished with value: 10.527490204671205 and parameters: {'lambda_l1': 0.4116475377054327, 'lambda_l2': 0.9204667306578523, 'num_leaves': 22, 'feature_fraction': 0.9206909372793464, 'learning_rate': 0.02090820246250718, 'bagging_fraction': 0.9142829557472354, 'bagging_freq': 5, 'min_child_samples': 39, 'max_bin': 235}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [153]	valid_0's l1: 10.3222
# [I 2025-08-09 16:56:34,910] Trial 691 finished with value: 10.322246960049661 and parameters: {'lambda_l1': 0.5916286872149681, 'lambda_l2': 0.7793442432250302, 'num_leaves': 34, 'feature_fraction': 0.9563597911914825, 'learning_rate': 0.030836514135383273, 'bagging_fraction': 0.8747214669674827, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 225}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [153]	valid_0's l1: 10.3222
# [I 2025-08-09 16:56:34,910] Trial 691 finished with value: 10.322246960049661 and parameters: {'lambda_l1': 0.5916286872149681, 'lambda_l2': 0.7793442432250302, 'num_leaves': 34, 'feature_fraction': 0.9563597911914825, 'learning_rate': 0.030836514135383273, 'bagging_fraction': 0.8747214669674827, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 225}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [363]	valid_0's l1: 10.5081
# [I 2025-08-09 16:56:36,019] Trial 692 finished with value: 10.508056887546301 and parameters: {'lambda_l1': 0.5715036448345305, 'lambda_l2': 0.7220774841422573, 'num_leaves': 36, 'feature_fraction': 0.9533990633560621, 'learning_rate': 0.011185539967932397, 'bagging_fraction': 0.8671770935354827, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 224}. Best is trial 571 with value: 10.176249643299561.
# Early stopping, best iteration is:
# [363]	valid_0's l1: 10.5081
# [I 2025-08-09 16:56:36,019] Trial 692 finished with value: 10.508056887546301 and parameters: {'lambda_l1': 0.5715036448345305, 'lambda_l2': 0.7220774841422573, 'num_leaves': 36, 'feature_fraction': 0.9533990633560621, 'learning_rate': 0.011185539967932397, 'bagging_fraction': 0.8671770935354827, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 224}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [178]	valid_0's l1: 13.7482
# [I 2025-08-09 16:56:36,682] Trial 693 finished with value: 13.74819870686095 and parameters: {'lambda_l1': 0.5225387911770243, 'lambda_l2': 0.8231647881059496, 'num_leaves': 33, 'feature_fraction': 0.9726958294810408, 'learning_rate': 0.03065864180647188, 'bagging_fraction': 0.8797495989103608, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 229}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [178]	valid_0's l1: 13.7482
# [I 2025-08-09 16:56:36,682] Trial 693 finished with value: 13.74819870686095 and parameters: {'lambda_l1': 0.5225387911770243, 'lambda_l2': 0.8231647881059496, 'num_leaves': 33, 'feature_fraction': 0.9726958294810408, 'learning_rate': 0.03065864180647188, 'bagging_fraction': 0.8797495989103608, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 229}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [107]	valid_0's l1: 10.7534
# [I 2025-08-09 16:56:37,135] Trial 694 finished with value: 10.753400765582253 and parameters: {'lambda_l1': 0.5445347677501057, 'lambda_l2': 0.7680559396494477, 'num_leaves': 33, 'feature_fraction': 0.9561138273723094, 'learning_rate': 0.03362656234669109, 'bagging_fraction': 0.8785768678830793, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 220}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [107]	valid_0's l1: 10.7534
# [I 2025-08-09 16:56:37,135] Trial 694 finished with value: 10.753400765582253 and parameters: {'lambda_l1': 0.5445347677501057, 'lambda_l2': 0.7680559396494477, 'num_leaves': 33, 'feature_fraction': 0.9561138273723094, 'learning_rate': 0.03362656234669109, 'bagging_fraction': 0.8785768678830793, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 220}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [156]	valid_0's l1: 10.4202
# [I 2025-08-09 16:56:37,573] Trial 695 finished with value: 10.420223544145394 and parameters: {'lambda_l1': 0.39764582525483916, 'lambda_l2': 0.6933578360549824, 'num_leaves': 20, 'feature_fraction': 0.9668034246417658, 'learning_rate': 0.03141812187653956, 'bagging_fraction': 0.8858194908082767, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 208}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [156]	valid_0's l1: 10.4202
# [I 2025-08-09 16:56:37,573] Trial 695 finished with value: 10.420223544145394 and parameters: {'lambda_l1': 0.39764582525483916, 'lambda_l2': 0.6933578360549824, 'num_leaves': 20, 'feature_fraction': 0.9668034246417658, 'learning_rate': 0.03141812187653956, 'bagging_fraction': 0.8858194908082767, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 208}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [138]	valid_0's l1: 10.8576
# [I 2025-08-09 16:56:38,111] Trial 696 finished with value: 10.857565803848223 and parameters: {'lambda_l1': 0.5814696255977463, 'lambda_l2': 0.7446445694977706, 'num_leaves': 33, 'feature_fraction': 0.9613833512653636, 'learning_rate': 0.029441250096110837, 'bagging_fraction': 0.8666098424124886, 'bagging_freq': 4, 'min_child_samples': 39, 'max_bin': 213}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [138]	valid_0's l1: 10.8576
# [I 2025-08-09 16:56:38,111] Trial 696 finished with value: 10.857565803848223 and parameters: {'lambda_l1': 0.5814696255977463, 'lambda_l2': 0.7446445694977706, 'num_leaves': 33, 'feature_fraction': 0.9613833512653636, 'learning_rate': 0.029441250096110837, 'bagging_fraction': 0.8666098424124886, 'bagging_freq': 4, 'min_child_samples': 39, 'max_bin': 213}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [101]	valid_0's l1: 11.1543
# [I 2025-08-09 16:56:39,118] Trial 697 finished with value: 11.154316548906259 and parameters: {'lambda_l1': 0.4747754655698963, 'lambda_l2': 0.13997392047981227, 'num_leaves': 103, 'feature_fraction': 0.9498926729148196, 'learning_rate': 0.033763679884616295, 'bagging_fraction': 0.8776848833920246, 'bagging_freq': 4, 'min_child_samples': 39, 'max_bin': 231}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [101]	valid_0's l1: 11.1543
# [I 2025-08-09 16:56:39,118] Trial 697 finished with value: 11.154316548906259 and parameters: {'lambda_l1': 0.4747754655698963, 'lambda_l2': 0.13997392047981227, 'num_leaves': 103, 'feature_fraction': 0.9498926729148196, 'learning_rate': 0.033763679884616295, 'bagging_fraction': 0.8776848833920246, 'bagging_freq': 4, 'min_child_samples': 39, 'max_bin': 231}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [142]	valid_0's l1: 10.8399
# [I 2025-08-09 16:56:39,838] Trial 698 finished with value: 10.839878914674166 and parameters: {'lambda_l1': 0.5614804776527056, 'lambda_l2': 0.7934007336428488, 'num_leaves': 47, 'feature_fraction': 0.9436865315594563, 'learning_rate': 0.03036293132826088, 'bagging_fraction': 0.8603140511830735, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 224}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [142]	valid_0's l1: 10.8399
# [I 2025-08-09 16:56:39,838] Trial 698 finished with value: 10.839878914674166 and parameters: {'lambda_l1': 0.5614804776527056, 'lambda_l2': 0.7934007336428488, 'num_leaves': 47, 'feature_fraction': 0.9436865315594563, 'learning_rate': 0.03036293132826088, 'bagging_fraction': 0.8603140511830735, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 224}. Best is trial 571 with value: 10.176249643299561.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [148]	valid_0's l1: 10.6511
# [I 2025-08-09 16:56:40,412] Trial 699 finished with value: 10.651115887178397 and parameters: {'lambda_l1': 0.6348371094326638, 'lambda_l2': 0.8472938768828799, 'num_leaves': 34, 'feature_fraction': 0.925392986763445, 'learning_rate': 0.029107866085422075, 'bagging_fraction': 0.8240380284713184, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 218}. Best is trial 571 with value: 10.176249643299561.
#
# ✅ Optimización completada!
# 🏆 Mejor MAE encontrado: 10.1762
#
# 🔧 HIPERPARÁMETROS OPTIMIZADOS PARA LINEAR_TREE:
# =================================================================
#    linear_tree:      True (FIJO - Característica principal) ⭐
#    lambda_l1:        1.4374
#    lambda_l2:        1.0068
#    num_leaves:       20
#    feature_fraction: 0.7340
#    learning_rate:    0.0199
#    bagging_fraction: 0.9767
#    bagging_freq:     4
#    min_child_samples: 38
#    max_bin:          232
# =================================================================
#
# 📊 Resumen de la optimización:
#   Trials completados: 700
#   Mejor trial: 571
#   Tiempo total: 391.6 segundos
# 🎲 Reproductibilidad garantizada con SEED=42
# Early stopping, best iteration is:
# [148]	valid_0's l1: 10.6511
# [I 2025-08-09 16:56:40,412] Trial 699 finished with value: 10.651115887178397 and parameters: {'lambda_l1': 0.6348371094326638, 'lambda_l2': 0.8472938768828799, 'num_leaves': 34, 'feature_fraction': 0.925392986763445, 'learning_rate': 0.029107866085422075, 'bagging_fraction': 0.8240380284713184, 'bagging_freq': 4, 'min_child_samples': 40, 'max_bin': 218}. Best is trial 571 with value: 10.176249643299561.
#
# ✅ Optimización completada!
# 🏆 Mejor MAE encontrado: 10.1762
#
# 🔧 HIPERPARÁMETROS OPTIMIZADOS PARA LINEAR_TREE:
# =================================================================
#    linear_tree:      True (FIJO - Característica principal) ⭐
#    lambda_l1:        1.4374
#    lambda_l2:        1.0068
#    num_leaves:       20
#    feature_fraction: 0.7340
#    learning_rate:    0.0199
#    bagging_fraction: 0.9767
#    bagging_freq:     4
#    min_child_samples: 38
#    max_bin:          232
# =================================================================
#
# 📊 Resumen de la optimización:
#   Trials completados: 700
#   Mejor trial: 571
#   Tiempo total: 391.6 segundos
# 🎲 Reproductibilidad garantizada con SEED=42

# %%
# 🚀 Entrenar 50 modelos LightGBM con diferentes semillas - LINEAR_TREE
print("ENTRENAMIENTO DE 50 MODELOS LIGHTGBM CON DIFERENTES SEMILLAS - LINEAR_TREE")
print("="*80)

# 🎲 Definir las 50 semillas diferentes (20 originales + 30 nuevas)
semillas = [42, 109, 113, 151, 167, 179, 193, 199, 211, 241,
            263, 281, 307, 331, 367, 401, 439, 487, 563, 617,
            40009, 42043, 45007, 47017, 50021, 52027, 55001, 57037, 60013, 62003,
            65029, 67003, 70001, 72019, 75011, 77003, 80021, 82009, 85009, 87011,
            90001, 92003, 95003, 97007, 99013, 99991, 99929, 99881, 99733, 99667]

print(f"🔢 Usando {len(semillas)} semillas diferentes para entrenamiento:")
print(f"   Semillas originales (20): {semillas[:20]}")
print(f"   Semillas nuevas (30): {semillas[20:]}")
print(f"   Total de modelos: {len(semillas)}")

# Usar los mejores parámetros encontrados por Optuna
lgb_params_base = best_params.copy()

# Listas para almacenar modelos y métricas
modelos = []
metricas = []
predicciones_val = []
predicciones_finales = []

# 💾 Crear directorio para guardar los modelos
import os
import pickle
modelos_dir = 'data/modelos_entrenados/v3'
os.makedirs(modelos_dir, exist_ok=True)

print(f"\n💾 Los modelos se guardarán en: {modelos_dir}/")
print(f"\n🚀 Iniciando entrenamiento de {len(semillas)} modelos...")

for i, seed in enumerate(semillas, 1):
    print(f"\n{'='*60}")
    print(f"🎯 ENTRENANDO MODELO {i}/{len(semillas)} - SEMILLA: {seed}")
    print(f"{'='*60}")
    
    # 🎲 Configurar semilla específica para este modelo
    np.random.seed(seed)
    random.seed(seed)
    
    # Crear parámetros específicos para este modelo
    lgb_params = lgb_params_base.copy()
    lgb_params.update({
        'random_state': seed,
        'bagging_seed': seed,
        'feature_fraction_seed': seed,
        'data_seed': seed
    })
    
    print(f"🔧 Parámetros para modelo {i}:")
    print(f"   linear_tree: {lgb_params['linear_tree']} ⭐")
    print(f"   random_state: {seed}")
    print(f"   learning_rate: {lgb_params['learning_rate']:.4f}")
    print(f"   num_leaves: {lgb_params['num_leaves']}")
    
    # Crear datasets de LightGBM
    train_dataset = lgb.Dataset(X_train, label=y_train)
    val_dataset = lgb.Dataset(X_val, label=y_val, reference=train_dataset)
    
    # Entrenar el modelo
    modelo = lgb.train(
        lgb_params,
        train_dataset,
        valid_sets=[train_dataset, val_dataset],
        valid_names=['train', 'eval'],
        num_boost_round=2000,
        callbacks=[
            lgb.early_stopping(stopping_rounds=150),
            lgb.log_evaluation(0)  # Silenciar logs individuales
        ]
    )
    
    # 💾 Guardar el modelo individual con su semilla
    model_filename = f"{modelos_dir}/modelo_lgbm_seed_{seed}.pkl"
    with open(model_filename, 'wb') as f:
        pickle.dump(modelo, f)
    print(f"💾 Modelo guardado en: {model_filename}")
    
    # Predicciones en validación
    y_pred_val = modelo.predict(X_val, num_iteration=modelo.best_iteration)
    
    # Calcular métricas
    mae = mean_absolute_error(y_val, y_pred_val)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred_val))
    mape = np.mean(np.abs((y_val - y_pred_val) / y_val)) * 100
    
    # Almacenar resultados (incluyendo ruta del modelo)
    modelos.append(modelo)
    metricas.append({
        'modelo': i,
        'semilla': seed,
        'mae': mae,
        'rmse': rmse,
        'mape': mape,
        'num_trees': modelo.num_trees(),
        'model_file': model_filename  # 📁 Ruta del archivo del modelo
    })
    predicciones_val.append(y_pred_val)
    
    print(f"✅ Modelo {i} entrenado exitosamente!")
    print(f"   MAE:  {mae:.4f}")
    print(f"   RMSE: {rmse:.4f}")
    print(f"   MAPE: {mape:.2f}%")
    print(f"   Árboles: {modelo.num_trees()}")

print(f"\n🎉 ¡TODOS LOS {len(semillas)} MODELOS ENTRENADOS EXITOSAMENTE!")
print(f"⭐ Cada modelo usa árboles lineales híbridos con parámetros optimizados por Optuna")
print(f"💾 Todos los modelos han sido guardados en: {modelos_dir}/")

# Crear DataFrame con métricas (incluyendo rutas de archivos)
df_metricas = pd.DataFrame(metricas)
print(f"\n📊 RESUMEN DE MÉTRICAS DE LOS {len(semillas)} MODELOS:")
print(f"{'='*60}")
print(df_metricas[['modelo', 'semilla', 'mae', 'rmse', 'mape', 'num_trees']])  # Mostrar sin la ruta por claridad

print(f"\n📈 ESTADÍSTICAS DE LAS MÉTRICAS:")
print(f"   MAE  - Promedio: {df_metricas['mae'].mean():.4f}, Std: {df_metricas['mae'].std():.4f}")
print(f"   RMSE - Promedio: {df_metricas['rmse'].mean():.4f}, Std: {df_metricas['rmse'].std():.4f}")
print(f"   MAPE - Promedio: {df_metricas['mape'].mean():.2f}%, Std: {df_metricas['mape'].std():.2f}%")

# Encontrar el mejor modelo
mejor_modelo_idx = df_metricas['mae'].idxmin()
mejor_modelo = modelos[mejor_modelo_idx]
mejor_semilla = semillas[mejor_modelo_idx]
mejor_model_file = df_metricas.loc[mejor_modelo_idx, 'model_file']

print(f"\n🏆 MEJOR MODELO:")
print(f"   Modelo: {mejor_modelo_idx + 1}")
print(f"   Semilla: {mejor_semilla}")
print(f"   MAE: {df_metricas.loc[mejor_modelo_idx, 'mae']:.4f}")
print(f"   RMSE: {df_metricas.loc[mejor_modelo_idx, 'rmse']:.4f}")
print(f"   MAPE: {df_metricas.loc[mejor_modelo_idx, 'mape']:.2f}%")
print(f"   📁 Archivo: {mejor_model_file}")

print(f"\n📁 LISTA DE MODELOS GUARDADOS:")
for i, row in df_metricas.iterrows():
    print(f"   Modelo {row['modelo']:2d} (seed {row['semilla']:3d}): {row['model_file']}")
# Out:
# ENTRENAMIENTO DE 50 MODELOS LIGHTGBM CON DIFERENTES SEMILLAS - LINEAR_TREE
# ================================================================================
# 🔢 Usando 50 semillas diferentes para entrenamiento:
#    Semillas originales (20): [42, 109, 113, 151, 167, 179, 193, 199, 211, 241, 263, 281, 307, 331, 367, 401, 439, 487, 563, 617]
#    Semillas nuevas (30): [40009, 42043, 45007, 47017, 50021, 52027, 55001, 57037, 60013, 62003, 65029, 67003, 70001, 72019, 75011, 77003, 80021, 82009, 85009, 87011, 90001, 92003, 95003, 97007, 99013, 99991, 99929, 99881, 99733, 99667]
#    Total de modelos: 50
#
# 💾 Los modelos se guardarán en: data/modelos_entrenados/v3/
#
# 🚀 Iniciando entrenamiento de 50 modelos...
#
# ============================================================
# 🎯 ENTRENANDO MODELO 1/50 - SEMILLA: 42
# ============================================================
# 🔧 Parámetros para modelo 1:
#    linear_tree: True ⭐
#    random_state: 42
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [206]	train's l1: 10.3601	eval's l1: 10.6723
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_42.pkl
# ✅ Modelo 1 entrenado exitosamente!
#    MAE:  10.6723
#    RMSE: 34.0035
#    MAPE: 325.41%
#    Árboles: 206
#
# ============================================================
# 🎯 ENTRENANDO MODELO 2/50 - SEMILLA: 109
# ============================================================
# 🔧 Parámetros para modelo 2:
#    linear_tree: True ⭐
#    random_state: 109
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [206]	train's l1: 10.3601	eval's l1: 10.6723
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_42.pkl
# ✅ Modelo 1 entrenado exitosamente!
#    MAE:  10.6723
#    RMSE: 34.0035
#    MAPE: 325.41%
#    Árboles: 206
#
# ============================================================
# 🎯 ENTRENANDO MODELO 2/50 - SEMILLA: 109
# ============================================================
# 🔧 Parámetros para modelo 2:
#    linear_tree: True ⭐
#    random_state: 109
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [188]	train's l1: 10.803	eval's l1: 10.7948
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_109.pkl
# ✅ Modelo 2 entrenado exitosamente!
#    MAE:  10.7948
#    RMSE: 33.5983
#    MAPE: 404.31%
#    Árboles: 188
#
# ============================================================
# 🎯 ENTRENANDO MODELO 3/50 - SEMILLA: 113
# ============================================================
# 🔧 Parámetros para modelo 3:
#    linear_tree: True ⭐
#    random_state: 113
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [188]	train's l1: 10.803	eval's l1: 10.7948
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_109.pkl
# ✅ Modelo 2 entrenado exitosamente!
#    MAE:  10.7948
#    RMSE: 33.5983
#    MAPE: 404.31%
#    Árboles: 188
#
# ============================================================
# 🎯 ENTRENANDO MODELO 3/50 - SEMILLA: 113
# ============================================================
# 🔧 Parámetros para modelo 3:
#    linear_tree: True ⭐
#    random_state: 113
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [235]	train's l1: 9.91009	eval's l1: 10.4717
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_113.pkl
# ✅ Modelo 3 entrenado exitosamente!
#    MAE:  10.4717
#    RMSE: 34.0684
#    MAPE: 232.88%
#    Árboles: 235
#
# ============================================================
# 🎯 ENTRENANDO MODELO 4/50 - SEMILLA: 151
# ============================================================
# 🔧 Parámetros para modelo 4:
#    linear_tree: True ⭐
#    random_state: 151
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [235]	train's l1: 9.91009	eval's l1: 10.4717
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_113.pkl
# ✅ Modelo 3 entrenado exitosamente!
#    MAE:  10.4717
#    RMSE: 34.0684
#    MAPE: 232.88%
#    Árboles: 235
#
# ============================================================
# 🎯 ENTRENANDO MODELO 4/50 - SEMILLA: 151
# ============================================================
# 🔧 Parámetros para modelo 4:
#    linear_tree: True ⭐
#    random_state: 151
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [206]	train's l1: 10.3545	eval's l1: 10.732
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_151.pkl
# ✅ Modelo 4 entrenado exitosamente!
#    MAE:  10.7320
#    RMSE: 33.7536
#    MAPE: 321.19%
#    Árboles: 206
#
# ============================================================
# 🎯 ENTRENANDO MODELO 5/50 - SEMILLA: 167
# ============================================================
# 🔧 Parámetros para modelo 5:
#    linear_tree: True ⭐
#    random_state: 167
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [206]	train's l1: 10.3545	eval's l1: 10.732
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_151.pkl
# ✅ Modelo 4 entrenado exitosamente!
#    MAE:  10.7320
#    RMSE: 33.7536
#    MAPE: 321.19%
#    Árboles: 206
#
# ============================================================
# 🎯 ENTRENANDO MODELO 5/50 - SEMILLA: 167
# ============================================================
# 🔧 Parámetros para modelo 5:
#    linear_tree: True ⭐
#    random_state: 167
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [257]	train's l1: 9.66203	eval's l1: 10.4076
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_167.pkl
# ✅ Modelo 5 entrenado exitosamente!
#    MAE:  10.4076
#    RMSE: 33.7398
#    MAPE: 216.54%
#    Árboles: 257
#
# ============================================================
# 🎯 ENTRENANDO MODELO 6/50 - SEMILLA: 179
# ============================================================
# 🔧 Parámetros para modelo 6:
#    linear_tree: True ⭐
#    random_state: 179
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [257]	train's l1: 9.66203	eval's l1: 10.4076
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_167.pkl
# ✅ Modelo 5 entrenado exitosamente!
#    MAE:  10.4076
#    RMSE: 33.7398
#    MAPE: 216.54%
#    Árboles: 257
#
# ============================================================
# 🎯 ENTRENANDO MODELO 6/50 - SEMILLA: 179
# ============================================================
# 🔧 Parámetros para modelo 6:
#    linear_tree: True ⭐
#    random_state: 179
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [212]	train's l1: 10.324	eval's l1: 10.6239
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_179.pkl
# ✅ Modelo 6 entrenado exitosamente!
#    MAE:  10.6239
#    RMSE: 33.9518
#    MAPE: 305.97%
#    Árboles: 212
#
# ============================================================
# 🎯 ENTRENANDO MODELO 7/50 - SEMILLA: 193
# ============================================================
# 🔧 Parámetros para modelo 7:
#    linear_tree: True ⭐
#    random_state: 193
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [212]	train's l1: 10.324	eval's l1: 10.6239
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_179.pkl
# ✅ Modelo 6 entrenado exitosamente!
#    MAE:  10.6239
#    RMSE: 33.9518
#    MAPE: 305.97%
#    Árboles: 212
#
# ============================================================
# 🎯 ENTRENANDO MODELO 7/50 - SEMILLA: 193
# ============================================================
# 🔧 Parámetros para modelo 7:
#    linear_tree: True ⭐
#    random_state: 193
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [193]	train's l1: 10.5861	eval's l1: 10.7781
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_193.pkl
# ✅ Modelo 7 entrenado exitosamente!
#    MAE:  10.7781
#    RMSE: 33.5885
#    MAPE: 382.15%
#    Árboles: 193
#
# ============================================================
# 🎯 ENTRENANDO MODELO 8/50 - SEMILLA: 199
# ============================================================
# 🔧 Parámetros para modelo 8:
#    linear_tree: True ⭐
#    random_state: 199
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [193]	train's l1: 10.5861	eval's l1: 10.7781
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_193.pkl
# ✅ Modelo 7 entrenado exitosamente!
#    MAE:  10.7781
#    RMSE: 33.5885
#    MAPE: 382.15%
#    Árboles: 193
#
# ============================================================
# 🎯 ENTRENANDO MODELO 8/50 - SEMILLA: 199
# ============================================================
# 🔧 Parámetros para modelo 8:
#    linear_tree: True ⭐
#    random_state: 199
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [179]	train's l1: 10.944	eval's l1: 10.8806
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_199.pkl
# ✅ Modelo 8 entrenado exitosamente!
#    MAE:  10.8806
#    RMSE: 33.4801
#    MAPE: 455.98%
#    Árboles: 179
#
# ============================================================
# 🎯 ENTRENANDO MODELO 9/50 - SEMILLA: 211
# ============================================================
# 🔧 Parámetros para modelo 9:
#    linear_tree: True ⭐
#    random_state: 211
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [179]	train's l1: 10.944	eval's l1: 10.8806
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_199.pkl
# ✅ Modelo 8 entrenado exitosamente!
#    MAE:  10.8806
#    RMSE: 33.4801
#    MAPE: 455.98%
#    Árboles: 179
#
# ============================================================
# 🎯 ENTRENANDO MODELO 9/50 - SEMILLA: 211
# ============================================================
# 🔧 Parámetros para modelo 9:
#    linear_tree: True ⭐
#    random_state: 211
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [276]	train's l1: 9.44144	eval's l1: 10.4128
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_211.pkl
# ✅ Modelo 9 entrenado exitosamente!
#    MAE:  10.4128
#    RMSE: 33.9884
#    MAPE: 218.58%
#    Árboles: 276
#
# ============================================================
# 🎯 ENTRENANDO MODELO 10/50 - SEMILLA: 241
# ============================================================
# 🔧 Parámetros para modelo 10:
#    linear_tree: True ⭐
#    random_state: 241
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [276]	train's l1: 9.44144	eval's l1: 10.4128
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_211.pkl
# ✅ Modelo 9 entrenado exitosamente!
#    MAE:  10.4128
#    RMSE: 33.9884
#    MAPE: 218.58%
#    Árboles: 276
#
# ============================================================
# 🎯 ENTRENANDO MODELO 10/50 - SEMILLA: 241
# ============================================================
# 🔧 Parámetros para modelo 10:
#    linear_tree: True ⭐
#    random_state: 241
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [175]	train's l1: 11.0241	eval's l1: 10.9984
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_241.pkl
# ✅ Modelo 10 entrenado exitosamente!
#    MAE:  10.9984
#    RMSE: 34.0037
#    MAPE: 480.68%
#    Árboles: 175
#
# ============================================================
# 🎯 ENTRENANDO MODELO 11/50 - SEMILLA: 263
# ============================================================
# 🔧 Parámetros para modelo 11:
#    linear_tree: True ⭐
#    random_state: 263
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [175]	train's l1: 11.0241	eval's l1: 10.9984
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_241.pkl
# ✅ Modelo 10 entrenado exitosamente!
#    MAE:  10.9984
#    RMSE: 34.0037
#    MAPE: 480.68%
#    Árboles: 175
#
# ============================================================
# 🎯 ENTRENANDO MODELO 11/50 - SEMILLA: 263
# ============================================================
# 🔧 Parámetros para modelo 11:
#    linear_tree: True ⭐
#    random_state: 263
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [203]	train's l1: 10.4471	eval's l1: 10.6763
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_263.pkl
# ✅ Modelo 11 entrenado exitosamente!
#    MAE:  10.6763
#    RMSE: 33.4391
#    MAPE: 331.30%
#    Árboles: 203
#
# ============================================================
# 🎯 ENTRENANDO MODELO 12/50 - SEMILLA: 281
# ============================================================
# 🔧 Parámetros para modelo 12:
#    linear_tree: True ⭐
#    random_state: 281
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [203]	train's l1: 10.4471	eval's l1: 10.6763
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_263.pkl
# ✅ Modelo 11 entrenado exitosamente!
#    MAE:  10.6763
#    RMSE: 33.4391
#    MAPE: 331.30%
#    Árboles: 203
#
# ============================================================
# 🎯 ENTRENANDO MODELO 12/50 - SEMILLA: 281
# ============================================================
# 🔧 Parámetros para modelo 12:
#    linear_tree: True ⭐
#    random_state: 281
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [234]	train's l1: 9.97071	eval's l1: 10.7771
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_281.pkl
# ✅ Modelo 12 entrenado exitosamente!
#    MAE:  10.7771
#    RMSE: 36.3509
#    MAPE: 244.07%
#    Árboles: 234
#
# ============================================================
# 🎯 ENTRENANDO MODELO 13/50 - SEMILLA: 307
# ============================================================
# 🔧 Parámetros para modelo 13:
#    linear_tree: True ⭐
#    random_state: 307
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [234]	train's l1: 9.97071	eval's l1: 10.7771
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_281.pkl
# ✅ Modelo 12 entrenado exitosamente!
#    MAE:  10.7771
#    RMSE: 36.3509
#    MAPE: 244.07%
#    Árboles: 234
#
# ============================================================
# 🎯 ENTRENANDO MODELO 13/50 - SEMILLA: 307
# ============================================================
# 🔧 Parámetros para modelo 13:
#    linear_tree: True ⭐
#    random_state: 307
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [232]	train's l1: 9.94796	eval's l1: 10.4075
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_307.pkl
# ✅ Modelo 13 entrenado exitosamente!
#    MAE:  10.4075
#    RMSE: 33.1736
#    MAPE: 240.26%
#    Árboles: 232
#
# ============================================================
# 🎯 ENTRENANDO MODELO 14/50 - SEMILLA: 331
# ============================================================
# 🔧 Parámetros para modelo 14:
#    linear_tree: True ⭐
#    random_state: 331
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [232]	train's l1: 9.94796	eval's l1: 10.4075
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_307.pkl
# ✅ Modelo 13 entrenado exitosamente!
#    MAE:  10.4075
#    RMSE: 33.1736
#    MAPE: 240.26%
#    Árboles: 232
#
# ============================================================
# 🎯 ENTRENANDO MODELO 14/50 - SEMILLA: 331
# ============================================================
# 🔧 Parámetros para modelo 14:
#    linear_tree: True ⭐
#    random_state: 331
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [219]	train's l1: 10.1639	eval's l1: 10.3963
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_331.pkl
# ✅ Modelo 14 entrenado exitosamente!
#    MAE:  10.3963
#    RMSE: 33.1004
#    MAPE: 277.16%
#    Árboles: 219
#
# ============================================================
# 🎯 ENTRENANDO MODELO 15/50 - SEMILLA: 367
# ============================================================
# 🔧 Parámetros para modelo 15:
#    linear_tree: True ⭐
#    random_state: 367
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [219]	train's l1: 10.1639	eval's l1: 10.3963
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_331.pkl
# ✅ Modelo 14 entrenado exitosamente!
#    MAE:  10.3963
#    RMSE: 33.1004
#    MAPE: 277.16%
#    Árboles: 219
#
# ============================================================
# 🎯 ENTRENANDO MODELO 15/50 - SEMILLA: 367
# ============================================================
# 🔧 Parámetros para modelo 15:
#    linear_tree: True ⭐
#    random_state: 367
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [227]	train's l1: 10.0375	eval's l1: 10.5347
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_367.pkl
# ✅ Modelo 15 entrenado exitosamente!
#    MAE:  10.5347
#    RMSE: 34.0102
#    MAPE: 257.81%
#    Árboles: 227
#
# ============================================================
# 🎯 ENTRENANDO MODELO 16/50 - SEMILLA: 401
# ============================================================
# 🔧 Parámetros para modelo 16:
#    linear_tree: True ⭐
#    random_state: 401
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [227]	train's l1: 10.0375	eval's l1: 10.5347
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_367.pkl
# ✅ Modelo 15 entrenado exitosamente!
#    MAE:  10.5347
#    RMSE: 34.0102
#    MAPE: 257.81%
#    Árboles: 227
#
# ============================================================
# 🎯 ENTRENANDO MODELO 16/50 - SEMILLA: 401
# ============================================================
# 🔧 Parámetros para modelo 16:
#    linear_tree: True ⭐
#    random_state: 401
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [196]	train's l1: 10.5685	eval's l1: 11.0037
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_401.pkl
# ✅ Modelo 16 entrenado exitosamente!
#    MAE:  11.0037
#    RMSE: 35.3645
#    MAPE: 374.18%
#    Árboles: 196
#
# ============================================================
# 🎯 ENTRENANDO MODELO 17/50 - SEMILLA: 439
# ============================================================
# 🔧 Parámetros para modelo 17:
#    linear_tree: True ⭐
#    random_state: 439
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [196]	train's l1: 10.5685	eval's l1: 11.0037
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_401.pkl
# ✅ Modelo 16 entrenado exitosamente!
#    MAE:  11.0037
#    RMSE: 35.3645
#    MAPE: 374.18%
#    Árboles: 196
#
# ============================================================
# 🎯 ENTRENANDO MODELO 17/50 - SEMILLA: 439
# ============================================================
# 🔧 Parámetros para modelo 17:
#    linear_tree: True ⭐
#    random_state: 439
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [191]	train's l1: 10.624	eval's l1: 10.749
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_439.pkl
# ✅ Modelo 17 entrenado exitosamente!
#    MAE:  10.7490
#    RMSE: 33.2541
#    MAPE: 390.45%
#    Árboles: 191
#
# ============================================================
# 🎯 ENTRENANDO MODELO 18/50 - SEMILLA: 487
# ============================================================
# 🔧 Parámetros para modelo 18:
#    linear_tree: True ⭐
#    random_state: 487
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [191]	train's l1: 10.624	eval's l1: 10.749
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_439.pkl
# ✅ Modelo 17 entrenado exitosamente!
#    MAE:  10.7490
#    RMSE: 33.2541
#    MAPE: 390.45%
#    Árboles: 191
#
# ============================================================
# 🎯 ENTRENANDO MODELO 18/50 - SEMILLA: 487
# ============================================================
# 🔧 Parámetros para modelo 18:
#    linear_tree: True ⭐
#    random_state: 487
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [229]	train's l1: 10.01	eval's l1: 10.6905
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_487.pkl
# ✅ Modelo 18 entrenado exitosamente!
#    MAE:  10.6905
#    RMSE: 34.3746
#    MAPE: 267.90%
#    Árboles: 229
#
# ============================================================
# 🎯 ENTRENANDO MODELO 19/50 - SEMILLA: 563
# ============================================================
# 🔧 Parámetros para modelo 19:
#    linear_tree: True ⭐
#    random_state: 563
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [229]	train's l1: 10.01	eval's l1: 10.6905
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_487.pkl
# ✅ Modelo 18 entrenado exitosamente!
#    MAE:  10.6905
#    RMSE: 34.3746
#    MAPE: 267.90%
#    Árboles: 229
#
# ============================================================
# 🎯 ENTRENANDO MODELO 19/50 - SEMILLA: 563
# ============================================================
# 🔧 Parámetros para modelo 19:
#    linear_tree: True ⭐
#    random_state: 563
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [207]	train's l1: 10.3352	eval's l1: 10.7648
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_563.pkl
# ✅ Modelo 19 entrenado exitosamente!
#    MAE:  10.7648
#    RMSE: 36.0240
#    MAPE: 322.75%
#    Árboles: 207
#
# ============================================================
# 🎯 ENTRENANDO MODELO 20/50 - SEMILLA: 617
# ============================================================
# 🔧 Parámetros para modelo 20:
#    linear_tree: True ⭐
#    random_state: 617
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [207]	train's l1: 10.3352	eval's l1: 10.7648
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_563.pkl
# ✅ Modelo 19 entrenado exitosamente!
#    MAE:  10.7648
#    RMSE: 36.0240
#    MAPE: 322.75%
#    Árboles: 207
#
# ============================================================
# 🎯 ENTRENANDO MODELO 20/50 - SEMILLA: 617
# ============================================================
# 🔧 Parámetros para modelo 20:
#    linear_tree: True ⭐
#    random_state: 617
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [225]	train's l1: 10.087	eval's l1: 10.5113
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_617.pkl
# ✅ Modelo 20 entrenado exitosamente!
#    MAE:  10.5113
#    RMSE: 34.0141
#    MAPE: 271.91%
#    Árboles: 225
#
# ============================================================
# 🎯 ENTRENANDO MODELO 21/50 - SEMILLA: 40009
# ============================================================
# 🔧 Parámetros para modelo 21:
#    linear_tree: True ⭐
#    random_state: 40009
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [225]	train's l1: 10.087	eval's l1: 10.5113
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_617.pkl
# ✅ Modelo 20 entrenado exitosamente!
#    MAE:  10.5113
#    RMSE: 34.0141
#    MAPE: 271.91%
#    Árboles: 225
#
# ============================================================
# 🎯 ENTRENANDO MODELO 21/50 - SEMILLA: 40009
# ============================================================
# 🔧 Parámetros para modelo 21:
#    linear_tree: True ⭐
#    random_state: 40009
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [249]	train's l1: 9.78871	eval's l1: 10.6648
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_40009.pkl
# ✅ Modelo 21 entrenado exitosamente!
#    MAE:  10.6648
#    RMSE: 35.0349
#    MAPE: 221.72%
#    Árboles: 249
#
# ============================================================
# 🎯 ENTRENANDO MODELO 22/50 - SEMILLA: 42043
# ============================================================
# 🔧 Parámetros para modelo 22:
#    linear_tree: True ⭐
#    random_state: 42043
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [249]	train's l1: 9.78871	eval's l1: 10.6648
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_40009.pkl
# ✅ Modelo 21 entrenado exitosamente!
#    MAE:  10.6648
#    RMSE: 35.0349
#    MAPE: 221.72%
#    Árboles: 249
#
# ============================================================
# 🎯 ENTRENANDO MODELO 22/50 - SEMILLA: 42043
# ============================================================
# 🔧 Parámetros para modelo 22:
#    linear_tree: True ⭐
#    random_state: 42043
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [345]	train's l1: 8.77925	eval's l1: 10.5245
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_42043.pkl
# ✅ Modelo 22 entrenado exitosamente!
#    MAE:  10.5245
#    RMSE: 36.3040
#    MAPE: 203.98%
#    Árboles: 345
#
# ============================================================
# 🎯 ENTRENANDO MODELO 23/50 - SEMILLA: 45007
# ============================================================
# 🔧 Parámetros para modelo 23:
#    linear_tree: True ⭐
#    random_state: 45007
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [345]	train's l1: 8.77925	eval's l1: 10.5245
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_42043.pkl
# ✅ Modelo 22 entrenado exitosamente!
#    MAE:  10.5245
#    RMSE: 36.3040
#    MAPE: 203.98%
#    Árboles: 345
#
# ============================================================
# 🎯 ENTRENANDO MODELO 23/50 - SEMILLA: 45007
# ============================================================
# 🔧 Parámetros para modelo 23:
#    linear_tree: True ⭐
#    random_state: 45007
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [160]	train's l1: 11.4805	eval's l1: 11.4099
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_45007.pkl
# ✅ Modelo 23 entrenado exitosamente!
#    MAE:  11.4099
#    RMSE: 34.5701
#    MAPE: 599.19%
#    Árboles: 160
#
# ============================================================
# 🎯 ENTRENANDO MODELO 24/50 - SEMILLA: 47017
# ============================================================
# 🔧 Parámetros para modelo 24:
#    linear_tree: True ⭐
#    random_state: 47017
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [160]	train's l1: 11.4805	eval's l1: 11.4099
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_45007.pkl
# ✅ Modelo 23 entrenado exitosamente!
#    MAE:  11.4099
#    RMSE: 34.5701
#    MAPE: 599.19%
#    Árboles: 160
#
# ============================================================
# 🎯 ENTRENANDO MODELO 24/50 - SEMILLA: 47017
# ============================================================
# 🔧 Parámetros para modelo 24:
#    linear_tree: True ⭐
#    random_state: 47017
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [337]	train's l1: 8.85308	eval's l1: 10.4277
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_47017.pkl
# ✅ Modelo 24 entrenado exitosamente!
#    MAE:  10.4277
#    RMSE: 34.3103
#    MAPE: 205.32%
#    Árboles: 337
#
# ============================================================
# 🎯 ENTRENANDO MODELO 25/50 - SEMILLA: 50021
# ============================================================
# 🔧 Parámetros para modelo 25:
#    linear_tree: True ⭐
#    random_state: 50021
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [337]	train's l1: 8.85308	eval's l1: 10.4277
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_47017.pkl
# ✅ Modelo 24 entrenado exitosamente!
#    MAE:  10.4277
#    RMSE: 34.3103
#    MAPE: 205.32%
#    Árboles: 337
#
# ============================================================
# 🎯 ENTRENANDO MODELO 25/50 - SEMILLA: 50021
# ============================================================
# 🔧 Parámetros para modelo 25:
#    linear_tree: True ⭐
#    random_state: 50021
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [209]	train's l1: 10.3337	eval's l1: 10.5962
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_50021.pkl
# ✅ Modelo 25 entrenado exitosamente!
#    MAE:  10.5962
#    RMSE: 33.7551
#    MAPE: 320.45%
#    Árboles: 209
#
# ============================================================
# 🎯 ENTRENANDO MODELO 26/50 - SEMILLA: 52027
# ============================================================
# 🔧 Parámetros para modelo 26:
#    linear_tree: True ⭐
#    random_state: 52027
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [209]	train's l1: 10.3337	eval's l1: 10.5962
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_50021.pkl
# ✅ Modelo 25 entrenado exitosamente!
#    MAE:  10.5962
#    RMSE: 33.7551
#    MAPE: 320.45%
#    Árboles: 209
#
# ============================================================
# 🎯 ENTRENANDO MODELO 26/50 - SEMILLA: 52027
# ============================================================
# 🔧 Parámetros para modelo 26:
#    linear_tree: True ⭐
#    random_state: 52027
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [256]	train's l1: 9.68155	eval's l1: 10.6428
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_52027.pkl
# ✅ Modelo 26 entrenado exitosamente!
#    MAE:  10.6428
#    RMSE: 35.6231
#    MAPE: 232.73%
#    Árboles: 256
#
# ============================================================
# 🎯 ENTRENANDO MODELO 27/50 - SEMILLA: 55001
# ============================================================
# 🔧 Parámetros para modelo 27:
#    linear_tree: True ⭐
#    random_state: 55001
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [256]	train's l1: 9.68155	eval's l1: 10.6428
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_52027.pkl
# ✅ Modelo 26 entrenado exitosamente!
#    MAE:  10.6428
#    RMSE: 35.6231
#    MAPE: 232.73%
#    Árboles: 256
#
# ============================================================
# 🎯 ENTRENANDO MODELO 27/50 - SEMILLA: 55001
# ============================================================
# 🔧 Parámetros para modelo 27:
#    linear_tree: True ⭐
#    random_state: 55001
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [300]	train's l1: 9.18422	eval's l1: 10.3996
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_55001.pkl
# ✅ Modelo 27 entrenado exitosamente!
#    MAE:  10.3996
#    RMSE: 33.9957
#    MAPE: 214.19%
#    Árboles: 300
#
# ============================================================
# 🎯 ENTRENANDO MODELO 28/50 - SEMILLA: 57037
# ============================================================
# 🔧 Parámetros para modelo 28:
#    linear_tree: True ⭐
#    random_state: 57037
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [300]	train's l1: 9.18422	eval's l1: 10.3996
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_55001.pkl
# ✅ Modelo 27 entrenado exitosamente!
#    MAE:  10.3996
#    RMSE: 33.9957
#    MAPE: 214.19%
#    Árboles: 300
#
# ============================================================
# 🎯 ENTRENANDO MODELO 28/50 - SEMILLA: 57037
# ============================================================
# 🔧 Parámetros para modelo 28:
#    linear_tree: True ⭐
#    random_state: 57037
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [243]	train's l1: 9.83954	eval's l1: 10.5623
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_57037.pkl
# ✅ Modelo 28 entrenado exitosamente!
#    MAE:  10.5623
#    RMSE: 34.6701
#    MAPE: 240.07%
#    Árboles: 243
#
# ============================================================
# 🎯 ENTRENANDO MODELO 29/50 - SEMILLA: 60013
# ============================================================
# 🔧 Parámetros para modelo 29:
#    linear_tree: True ⭐
#    random_state: 60013
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [243]	train's l1: 9.83954	eval's l1: 10.5623
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_57037.pkl
# ✅ Modelo 28 entrenado exitosamente!
#    MAE:  10.5623
#    RMSE: 34.6701
#    MAPE: 240.07%
#    Árboles: 243
#
# ============================================================
# 🎯 ENTRENANDO MODELO 29/50 - SEMILLA: 60013
# ============================================================
# 🔧 Parámetros para modelo 29:
#    linear_tree: True ⭐
#    random_state: 60013
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [239]	train's l1: 9.9081	eval's l1: 10.6013
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_60013.pkl
# ✅ Modelo 29 entrenado exitosamente!
#    MAE:  10.6013
#    RMSE: 34.2892
#    MAPE: 240.32%
#    Árboles: 239
#
# ============================================================
# 🎯 ENTRENANDO MODELO 30/50 - SEMILLA: 62003
# ============================================================
# 🔧 Parámetros para modelo 30:
#    linear_tree: True ⭐
#    random_state: 62003
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [239]	train's l1: 9.9081	eval's l1: 10.6013
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_60013.pkl
# ✅ Modelo 29 entrenado exitosamente!
#    MAE:  10.6013
#    RMSE: 34.2892
#    MAPE: 240.32%
#    Árboles: 239
#
# ============================================================
# 🎯 ENTRENANDO MODELO 30/50 - SEMILLA: 62003
# ============================================================
# 🔧 Parámetros para modelo 30:
#    linear_tree: True ⭐
#    random_state: 62003
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [195]	train's l1: 10.5625	eval's l1: 10.7822
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_62003.pkl
# ✅ Modelo 30 entrenado exitosamente!
#    MAE:  10.7822
#    RMSE: 33.9780
#    MAPE: 375.38%
#    Árboles: 195
#
# ============================================================
# 🎯 ENTRENANDO MODELO 31/50 - SEMILLA: 65029
# ============================================================
# 🔧 Parámetros para modelo 31:
#    linear_tree: True ⭐
#    random_state: 65029
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [195]	train's l1: 10.5625	eval's l1: 10.7822
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_62003.pkl
# ✅ Modelo 30 entrenado exitosamente!
#    MAE:  10.7822
#    RMSE: 33.9780
#    MAPE: 375.38%
#    Árboles: 195
#
# ============================================================
# 🎯 ENTRENANDO MODELO 31/50 - SEMILLA: 65029
# ============================================================
# 🔧 Parámetros para modelo 31:
#    linear_tree: True ⭐
#    random_state: 65029
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [201]	train's l1: 10.4791	eval's l1: 10.6946
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_65029.pkl
# ✅ Modelo 31 entrenado exitosamente!
#    MAE:  10.6946
#    RMSE: 33.7925
#    MAPE: 353.36%
#    Árboles: 201
#
# ============================================================
# 🎯 ENTRENANDO MODELO 32/50 - SEMILLA: 67003
# ============================================================
# 🔧 Parámetros para modelo 32:
#    linear_tree: True ⭐
#    random_state: 67003
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [201]	train's l1: 10.4791	eval's l1: 10.6946
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_65029.pkl
# ✅ Modelo 31 entrenado exitosamente!
#    MAE:  10.6946
#    RMSE: 33.7925
#    MAPE: 353.36%
#    Árboles: 201
#
# ============================================================
# 🎯 ENTRENANDO MODELO 32/50 - SEMILLA: 67003
# ============================================================
# 🔧 Parámetros para modelo 32:
#    linear_tree: True ⭐
#    random_state: 67003
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [197]	train's l1: 10.5519	eval's l1: 10.7557
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_67003.pkl
# ✅ Modelo 32 entrenado exitosamente!
#    MAE:  10.7557
#    RMSE: 33.7245
#    MAPE: 369.06%
#    Árboles: 197
#
# ============================================================
# 🎯 ENTRENANDO MODELO 33/50 - SEMILLA: 70001
# ============================================================
# 🔧 Parámetros para modelo 33:
#    linear_tree: True ⭐
#    random_state: 70001
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [197]	train's l1: 10.5519	eval's l1: 10.7557
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_67003.pkl
# ✅ Modelo 32 entrenado exitosamente!
#    MAE:  10.7557
#    RMSE: 33.7245
#    MAPE: 369.06%
#    Árboles: 197
#
# ============================================================
# 🎯 ENTRENANDO MODELO 33/50 - SEMILLA: 70001
# ============================================================
# 🔧 Parámetros para modelo 33:
#    linear_tree: True ⭐
#    random_state: 70001
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [188]	train's l1: 10.7517	eval's l1: 10.8669
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_70001.pkl
# ✅ Modelo 33 entrenado exitosamente!
#    MAE:  10.8669
#    RMSE: 34.0646
#    MAPE: 413.37%
#    Árboles: 188
#
# ============================================================
# 🎯 ENTRENANDO MODELO 34/50 - SEMILLA: 72019
# ============================================================
# 🔧 Parámetros para modelo 34:
#    linear_tree: True ⭐
#    random_state: 72019
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [188]	train's l1: 10.7517	eval's l1: 10.8669
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_70001.pkl
# ✅ Modelo 33 entrenado exitosamente!
#    MAE:  10.8669
#    RMSE: 34.0646
#    MAPE: 413.37%
#    Árboles: 188
#
# ============================================================
# 🎯 ENTRENANDO MODELO 34/50 - SEMILLA: 72019
# ============================================================
# 🔧 Parámetros para modelo 34:
#    linear_tree: True ⭐
#    random_state: 72019
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [220]	train's l1: 10.1565	eval's l1: 10.6022
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_72019.pkl
# ✅ Modelo 34 entrenado exitosamente!
#    MAE:  10.6022
#    RMSE: 33.7872
#    MAPE: 285.88%
#    Árboles: 220
#
# ============================================================
# 🎯 ENTRENANDO MODELO 35/50 - SEMILLA: 75011
# ============================================================
# 🔧 Parámetros para modelo 35:
#    linear_tree: True ⭐
#    random_state: 75011
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [220]	train's l1: 10.1565	eval's l1: 10.6022
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_72019.pkl
# ✅ Modelo 34 entrenado exitosamente!
#    MAE:  10.6022
#    RMSE: 33.7872
#    MAPE: 285.88%
#    Árboles: 220
#
# ============================================================
# 🎯 ENTRENANDO MODELO 35/50 - SEMILLA: 75011
# ============================================================
# 🔧 Parámetros para modelo 35:
#    linear_tree: True ⭐
#    random_state: 75011
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [179]	train's l1: 10.9274	eval's l1: 10.9193
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_75011.pkl
# ✅ Modelo 35 entrenado exitosamente!
#    MAE:  10.9193
#    RMSE: 33.6590
#    MAPE: 453.88%
#    Árboles: 179
#
# ============================================================
# 🎯 ENTRENANDO MODELO 36/50 - SEMILLA: 77003
# ============================================================
# 🔧 Parámetros para modelo 36:
#    linear_tree: True ⭐
#    random_state: 77003
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [179]	train's l1: 10.9274	eval's l1: 10.9193
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_75011.pkl
# ✅ Modelo 35 entrenado exitosamente!
#    MAE:  10.9193
#    RMSE: 33.6590
#    MAPE: 453.88%
#    Árboles: 179
#
# ============================================================
# 🎯 ENTRENANDO MODELO 36/50 - SEMILLA: 77003
# ============================================================
# 🔧 Parámetros para modelo 36:
#    linear_tree: True ⭐
#    random_state: 77003
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [175]	train's l1: 11.0547	eval's l1: 10.989
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_77003.pkl
# ✅ Modelo 36 entrenado exitosamente!
#    MAE:  10.9890
#    RMSE: 33.6849
#    MAPE: 481.04%
#    Árboles: 175
#
# ============================================================
# 🎯 ENTRENANDO MODELO 37/50 - SEMILLA: 80021
# ============================================================
# 🔧 Parámetros para modelo 37:
#    linear_tree: True ⭐
#    random_state: 80021
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [175]	train's l1: 11.0547	eval's l1: 10.989
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_77003.pkl
# ✅ Modelo 36 entrenado exitosamente!
#    MAE:  10.9890
#    RMSE: 33.6849
#    MAPE: 481.04%
#    Árboles: 175
#
# ============================================================
# 🎯 ENTRENANDO MODELO 37/50 - SEMILLA: 80021
# ============================================================
# 🔧 Parámetros para modelo 37:
#    linear_tree: True ⭐
#    random_state: 80021
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [272]	train's l1: 9.48577	eval's l1: 10.4034
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_80021.pkl
# ✅ Modelo 37 entrenado exitosamente!
#    MAE:  10.4034
#    RMSE: 34.0454
#    MAPE: 198.17%
#    Árboles: 272
#
# ============================================================
# 🎯 ENTRENANDO MODELO 38/50 - SEMILLA: 82009
# ============================================================
# 🔧 Parámetros para modelo 38:
#    linear_tree: True ⭐
#    random_state: 82009
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [272]	train's l1: 9.48577	eval's l1: 10.4034
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_80021.pkl
# ✅ Modelo 37 entrenado exitosamente!
#    MAE:  10.4034
#    RMSE: 34.0454
#    MAPE: 198.17%
#    Árboles: 272
#
# ============================================================
# 🎯 ENTRENANDO MODELO 38/50 - SEMILLA: 82009
# ============================================================
# 🔧 Parámetros para modelo 38:
#    linear_tree: True ⭐
#    random_state: 82009
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [189]	train's l1: 10.6856	eval's l1: 11.074
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_82009.pkl
# ✅ Modelo 38 entrenado exitosamente!
#    MAE:  11.0740
#    RMSE: 35.1167
#    MAPE: 403.03%
#    Árboles: 189
#
# ============================================================
# 🎯 ENTRENANDO MODELO 39/50 - SEMILLA: 85009
# ============================================================
# 🔧 Parámetros para modelo 39:
#    linear_tree: True ⭐
#    random_state: 85009
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [189]	train's l1: 10.6856	eval's l1: 11.074
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_82009.pkl
# ✅ Modelo 38 entrenado exitosamente!
#    MAE:  11.0740
#    RMSE: 35.1167
#    MAPE: 403.03%
#    Árboles: 189
#
# ============================================================
# 🎯 ENTRENANDO MODELO 39/50 - SEMILLA: 85009
# ============================================================
# 🔧 Parámetros para modelo 39:
#    linear_tree: True ⭐
#    random_state: 85009
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [173]	train's l1: 11.0628	eval's l1: 10.9992
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_85009.pkl
# ✅ Modelo 39 entrenado exitosamente!
#    MAE:  10.9992
#    RMSE: 33.6155
#    MAPE: 495.54%
#    Árboles: 173
#
# ============================================================
# 🎯 ENTRENANDO MODELO 40/50 - SEMILLA: 87011
# ============================================================
# 🔧 Parámetros para modelo 40:
#    linear_tree: True ⭐
#    random_state: 87011
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [173]	train's l1: 11.0628	eval's l1: 10.9992
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_85009.pkl
# ✅ Modelo 39 entrenado exitosamente!
#    MAE:  10.9992
#    RMSE: 33.6155
#    MAPE: 495.54%
#    Árboles: 173
#
# ============================================================
# 🎯 ENTRENANDO MODELO 40/50 - SEMILLA: 87011
# ============================================================
# 🔧 Parámetros para modelo 40:
#    linear_tree: True ⭐
#    random_state: 87011
#    learning_rate: 0.0199
#    num_leaves: 20
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# ...
#
# 📊 RESUMEN DE MÉTRICAS DE LOS 50 MODELOS:
# ============================================================
#     modelo  semilla        mae       rmse        mape  num_trees
# 0        1       42  10.672274  34.003515  325.408290        206
# 1        2      109  10.794758  33.598266  404.306610        188
# 2        3      113  10.471720  34.068376  232.884232        235
# 3        4      151  10.732014  33.753630  321.194634        206
# 4        5      167  10.407562  33.739811  216.543469        257
# 5        6      179  10.623923  33.951776  305.970913        212
# 6        7      193  10.778080  33.588464  382.145450        193
# 7        8      199  10.880621  33.480100  455.976902        179
# 8        9      211  10.412765  33.988438  218.582429        276
# 9       10      241  10.998372  34.003665  480.676841        175
# 10      11      263  10.676301  33.439144  331.298733        203
# 11      12      281  10.777067  36.350948  244.074813        234
# 12      13      307  10.407489  33.173554  240.256845        232
# 13      14      331  10.396254  33.100402  277.163190        219
# 14      15      367  10.534682  34.010248  257.805784        227
# 15      16      401  11.003692  35.364474  374.176481        196
# 16      17      439  10.749047  33.254095  390.452902        191
# 17      18      487  10.690502  34.374602  267.896802        229
# 18      19      563  10.764765  36.024005  322.750085        207
# 19      20      617  10.511302  34.014140  271.912446        225
# 20      21    40009  10.664753  35.034856  221.722023        249
# 21      22    42043  10.524460  36.304032  203.981619        345
# 22      23    45007  11.409910  34.570063  599.193122        160
# 23      24    47017  10.427729  34.310333  205.316201        337
# 24      25    50021  10.596194  33.755085  320.454167        209
# 25      26    52027  10.642835  35.623051  232.727574        256
# 26      27    55001  10.399581  33.995677  214.193419        300
# 27      28    57037  10.562343  34.670068  240.065402        243
# 28      29    60013  10.601277  34.289221  240.323391        239
# 29      30    62003  10.782151  33.977955  375.377974        195
# 30      31    65029  10.694630  33.792506  353.357343        201
# 31      32    67003  10.755670  33.724546  369.062955        197
# 32      33    70001  10.866878  34.064578  413.366958        188
# 33      34    72019  10.602240  33.787236  285.877750        220
# 34      35    75011  10.919263  33.658974  453.881485        179
# 35      36    77003  10.989006  33.684911  481.038127        175
# 36      37    80021  10.403403  34.045354  198.167632        272
# 37      38    82009  11.073994  35.116704  403.034040        189
# 38      39    85009  10.999237  33.615533  495.543551        173
# 39      40    87011  10.631779  33.741273  335.605943        204
# 40      41    90001  10.514986  34.505866  220.500711        262
# 41      42    92003  10.375165  33.288205  225.238719        247
# 42      43    95003  10.854268  36.378226  324.419528        208
# 43      44    97007  10.345382  34.043074  201.410561        296
# 44      45    99013  10.722462  39.648726  204.004680        310
# 45      46    99991  10.871521  35.208729  297.699078        214
# 46      47    99929  10.895196  33.316763  450.300271        180
# 47      48    99881  10.687383  33.187260  381.818814        193
# 48      49    99733  10.588085  33.864226  284.928285        220
# 49      50    99667  11.602714  37.533361  561.871484        164
#
# 📈 ESTADÍSTICAS DE LAS MÉTRICAS:
#    MAE  - Promedio: 10.7058, Std: 0.2531
#    RMSE - Promedio: 34.3604, Std: 1.2250
#    MAPE - Promedio: 322.32%, Std: 101.12%
#
# 🏆 MEJOR MODELO:
#    Modelo: 44
#    Semilla: 97007
#    MAE: 10.3454
#    RMSE: 34.0431
#    MAPE: 201.41%
#    📁 Archivo: data/modelos_entrenados/v3/modelo_lgbm_seed_97007.pkl
#
# 📁 LISTA DE MODELOS GUARDADOS:
#    Modelo  1 (seed  42): data/modelos_entrenados/v3/modelo_lgbm_seed_42.pkl
#    Modelo  2 (seed 109): data/modelos_entrenados/v3/modelo_lgbm_seed_109.pkl
#    Modelo  3 (seed 113): data/modelos_entrenados/v3/modelo_lgbm_seed_113.pkl
#    Modelo  4 (seed 151): data/modelos_entrenados/v3/modelo_lgbm_seed_151.pkl
#    Modelo  5 (seed 167): data/modelos_entrenados/v3/modelo_lgbm_seed_167.pkl
#    Modelo  6 (seed 179): data/modelos_entrenados/v3/modelo_lgbm_seed_179.pkl
#    Modelo  7 (seed 193): data/modelos_entrenados/v3/modelo_lgbm_seed_193.pkl
#    Modelo  8 (seed 199): data/modelos_entrenados/v3/modelo_lgbm_seed_199.pkl
#    Modelo  9 (seed 211): data/modelos_entrenados/v3/modelo_lgbm_seed_211.pkl
#    Modelo 10 (seed 241): data/modelos_entrenados/v3/modelo_lgbm_seed_241.pkl
#    Modelo 11 (seed 263): data/modelos_entrenados/v3/modelo_lgbm_seed_263.pkl
#    Modelo 12 (seed 281): data/modelos_entrenados/v3/modelo_lgbm_seed_281.pkl
#    Modelo 13 (seed 307): data/modelos_entrenados/v3/modelo_lgbm_seed_307.pkl
#    Modelo 14 (seed 331): data/modelos_entrenados/v3/modelo_lgbm_seed_331.pkl
#    Modelo 15 (seed 367): data/modelos_entrenados/v3/modelo_lgbm_seed_367.pkl
#    Modelo 16 (seed 401): data/modelos_entrenados/v3/modelo_lgbm_seed_401.pkl
#    Modelo 17 (seed 439): data/modelos_entrenados/v3/modelo_lgbm_seed_439.pkl
#    Modelo 18 (seed 487): data/modelos_entrenados/v3/modelo_lgbm_seed_487.pkl
#    Modelo 19 (seed 563): data/modelos_entrenados/v3/modelo_lgbm_seed_563.pkl
#    Modelo 20 (seed 617): data/modelos_entrenados/v3/modelo_lgbm_seed_617.pkl
#    Modelo 21 (seed 40009): data/modelos_entrenados/v3/modelo_lgbm_seed_40009.pkl
#    Modelo 22 (seed 42043): data/modelos_entrenados/v3/modelo_lgbm_seed_42043.pkl
#    Modelo 23 (seed 45007): data/modelos_entrenados/v3/modelo_lgbm_seed_45007.pkl
#    Modelo 24 (seed 47017): data/modelos_entrenados/v3/modelo_lgbm_seed_47017.pkl
#    Modelo 25 (seed 50021): data/modelos_entrenados/v3/modelo_lgbm_seed_50021.pkl
#    Modelo 26 (seed 52027): data/modelos_entrenados/v3/modelo_lgbm_seed_52027.pkl
#    Modelo 27 (seed 55001): data/modelos_entrenados/v3/modelo_lgbm_seed_55001.pkl
#    Modelo 28 (seed 57037): data/modelos_entrenados/v3/modelo_lgbm_seed_57037.pkl
#    Modelo 29 (seed 60013): data/modelos_entrenados/v3/modelo_lgbm_seed_60013.pkl
#    Modelo 30 (seed 62003): data/modelos_entrenados/v3/modelo_lgbm_seed_62003.pkl
#    Modelo 31 (seed 65029): data/modelos_entrenados/v3/modelo_lgbm_seed_65029.pkl
#    Modelo 32 (seed 67003): data/modelos_entrenados/v3/modelo_lgbm_seed_67003.pkl
#    Modelo 33 (seed 70001): data/modelos_entrenados/v3/modelo_lgbm_seed_70001.pkl
#    Modelo 34 (seed 72019): data/modelos_entrenados/v3/modelo_lgbm_seed_72019.pkl
#    Modelo 35 (seed 75011): data/modelos_entrenados/v3/modelo_lgbm_seed_75011.pkl
#    Modelo 36 (seed 77003): data/modelos_entrenados/v3/modelo_lgbm_seed_77003.pkl
#    Modelo 37 (seed 80021): data/modelos_entrenados/v3/modelo_lgbm_seed_80021.pkl
#    Modelo 38 (seed 82009): data/modelos_entrenados/v3/modelo_lgbm_seed_82009.pkl
#    Modelo 39 (seed 85009): data/modelos_entrenados/v3/modelo_lgbm_seed_85009.pkl
#    Modelo 40 (seed 87011): data/modelos_entrenados/v3/modelo_lgbm_seed_87011.pkl
#    Modelo 41 (seed 90001): data/modelos_entrenados/v3/modelo_lgbm_seed_90001.pkl
#    Modelo 42 (seed 92003): data/modelos_entrenados/v3/modelo_lgbm_seed_92003.pkl
#    Modelo 43 (seed 95003): data/modelos_entrenados/v3/modelo_lgbm_seed_95003.pkl
#    Modelo 44 (seed 97007): data/modelos_entrenados/v3/modelo_lgbm_seed_97007.pkl
#    Modelo 45 (seed 99013): data/modelos_entrenados/v3/modelo_lgbm_seed_99013.pkl
#    Modelo 46 (seed 99991): data/modelos_entrenados/v3/modelo_lgbm_seed_99991.pkl
#    Modelo 47 (seed 99929): data/modelos_entrenados/v3/modelo_lgbm_seed_99929.pkl
#    Modelo 48 (seed 99881): data/modelos_entrenados/v3/modelo_lgbm_seed_99881.pkl
#    Modelo 49 (seed 99733): data/modelos_entrenados/v3/modelo_lgbm_seed_99733.pkl
#    Modelo 50 (seed 99667): data/modelos_entrenados/v3/modelo_lgbm_seed_99667.pkl
# Early stopping, best iteration is:
# [164]	train's l1: 11.3221	eval's l1: 11.6027
# 💾 Modelo guardado en: data/modelos_entrenados/v3/modelo_lgbm_seed_99667.pkl
# ✅ Modelo 50 entrenado exitosamente!
#    MAE:  11.6027
#    RMSE: 37.5334
#    MAPE: 561.87%
#    Árboles: 164
#
# 🎉 ¡TODOS LOS 50 MODELOS ENTRENADOS EXITOSAMENTE!
# ⭐ Cada modelo usa árboles lineales híbridos con parámetros optimizados por Optuna
# 💾 Todos los modelos han sido guardados en: data/modelos_entrenados/v3/
#
# 📊 RESUMEN DE MÉTRICAS DE LOS 50 MODELOS:
# ============================================================
#     modelo  semilla        mae       rmse        mape  num_trees
# 0        1       42  10.672274  34.003515  325.408290        206
# 1        2      109  10.794758  33.598266  404.306610        188
# 2        3      113  10.471720  34.068376  232.884232        235
# 3        4      151  10.732014  33.753630  321.194634        206
# 4        5      167  10.407562  33.739811  216.543469        257
# 5        6      179  10.623923  33.951776  305.970913        212
# 6        7      193  10.778080  33.588464  382.145450        193
# 7        8      199  10.880621  33.480100  455.976902        179
# 8        9      211  10.412765  33.988438  218.582429        276
# 9       10      241  10.998372  34.003665  480.676841        175
# 10      11      263  10.676301  33.439144  331.298733        203
# 11      12      281  10.777067  36.350948  244.074813        234
# 12      13      307  10.407489  33.173554  240.256845        232
# 13      14      331  10.396254  33.100402  277.163190        219
# 14      15      367  10.534682  34.010248  257.805784        227
# 15      16      401  11.003692  35.364474  374.176481        196
# 16      17      439  10.749047  33.254095  390.452902        191
# 17      18      487  10.690502  34.374602  267.896802        229
# 18      19      563  10.764765  36.024005  322.750085        207
# 19      20      617  10.511302  34.014140  271.912446        225
# 20      21    40009  10.664753  35.034856  221.722023        249
# 21      22    42043  10.524460  36.304032  203.981619        345
# 22      23    45007  11.409910  34.570063  599.193122        160
# 23      24    47017  10.427729  34.310333  205.316201        337
# 24      25    50021  10.596194  33.755085  320.454167        209
# 25      26    52027  10.642835  35.623051  232.727574        256
# 26      27    55001  10.399581  33.995677  214.193419        300
# 27      28    57037  10.562343  34.670068  240.065402        243
# 28      29    60013  10.601277  34.289221  240.323391        239
# 29      30    62003  10.782151  33.977955  375.377974        195
# 30      31    65029  10.694630  33.792506  353.357343        201
# 31      32    67003  10.755670  33.724546  369.062955        197
# 32      33    70001  10.866878  34.064578  413.366958        188
# 33      34    72019  10.602240  33.787236  285.877750        220
# 34      35    75011  10.919263  33.658974  453.881485        179
# 35      36    77003  10.989006  33.684911  481.038127        175
# 36      37    80021  10.403403  34.045354  198.167632        272
# 37      38    82009  11.073994  35.116704  403.034040        189
# 38      39    85009  10.999237  33.615533  495.543551        173
# 39      40    87011  10.631779  33.741273  335.605943        204
# 40      41    90001  10.514986  34.505866  220.500711        262
# 41      42    92003  10.375165  33.288205  225.238719        247
# 42      43    95003  10.854268  36.378226  324.419528        208
# 43      44    97007  10.345382  34.043074  201.410561        296
# 44      45    99013  10.722462  39.648726  204.004680        310
# 45      46    99991  10.871521  35.208729  297.699078        214
# 46      47    99929  10.895196  33.316763  450.300271        180
# 47      48    99881  10.687383  33.187260  381.818814        193
# 48      49    99733  10.588085  33.864226  284.928285        220
# 49      50    99667  11.602714  37.533361  561.871484        164
#
# 📈 ESTADÍSTICAS DE LAS MÉTRICAS:
#    MAE  - Promedio: 10.7058, Std: 0.2531
#    RMSE - Promedio: 34.3604, Std: 1.2250
#    MAPE - Promedio: 322.32%, Std: 101.12%
#
# 🏆 MEJOR MODELO:
#    Modelo: 44
#    Semilla: 97007
#    MAE: 10.3454
#    RMSE: 34.0431
#    MAPE: 201.41%
#    📁 Archivo: data/modelos_entrenados/v3/modelo_lgbm_seed_97007.pkl
#
# 📁 LISTA DE MODELOS GUARDADOS:
#    Modelo  1 (seed  42): data/modelos_entrenados/v3/modelo_lgbm_seed_42.pkl
#    Modelo  2 (seed 109): data/modelos_entrenados/v3/modelo_lgbm_seed_109.pkl
#    Modelo  3 (seed 113): data/modelos_entrenados/v3/modelo_lgbm_seed_113.pkl
#    Modelo  4 (seed 151): data/modelos_entrenados/v3/modelo_lgbm_seed_151.pkl
#    Modelo  5 (seed 167): data/modelos_entrenados/v3/modelo_lgbm_seed_167.pkl
#    Modelo  6 (seed 179): data/modelos_entrenados/v3/modelo_lgbm_seed_179.pkl
#    Modelo  7 (seed 193): data/modelos_entrenados/v3/modelo_lgbm_seed_193.pkl
#    Modelo  8 (seed 199): data/modelos_entrenados/v3/modelo_lgbm_seed_199.pkl
#    Modelo  9 (seed 211): data/modelos_entrenados/v3/modelo_lgbm_seed_211.pkl
#    Modelo 10 (seed 241): data/modelos_entrenados/v3/modelo_lgbm_seed_241.pkl
#    Modelo 11 (seed 263): data/modelos_entrenados/v3/modelo_lgbm_seed_263.pkl
#    Modelo 12 (seed 281): data/modelos_entrenados/v3/modelo_lgbm_seed_281.pkl
#    Modelo 13 (seed 307): data/modelos_entrenados/v3/modelo_lgbm_seed_307.pkl
#    Modelo 14 (seed 331): data/modelos_entrenados/v3/modelo_lgbm_seed_331.pkl
#    Modelo 15 (seed 367): data/modelos_entrenados/v3/modelo_lgbm_seed_367.pkl
#    Modelo 16 (seed 401): data/modelos_entrenados/v3/modelo_lgbm_seed_401.pkl
#    Modelo 17 (seed 439): data/modelos_entrenados/v3/modelo_lgbm_seed_439.pkl
#    Modelo 18 (seed 487): data/modelos_entrenados/v3/modelo_lgbm_seed_487.pkl
#    Modelo 19 (seed 563): data/modelos_entrenados/v3/modelo_lgbm_seed_563.pkl
#    Modelo 20 (seed 617): data/modelos_entrenados/v3/modelo_lgbm_seed_617.pkl
#    Modelo 21 (seed 40009): data/modelos_entrenados/v3/modelo_lgbm_seed_40009.pkl
#    Modelo 22 (seed 42043): data/modelos_entrenados/v3/modelo_lgbm_seed_42043.pkl
#    Modelo 23 (seed 45007): data/modelos_entrenados/v3/modelo_lgbm_seed_45007.pkl
#    Modelo 24 (seed 47017): data/modelos_entrenados/v3/modelo_lgbm_seed_47017.pkl
#    Modelo 25 (seed 50021): data/modelos_entrenados/v3/modelo_lgbm_seed_50021.pkl
#    Modelo 26 (seed 52027): data/modelos_entrenados/v3/modelo_lgbm_seed_52027.pkl
#    Modelo 27 (seed 55001): data/modelos_entrenados/v3/modelo_lgbm_seed_55001.pkl
#    Modelo 28 (seed 57037): data/modelos_entrenados/v3/modelo_lgbm_seed_57037.pkl
#    Modelo 29 (seed 60013): data/modelos_entrenados/v3/modelo_lgbm_seed_60013.pkl
#    Modelo 30 (seed 62003): data/modelos_entrenados/v3/modelo_lgbm_seed_62003.pkl
#    Modelo 31 (seed 65029): data/modelos_entrenados/v3/modelo_lgbm_seed_65029.pkl
#    Modelo 32 (seed 67003): data/modelos_entrenados/v3/modelo_lgbm_seed_67003.pkl
#    Modelo 33 (seed 70001): data/modelos_entrenados/v3/modelo_lgbm_seed_70001.pkl
#    Modelo 34 (seed 72019): data/modelos_entrenados/v3/modelo_lgbm_seed_72019.pkl
#    Modelo 35 (seed 75011): data/modelos_entrenados/v3/modelo_lgbm_seed_75011.pkl
#    Modelo 36 (seed 77003): data/modelos_entrenados/v3/modelo_lgbm_seed_77003.pkl
#    Modelo 37 (seed 80021): data/modelos_entrenados/v3/modelo_lgbm_seed_80021.pkl
#    Modelo 38 (seed 82009): data/modelos_entrenados/v3/modelo_lgbm_seed_82009.pkl
#    Modelo 39 (seed 85009): data/modelos_entrenados/v3/modelo_lgbm_seed_85009.pkl
#    Modelo 40 (seed 87011): data/modelos_entrenados/v3/modelo_lgbm_seed_87011.pkl
#    Modelo 41 (seed 90001): data/modelos_entrenados/v3/modelo_lgbm_seed_90001.pkl
#    Modelo 42 (seed 92003): data/modelos_entrenados/v3/modelo_lgbm_seed_92003.pkl
#    Modelo 43 (seed 95003): data/modelos_entrenados/v3/modelo_lgbm_seed_95003.pkl
#    Modelo 44 (seed 97007): data/modelos_entrenados/v3/modelo_lgbm_seed_97007.pkl
#    Modelo 45 (seed 99013): data/modelos_entrenados/v3/modelo_lgbm_seed_99013.pkl
#    Modelo 46 (seed 99991): data/modelos_entrenados/v3/modelo_lgbm_seed_99991.pkl
#    Modelo 47 (seed 99929): data/modelos_entrenados/v3/modelo_lgbm_seed_99929.pkl
#    Modelo 48 (seed 99881): data/modelos_entrenados/v3/modelo_lgbm_seed_99881.pkl
#    Modelo 49 (seed 99733): data/modelos_entrenados/v3/modelo_lgbm_seed_99733.pkl
#    Modelo 50 (seed 99667): data/modelos_entrenados/v3/modelo_lgbm_seed_99667.pkl

# %%
# # 📊 Análisis de importancia de features
# print("ANÁLISIS DE IMPORTANCIA DE FEATURES")
# print("="*50)

# # Obtener importancia de features
# feature_importance = model.feature_importance(importance_type='gain')
# feature_names = feature_columns

# # Crear DataFrame con importancias
# importance_df = pd.DataFrame({
#     'feature': feature_names,
#     'importance': feature_importance
# }).sort_values('importance', ascending=False)

# print("🔝 Top 10 features más importantes:")
# print(importance_df.head(10))

# # Visualizar importancia
# plt.figure(figsize=(10, 8))
# top_features = importance_df.head(15)
# plt.barh(range(len(top_features)), top_features['importance'])
# plt.yticks(range(len(top_features)), top_features['feature'])
# plt.xlabel('Importancia')
# plt.title('Top 15 Features - Importancia LightGBM')
# plt.gca().invert_yaxis()
# plt.tight_layout()
# plt.show()

# # Análisis de predicciones
# print(f"\n🎯 ANÁLISIS DE PREDICCIONES:")
# print(f"Predicciones mínimas: {y_pred_val.min():.2f}")
# print(f"Predicciones máximas: {y_pred_val.max():.2f}")
# print(f"Predicciones promedio: {y_pred_val.mean():.2f}")
# print(f"Valores reales promedio: {y_val.mean():.2f}")

# # Verificar predicciones negativas
# negative_preds = (y_pred_val < 0).sum()
# print(f"Predicciones negativas: {negative_preds} ({negative_preds/len(y_pred_val)*100:.1f}%)")

# %%
# 🔧 Funciones de utilidad para cargar modelos guardados
import pickle
import os

def cargar_modelo_por_semilla(semilla, modelos_dir='data/modelos_entrenados/v3'):
    """
    Cargar un modelo específico por su semilla
    
    Args:
        semilla (int): La semilla del modelo a cargar
        modelos_dir (str): Directorio donde están guardados los modelos
    
    Returns:
        lightgbm.Booster: El modelo cargado
    """
    model_path = f"{modelos_dir}/modelo_lgbm_seed_{semilla}.pkl"
    if os.path.exists(model_path):
        with open(model_path, 'rb') as f:
            modelo = pickle.load(f)
        print(f"✅ Modelo con semilla {semilla} cargado desde: {model_path}")
        return modelo
    else:
        raise FileNotFoundError(f"❌ No se encontró el modelo con semilla {semilla} en {model_path}")

def cargar_todos_los_modelos(semillas, modelos_dir='data/modelos_entrenados/v3'):
    """
    Cargar todos los modelos por sus semillas
    
    Args:
        semillas (list): Lista de semillas de los modelos a cargar
        modelos_dir (str): Directorio donde están guardados los modelos
    
    Returns:
        list: Lista de modelos cargados
    """
    modelos_cargados = []
    print(f"🔄 Cargando {len(semillas)} modelos desde {modelos_dir}/...")
    
    for i, semilla in enumerate(semillas, 1):
        try:
            modelo = cargar_modelo_por_semilla(semilla, modelos_dir)
            modelos_cargados.append(modelo)
            print(f"   {i:2d}/{len(semillas)} - Modelo semilla {semilla} ✅")
        except FileNotFoundError as e:
            print(f"   {i:2d}/{len(semillas)} - Error: {e}")
            return None
    
    print(f"🎉 Todos los {len(modelos_cargados)} modelos cargados exitosamente!")
    return modelos_cargados

def cargar_mejor_modelo(df_metricas, modelos_dir='data/modelos_entrenados/v3'):
    """
    Cargar el mejor modelo basado en las métricas
    
    Args:
        df_metricas (pd.DataFrame): DataFrame con las métricas de los modelos
        modelos_dir (str): Directorio donde están guardados los modelos
    
    Returns:
        tuple: (modelo, semilla, mae)
    """
    mejor_idx = df_metricas['mae'].idxmin()
    mejor_semilla = df_metricas.loc[mejor_idx, 'semilla']
    mejor_mae = df_metricas.loc[mejor_idx, 'mae']
    
    mejor_modelo = cargar_modelo_por_semilla(mejor_semilla, modelos_dir)
    print(f"🏆 Mejor modelo cargado: Semilla {mejor_semilla} (MAE: {mejor_mae:.4f})")
    
    return mejor_modelo, mejor_semilla, mejor_mae

def generar_predicciones_ensemble(modelos_cargados, X_pred, estrategia='promedio'):
    """
    Generar predicciones usando ensemble de modelos
    
    Args:
        modelos_cargados (list): Lista de modelos cargados
        X_pred (pd.DataFrame): Features para predecir
        estrategia (str): 'promedio', 'mediana', o 'weighted'
    
    Returns:
        np.array: Predicciones del ensemble
    """
    print(f"🔮 Generando predicciones con ensemble de {len(modelos_cargados)} modelos...")
    
    todas_predicciones = []
    for i, modelo in enumerate(modelos_cargados, 1):
        predicciones = modelo.predict(X_pred, num_iteration=modelo.best_iteration)
        predicciones = np.maximum(predicciones, 0)  # Eliminar predicciones negativas
        todas_predicciones.append(predicciones)
        print(f"   Predicciones modelo {i}/{len(modelos_cargados)} generadas ✅")
    
    todas_predicciones = np.array(todas_predicciones)
    
    if estrategia == 'promedio':
        resultado = np.mean(todas_predicciones, axis=0)
        print(f"📊 Ensemble promedio calculado")
    elif estrategia == 'mediana':
        resultado = np.median(todas_predicciones, axis=0)
        print(f"📊 Ensemble mediana calculado")
    else:
        # Por defecto usar promedio
        resultado = np.mean(todas_predicciones, axis=0)
        print(f"📊 Ensemble promedio calculado (estrategia por defecto)")
    
    return resultado, todas_predicciones

print("🔧 Funciones de utilidad para manejo de modelos definidas:")
print("   - cargar_modelo_por_semilla(semilla)")
print("   - cargar_todos_los_modelos(semillas)")
print("   - cargar_mejor_modelo(df_metricas)")
print("   - generar_predicciones_ensemble(modelos, X_pred, estrategia)")
print("✅ Ahora puedes cargar y usar los modelos individuales para ensembles")
# Out:
# 🔧 Funciones de utilidad para manejo de modelos definidas:
#    - cargar_modelo_por_semilla(semilla)
#    - cargar_todos_los_modelos(semillas)
#    - cargar_mejor_modelo(df_metricas)
#    - generar_predicciones_ensemble(modelos, X_pred, estrategia)
# ✅ Ahora puedes cargar y usar los modelos individuales para ensembles

# %%
# 🔮 Generar predicciones finales cargando los modelos guardados
print("GENERACIÓN DE PREDICCIONES FINALES CARGANDO MODELOS GUARDADOS")
print("="*70)

# Preparar datos para predicción (últimos datos disponibles de cada producto)
ultimo_periodo = data_combined.groupby('product_id')['fecha'].max().reset_index()
ultimo_periodo.columns = ['product_id', 'ultima_fecha']

# Unir con datos completos para obtener features más recientes
datos_prediccion = pd.merge(data_combined, ultimo_periodo, on='product_id')
datos_prediccion = datos_prediccion[datos_prediccion['fecha'] == datos_prediccion['ultima_fecha']].copy()

print(f"📊 Productos para predicción: {len(datos_prediccion)}")
print(f"📅 Período base para predicción: {datos_prediccion['periodo'].value_counts().head()}")

# Preparar features para predicción
X_pred = datos_prediccion[feature_columns].copy()
X_pred = X_pred.fillna(0)

print(f"🔍 Shape de datos de predicción: {X_pred.shape}")
print(f"🔍 Valores nulos en predicción: {X_pred.isnull().sum().sum()}")

# 💾 OPCIÓN 1: Cargar todos los modelos desde disco para ensemble completo
print(f"\n💾 CARGANDO MODELOS DESDE DISCO PARA ENSEMBLE...")
modelos_cargados = cargar_todos_los_modelos(semillas)

if modelos_cargados is not None:
    # Generar predicciones con ensemble
    predicciones_promedio, todas_las_predicciones = generar_predicciones_ensemble(
        modelos_cargados, X_pred, estrategia='promedio'
    )
    
    predicciones_mediana, _ = generar_predicciones_ensemble(
        modelos_cargados, X_pred, estrategia='mediana'
    )
    
    print(f"✅ Ensemble completo generado con {len(modelos_cargados)} modelos")
else:
    # Fallback: usar modelos en memoria si fallan las cargas
    print("⚠️ Fallback: Usando modelos en memoria...")
    todas_las_predicciones = []
    for i, modelo in enumerate(modelos, 1):
        print(f"   Generando predicciones con modelo {i} (semilla {semillas[i-1]})...")
        predicciones = modelo.predict(X_pred, num_iteration=modelo.best_iteration)
        predicciones = np.maximum(predicciones, 0)
        todas_las_predicciones.append(predicciones)
    
    todas_las_predicciones = np.array(todas_las_predicciones)
    predicciones_promedio = np.mean(todas_las_predicciones, axis=0)
    predicciones_mediana = np.median(todas_las_predicciones, axis=0)

# 🏆 OPCIÓN 2: Cargar solo el mejor modelo
print(f"\n🏆 CARGANDO MEJOR MODELO INDIVIDUAL...")
mejor_modelo_cargado, mejor_semilla_cargada, mejor_mae_cargado = cargar_mejor_modelo(df_metricas)
mejor_predicciones = mejor_modelo_cargado.predict(X_pred, num_iteration=mejor_modelo_cargado.best_iteration)
mejor_predicciones = np.maximum(mejor_predicciones, 0)

# Calcular estadísticas adicionales
predicciones_std = np.std(todas_las_predicciones, axis=0)
predicciones_min = np.min(todas_las_predicciones, axis=0)
predicciones_max = np.max(todas_las_predicciones, axis=0)

print(f"\n📊 ESTADÍSTICAS DE LAS PREDICCIONES:")
print(f"   Promedio de ensemble promedio: {predicciones_promedio.mean():.2f}")
print(f"   Promedio de ensemble mediana: {predicciones_mediana.mean():.2f}")
print(f"   Promedio de desviación estándar: {predicciones_std.mean():.2f}")
print(f"   Promedio del mejor modelo: {mejor_predicciones.mean():.2f}")

# Crear DataFrames de resultados
print(f"\n💾 Creando DataFrames de resultados...")

# DataFrame con todas las predicciones individuales
df_predicciones_individuales = pd.DataFrame({
    'product_id': datos_prediccion['product_id'].values
})

for i, semilla in enumerate(semillas):
    df_predicciones_individuales[f'pred_modelo_{i+1}_seed_{semilla}'] = todas_las_predicciones[i]

# DataFrame con estadísticas agregadas
resultado_lgbm_estadisticas = pd.DataFrame({
    'product_id': datos_prediccion['product_id'].values,
    'tn_promedio': predicciones_promedio,
    'tn_mediana': predicciones_mediana,
    'tn_std': predicciones_std,
    'tn_min': predicciones_min,
    'tn_max': predicciones_max,
    'tn_mejor_modelo': mejor_predicciones
})

# DataFrame principal (para compatibilidad) - usando promedio
resultado_lgbm = pd.DataFrame({
    'product_id': datos_prediccion['product_id'].values,
    'tn': predicciones_promedio
})

print(f"✅ Predicciones generadas para {len(resultado_lgbm)} productos")
print(f"\n📊 Estadísticas del ensemble promedio:")
print(f"  Promedio: {resultado_lgbm['tn'].mean():.2f}")
print(f"  Mediana:  {resultado_lgbm['tn'].median():.2f}")
print(f"  Mínimo:   {resultado_lgbm['tn'].min():.2f}")
print(f"  Máximo:   {resultado_lgbm['tn'].max():.2f}")
print(f"  Std:      {resultado_lgbm['tn'].std():.2f}")

print(f"\n📊 Estadísticas del mejor modelo:")
print(f"  Promedio: {mejor_predicciones.mean():.2f}")
print(f"  Mediana:  {np.median(mejor_predicciones):.2f}")
print(f"  Mínimo:   {mejor_predicciones.min():.2f}")
print(f"  Máximo:   {mejor_predicciones.max():.2f}")
print(f"  Std:      {mejor_predicciones.std():.2f}")

print(f"\n💾 DEMOSTRACIÓN DE FUNCIONALIDAD:")
print(f"✅ Modelos guardados individualmente por semilla")
print(f"✅ Ensemble promedio generado cargando modelos desde disco")
print(f"✅ Mejor modelo individual cargado por semilla {mejor_semilla_cargada}")
print(f"✅ Funciones disponibles para cargar cualquier modelo específico")

print(f"\nPrimeras 10 predicciones (ensemble promedio):")
print(resultado_lgbm.head(10))
# Out:
# GENERACIÓN DE PREDICCIONES FINALES CARGANDO MODELOS GUARDADOS
# ======================================================================
# 📊 Productos para predicción: 780
# 📅 Período base para predicción: periodo
# 201912    780
# Name: count, dtype: int64
# 🔍 Shape de datos de predicción: (780, 74)
# 🔍 Valores nulos en predicción: 0
#
# 💾 CARGANDO MODELOS DESDE DISCO PARA ENSEMBLE...
# 🔄 Cargando 50 modelos desde data/modelos_entrenados/v3/...
# ✅ Modelo con semilla 42 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_42.pkl
#     1/50 - Modelo semilla 42 ✅
# ✅ Modelo con semilla 109 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_109.pkl
#     2/50 - Modelo semilla 109 ✅
# ✅ Modelo con semilla 113 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_113.pkl
#     3/50 - Modelo semilla 113 ✅
# ✅ Modelo con semilla 151 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_151.pkl
#     4/50 - Modelo semilla 151 ✅
# ✅ Modelo con semilla 167 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_167.pkl
#     5/50 - Modelo semilla 167 ✅
# ✅ Modelo con semilla 179 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_179.pkl
#     6/50 - Modelo semilla 179 ✅
# ✅ Modelo con semilla 193 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_193.pkl
#     7/50 - Modelo semilla 193 ✅
# ✅ Modelo con semilla 199 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_199.pkl
#     8/50 - Modelo semilla 199 ✅
# ✅ Modelo con semilla 211 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_211.pkl
#     9/50 - Modelo semilla 211 ✅
# ✅ Modelo con semilla 241 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_241.pkl
#    10/50 - Modelo semilla 241 ✅
# ✅ Modelo con semilla 263 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_263.pkl
#    11/50 - Modelo semilla 263 ✅
# ✅ Modelo con semilla 281 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_281.pkl
#    12/50 - Modelo semilla 281 ✅
# ✅ Modelo con semilla 307 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_307.pkl
#    13/50 - Modelo semilla 307 ✅
# ✅ Modelo con semilla 331 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_331.pkl
#    14/50 - Modelo semilla 331 ✅
# ✅ Modelo con semilla 367 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_367.pkl
#    15/50 - Modelo semilla 367 ✅
# ✅ Modelo con semilla 401 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_401.pkl
#    16/50 - Modelo semilla 401 ✅
# ✅ Modelo con semilla 439 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_439.pkl
#    17/50 - Modelo semilla 439 ✅
# ✅ Modelo con semilla 487 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_487.pkl
#    18/50 - Modelo semilla 487 ✅
# ✅ Modelo con semilla 563 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_563.pkl
#    19/50 - Modelo semilla 563 ✅
# ✅ Modelo con semilla 617 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_617.pkl
#    20/50 - Modelo semilla 617 ✅
# ✅ Modelo con semilla 40009 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_40009.pkl
#    21/50 - Modelo semilla 40009 ✅
# ✅ Modelo con semilla 42043 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_42043.pkl
#    22/50 - Modelo semilla 42043 ✅
# ✅ Modelo con semilla 45007 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_45007.pkl
#    23/50 - Modelo semilla 45007 ✅
# ✅ Modelo con semilla 47017 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_47017.pkl
#    24/50 - Modelo semilla 47017 ✅
# ✅ Modelo con semilla 50021 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_50021.pkl
#    25/50 - Modelo semilla 50021 ✅
# ✅ Modelo con semilla 52027 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_52027.pkl
#    26/50 - Modelo semilla 52027 ✅
# ✅ Modelo con semilla 55001 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_55001.pkl
#    27/50 - Modelo semilla 55001 ✅
# ✅ Modelo con semilla 57037 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_57037.pkl
#    28/50 - Modelo semilla 57037 ✅
# ✅ Modelo con semilla 60013 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_60013.pkl
#    29/50 - Modelo semilla 60013 ✅
# ✅ Modelo con semilla 62003 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_62003.pkl
#    30/50 - Modelo semilla 62003 ✅
# ✅ Modelo con semilla 65029 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_65029.pkl
#    31/50 - Modelo semilla 65029 ✅
# ✅ Modelo con semilla 67003 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_67003.pkl
#    32/50 - Modelo semilla 67003 ✅
# ✅ Modelo con semilla 70001 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_70001.pkl
#    33/50 - Modelo semilla 70001 ✅
# ✅ Modelo con semilla 72019 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_72019.pkl
#    34/50 - Modelo semilla 72019 ✅
# ✅ Modelo con semilla 75011 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_75011.pkl
#    35/50 - Modelo semilla 75011 ✅
# ✅ Modelo con semilla 77003 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_77003.pkl
#    36/50 - Modelo semilla 77003 ✅
# ✅ Modelo con semilla 331 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_331.pkl
#    14/50 - Modelo semilla 331 ✅
# ✅ Modelo con semilla 367 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_367.pkl
#    15/50 - Modelo semilla 367 ✅
# ✅ Modelo con semilla 401 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_401.pkl
#    16/50 - Modelo semilla 401 ✅
# ✅ Modelo con semilla 439 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_439.pkl
#    17/50 - Modelo semilla 439 ✅
# ✅ Modelo con semilla 487 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_487.pkl
#    18/50 - Modelo semilla 487 ✅
# ✅ Modelo con semilla 563 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_563.pkl
#    19/50 - Modelo semilla 563 ✅
# ✅ Modelo con semilla 617 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_617.pkl
#    20/50 - Modelo semilla 617 ✅
# ✅ Modelo con semilla 40009 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_40009.pkl
#    21/50 - Modelo semilla 40009 ✅
# ✅ Modelo con semilla 42043 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_42043.pkl
#    22/50 - Modelo semilla 42043 ✅
# ✅ Modelo con semilla 45007 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_45007.pkl
#    23/50 - Modelo semilla 45007 ✅
# ✅ Modelo con semilla 47017 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_47017.pkl
#    24/50 - Modelo semilla 47017 ✅
# ✅ Modelo con semilla 50021 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_50021.pkl
#    25/50 - Modelo semilla 50021 ✅
# ✅ Modelo con semilla 52027 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_52027.pkl
#    26/50 - Modelo semilla 52027 ✅
# ✅ Modelo con semilla 55001 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_55001.pkl
#    27/50 - Modelo semilla 55001 ✅
# ✅ Modelo con semilla 57037 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_57037.pkl
#    28/50 - Modelo semilla 57037 ✅
# ✅ Modelo con semilla 60013 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_60013.pkl
#    29/50 - Modelo semilla 60013 ✅
# ✅ Modelo con semilla 62003 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_62003.pkl
#    30/50 - Modelo semilla 62003 ✅
# ✅ Modelo con semilla 65029 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_65029.pkl
#    31/50 - Modelo semilla 65029 ✅
# ✅ Modelo con semilla 67003 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_67003.pkl
#    32/50 - Modelo semilla 67003 ✅
# ✅ Modelo con semilla 70001 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_70001.pkl
#    33/50 - Modelo semilla 70001 ✅
# ✅ Modelo con semilla 72019 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_72019.pkl
#    34/50 - Modelo semilla 72019 ✅
# ✅ Modelo con semilla 75011 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_75011.pkl
#    35/50 - Modelo semilla 75011 ✅
# ✅ Modelo con semilla 77003 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_77003.pkl
#    36/50 - Modelo semilla 77003 ✅
# ✅ Modelo con semilla 80021 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_80021.pkl
#    37/50 - Modelo semilla 80021 ✅
# ✅ Modelo con semilla 82009 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_82009.pkl
#    38/50 - Modelo semilla 82009 ✅
# ✅ Modelo con semilla 85009 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_85009.pkl
#    39/50 - Modelo semilla 85009 ✅
# ✅ Modelo con semilla 87011 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_87011.pkl
#    40/50 - Modelo semilla 87011 ✅
# ✅ Modelo con semilla 90001 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_90001.pkl
#    41/50 - Modelo semilla 90001 ✅
# ✅ Modelo con semilla 92003 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_92003.pkl
#    42/50 - Modelo semilla 92003 ✅
# ✅ Modelo con semilla 95003 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_95003.pkl
#    43/50 - Modelo semilla 95003 ✅
# ✅ Modelo con semilla 97007 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_97007.pkl
#    44/50 - Modelo semilla 97007 ✅
# ✅ Modelo con semilla 99013 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_99013.pkl
#    45/50 - Modelo semilla 99013 ✅
# ✅ Modelo con semilla 99991 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_99991.pkl
#    46/50 - Modelo semilla 99991 ✅
# ✅ Modelo con semilla 99929 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_99929.pkl
#    47/50 - Modelo semilla 99929 ✅
# ✅ Modelo con semilla 99881 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_99881.pkl
#    48/50 - Modelo semilla 99881 ✅
# ✅ Modelo con semilla 99733 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_99733.pkl
#    49/50 - Modelo semilla 99733 ✅
# ✅ Modelo con semilla 99667 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_99667.pkl
#    50/50 - Modelo semilla 99667 ✅
# 🎉 Todos los 50 modelos cargados exitosamente!
# 🔮 Generando predicciones con ensemble de 50 modelos...
#    Predicciones modelo 1/50 generadas ✅
#    Predicciones modelo 2/50 generadas ✅
#    Predicciones modelo 3/50 generadas ✅
#    Predicciones modelo 4/50 generadas ✅
#    Predicciones modelo 5/50 generadas ✅
#    Predicciones modelo 6/50 generadas ✅
#    Predicciones modelo 7/50 generadas ✅
#    Predicciones modelo 8/50 generadas ✅
#    Predicciones modelo 9/50 generadas ✅
#    Predicciones modelo 10/50 generadas ✅
#    Predicciones modelo 11/50 generadas ✅
#    Predicciones modelo 12/50 generadas ✅
#    Predicciones modelo 13/50 generadas ✅
#    Predicciones modelo 14/50 generadas ✅
#    Predicciones modelo 15/50 generadas ✅
# ✅ Modelo con semilla 80021 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_80021.pkl
#    37/50 - Modelo semilla 80021 ✅
# ✅ Modelo con semilla 82009 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_82009.pkl
#    38/50 - Modelo semilla 82009 ✅
# ✅ Modelo con semilla 85009 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_85009.pkl
#    39/50 - Modelo semilla 85009 ✅
# ✅ Modelo con semilla 87011 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_87011.pkl
#    40/50 - Modelo semilla 87011 ✅
# ✅ Modelo con semilla 90001 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_90001.pkl
#    41/50 - Modelo semilla 90001 ✅
# ✅ Modelo con semilla 92003 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_92003.pkl
#    42/50 - Modelo semilla 92003 ✅
# ✅ Modelo con semilla 95003 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_95003.pkl
#    43/50 - Modelo semilla 95003 ✅
# ✅ Modelo con semilla 97007 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_97007.pkl
#    44/50 - Modelo semilla 97007 ✅
# ✅ Modelo con semilla 99013 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_99013.pkl
#    45/50 - Modelo semilla 99013 ✅
# ✅ Modelo con semilla 99991 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_99991.pkl
#    46/50 - Modelo semilla 99991 ✅
# ✅ Modelo con semilla 99929 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_99929.pkl
#    47/50 - Modelo semilla 99929 ✅
# ✅ Modelo con semilla 99881 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_99881.pkl
#    48/50 - Modelo semilla 99881 ✅
# ✅ Modelo con semilla 99733 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_99733.pkl
#    49/50 - Modelo semilla 99733 ✅
# ✅ Modelo con semilla 99667 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_99667.pkl
#    50/50 - Modelo semilla 99667 ✅
# 🎉 Todos los 50 modelos cargados exitosamente!
# 🔮 Generando predicciones con ensemble de 50 modelos...
#    Predicciones modelo 1/50 generadas ✅
#    Predicciones modelo 2/50 generadas ✅
#    Predicciones modelo 3/50 generadas ✅
#    Predicciones modelo 4/50 generadas ✅
#    Predicciones modelo 5/50 generadas ✅
#    Predicciones modelo 6/50 generadas ✅
#    Predicciones modelo 7/50 generadas ✅
#    Predicciones modelo 8/50 generadas ✅
#    Predicciones modelo 9/50 generadas ✅
#    Predicciones modelo 10/50 generadas ✅
#    Predicciones modelo 11/50 generadas ✅
#    Predicciones modelo 12/50 generadas ✅
#    Predicciones modelo 13/50 generadas ✅
#    Predicciones modelo 14/50 generadas ✅
#    Predicciones modelo 15/50 generadas ✅
#    Predicciones modelo 16/50 generadas ✅
#    Predicciones modelo 17/50 generadas ✅
#    Predicciones modelo 18/50 generadas ✅
#    Predicciones modelo 19/50 generadas ✅
#    Predicciones modelo 20/50 generadas ✅
#    Predicciones modelo 21/50 generadas ✅
#    Predicciones modelo 22/50 generadas ✅
#    Predicciones modelo 23/50 generadas ✅
#    Predicciones modelo 24/50 generadas ✅
#    Predicciones modelo 25/50 generadas ✅
#    Predicciones modelo 26/50 generadas ✅
#    Predicciones modelo 27/50 generadas ✅
#    Predicciones modelo 28/50 generadas ✅
#    Predicciones modelo 29/50 generadas ✅
#    Predicciones modelo 30/50 generadas ✅
#    Predicciones modelo 31/50 generadas ✅
#    Predicciones modelo 32/50 generadas ✅
#    Predicciones modelo 33/50 generadas ✅
#    Predicciones modelo 34/50 generadas ✅
#    Predicciones modelo 35/50 generadas ✅
#    Predicciones modelo 36/50 generadas ✅
#    Predicciones modelo 37/50 generadas ✅
#    Predicciones modelo 38/50 generadas ✅
#    Predicciones modelo 39/50 generadas ✅
#    Predicciones modelo 40/50 generadas ✅
#    Predicciones modelo 41/50 generadas ✅
#    Predicciones modelo 42/50 generadas ✅
#    Predicciones modelo 43/50 generadas ✅
#    Predicciones modelo 44/50 generadas ✅
#    Predicciones modelo 45/50 generadas ✅
#    Predicciones modelo 46/50 generadas ✅
#    Predicciones modelo 47/50 generadas ✅
#    Predicciones modelo 48/50 generadas ✅
#    Predicciones modelo 49/50 generadas ✅
#    Predicciones modelo 50/50 generadas ✅
# 📊 Ensemble promedio calculado
# 🔮 Generando predicciones con ensemble de 50 modelos...
#    Predicciones modelo 1/50 generadas ✅
#    Predicciones modelo 2/50 generadas ✅
#    Predicciones modelo 3/50 generadas ✅
#    Predicciones modelo 4/50 generadas ✅
#    Predicciones modelo 5/50 generadas ✅
#    Predicciones modelo 6/50 generadas ✅
#    Predicciones modelo 7/50 generadas ✅
#    Predicciones modelo 8/50 generadas ✅
#    Predicciones modelo 9/50 generadas ✅
#    Predicciones modelo 10/50 generadas ✅
#    Predicciones modelo 11/50 generadas ✅
#    Predicciones modelo 12/50 generadas ✅
#    Predicciones modelo 13/50 generadas ✅
#    Predicciones modelo 14/50 generadas ✅
#    Predicciones modelo 15/50 generadas ✅
#    Predicciones modelo 16/50 generadas ✅
#    Predicciones modelo 17/50 generadas ✅
#    Predicciones modelo 18/50 generadas ✅
#    Predicciones modelo 19/50 generadas ✅
#    Predicciones modelo 20/50 generadas ✅
#    Predicciones modelo 21/50 generadas ✅
#    Predicciones modelo 22/50 generadas ✅
#    Predicciones modelo 23/50 generadas ✅
#    Predicciones modelo 24/50 generadas ✅
#    Predicciones modelo 25/50 generadas ✅
#    Predicciones modelo 26/50 generadas ✅
#    Predicciones modelo 27/50 generadas ✅
#    Predicciones modelo 28/50 generadas ✅
#    Predicciones modelo 29/50 generadas ✅
#    Predicciones modelo 30/50 generadas ✅
#    Predicciones modelo 16/50 generadas ✅
#    Predicciones modelo 17/50 generadas ✅
#    Predicciones modelo 18/50 generadas ✅
#    Predicciones modelo 19/50 generadas ✅
#    Predicciones modelo 20/50 generadas ✅
#    Predicciones modelo 21/50 generadas ✅
#    Predicciones modelo 22/50 generadas ✅
#    Predicciones modelo 23/50 generadas ✅
#    Predicciones modelo 24/50 generadas ✅
#    Predicciones modelo 25/50 generadas ✅
#    Predicciones modelo 26/50 generadas ✅
#    Predicciones modelo 27/50 generadas ✅
#    Predicciones modelo 28/50 generadas ✅
#    Predicciones modelo 29/50 generadas ✅
#    Predicciones modelo 30/50 generadas ✅
#    Predicciones modelo 31/50 generadas ✅
#    Predicciones modelo 32/50 generadas ✅
#    Predicciones modelo 33/50 generadas ✅
#    Predicciones modelo 34/50 generadas ✅
#    Predicciones modelo 35/50 generadas ✅
#    Predicciones modelo 36/50 generadas ✅
#    Predicciones modelo 37/50 generadas ✅
#    Predicciones modelo 38/50 generadas ✅
#    Predicciones modelo 39/50 generadas ✅
#    Predicciones modelo 40/50 generadas ✅
#    Predicciones modelo 41/50 generadas ✅
#    Predicciones modelo 42/50 generadas ✅
#    Predicciones modelo 43/50 generadas ✅
#    Predicciones modelo 44/50 generadas ✅
#    Predicciones modelo 45/50 generadas ✅
#    Predicciones modelo 46/50 generadas ✅
#    Predicciones modelo 47/50 generadas ✅
#    Predicciones modelo 48/50 generadas ✅
#    Predicciones modelo 49/50 generadas ✅
#    Predicciones modelo 50/50 generadas ✅
# 📊 Ensemble promedio calculado
# 🔮 Generando predicciones con ensemble de 50 modelos...
#    Predicciones modelo 1/50 generadas ✅
#    Predicciones modelo 2/50 generadas ✅
#    Predicciones modelo 3/50 generadas ✅
#    Predicciones modelo 4/50 generadas ✅
#    Predicciones modelo 5/50 generadas ✅
#    Predicciones modelo 6/50 generadas ✅
#    Predicciones modelo 7/50 generadas ✅
#    Predicciones modelo 8/50 generadas ✅
#    Predicciones modelo 9/50 generadas ✅
#    Predicciones modelo 10/50 generadas ✅
#    Predicciones modelo 11/50 generadas ✅
#    Predicciones modelo 12/50 generadas ✅
#    Predicciones modelo 13/50 generadas ✅
#    Predicciones modelo 14/50 generadas ✅
#    Predicciones modelo 15/50 generadas ✅
#    Predicciones modelo 16/50 generadas ✅
#    Predicciones modelo 17/50 generadas ✅
#    Predicciones modelo 18/50 generadas ✅
#    Predicciones modelo 19/50 generadas ✅
#    Predicciones modelo 20/50 generadas ✅
#    Predicciones modelo 21/50 generadas ✅
#    Predicciones modelo 22/50 generadas ✅
#    Predicciones modelo 23/50 generadas ✅
#    Predicciones modelo 24/50 generadas ✅
#    Predicciones modelo 25/50 generadas ✅
#    Predicciones modelo 26/50 generadas ✅
#    Predicciones modelo 27/50 generadas ✅
#    Predicciones modelo 28/50 generadas ✅
#    Predicciones modelo 29/50 generadas ✅
#    Predicciones modelo 30/50 generadas ✅
#    Predicciones modelo 31/50 generadas ✅
#    Predicciones modelo 32/50 generadas ✅
#    Predicciones modelo 33/50 generadas ✅
#    Predicciones modelo 34/50 generadas ✅
#    Predicciones modelo 35/50 generadas ✅
#    Predicciones modelo 36/50 generadas ✅
#    Predicciones modelo 37/50 generadas ✅
#    Predicciones modelo 38/50 generadas ✅
#    Predicciones modelo 39/50 generadas ✅
#    Predicciones modelo 40/50 generadas ✅
#    Predicciones modelo 41/50 generadas ✅
#    Predicciones modelo 42/50 generadas ✅
#    Predicciones modelo 43/50 generadas ✅
#    Predicciones modelo 44/50 generadas ✅
#    Predicciones modelo 45/50 generadas ✅
#    Predicciones modelo 46/50 generadas ✅
#    Predicciones modelo 47/50 generadas ✅
#    Predicciones modelo 48/50 generadas ✅
#    Predicciones modelo 49/50 generadas ✅
#    Predicciones modelo 50/50 generadas ✅
# 📊 Ensemble mediana calculado
# ✅ Ensemble completo generado con 50 modelos
#
# 🏆 CARGANDO MEJOR MODELO INDIVIDUAL...
# ✅ Modelo con semilla 97007 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_97007.pkl
# 🏆 Mejor modelo cargado: Semilla 97007 (MAE: 10.3454)
#
# 📊 ESTADÍSTICAS DE LAS PREDICCIONES:
#    Promedio de ensemble promedio: 34.45
#    Promedio de ensemble mediana: 34.33
#    Promedio de desviación estándar: 1.47
#    Promedio del mejor modelo: 34.35
#
# 💾 Creando DataFrames de resultados...
# ✅ Predicciones generadas para 780 productos
#
# 📊 Estadísticas del ensemble promedio:
#   Promedio: 34.45
#   Mediana:  9.14
#   Mínimo:   1.06
#   Máximo:   1371.28
#   Std:      90.20
#
# 📊 Estadísticas del mejor modelo:
#   Promedio: 34.35
#   Mediana:  8.51
#   Mínimo:   0.40
#   Máximo:   1370.59
#   Std:      90.93
#
# 💾 DEMOSTRACIÓN DE FUNCIONALIDAD:
# ✅ Modelos guardados individualmente por semilla
# ✅ Ensemble promedio generado cargando modelos desde disco
# ✅ Mejor modelo individual cargado por semilla 97007
# ✅ Funciones disponibles para cargar cualquier modelo específico
#
# Primeras 10 predicciones (ensemble promedio):
#    product_id           tn
# 0       20001  1371.277605
# 1       20002  1107.873036
# 2       20003   744.782148
# 3       20004   471.643856
# 4       20005   577.964977
# 5       20006   399.473275
# 6       20007   349.407301
# 7       20008   349.121592
# 8       20009   395.588053
# 9       20010   332.666909
#    Predicciones modelo 31/50 generadas ✅
#    Predicciones modelo 32/50 generadas ✅
#    Predicciones modelo 33/50 generadas ✅
#    Predicciones modelo 34/50 generadas ✅
#    Predicciones modelo 35/50 generadas ✅
#    Predicciones modelo 36/50 generadas ✅
#    Predicciones modelo 37/50 generadas ✅
#    Predicciones modelo 38/50 generadas ✅
#    Predicciones modelo 39/50 generadas ✅
#    Predicciones modelo 40/50 generadas ✅
#    Predicciones modelo 41/50 generadas ✅
#    Predicciones modelo 42/50 generadas ✅
#    Predicciones modelo 43/50 generadas ✅
#    Predicciones modelo 44/50 generadas ✅
#    Predicciones modelo 45/50 generadas ✅
#    Predicciones modelo 46/50 generadas ✅
#    Predicciones modelo 47/50 generadas ✅
#    Predicciones modelo 48/50 generadas ✅
#    Predicciones modelo 49/50 generadas ✅
#    Predicciones modelo 50/50 generadas ✅
# 📊 Ensemble mediana calculado
# ✅ Ensemble completo generado con 50 modelos
#
# 🏆 CARGANDO MEJOR MODELO INDIVIDUAL...
# ✅ Modelo con semilla 97007 cargado desde: data/modelos_entrenados/v3/modelo_lgbm_seed_97007.pkl
# 🏆 Mejor modelo cargado: Semilla 97007 (MAE: 10.3454)
#
# 📊 ESTADÍSTICAS DE LAS PREDICCIONES:
#    Promedio de ensemble promedio: 34.45
#    Promedio de ensemble mediana: 34.33
#    Promedio de desviación estándar: 1.47
#    Promedio del mejor modelo: 34.35
#
# 💾 Creando DataFrames de resultados...
# ✅ Predicciones generadas para 780 productos
#
# 📊 Estadísticas del ensemble promedio:
#   Promedio: 34.45
#   Mediana:  9.14
#   Mínimo:   1.06
#   Máximo:   1371.28
#   Std:      90.20
#
# 📊 Estadísticas del mejor modelo:
#   Promedio: 34.35
#   Mediana:  8.51
#   Mínimo:   0.40
#   Máximo:   1370.59
#   Std:      90.93
#
# 💾 DEMOSTRACIÓN DE FUNCIONALIDAD:
# ✅ Modelos guardados individualmente por semilla
# ✅ Ensemble promedio generado cargando modelos desde disco
# ✅ Mejor modelo individual cargado por semilla 97007
# ✅ Funciones disponibles para cargar cualquier modelo específico
#
# Primeras 10 predicciones (ensemble promedio):
#    product_id           tn
# 0       20001  1371.277605
# 1       20002  1107.873036
# 2       20003   744.782148
# 3       20004   471.643856
# 4       20005   577.964977
# 5       20006   399.473275
# 6       20007   349.407301
# 7       20008   349.121592
# 8       20009   395.588053
# 9       20010   332.666909

# %%
# 💾 Guardar todos los archivos de predicciones y información de modelos
import os
os.makedirs('data', exist_ok=True)

print("GUARDANDO ARCHIVOS DE PREDICCIONES Y MODELOS")
print("="*60)

# 1. Guardar predicciones promedio (archivo principal)
archivo_promedio = 'data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_promedio.csv'
resultado_lgbm.to_csv(archivo_promedio, index=False)
print(f"✅ Predicciones promedio guardadas en: {archivo_promedio}")

# 2. Guardar predicciones del mejor modelo
archivo_mejor = 'data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_mejor.csv'
resultado_mejor = pd.DataFrame({
    'product_id': datos_prediccion['product_id'].values,
    'tn': mejor_predicciones
})
resultado_mejor.to_csv(archivo_mejor, index=False)
print(f"✅ Predicciones del mejor modelo guardadas en: {archivo_mejor}")

# 3. Guardar estadísticas completas
archivo_estadisticas = 'data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_estadisticas.csv'
resultado_lgbm_estadisticas.to_csv(archivo_estadisticas, index=False)
print(f"✅ Estadísticas completas guardadas en: {archivo_estadisticas}")

# 4. Guardar todas las predicciones individuales
archivo_individuales = 'data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_individuales.csv'
df_predicciones_individuales.to_csv(archivo_individuales, index=False)
print(f"✅ Predicciones individuales guardadas en: {archivo_individuales}")

# 5. Guardar métricas de los modelos (incluyendo rutas de archivos)
archivo_metricas = 'data/metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_2.csv'
df_metricas.to_csv(archivo_metricas, index=False)
print(f"✅ Métricas de los modelos guardadas en: {archivo_metricas}")

# 6. Guardar inventario de modelos guardados
archivo_inventario = 'data/inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_2.csv'
inventario_modelos = df_metricas[['modelo', 'semilla', 'mae', 'rmse', 'mape', 'model_file']].copy()
inventario_modelos['modelo_existe'] = inventario_modelos['model_file'].apply(os.path.exists)
inventario_modelos.to_csv(archivo_inventario, index=False)
print(f"✅ Inventario de modelos guardado en: {archivo_inventario}")

print(f"\n📁 RESUMEN DE ARCHIVOS GUARDADOS:")
print(f"   1. {archivo_promedio} - Predicciones promedio de los 20 modelos")
print(f"   2. {archivo_mejor} - Predicciones del mejor modelo (semilla {mejor_semilla})")
print(f"   3. {archivo_estadisticas} - Estadísticas completas (promedio, mediana, std, min, max)")
print(f"   4. {archivo_individuales} - Predicciones de cada uno de los 20 modelos")
print(f"   5. {archivo_metricas} - Métricas de rendimiento de cada modelo")
print(f"   6. {archivo_inventario} - Inventario de modelos guardados con ubicaciones")

print(f"\n🤖 MODELOS INDIVIDUALES GUARDADOS:")
print(f"   Directorio: {modelos_dir}/")
for i, row in df_metricas.iterrows():
    existe = "✅" if os.path.exists(row['model_file']) else "❌"
    print(f"   {existe} modelo_lgbm_seed_{row['semilla']}.pkl (MAE: {row['mae']:.4f})")

print(f"\n🎯 INSTRUCCIONES DE USO:")
print(f"   📖 Para cargar un modelo específico:")
print(f"      modelo = cargar_modelo_por_semilla(semilla)")
print(f"   📖 Para cargar el mejor modelo:")
print(f"      mejor_modelo, semilla, mae = cargar_mejor_modelo(df_metricas)")
print(f"   📖 Para generar ensemble personalizado:")
print(f"      semillas_subset = [42, 113, 241]  # Ejemplo")
print(f"      modelos_subset = cargar_todos_los_modelos(semillas_subset)")
print(f"      predicciones = generar_predicciones_ensemble(modelos_subset, X_pred)")

print(f"\n✅ SISTEMA DE MODELOS PERSISTENTES IMPLEMENTADO EXITOSAMENTE!")
print(f"🔄 Los modelos están disponibles para reutilización y experimentos futuros")
# Out:
# GUARDANDO ARCHIVOS DE PREDICCIONES Y MODELOS
# ============================================================
# ✅ Predicciones promedio guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_promedio.csv
# ✅ Predicciones del mejor modelo guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_mejor.csv
# ✅ Estadísticas completas guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_estadisticas.csv
# ✅ Predicciones individuales guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_individuales.csv
# ✅ Métricas de los modelos guardadas en: data/metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_2.csv
# ✅ Inventario de modelos guardado en: data/inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_2.csv
#
# 📁 RESUMEN DE ARCHIVOS GUARDADOS:
#    1. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_promedio.csv - Predicciones promedio de los 20 modelos
#    2. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_mejor.csv - Predicciones del mejor modelo (semilla 97007)
#    3. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_estadisticas.csv - Estadísticas completas (promedio, mediana, std, min, max)
#    4. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_individuales.csv - Predicciones de cada uno de los 20 modelos
#    5. data/metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_2.csv - Métricas de rendimiento de cada modelo
#    6. data/inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_2.csv - Inventario de modelos guardados con ubicaciones
#
# 🤖 MODELOS INDIVIDUALES GUARDADOS:
#    Directorio: data/modelos_entrenados/v3/
#    ✅ modelo_lgbm_seed_42.pkl (MAE: 10.6723)
#    ✅ modelo_lgbm_seed_109.pkl (MAE: 10.7948)
#    ✅ modelo_lgbm_seed_113.pkl (MAE: 10.4717)
#    ✅ modelo_lgbm_seed_151.pkl (MAE: 10.7320)
#    ✅ modelo_lgbm_seed_167.pkl (MAE: 10.4076)
#    ✅ modelo_lgbm_seed_179.pkl (MAE: 10.6239)
#    ✅ modelo_lgbm_seed_193.pkl (MAE: 10.7781)
#    ✅ modelo_lgbm_seed_199.pkl (MAE: 10.8806)
#    ✅ modelo_lgbm_seed_211.pkl (MAE: 10.4128)
#    ✅ modelo_lgbm_seed_241.pkl (MAE: 10.9984)
#    ✅ modelo_lgbm_seed_263.pkl (MAE: 10.6763)
#    ✅ modelo_lgbm_seed_281.pkl (MAE: 10.7771)
#    ✅ modelo_lgbm_seed_307.pkl (MAE: 10.4075)
#    ✅ modelo_lgbm_seed_331.pkl (MAE: 10.3963)
#    ✅ modelo_lgbm_seed_367.pkl (MAE: 10.5347)
#    ✅ modelo_lgbm_seed_401.pkl (MAE: 11.0037)
#    ✅ modelo_lgbm_seed_439.pkl (MAE: 10.7490)
#    ✅ modelo_lgbm_seed_487.pkl (MAE: 10.6905)
#    ✅ modelo_lgbm_seed_563.pkl (MAE: 10.7648)
#    ✅ modelo_lgbm_seed_617.pkl (MAE: 10.5113)
#    ✅ modelo_lgbm_seed_40009.pkl (MAE: 10.6648)
#    ✅ modelo_lgbm_seed_42043.pkl (MAE: 10.5245)
#    ✅ modelo_lgbm_seed_45007.pkl (MAE: 11.4099)
#    ✅ modelo_lgbm_seed_47017.pkl (MAE: 10.4277)
#    ✅ modelo_lgbm_seed_50021.pkl (MAE: 10.5962)
#    ✅ modelo_lgbm_seed_52027.pkl (MAE: 10.6428)
#    ✅ modelo_lgbm_seed_55001.pkl (MAE: 10.3996)
#    ✅ modelo_lgbm_seed_57037.pkl (MAE: 10.5623)
#    ✅ modelo_lgbm_seed_60013.pkl (MAE: 10.6013)
#    ✅ modelo_lgbm_seed_62003.pkl (MAE: 10.7822)
#    ✅ modelo_lgbm_seed_65029.pkl (MAE: 10.6946)
#    ✅ modelo_lgbm_seed_67003.pkl (MAE: 10.7557)
#    ✅ modelo_lgbm_seed_70001.pkl (MAE: 10.8669)
#    ✅ modelo_lgbm_seed_72019.pkl (MAE: 10.6022)
#    ✅ modelo_lgbm_seed_75011.pkl (MAE: 10.9193)
#    ✅ modelo_lgbm_seed_77003.pkl (MAE: 10.9890)
#    ✅ modelo_lgbm_seed_80021.pkl (MAE: 10.4034)
#    ✅ modelo_lgbm_seed_82009.pkl (MAE: 11.0740)
#    ✅ modelo_lgbm_seed_85009.pkl (MAE: 10.9992)
#    ✅ modelo_lgbm_seed_87011.pkl (MAE: 10.6318)
#    ✅ modelo_lgbm_seed_90001.pkl (MAE: 10.5150)
#    ✅ modelo_lgbm_seed_92003.pkl (MAE: 10.3752)
#    ✅ modelo_lgbm_seed_95003.pkl (MAE: 10.8543)
#    ✅ modelo_lgbm_seed_97007.pkl (MAE: 10.3454)
#    ✅ modelo_lgbm_seed_99013.pkl (MAE: 10.7225)
#    ✅ modelo_lgbm_seed_99991.pkl (MAE: 10.8715)
#    ✅ modelo_lgbm_seed_99929.pkl (MAE: 10.8952)
#    ✅ modelo_lgbm_seed_99881.pkl (MAE: 10.6874)
#    ✅ modelo_lgbm_seed_99733.pkl (MAE: 10.5881)
#    ✅ modelo_lgbm_seed_99667.pkl (MAE: 11.6027)
#
# 🎯 INSTRUCCIONES DE USO:
#    📖 Para cargar un modelo específico:
#       modelo = cargar_modelo_por_semilla(semilla)
#    📖 Para cargar el mejor modelo:
#       mejor_modelo, semilla, mae = cargar_mejor_modelo(df_metricas)
#    📖 Para generar ensemble personalizado:
#       semillas_subset = [42, 113, 241]  # Ejemplo
#       modelos_subset = cargar_todos_los_modelos(semillas_subset)
#       predicciones = generar_predicciones_ensemble(modelos_subset, X_pred)
#
# ✅ SISTEMA DE MODELOS PERSISTENTES IMPLEMENTADO EXITOSAMENTE!
# 🔄 Los modelos están disponibles para reutilización y experimentos futuros
# ✅ Predicciones individuales guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_individuales.csv
# ✅ Métricas de los modelos guardadas en: data/metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_2.csv
# ✅ Inventario de modelos guardado en: data/inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_2.csv
#
# 📁 RESUMEN DE ARCHIVOS GUARDADOS:
#    1. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_promedio.csv - Predicciones promedio de los 20 modelos
#    2. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_mejor.csv - Predicciones del mejor modelo (semilla 97007)
#    3. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_estadisticas.csv - Estadísticas completas (promedio, mediana, std, min, max)
#    4. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_individuales.csv - Predicciones de cada uno de los 20 modelos
#    5. data/metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_2.csv - Métricas de rendimiento de cada modelo
#    6. data/inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_2.csv - Inventario de modelos guardados con ubicaciones
#
# 🤖 MODELOS INDIVIDUALES GUARDADOS:
#    Directorio: data/modelos_entrenados/v3/
#    ✅ modelo_lgbm_seed_42.pkl (MAE: 10.6723)
#    ✅ modelo_lgbm_seed_109.pkl (MAE: 10.7948)
#    ✅ modelo_lgbm_seed_113.pkl (MAE: 10.4717)
#    ✅ modelo_lgbm_seed_151.pkl (MAE: 10.7320)
#    ✅ modelo_lgbm_seed_167.pkl (MAE: 10.4076)
#    ✅ modelo_lgbm_seed_179.pkl (MAE: 10.6239)
#    ✅ modelo_lgbm_seed_193.pkl (MAE: 10.7781)
#    ✅ modelo_lgbm_seed_199.pkl (MAE: 10.8806)
#    ✅ modelo_lgbm_seed_211.pkl (MAE: 10.4128)
#    ✅ modelo_lgbm_seed_241.pkl (MAE: 10.9984)
#    ✅ modelo_lgbm_seed_263.pkl (MAE: 10.6763)
#    ✅ modelo_lgbm_seed_281.pkl (MAE: 10.7771)
#    ✅ modelo_lgbm_seed_307.pkl (MAE: 10.4075)
#    ✅ modelo_lgbm_seed_331.pkl (MAE: 10.3963)
#    ✅ modelo_lgbm_seed_367.pkl (MAE: 10.5347)
#    ✅ modelo_lgbm_seed_401.pkl (MAE: 11.0037)
#    ✅ modelo_lgbm_seed_439.pkl (MAE: 10.7490)
#    ✅ modelo_lgbm_seed_487.pkl (MAE: 10.6905)
#    ✅ modelo_lgbm_seed_563.pkl (MAE: 10.7648)
#    ✅ modelo_lgbm_seed_617.pkl (MAE: 10.5113)
#    ✅ modelo_lgbm_seed_40009.pkl (MAE: 10.6648)
#    ✅ modelo_lgbm_seed_42043.pkl (MAE: 10.5245)
#    ✅ modelo_lgbm_seed_45007.pkl (MAE: 11.4099)
#    ✅ modelo_lgbm_seed_47017.pkl (MAE: 10.4277)
#    ✅ modelo_lgbm_seed_50021.pkl (MAE: 10.5962)
#    ✅ modelo_lgbm_seed_52027.pkl (MAE: 10.6428)
#    ✅ modelo_lgbm_seed_55001.pkl (MAE: 10.3996)
#    ✅ modelo_lgbm_seed_57037.pkl (MAE: 10.5623)
#    ✅ modelo_lgbm_seed_60013.pkl (MAE: 10.6013)
#    ✅ modelo_lgbm_seed_62003.pkl (MAE: 10.7822)
#    ✅ modelo_lgbm_seed_65029.pkl (MAE: 10.6946)
#    ✅ modelo_lgbm_seed_67003.pkl (MAE: 10.7557)
#    ✅ modelo_lgbm_seed_70001.pkl (MAE: 10.8669)
#    ✅ modelo_lgbm_seed_72019.pkl (MAE: 10.6022)
#    ✅ modelo_lgbm_seed_75011.pkl (MAE: 10.9193)
#    ✅ modelo_lgbm_seed_77003.pkl (MAE: 10.9890)
#    ✅ modelo_lgbm_seed_80021.pkl (MAE: 10.4034)
#    ✅ modelo_lgbm_seed_82009.pkl (MAE: 11.0740)
#    ✅ modelo_lgbm_seed_85009.pkl (MAE: 10.9992)
#    ✅ modelo_lgbm_seed_87011.pkl (MAE: 10.6318)
#    ✅ modelo_lgbm_seed_90001.pkl (MAE: 10.5150)
#    ✅ modelo_lgbm_seed_92003.pkl (MAE: 10.3752)
#    ✅ modelo_lgbm_seed_95003.pkl (MAE: 10.8543)
#    ✅ modelo_lgbm_seed_97007.pkl (MAE: 10.3454)
#    ✅ modelo_lgbm_seed_99013.pkl (MAE: 10.7225)
#    ✅ modelo_lgbm_seed_99991.pkl (MAE: 10.8715)
#    ✅ modelo_lgbm_seed_99929.pkl (MAE: 10.8952)
#    ✅ modelo_lgbm_seed_99881.pkl (MAE: 10.6874)
#    ✅ modelo_lgbm_seed_99733.pkl (MAE: 10.5881)
#    ✅ modelo_lgbm_seed_99667.pkl (MAE: 11.6027)
#
# 🎯 INSTRUCCIONES DE USO:
#    📖 Para cargar un modelo específico:
#       modelo = cargar_modelo_por_semilla(semilla)
#    📖 Para cargar el mejor modelo:
#       mejor_modelo, semilla, mae = cargar_mejor_modelo(df_metricas)
#    📖 Para generar ensemble personalizado:
#       semillas_subset = [42, 113, 241]  # Ejemplo
#       modelos_subset = cargar_todos_los_modelos(semillas_subset)
#       predicciones = generar_predicciones_ensemble(modelos_subset, X_pred)
#
# ✅ SISTEMA DE MODELOS PERSISTENTES IMPLEMENTADO EXITOSAMENTE!
# 🔄 Los modelos están disponibles para reutilización y experimentos futuros

# %%
print(f"🎉 ¡SISTEMA DE ENSEMBLE CON MODELOS PERSISTENTES COMPLETADO!")
print(f"⭐ Cada modelo usa árboles lineales híbridos con optimización Optuna")
print(f"🔢 20 modelos entrenados con semillas diferentes para mayor robustez")
print(f"💾 Todos los modelos guardados individualmente para reutilización")
print(f"🏆 Mejor modelo individual: Semilla {mejor_semilla} (MAE: {df_metricas.loc[mejor_modelo_idx, 'mae']:.4f})")
print(f"📊 MAE promedio del conjunto: {df_metricas['mae'].mean():.4f} (±{df_metricas['mae'].std():.4f})")
print(f"📁 6 archivos de predicciones + 20 modelos individuales guardados")
print(f"🔧 Funciones de utilidad disponibles para cargar modelos por semilla")
print(f"🎲 Semillas utilizadas: {semillas}")
print(f"🏆 Tecnología: LINEAR_TREE + OPTUNA + 36 LAGS + ENSEMBLE PERSISTENTE DE 20 MODELOS")
print(f"")
print(f"🎯 NUEVAS CAPACIDADES DISPONIBLES:")
print(f"   🔄 Cargar cualquier modelo por su semilla")
print(f"   🏆 Cargar automáticamente el mejor modelo")
print(f"   📊 Generar ensembles personalizados con subconjuntos de modelos")
print(f"   💾 Reutilizar modelos sin re-entrenar")
print(f"   🔬 Experimentar con diferentes estrategias de ensemble")
# Out:
# 🎉 ¡SISTEMA DE ENSEMBLE CON MODELOS PERSISTENTES COMPLETADO!
# ⭐ Cada modelo usa árboles lineales híbridos con optimización Optuna
# 🔢 20 modelos entrenados con semillas diferentes para mayor robustez
# 💾 Todos los modelos guardados individualmente para reutilización
# 🏆 Mejor modelo individual: Semilla 97007 (MAE: 10.3454)
# 📊 MAE promedio del conjunto: 10.7058 (±0.2531)
# 📁 6 archivos de predicciones + 20 modelos individuales guardados
# 🔧 Funciones de utilidad disponibles para cargar modelos por semilla
# 🎲 Semillas utilizadas: [42, 109, 113, 151, 167, 179, 193, 199, 211, 241, 263, 281, 307, 331, 367, 401, 439, 487, 563, 617, 40009, 42043, 45007, 47017, 50021, 52027, 55001, 57037, 60013, 62003, 65029, 67003, 70001, 72019, 75011, 77003, 80021, 82009, 85009, 87011, 90001, 92003, 95003, 97007, 99013, 99991, 99929, 99881, 99733, 99667]
# 🏆 Tecnología: LINEAR_TREE + OPTUNA + 36 LAGS + ENSEMBLE PERSISTENTE DE 20 MODELOS
#
# 🎯 NUEVAS CAPACIDADES DISPONIBLES:
#    🔄 Cargar cualquier modelo por su semilla
#    🏆 Cargar automáticamente el mejor modelo
#    📊 Generar ensembles personalizados con subconjuntos de modelos
#    💾 Reutilizar modelos sin re-entrenar
#    🔬 Experimentar con diferentes estrategias de ensemble

# %%
# Guardar información de reproductibilidad del conjunto de modelos con persistencia
import json
os.makedirs('data', exist_ok=True)

# Crear información detallada de reproductibilidad
reproducibility_info_ensemble = {
    'experimento': 'LGBM_v3_FE_02_v3_linear_tree_opt_03_36lags_semillerio_2_persistente',
    'descripcion': 'Conjunto de 50 modelos LightGBM con linear_tree, parámetros optimizados por Optuna y persistencia individual - Semillerio 2',
    'numero_modelos': len(semillas),
    'semillas_utilizadas': semillas,
    'semilla_optuna': 42,
    'modelos_guardados': {
        'directorio': modelos_dir,
        'formato': 'pickle (.pkl)',
        'patron_nombre': 'modelo_lgbm_seed_{semilla}.pkl',
        'total_archivos': len(semillas)
    },
    'mejor_modelo': {
        'indice': int(mejor_modelo_idx + 1),
        'semilla': int(mejor_semilla),
        'mae': float(df_metricas.loc[mejor_modelo_idx, 'mae']),
        'rmse': float(df_metricas.loc[mejor_modelo_idx, 'rmse']),
        'mape': float(df_metricas.loc[mejor_modelo_idx, 'mape']),
        'archivo': mejor_model_file
    },
    'estadisticas_conjunto': {
        'mae_promedio': float(df_metricas['mae'].mean()),
        'mae_std': float(df_metricas['mae'].std()),
        'rmse_promedio': float(df_metricas['rmse'].mean()),
        'rmse_std': float(df_metricas['rmse'].std()),
        'mape_promedio': float(df_metricas['mape'].mean()),
        'mape_std': float(df_metricas['mape'].std())
    },
    'parametros_optimizados': {
        'linear_tree': lgb_params_base['linear_tree'],
        'lambda_l1': lgb_params_base['lambda_l1'],
        'lambda_l2': lgb_params_base['lambda_l2'],
        'num_leaves': lgb_params_base['num_leaves'],
        'feature_fraction': lgb_params_base['feature_fraction'],
        'learning_rate': lgb_params_base['learning_rate'],
        'bagging_fraction': lgb_params_base['bagging_fraction'],
        'bagging_freq': lgb_params_base['bagging_freq'],
        'min_child_samples': lgb_params_base['min_child_samples'],
        'max_bin': lgb_params_base['max_bin']
    },
    'configuracion_entrenamiento': {
        'num_boost_round': 2000,
        'early_stopping_rounds': 150,
        'validation_split': 0.8
    },
    'features_utilizadas': len(feature_columns),
    'lags_toneladas': 36,
    'funciones_utilidad': [
        'cargar_modelo_por_semilla(semilla)',
        'cargar_todos_los_modelos(semillas)',
        'cargar_mejor_modelo(df_metricas)',
        'generar_predicciones_ensemble(modelos, X_pred, estrategia)'
    ],
    'archivos_generados': [
        'pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_promedio.csv',
        'pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_mejor.csv',
        'pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_estadisticas.csv',
        'pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_2_individuales.csv',
        'metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_2.csv',
        'inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_2.csv'
    ],
    'modelos_individuales': [f"modelo_lgbm_seed_{seed}.pkl" for seed in semillas]
}

# Guardar archivo de reproductibilidad
archivo_reproducibilidad = 'data/reproducibility_info_lgbm_v3_FE_02_v3_linear_tree_opt_36lags_sem_2_ensemble_persistente.json'
with open(archivo_reproducibilidad, 'w') as f:
    json.dump(reproducibility_info_ensemble, f, indent=2)

print("🎲 INFORMACIÓN DE REPRODUCTIBILIDAD DEL CONJUNTO PERSISTENTE:")
print(f"   Experimento: {reproducibility_info_ensemble['experimento']}")
print(f"   Número de modelos: {len(semillas)}")
print(f"   Semillas utilizadas: {semillas}")
print(f"   Semilla para Optuna: 42")
print(f"   Mejor modelo: #{mejor_modelo_idx + 1} (semilla {mejor_semilla})")
print(f"   MAE promedio: {df_metricas['mae'].mean():.4f} (±{df_metricas['mae'].std():.4f})")
print(f"   Modelos guardados en: {modelos_dir}/")

print(f"\n✅ Información de reproductibilidad guardada en:")
print(f"   {archivo_reproducibilidad}")

print(f"\n📊 RESUMEN FINAL DEL EXPERIMENTO CON PERSISTENCIA:")
print(f"   🔬 Estrategia: Conjunto de {len(semillas)} modelos LightGBM persistentes")
print(f"   ⭐ Tecnología: LINEAR_TREE + OPTUNA + 36 LAGS + PERSISTENCIA")
print(f"   🎯 Objetivo: Máxima robustez, precisión y reutilización")
print(f"   📁 Archivos: 6 archivos CSV + {len(semillas)} modelos .pkl + 1 JSON reproductibilidad")
print(f"   🏆 Resultado: Sistema completo de ensemble reutilizable")
print(f"   🔄 Capacidad: Cargar y usar cualquier modelo individual por semilla")
print(f"   🎛️ Flexibilidad: Crear ensembles personalizados sin re-entrenar")

print(f"\n🎉 ¡SISTEMA DE MACHINE LEARNING PERSISTENTE COMPLETADO EXITOSAMENTE!")
print(f"💪 Máxima robustez, flexibilidad y capacidad de experimentación")
# Out:
# 🎲 INFORMACIÓN DE REPRODUCTIBILIDAD DEL CONJUNTO PERSISTENTE:
#    Experimento: LGBM_v3_FE_02_v3_linear_tree_opt_03_36lags_semillerio_2_persistente
#    Número de modelos: 50
#    Semillas utilizadas: [42, 109, 113, 151, 167, 179, 193, 199, 211, 241, 263, 281, 307, 331, 367, 401, 439, 487, 563, 617, 40009, 42043, 45007, 47017, 50021, 52027, 55001, 57037, 60013, 62003, 65029, 67003, 70001, 72019, 75011, 77003, 80021, 82009, 85009, 87011, 90001, 92003, 95003, 97007, 99013, 99991, 99929, 99881, 99733, 99667]
#    Semilla para Optuna: 42
#    Mejor modelo: #44 (semilla 97007)
#    MAE promedio: 10.7058 (±0.2531)
#    Modelos guardados en: data/modelos_entrenados/v3/
#
# ✅ Información de reproductibilidad guardada en:
#    data/reproducibility_info_lgbm_v3_FE_02_v3_linear_tree_opt_36lags_sem_2_ensemble_persistente.json
#
# 📊 RESUMEN FINAL DEL EXPERIMENTO CON PERSISTENCIA:
#    🔬 Estrategia: Conjunto de 50 modelos LightGBM persistentes
#    ⭐ Tecnología: LINEAR_TREE + OPTUNA + 36 LAGS + PERSISTENCIA
#    🎯 Objetivo: Máxima robustez, precisión y reutilización
#    📁 Archivos: 6 archivos CSV + 50 modelos .pkl + 1 JSON reproductibilidad
#    🏆 Resultado: Sistema completo de ensemble reutilizable
#    🔄 Capacidad: Cargar y usar cualquier modelo individual por semilla
#    🎛️ Flexibilidad: Crear ensembles personalizados sin re-entrenar
#
# 🎉 ¡SISTEMA DE MACHINE LEARNING PERSISTENTE COMPLETADO EXITOSAMENTE!
# 💪 Máxima robustez, flexibilidad y capacidad de experimentación
