# %% [markdown]
# LGBM 01 con linear_tree = true
#
# lags 1 al 36 (3 años)
#
# cantidad de clientes que compraron un producto
#
# meses de vida

# %%
# 📦 Importar librerías necesarias
import pandas as pd
import numpy as np
import random

# 🎲 Configurar semillas para reproductibilidad
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

print("✅ Librerías importadas correctamente")
print(f"🎲 Semilla configurada: {SEED} para reproductibilidad total")
# Out:
# ✅ Librerías importadas correctamente
# 🎲 Semilla configurada: 42 para reproductibilidad total

# %%
# 📄 Cargar todos los datasets
print("Cargando datasets...")

# Load the sales data (tab-delimited)
sales = pd.read_csv("datasets/sell-in.txt", sep="\t", dtype={"periodo": str})
print(f"✅ Sales data cargado: {sales.shape}")

# Load the stocks data (tab-delimited) 
stocks = pd.read_csv("datasets/tb_stocks.txt", sep="\t", dtype={"periodo": str})
print(f"✅ Stocks data cargado: {stocks.shape}")

# Load the product information data (tab-delimited)
product_info = pd.read_csv("datasets/tb_productos.txt", sep="\t")
print(f"✅ Product info cargado: {product_info.shape}")

# Carga productos a predecir
product_predict = pd.read_csv("datasets/product_id_apredecir201912.txt", sep="\t", header=0)
print(f"✅ Productos a predecir cargados: {product_predict.shape}")

print("\n🎯 Todos los datasets cargados exitosamente")
# Out:
# Cargando datasets...
# ✅ Sales data cargado: (2945818, 7)
# ✅ Stocks data cargado: (13691, 3)
# ✅ Product info cargado: (1251, 7)
# ✅ Productos a predecir cargados: (780, 1)
#
# 🎯 Todos los datasets cargados exitosamente
# ✅ Sales data cargado: (2945818, 7)
# ✅ Stocks data cargado: (13691, 3)
# ✅ Product info cargado: (1251, 7)
# ✅ Productos a predecir cargados: (780, 1)
#
# 🎯 Todos los datasets cargados exitosamente

# %%
# 🔍 Explorar estructura de los datos
print("EXPLORACIÓN DE DATOS")
print("="*50)

print("\n📊 SALES DATA:")
print(f"Columnas: {list(sales.columns)}")
print(f"Períodos únicos: {sales['periodo'].nunique()}")
print(f"Productos únicos: {sales['product_id'].nunique()}")
print("Primeras filas:")
print(sales.head())

print("\n📦 STOCKS DATA:")
print(f"Columnas: {list(stocks.columns)}")
print(f"Períodos únicos: {stocks['periodo'].nunique()}")
print(f"Productos únicos: {stocks['product_id'].nunique()}")
print("Primeras filas:")
print(stocks.head())

print("\n🏷️ PRODUCT INFO:")
print(f"Columnas: {list(product_info.columns)}")
print(f"Productos únicos: {product_info['product_id'].nunique()}")
print("Primeras filas:")
print(product_info.head())

print("\n🎯 PRODUCTOS A PREDECIR:")
print(f"Columnas: {list(product_predict.columns)}")
print(f"Total productos a predecir: {len(product_predict)}")
print("Primeras filas:")
print(product_predict.head())
# Out:
# EXPLORACIÓN DE DATOS
# ==================================================
#
# 📊 SALES DATA:
# Columnas: ['periodo', 'customer_id', 'product_id', 'plan_precios_cuidados', 'cust_request_qty', 'cust_request_tn', 'tn']
# Períodos únicos: 36
# Productos únicos: 1233
# Primeras filas:
#   periodo  customer_id  product_id  plan_precios_cuidados  cust_request_qty  \
# 0  201701        10234       20524                      0                 2
# 1  201701        10032       20524                      0                 1
# 2  201701        10217       20524                      0                 1
# 3  201701        10125       20524                      0                 1
# 4  201701        10012       20524                      0                11
#
#    cust_request_tn       tn
# 0          0.05300  0.05300
# 1          0.13628  0.13628
# 2          0.03028  0.03028
# 3          0.02271  0.02271
# 4          1.54452  1.54452
#
# 📦 STOCKS DATA:
# Columnas: ['periodo', 'product_id', 'stock_final']
# Períodos únicos: 15
# Productos únicos: 1095
# Primeras filas:
#   periodo  product_id  stock_final
# 0  201810       20524      1.61267
# 1  201810       20311      2.93657
# 2  201810       20654      6.83269
# 3  201810       21005      1.01338
# 4  201810       20974      0.34595
#
# 🏷️ PRODUCT INFO:
# Columnas: ['cat1', 'cat2', 'cat3', 'brand', 'sku_size', 'product_id', 'descripcion']
# Productos únicos: 1251
# Primeras filas:
#     cat1      cat2         cat3   brand  sku_size  product_id  \
# 0  FOODS  ADEREZOS  Aji Picante  NATURA       240       20609
# 1  FOODS  ADEREZOS     Barbacoa  NATURA       250       20266
# 2  FOODS  ADEREZOS     Barbacoa  NATURA       400       20325
# 3  FOODS  ADEREZOS     Barbacoa  NATURA       500       20503
# 4  FOODS  ADEREZOS  Chimichurri  NATURA       350       20797
#
#          descripcion
# 0  Salsa Aji Picante
# 1     Salsa Barbacoa
# 2     Salsa Barbacoa
# 3     Salsa Barbacoa
# 4        Chimichurri
#
# 🎯 PRODUCTOS A PREDECIR:
# Columnas: ['product_id']
# Total productos a predecir: 780
# Primeras filas:
#    product_id
# 0       20001
# 1       20002
# 2       20003
# 3       20004
# 4       20005

# %%
# 🔗 Verificar consistencia entre datasets
print("VERIFICACIÓN DE CONSISTENCIA")
print("="*50)

# Productos únicos en cada dataset
productos_sales = set(sales['product_id'].unique())
productos_stocks = set(stocks['product_id'].unique())
productos_info = set(product_info['product_id'].unique())

# Si product_predict tiene columna product_id
if 'product_id' in product_predict.columns:
    productos_predict = set(product_predict['product_id'].unique())
else:
    # Si la primera columna contiene los product_ids
    primera_columna = product_predict.columns[0]
    productos_predict = set(product_predict[primera_columna].unique())
    print(f"⚠️ Usando columna '{primera_columna}' como product_id")

print(f"📊 Productos en sales: {len(productos_sales)}")
print(f"📦 Productos en stocks: {len(productos_stocks)}")
print(f"🏷️ Productos en product_info: {len(productos_info)}")
print(f"🎯 Productos a predecir: {len(productos_predict)}")

# Verificar intersecciones
print(f"\n🔍 INTERSECCIONES:")
print(f"Sales ∩ Stocks: {len(productos_sales & productos_stocks)}")
print(f"Sales ∩ Product_info: {len(productos_sales & productos_info)}")
print(f"Sales ∩ Productos_predict: {len(productos_sales & productos_predict)}")
print(f"Stocks ∩ Productos_predict: {len(productos_stocks & productos_predict)}")
print(f"Product_info ∩ Productos_predict: {len(productos_info & productos_predict)}")

# Verificar rangos de fechas
print(f"\n📅 RANGOS DE FECHAS:")
print(f"Sales - períodos: {sales['periodo'].min()} a {sales['periodo'].max()}")
print(f"Stocks - períodos: {stocks['periodo'].min()} a {stocks['periodo'].max()}")
# Out:
# VERIFICACIÓN DE CONSISTENCIA
# ==================================================
# 📊 Productos en sales: 1233
# 📦 Productos en stocks: 1095
# 🏷️ Productos en product_info: 1251
# 🎯 Productos a predecir: 780
#
# 🔍 INTERSECCIONES:
# Sales ∩ Stocks: 1095
# Sales ∩ Product_info: 1188
# Sales ∩ Productos_predict: 780
# Stocks ∩ Productos_predict: 779
# Product_info ∩ Productos_predict: 780
#
# 📅 RANGOS DE FECHAS:
# Sales - períodos: 201701 a 201912
# Stocks - períodos: 201810 a 201912
# Sales - períodos: 201701 a 201912
# Stocks - períodos: 201810 a 201912

# %%
# 📦 Instalar e importar LightGBM, Optuna y librerías adicionales
# %pip install lightgbm optuna

import lightgbm as lgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# 🎲 Configurar semillas adicionales para reproductibilidad
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

# Configurar semilla para matplotlib (si se usa)
plt.rcParams['figure.max_open_warning'] = 0

print("✅ LightGBM, Optuna y librerías ML importadas correctamente")
print(f"🎲 Todas las semillas configuradas con SEED={SEED} para reproductibilidad")
# Out:
# ✅ LightGBM, Optuna y librerías ML importadas correctamente
# 🎲 Todas las semillas configuradas con SEED=42 para reproductibilidad

# %%
# 🧹 Preparación de datos para el modelo LightGBM
print("PREPARACIÓN DE DATOS PARA LGBM - GRANULARIDAD POR PRODUCTO")
print("="*60)

# Convertir período a datetime para facilitar manipulación
sales['fecha'] = pd.to_datetime(sales['periodo'], format='%Y%m')
stocks['fecha'] = pd.to_datetime(stocks['periodo'], format='%Y%m')

# Filtrar solo productos que necesitamos predecir
if 'product_id' in product_predict.columns:
    productos_objetivo = product_predict['product_id'].tolist()
else:
    productos_objetivo = product_predict[product_predict.columns[0]].tolist()

print(f"🎯 Productos objetivo: {len(productos_objetivo)}")

# Filtrar sales y stocks para productos objetivo
sales_filtered = sales[sales['product_id'].isin(productos_objetivo)].copy()
stocks_filtered = stocks[stocks['product_id'].isin(productos_objetivo)].copy()

print(f"📊 Sales filtradas: {sales_filtered.shape}")
print(f"📦 Stocks filtradas: {stocks_filtered.shape}")

# AGREGACIÓN POR PRODUCTO: Sumar por producto y período (agregando todos los clientes)
sales_agg = sales_filtered.groupby(['product_id', 'fecha', 'periodo']).agg({
    'tn': 'sum',                    # Total toneladas por producto
    'customer_id': 'nunique',       # Número de clientes únicos
    'cust_request_qty': 'sum',      # Total cantidad solicitada
    'cust_request_tn': 'sum'        # Total toneladas solicitadas
}).reset_index()

# Renombrar columnas para claridad
sales_agg.rename(columns={
    'customer_id': 'num_customers',
    'cust_request_qty': 'total_request_qty', 
    'cust_request_tn': 'total_request_tn'
}, inplace=True)

print(f"📈 Sales agregadas por producto: {sales_agg.shape}")
print("Primeras filas de sales agregadas:")
print(sales_agg.head())

print(f"\n📊 Estadísticas por producto:")
print(f"  Promedio tn por producto-período: {sales_agg['tn'].mean():.2f}")
print(f"  Promedio clientes por producto-período: {sales_agg['num_customers'].mean():.2f}")
print(f"  Productos únicos: {sales_agg['product_id'].nunique()}")
print(f"  Períodos únicos: {sales_agg['periodo'].nunique()}")
# Out:
# PREPARACIÓN DE DATOS PARA LGBM - GRANULARIDAD POR PRODUCTO
# ============================================================
# 🎯 Productos objetivo: 780
# 🎯 Productos objetivo: 780
# 📊 Sales filtradas: (2293481, 8)
# 📦 Stocks filtradas: (10727, 4)
# 📊 Sales filtradas: (2293481, 8)
# 📦 Stocks filtradas: (10727, 4)
# 📈 Sales agregadas por producto: (22349, 7)
# Primeras filas de sales agregadas:
#    product_id      fecha periodo          tn  num_customers  \
# 0       20001 2017-01-01  201701   934.77222            186
# 1       20001 2017-02-01  201702   798.01620            185
# 2       20001 2017-03-01  201703  1303.35771            188
# 3       20001 2017-04-01  201704  1069.96130            104
# 4       20001 2017-05-01  201705  1502.20132            238
#
#    total_request_qty  total_request_tn
# 0                479         937.72717
# 1                432         833.72187
# 2                509        1330.74697
# 3                279        1132.94430
# 4                701        1550.68936
#
# 📊 Estadísticas por producto:
#   Promedio tn por producto-período: 50.23
#   Promedio clientes por producto-período: 102.62
#   Productos únicos: 780
#   Períodos únicos: 36
# 📈 Sales agregadas por producto: (22349, 7)
# Primeras filas de sales agregadas:
#    product_id      fecha periodo          tn  num_customers  \
# 0       20001 2017-01-01  201701   934.77222            186
# 1       20001 2017-02-01  201702   798.01620            185
# 2       20001 2017-03-01  201703  1303.35771            188
# 3       20001 2017-04-01  201704  1069.96130            104
# 4       20001 2017-05-01  201705  1502.20132            238
#
#    total_request_qty  total_request_tn
# 0                479         937.72717
# 1                432         833.72187
# 2                509        1330.74697
# 3                279        1132.94430
# 4                701        1550.68936
#
# 📊 Estadísticas por producto:
#   Promedio tn por producto-período: 50.23
#   Promedio clientes por producto-período: 102.62
#   Productos únicos: 780
#   Períodos únicos: 36

# %%
# 🔧 Crear features de lag y combinar con stocks - GRANULARIDAD POR PRODUCTO
print("CREACIÓN DE FEATURES POR PRODUCTO")
print("="*50)

# Crear features de lag para cada producto
def create_lag_features(df, product_col, value_col, date_col, lags=[1, 2, 3, 6, 12]):
    """Crear features de lag para series temporales por producto"""
    df_features = df.copy()
    df_features = df_features.sort_values([product_col, date_col])
    
    for lag in lags:
        df_features[f'{value_col}_lag_{lag}'] = df_features.groupby(product_col)[value_col].shift(lag)
    
    return df_features

# Crear lags para ventas (tn) por producto - EXPANDIDO HASTA LAG 36
sales_with_lags = create_lag_features(
    sales_agg, 
    'product_id', 
    'tn', 
    'fecha', 
    lags=list(range(1, 37))  # Todos los lags de 1 a 36 meses (3 años completos)
)

# Crear lags para número de clientes por producto
sales_with_lags = create_lag_features(
    sales_with_lags, 
    'product_id', 
    'num_customers', 
    'fecha', 
    lags=[1, 2, 3]
)

# Crear lags para solicitudes de clientes
sales_with_lags = create_lag_features(
    sales_with_lags, 
    'product_id', 
    'total_request_tn', 
    'fecha', 
    lags=[1, 2, 3]
)

print(f"📊 Sales con lags por producto: {sales_with_lags.shape}")

# Agregar datos de stock por producto
stocks_agg = stocks_filtered.groupby(['product_id', 'fecha', 'periodo']).agg({
    'stock_final': ['mean', 'sum', 'std']  # Stock promedio, total y desviación estándar por producto
}).reset_index()

# Aplanar columnas multinivel
stocks_agg.columns = ['product_id', 'fecha', 'periodo', 'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std']
stocks_agg['stock_tn_std'] = stocks_agg['stock_tn_std'].fillna(0)  # Rellenar NaN en std

# Combinar sales y stocks por producto
data_combined = pd.merge(
    sales_with_lags, 
    stocks_agg[['product_id', 'fecha', 'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std']], 
    on=['product_id', 'fecha'], 
    how='left'
)

# Crear lags para stock por producto
data_combined = create_lag_features(
    data_combined, 
    'product_id', 
    'stock_tn_mean', 
    'fecha', 
    lags=[1, 2, 3]
)

data_combined = create_lag_features(
    data_combined, 
    'product_id', 
    'stock_tn_sum', 
    'fecha', 
    lags=[1, 2]
)

print(f"📦 Datos combinados con stock por producto: {data_combined.shape}")
print(f"Columnas disponibles: {len(data_combined.columns)}")
print("\nPrimeras columnas:")
print(data_combined.columns.tolist()[:15])
print("Últimas columnas:")
print(data_combined.columns.tolist()[-10:])
# Out:
# CREACIÓN DE FEATURES POR PRODUCTO
# ==================================================
# 📊 Sales con lags por producto: (22349, 49)
# 📦 Datos combinados con stock por producto: (22349, 57)
# Columnas disponibles: 57
#
# Primeras columnas:
# ['product_id', 'fecha', 'periodo', 'tn', 'num_customers', 'total_request_qty', 'total_request_tn', 'tn_lag_1', 'tn_lag_2', 'tn_lag_3', 'tn_lag_4', 'tn_lag_5', 'tn_lag_6', 'tn_lag_7', 'tn_lag_8']
# Últimas columnas:
# ['total_request_tn_lag_2', 'total_request_tn_lag_3', 'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std', 'stock_tn_mean_lag_1', 'stock_tn_mean_lag_2', 'stock_tn_mean_lag_3', 'stock_tn_sum_lag_1', 'stock_tn_sum_lag_2']

# %%
# 🎯 Crear target y features adicionales
print("CREACIÓN DE TARGET Y FEATURES ADICIONALES")
print("="*50)

# Crear target: tn de 2 períodos a futuro
data_combined = data_combined.sort_values(['product_id', 'fecha'])
data_combined['target'] = data_combined.groupby('product_id')['tn'].shift(-2)

# Crear features temporales
data_combined['mes'] = data_combined['fecha'].dt.month
data_combined['trimestre'] = data_combined['fecha'].dt.quarter
data_combined['año'] = data_combined['fecha'].dt.year

# 🔢 Crear feature de clientes únicos por producto
print(f"\n🔍 Creando feature de clientes únicos por producto...")
# Calcular cantidad total de clientes únicos que compraron cada producto
clientes_unicos_por_producto = sales_filtered.groupby('product_id')['customer_id'].nunique().reset_index()
clientes_unicos_por_producto.rename(columns={'customer_id': 'cant_clientes_unicos'}, inplace=True)

# Agregar esta información a data_combined
data_combined = pd.merge(
    data_combined,
    clientes_unicos_por_producto,
    on='product_id',
    how='left'
)

print(f"✅ Feature 'cant_clientes_unicos' agregada")
print(f"📊 Estadísticas de clientes únicos por producto:")
print(f"   Promedio: {data_combined['cant_clientes_unicos'].mean():.1f}")
print(f"   Mediana:  {data_combined['cant_clientes_unicos'].median():.1f}")
print(f"   Mínimo:   {data_combined['cant_clientes_unicos'].min()}")
print(f"   Máximo:   {data_combined['cant_clientes_unicos'].max()}")

# 🗓️ Crear feature de meses de vida por producto
print(f"\n🔍 Creando feature de meses de vida por producto...")
# Calcular primer y último período de compra para cada producto
vida_producto = sales_filtered.groupby('product_id')['fecha'].agg(['min', 'max']).reset_index()
vida_producto.columns = ['product_id', 'primer_periodo', 'ultimo_periodo']

# Calcular diferencia en meses
vida_producto['meses_vida'] = ((vida_producto['ultimo_periodo'] - vida_producto['primer_periodo']).dt.days / 30.44).round().astype(int)

# Asegurar que el mínimo sea 1 (productos con una sola compra tienen 1 mes de vida)
vida_producto['meses_vida'] = vida_producto['meses_vida'].apply(lambda x: max(1, x))

# Agregar esta información a data_combined
data_combined = pd.merge(
    data_combined,
    vida_producto[['product_id', 'meses_vida']],
    on='product_id',
    how='left'
)

print(f"✅ Feature 'meses_vida' agregada")
print(f"📊 Estadísticas de meses de vida por producto:")
print(f"   Promedio: {data_combined['meses_vida'].mean():.1f} meses")
print(f"   Mediana:  {data_combined['meses_vida'].median():.1f} meses")
print(f"   Mínimo:   {data_combined['meses_vida'].min()} meses")
print(f"   Máximo:   {data_combined['meses_vida'].max()} meses")
print(f"   Productos con > 24 meses: {(data_combined['meses_vida'] > 24).sum()}")
print(f"   Productos con > 36 meses: {(data_combined['meses_vida'] > 36).sum()}")

# Crear features estadísticas móviles
def create_rolling_features(df, product_col, value_col, date_col, windows=[3, 6, 12]):
    """Crear features de ventanas móviles"""
    df = df.sort_values([product_col, date_col])
    
    for window in windows:
        df[f'{value_col}_rolling_mean_{window}'] = df.groupby(product_col)[value_col].rolling(window, min_periods=1).mean().reset_index(level=0, drop=True)
        df[f'{value_col}_rolling_std_{window}'] = df.groupby(product_col)[value_col].rolling(window, min_periods=1).std().reset_index(level=0, drop=True)
    
    return df

# Crear rolling features para ventas
data_combined = create_rolling_features(data_combined, 'product_id', 'tn', 'fecha', windows=[3, 6])

# 📊 Verificar features de lags de toneladas creados
print(f"\n📈 FEATURES DE LAGS DE TONELADAS DISPONIBLES:")
tn_lag_features = [col for col in data_combined.columns if col.startswith('tn_lag_')]
tn_lag_features.sort(key=lambda x: int(x.split('_')[-1]))  # Ordenar por número de lag
print(f"   Total de lags de toneladas: {len(tn_lag_features)}")
for i, feature in enumerate(tn_lag_features, 1):
    lag_num = feature.split('_')[-1]
    print(f"   {i:2d}. {feature} (toneladas de {lag_num} mes{'es' if int(lag_num) > 1 else ''} atrás)")

print(f"\n✅ Features expandidas: Lags de toneladas desde 1 hasta 36 meses")
print(f"🎯 Esto permite al modelo capturar patrones estacionales multi-anuales")

# Agregar información de productos si está disponible
if len(product_info) > 0:
    data_combined = pd.merge(
        data_combined, 
        product_info, 
        on='product_id', 
        how='left'
    )
    print(f"✅ Información de productos agregada")

print(f"📊 Dataset final: {data_combined.shape}")
print(f"📈 Registros con target válido: {data_combined['target'].notna().sum()}")

# Mostrar algunas estadísticas del target
target_stats = data_combined['target'].describe()
print(f"\n📊 Estadísticas del target:")
print(target_stats)
# Out:
# CREACIÓN DE TARGET Y FEATURES ADICIONALES
# ==================================================
#
# 🔍 Creando feature de clientes únicos por producto...
# ✅ Feature 'cant_clientes_unicos' agregada
# 📊 Estadísticas de clientes únicos por producto:
#    Promedio: 359.6
#    Mediana:  372.0
#    Mínimo:   22
#    Máximo:   521
#
# 🔍 Creando feature de meses de vida por producto...
# ✅ Feature 'meses_vida' agregada
# 📊 Estadísticas de meses de vida por producto:
#    Promedio: 31.9 meses
#    Mediana:  35.0 meses
#    Mínimo:   3 meses
#    Máximo:   35 meses
#    Productos con > 24 meses: 19798
#    Productos con > 36 meses: 0
#
# 📈 FEATURES DE LAGS DE TONELADAS DISPONIBLES:
#    Total de lags de toneladas: 36
#     1. tn_lag_1 (toneladas de 1 mes atrás)
#     2. tn_lag_2 (toneladas de 2 meses atrás)
#     3. tn_lag_3 (toneladas de 3 meses atrás)
#     4. tn_lag_4 (toneladas de 4 meses atrás)
#     5. tn_lag_5 (toneladas de 5 meses atrás)
#     6. tn_lag_6 (toneladas de 6 meses atrás)
#     7. tn_lag_7 (toneladas de 7 meses atrás)
#     8. tn_lag_8 (toneladas de 8 meses atrás)
#     9. tn_lag_9 (toneladas de 9 meses atrás)
#    10. tn_lag_10 (toneladas de 10 meses atrás)
#    11. tn_lag_11 (toneladas de 11 meses atrás)
#    12. tn_lag_12 (toneladas de 12 meses atrás)
#    13. tn_lag_13 (toneladas de 13 meses atrás)
#    14. tn_lag_14 (toneladas de 14 meses atrás)
#    15. tn_lag_15 (toneladas de 15 meses atrás)
#    16. tn_lag_16 (toneladas de 16 meses atrás)
#    17. tn_lag_17 (toneladas de 17 meses atrás)
#    18. tn_lag_18 (toneladas de 18 meses atrás)
#    19. tn_lag_19 (toneladas de 19 meses atrás)
#    20. tn_lag_20 (toneladas de 20 meses atrás)
#    21. tn_lag_21 (toneladas de 21 meses atrás)
#    22. tn_lag_22 (toneladas de 22 meses atrás)
#    23. tn_lag_23 (toneladas de 23 meses atrás)
#    24. tn_lag_24 (toneladas de 24 meses atrás)
#    25. tn_lag_25 (toneladas de 25 meses atrás)
#    26. tn_lag_26 (toneladas de 26 meses atrás)
#    27. tn_lag_27 (toneladas de 27 meses atrás)
#    28. tn_lag_28 (toneladas de 28 meses atrás)
#    29. tn_lag_29 (toneladas de 29 meses atrás)
#    30. tn_lag_30 (toneladas de 30 meses atrás)
#    31. tn_lag_31 (toneladas de 31 meses atrás)
#    32. tn_lag_32 (toneladas de 32 meses atrás)
#    33. tn_lag_33 (toneladas de 33 meses atrás)
#    34. tn_lag_34 (toneladas de 34 meses atrás)
#    35. tn_lag_35 (toneladas de 35 meses atrás)
#    36. tn_lag_36 (toneladas de 36 meses atrás)
#
# ✅ Features expandidas: Lags de toneladas desde 1 hasta 36 meses
# 🎯 Esto permite al modelo capturar patrones estacionales multi-anuales
# ✅ Información de productos agregada
# 📊 Dataset final: (22349, 73)
# 📈 Registros con target válido: 20789
#
# 📊 Estadísticas del target:
# count    20789.000000
# mean        50.931444
# std        127.140873
# min          0.000890
# 25%          3.009870
# 50%         11.928920
# 75%         36.636220
# max       2295.198320
# Name: target, dtype: float64
# ✅ Feature 'meses_vida' agregada
# 📊 Estadísticas de meses de vida por producto:
#    Promedio: 31.9 meses
#    Mediana:  35.0 meses
#    Mínimo:   3 meses
#    Máximo:   35 meses
#    Productos con > 24 meses: 19798
#    Productos con > 36 meses: 0
#
# 📈 FEATURES DE LAGS DE TONELADAS DISPONIBLES:
#    Total de lags de toneladas: 36
#     1. tn_lag_1 (toneladas de 1 mes atrás)
#     2. tn_lag_2 (toneladas de 2 meses atrás)
#     3. tn_lag_3 (toneladas de 3 meses atrás)
#     4. tn_lag_4 (toneladas de 4 meses atrás)
#     5. tn_lag_5 (toneladas de 5 meses atrás)
#     6. tn_lag_6 (toneladas de 6 meses atrás)
#     7. tn_lag_7 (toneladas de 7 meses atrás)
#     8. tn_lag_8 (toneladas de 8 meses atrás)
#     9. tn_lag_9 (toneladas de 9 meses atrás)
#    10. tn_lag_10 (toneladas de 10 meses atrás)
#    11. tn_lag_11 (toneladas de 11 meses atrás)
#    12. tn_lag_12 (toneladas de 12 meses atrás)
#    13. tn_lag_13 (toneladas de 13 meses atrás)
#    14. tn_lag_14 (toneladas de 14 meses atrás)
#    15. tn_lag_15 (toneladas de 15 meses atrás)
#    16. tn_lag_16 (toneladas de 16 meses atrás)
#    17. tn_lag_17 (toneladas de 17 meses atrás)
#    18. tn_lag_18 (toneladas de 18 meses atrás)
#    19. tn_lag_19 (toneladas de 19 meses atrás)
#    20. tn_lag_20 (toneladas de 20 meses atrás)
#    21. tn_lag_21 (toneladas de 21 meses atrás)
#    22. tn_lag_22 (toneladas de 22 meses atrás)
#    23. tn_lag_23 (toneladas de 23 meses atrás)
#    24. tn_lag_24 (toneladas de 24 meses atrás)
#    25. tn_lag_25 (toneladas de 25 meses atrás)
#    26. tn_lag_26 (toneladas de 26 meses atrás)
#    27. tn_lag_27 (toneladas de 27 meses atrás)
#    28. tn_lag_28 (toneladas de 28 meses atrás)
#    29. tn_lag_29 (toneladas de 29 meses atrás)
#    30. tn_lag_30 (toneladas de 30 meses atrás)
#    31. tn_lag_31 (toneladas de 31 meses atrás)
#    32. tn_lag_32 (toneladas de 32 meses atrás)
#    33. tn_lag_33 (toneladas de 33 meses atrás)
#    34. tn_lag_34 (toneladas de 34 meses atrás)
#    35. tn_lag_35 (toneladas de 35 meses atrás)
#    36. tn_lag_36 (toneladas de 36 meses atrás)
#
# ✅ Features expandidas: Lags de toneladas desde 1 hasta 36 meses
# 🎯 Esto permite al modelo capturar patrones estacionales multi-anuales
# ✅ Información de productos agregada
# 📊 Dataset final: (22349, 73)
# 📈 Registros con target válido: 20789
#
# 📊 Estadísticas del target:
# count    20789.000000
# mean        50.931444
# std        127.140873
# min          0.000890
# 25%          3.009870
# 50%         11.928920
# 75%         36.636220
# max       2295.198320
# Name: target, dtype: float64

# %%
# 📋 Preparar datos para entrenamiento - GRANULARIDAD POR PRODUCTO
print("PREPARACIÓN DE DATOS DE ENTRENAMIENTO POR PRODUCTO")
print("="*60)

# Filtrar registros con target válido
train_data = data_combined[data_combined['target'].notna()].copy()
print(f"📊 Registros válidos para entrenamiento: {len(train_data)}")

# Seleccionar features para el modelo con granularidad por producto
feature_columns = [
    # Lags de ventas (tn) por producto - EXPANDIDO A 36 LAGS (3 AÑOS)
    'tn_lag_1', 'tn_lag_2', 'tn_lag_3', 'tn_lag_4', 'tn_lag_5', 'tn_lag_6',
    'tn_lag_7', 'tn_lag_8', 'tn_lag_9', 'tn_lag_10', 'tn_lag_11', 'tn_lag_12',
    'tn_lag_13', 'tn_lag_14', 'tn_lag_15', 'tn_lag_16', 'tn_lag_17', 'tn_lag_18',
    'tn_lag_19', 'tn_lag_20', 'tn_lag_21', 'tn_lag_22', 'tn_lag_23', 'tn_lag_24',
    'tn_lag_25', 'tn_lag_26', 'tn_lag_27', 'tn_lag_28', 'tn_lag_29', 'tn_lag_30',
    'tn_lag_31', 'tn_lag_32', 'tn_lag_33', 'tn_lag_34', 'tn_lag_35', 'tn_lag_36',
    
    # Lags de clientes por producto
    'num_customers_lag_1', 'num_customers_lag_2', 'num_customers_lag_3',
    
    # Lags de solicitudes por producto
    'total_request_tn_lag_1', 'total_request_tn_lag_2', 'total_request_tn_lag_3',
    
    # Lags de stock por producto
    'stock_tn_mean_lag_1', 'stock_tn_mean_lag_2', 'stock_tn_mean_lag_3',
    'stock_tn_sum_lag_1', 'stock_tn_sum_lag_2',
    
    # Features temporales
    'mes', 'trimestre', 'año',
    
    # Rolling features por producto
    'tn_rolling_mean_3', 'tn_rolling_mean_6',
    'tn_rolling_std_3', 'tn_rolling_std_6',
    
    # Features actuales por producto
    'num_customers', 'total_request_qty', 'total_request_tn',
    'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std',
    
    # Feature de diversidad de clientes
    'cant_clientes_unicos',
    
    # Feature de longevidad del producto
    'meses_vida'
]

# Verificar qué features existen
available_features = [col for col in feature_columns if col in train_data.columns]
missing_features = [col for col in feature_columns if col not in train_data.columns]

print(f"✅ Features disponibles: {len(available_features)}")
print(f"⚠️ Features faltantes: {len(missing_features)}")
if missing_features:
    print(f"Features faltantes: {missing_features}")

# Usar solo features disponibles
feature_columns = available_features

# Preparar X e y
X = train_data[feature_columns].copy()
y = train_data['target'].copy()

# Rellenar valores nulos con 0 (para lags iniciales y stocks faltantes)
X = X.fillna(0)

print(f"📊 Shape de X: {X.shape}")
print(f"📈 Shape de y: {y.shape}")
print(f"🔍 Valores nulos en X: {X.isnull().sum().sum()}")
print(f"🔍 Valores nulos en y: {y.isnull().sum()}")

# División temporal para validación (últimos períodos como validación)
train_data_sorted = train_data.sort_values('fecha')
split_date = train_data_sorted['fecha'].quantile(0.8)  # 80% entrenamiento, 20% validación

train_mask = train_data_sorted['fecha'] <= split_date
X_train = X.loc[train_mask]
X_val = X.loc[~train_mask] 
y_train = y.loc[train_mask]
y_val = y.loc[~train_mask]

print(f"\n📊 DIVISIÓN TEMPORAL:")
print(f"Entrenamiento: {len(X_train)} registros (hasta {split_date.strftime('%Y-%m')})")
print(f"Validación: {len(X_val)} registros (desde {split_date.strftime('%Y-%m')})")

print(f"\n🎯 PRODUCTOS EN ENTRENAMIENTO:")
productos_train = train_data.loc[train_mask, 'product_id'].nunique()
productos_val = train_data.loc[~train_mask, 'product_id'].nunique()
print(f"Productos únicos en entrenamiento: {productos_train}")
print(f"Productos únicos en validación: {productos_val}")

print(f"\nFeatures seleccionadas para granularidad por producto:")
for i, feat in enumerate(feature_columns):
    print(f"  {i+1:2d}. {feat}")
# Out:
# PREPARACIÓN DE DATOS DE ENTRENAMIENTO POR PRODUCTO
# ============================================================
# 📊 Registros válidos para entrenamiento: 20789
# ✅ Features disponibles: 62
# ⚠️ Features faltantes: 0
# 📊 Shape de X: (20789, 62)
# 📈 Shape de y: (20789,)
# 🔍 Valores nulos en X: 0
# 🔍 Valores nulos en y: 0
#
# 📊 DIVISIÓN TEMPORAL:
# Entrenamiento: 16970 registros (hasta 2019-05)
# Validación: 3819 registros (desde 2019-05)
#
# 🎯 PRODUCTOS EN ENTRENAMIENTO:
# Productos únicos en entrenamiento: 718
# Productos únicos en validación: 780
#
# Features seleccionadas para granularidad por producto:
#    1. tn_lag_1
#    2. tn_lag_2
#    3. tn_lag_3
#    4. tn_lag_4
#    5. tn_lag_5
#    6. tn_lag_6
#    7. tn_lag_7
#    8. tn_lag_8
#    9. tn_lag_9
#   10. tn_lag_10
#   11. tn_lag_11
#   12. tn_lag_12
#   13. tn_lag_13
#   14. tn_lag_14
#   15. tn_lag_15
#   16. tn_lag_16
#   17. tn_lag_17
#   18. tn_lag_18
#   19. tn_lag_19
#   20. tn_lag_20
#   21. tn_lag_21
#   22. tn_lag_22
#   23. tn_lag_23
#   24. tn_lag_24
#   25. tn_lag_25
#   26. tn_lag_26
#   27. tn_lag_27
#   28. tn_lag_28
#   29. tn_lag_29
#   30. tn_lag_30
#   31. tn_lag_31
#   32. tn_lag_32
#   33. tn_lag_33
#   34. tn_lag_34
#   35. tn_lag_35
#   36. tn_lag_36
#   37. num_customers_lag_1
#   38. num_customers_lag_2
#   39. num_customers_lag_3
#   40. total_request_tn_lag_1
#   41. total_request_tn_lag_2
#   42. total_request_tn_lag_3
#   43. stock_tn_mean_lag_1
#   44. stock_tn_mean_lag_2
#   45. stock_tn_mean_lag_3
#   46. stock_tn_sum_lag_1
#   47. stock_tn_sum_lag_2
#   48. mes
#   49. trimestre
#   50. año
#   51. tn_rolling_mean_3
#   52. tn_rolling_mean_6
#   53. tn_rolling_std_3
#   54. tn_rolling_std_6
#   55. num_customers
#   56. total_request_qty
#   57. total_request_tn
#   58. stock_tn_mean
#   59. stock_tn_sum
#   60. stock_tn_std
#   61. cant_clientes_unicos
#   62. meses_vida

# %%
# 📊 Resumen detallado de features con lags de toneladas expandidos
print("RESUMEN DETALLADO DE FEATURES CON LAGS EXPANDIDOS")
print("="*60)

# Agrupar features por categoría
tn_lags = [f for f in feature_columns if f.startswith('tn_lag_')]
customer_lags = [f for f in feature_columns if f.startswith('num_customers_lag_')]
request_lags = [f for f in feature_columns if f.startswith('total_request_tn_lag_')]
stock_lags = [f for f in feature_columns if f.startswith('stock_tn_')]
temporal_features = [f for f in feature_columns if f in ['mes', 'trimestre', 'año']]
rolling_features = [f for f in feature_columns if 'rolling' in f]
current_features = [f for f in feature_columns if f in ['num_customers', 'total_request_qty', 'total_request_tn', 'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std', 'cant_clientes_unicos', 'meses_vida']]

print(f"📈 LAGS DE TONELADAS (EXPANDIDOS A 36): {len(tn_lags)} features")
tn_lags_sorted = sorted(tn_lags, key=lambda x: int(x.split('_')[-1]))
for i, lag in enumerate(tn_lags_sorted, 1):
    lag_num = lag.split('_')[-1]
    print(f"   {i:2d}. {lag} (ventas de {lag_num} mes{'es' if int(lag_num) > 1 else ''} atrás)")

print(f"\n👥 LAGS DE CLIENTES: {len(customer_lags)} features")
for i, lag in enumerate(customer_lags, 1):
    print(f"   {i}. {lag}")

print(f"\n📋 LAGS DE SOLICITUDES: {len(request_lags)} features")
for i, lag in enumerate(request_lags, 1):
    print(f"   {i}. {lag}")

print(f"\n📦 FEATURES DE STOCK: {len(stock_lags)} features")
for i, lag in enumerate(stock_lags, 1):
    print(f"   {i}. {lag}")

print(f"\n📅 FEATURES TEMPORALES: {len(temporal_features)} features")
for i, feat in enumerate(temporal_features, 1):
    print(f"   {i}. {feat}")

print(f"\n📊 FEATURES ROLLING: {len(rolling_features)} features")
for i, feat in enumerate(rolling_features, 1):
    print(f"   {i}. {feat}")

print(f"\n🔄 FEATURES ACTUALES: {len(current_features)} features")
for i, feat in enumerate(current_features, 1):
    print(f"   {i}. {feat}")

print(f"\n✅ TOTAL DE FEATURES: {len(feature_columns)}")
print(f"🎯 MEJORA PRINCIPAL: Lags de toneladas expandidos de 12 → 36 features")
print(f"🔢 NUEVA FEATURE: cant_clientes_unicos (diversidad de base de clientes)")
print(f"🗓️ NUEVA FEATURE: meses_vida (longevidad del producto en el mercado)")
print(f"📈 Esto permite capturar:")
print(f"   • Patrones estacionales anuales completos (12 meses)")
print(f"   • Patrones estacionales bi-anuales (24 meses)")
print(f"   • Patrones estacionales tri-anuales (36 meses)")
print(f"   • Tendencias de corto plazo (1-6 meses)")
print(f"   • Tendencias de mediano plazo (7-18 meses)")
print(f"   • Tendencias de largo plazo (19-36 meses)")
print(f"   • Ciclos multi-anuales y efectos estacionales profundos")
print(f"   • Diversidad de base de clientes por producto")
print(f"   • Madurez y longevidad del producto en el mercado")
# Out:
# RESUMEN DETALLADO DE FEATURES CON LAGS EXPANDIDOS
# ============================================================
# 📈 LAGS DE TONELADAS (EXPANDIDOS A 36): 36 features
#     1. tn_lag_1 (ventas de 1 mes atrás)
#     2. tn_lag_2 (ventas de 2 meses atrás)
#     3. tn_lag_3 (ventas de 3 meses atrás)
#     4. tn_lag_4 (ventas de 4 meses atrás)
#     5. tn_lag_5 (ventas de 5 meses atrás)
#     6. tn_lag_6 (ventas de 6 meses atrás)
#     7. tn_lag_7 (ventas de 7 meses atrás)
#     8. tn_lag_8 (ventas de 8 meses atrás)
#     9. tn_lag_9 (ventas de 9 meses atrás)
#    10. tn_lag_10 (ventas de 10 meses atrás)
#    11. tn_lag_11 (ventas de 11 meses atrás)
#    12. tn_lag_12 (ventas de 12 meses atrás)
#    13. tn_lag_13 (ventas de 13 meses atrás)
#    14. tn_lag_14 (ventas de 14 meses atrás)
#    15. tn_lag_15 (ventas de 15 meses atrás)
#    16. tn_lag_16 (ventas de 16 meses atrás)
#    17. tn_lag_17 (ventas de 17 meses atrás)
#    18. tn_lag_18 (ventas de 18 meses atrás)
#    19. tn_lag_19 (ventas de 19 meses atrás)
#    20. tn_lag_20 (ventas de 20 meses atrás)
#    21. tn_lag_21 (ventas de 21 meses atrás)
#    22. tn_lag_22 (ventas de 22 meses atrás)
#    23. tn_lag_23 (ventas de 23 meses atrás)
#    24. tn_lag_24 (ventas de 24 meses atrás)
#    25. tn_lag_25 (ventas de 25 meses atrás)
#    26. tn_lag_26 (ventas de 26 meses atrás)
#    27. tn_lag_27 (ventas de 27 meses atrás)
#    28. tn_lag_28 (ventas de 28 meses atrás)
#    29. tn_lag_29 (ventas de 29 meses atrás)
#    30. tn_lag_30 (ventas de 30 meses atrás)
#    31. tn_lag_31 (ventas de 31 meses atrás)
#    32. tn_lag_32 (ventas de 32 meses atrás)
#    33. tn_lag_33 (ventas de 33 meses atrás)
#    34. tn_lag_34 (ventas de 34 meses atrás)
#    35. tn_lag_35 (ventas de 35 meses atrás)
#    36. tn_lag_36 (ventas de 36 meses atrás)
#
# 👥 LAGS DE CLIENTES: 3 features
#    1. num_customers_lag_1
#    2. num_customers_lag_2
#    3. num_customers_lag_3
#
# 📋 LAGS DE SOLICITUDES: 3 features
#    1. total_request_tn_lag_1
#    2. total_request_tn_lag_2
#    3. total_request_tn_lag_3
#
# 📦 FEATURES DE STOCK: 8 features
#    1. stock_tn_mean_lag_1
#    2. stock_tn_mean_lag_2
#    3. stock_tn_mean_lag_3
#    4. stock_tn_sum_lag_1
#    5. stock_tn_sum_lag_2
#    6. stock_tn_mean
#    7. stock_tn_sum
#    8. stock_tn_std
#
# 📅 FEATURES TEMPORALES: 3 features
#    1. mes
#    2. trimestre
#    3. año
#
# 📊 FEATURES ROLLING: 4 features
#    1. tn_rolling_mean_3
#    2. tn_rolling_mean_6
#    3. tn_rolling_std_3
#    4. tn_rolling_std_6
#
# 🔄 FEATURES ACTUALES: 8 features
#    1. num_customers
#    2. total_request_qty
#    3. total_request_tn
#    4. stock_tn_mean
#    5. stock_tn_sum
#    6. stock_tn_std
#    7. cant_clientes_unicos
#    8. meses_vida
#
# ✅ TOTAL DE FEATURES: 62
# 🎯 MEJORA PRINCIPAL: Lags de toneladas expandidos de 12 → 36 features
# 🔢 NUEVA FEATURE: cant_clientes_unicos (diversidad de base de clientes)
# 🗓️ NUEVA FEATURE: meses_vida (longevidad del producto en el mercado)
# 📈 Esto permite capturar:
#    • Patrones estacionales anuales completos (12 meses)
#    • Patrones estacionales bi-anuales (24 meses)
#    • Patrones estacionales tri-anuales (36 meses)
#    • Tendencias de corto plazo (1-6 meses)
#    • Tendencias de mediano plazo (7-18 meses)
#    • Tendencias de largo plazo (19-36 meses)
#    • Ciclos multi-anuales y efectos estacionales profundos
#    • Diversidad de base de clientes por producto
#    • Madurez y longevidad del producto en el mercado

# %%
# 🔧 NORMALIZACIÓN DE CARACTERÍSTICAS DE TONELADAS
print("NORMALIZACIÓN DE CARACTERÍSTICAS DE TONELADAS")
print("="*60)

import os
import pickle
from sklearn.preprocessing import StandardScaler

# Identificar todas las características relacionadas con toneladas (tn)
tn_features = []

# 1. Lags de toneladas (tn_lag_1 hasta tn_lag_36)
tn_features.extend([f for f in feature_columns if f.startswith('tn_lag_')])

# 2. Rolling features de toneladas
tn_features.extend([f for f in feature_columns if f.startswith('tn_rolling_')])

# 3. Features de stock de toneladas
tn_features.extend([f for f in feature_columns if f.startswith('stock_tn_')])

# 4. Features de request de toneladas
tn_features.extend([f for f in feature_columns if f.startswith('total_request_tn')])

# 5. Cualquier otra característica que contenga 'tn'
other_tn_features = [f for f in feature_columns 
                    if 'tn' in f.lower() and f not in tn_features 
                    and f not in ['mes', 'trimestre', 'año']]  # Excluir temporales
tn_features.extend(other_tn_features)

# Verificar que las características existen en los datos
tn_features_disponibles = [f for f in tn_features if f in X.columns]

print(f"📊 CARACTERÍSTICAS DE TONELADAS IDENTIFICADAS:")
print(f"   ✅ Total identificadas: {len(tn_features)}")
print(f"   ✅ Disponibles en datos: {len(tn_features_disponibles)}")

# Mostrar las características por categoría
tn_lags_norm = [f for f in tn_features_disponibles if f.startswith('tn_lag_')]
tn_rolling_norm = [f for f in tn_features_disponibles if f.startswith('tn_rolling_')]
stock_tn_norm = [f for f in tn_features_disponibles if f.startswith('stock_tn_')]
request_tn_norm = [f for f in tn_features_disponibles if f.startswith('total_request_tn')]

print(f"\n📈 LAGS DE TONELADAS A NORMALIZAR: {len(tn_lags_norm)}")
for i, feat in enumerate(sorted(tn_lags_norm, key=lambda x: int(x.split('_')[-1])), 1):
    print(f"   {i:2d}. {feat}")

print(f"\n📊 ROLLING FEATURES DE TONELADAS: {len(tn_rolling_norm)}")
for i, feat in enumerate(tn_rolling_norm, 1):
    print(f"   {i}. {feat}")

print(f"\n📦 STOCK FEATURES DE TONELADAS: {len(stock_tn_norm)}")
for i, feat in enumerate(stock_tn_norm, 1):
    print(f"   {i}. {feat}")

print(f"\n📋 REQUEST FEATURES DE TONELADAS: {len(request_tn_norm)}")
for i, feat in enumerate(request_tn_norm, 1):
    print(f"   {i}. {feat}")

# Aplicar normalización solo a características de toneladas
print(f"\n🔧 APLICANDO NORMALIZACIÓN STANDARDSCALER...")
print(f"   🎯 ESTRATEGIA: Ajustar scaler SOLO con datos de entrenamiento")

# Inicializar el scaler
scaler_tn = StandardScaler()

# Verificar que las características de toneladas están disponibles
if tn_features_disponibles:
    print(f"   📊 Características a normalizar: {len(tn_features_disponibles)}")
    
    # PASO 1: Ajustar el scaler ÚNICAMENTE con datos de entrenamiento
    print(f"\n   🎓 PASO 1: Ajustando scaler con datos de entrenamiento...")
    print(f"      📊 Registros de entrenamiento: {len(X_train)}")
    print(f"      🔍 Verificando que no hay data leakage...")
    
    scaler_tn.fit(X_train[tn_features_disponibles])
    
    # Mostrar estadísticas del ajuste
    print(f"      ✅ Scaler ajustado exitosamente")
    print(f"      📈 Media aprendida: {scaler_tn.mean_[:3]} ... (primeras 3)")
    print(f"      📏 Std aprendida:  {scaler_tn.scale_[:3]} ... (primeras 3)")
    
    # PASO 2: Aplicar transformación a todos los conjuntos usando parámetros del entrenamiento
    print(f"\n   🔄 PASO 2: Aplicando transformación con parámetros aprendidos...")
    
    # Crear copias de los datos originales
    X_normalized = X.copy()
    X_train_normalized = X_train.copy()
    X_val_normalized = X_val.copy()
    
    # Transformar usando los parámetros aprendidos del entrenamiento
    X_normalized[tn_features_disponibles] = scaler_tn.transform(X[tn_features_disponibles])
    X_train_normalized[tn_features_disponibles] = scaler_tn.transform(X_train[tn_features_disponibles])
    X_val_normalized[tn_features_disponibles] = scaler_tn.transform(X_val[tn_features_disponibles])
    
    print(f"      ✅ Transformación aplicada a:")
    print(f"         📊 Dataset completo: {X_normalized.shape}")
    print(f"         🎓 Entrenamiento: {X_train_normalized.shape}")
    print(f"         🔍 Validación: {X_val_normalized.shape}")
    
    # PASO 3: Verificar la normalización
    print(f"\n   📊 PASO 3: Verificando normalización correcta...")
    
    # Verificar que entrenamiento tiene media≈0 y std≈1
    train_means = X_train_normalized[tn_features_disponibles].mean()
    train_stds = X_train_normalized[tn_features_disponibles].std()
    
    print(f"      📈 Datos de entrenamiento normalizados:")
    print(f"         Media promedio: {train_means.mean():.6f} (debe ≈ 0)")
    print(f"         Std promedio:   {train_stds.mean():.6f} (debe ≈ 1)")
    
    # Verificar que validación usa los mismos parámetros
    val_means = X_val_normalized[tn_features_disponibles].mean()
    val_stds = X_val_normalized[tn_features_disponibles].std()
    
    print(f"      🔍 Datos de validación normalizados:")
    print(f"         Media promedio: {val_means.mean():.6f}")
    print(f"         Std promedio:   {val_stds.mean():.6f}")
    print(f"         ⚠️  Nota: Validación puede diferir de 0/1 (correcto)")
    
    # Mostrar estadísticas detalladas para algunas características
    print(f"\n   📊 ESTADÍSTICAS DETALLADAS (primeras 3 características):")
    muestra_features = tn_features_disponibles[:3]
    
    for feat in muestra_features:
        print(f"\n      📈 {feat}:")
        print(f"         ANTES NORMALIZACIÓN:")
        print(f"           Train - Media: {X_train[feat].mean():8.2f}, Std: {X_train[feat].std():8.2f}")
        print(f"           Val   - Media: {X_val[feat].mean():8.2f}, Std: {X_val[feat].std():8.2f}")
        print(f"         DESPUÉS NORMALIZACIÓN:")
        print(f"           Train - Media: {X_train_normalized[feat].mean():8.2f}, Std: {X_train_normalized[feat].std():8.2f}")
        print(f"           Val   - Media: {X_val_normalized[feat].mean():8.2f}, Std: {X_val_normalized[feat].std():8.2f}")
    
    # Guardar el scaler para uso futuro
    scaler_path = 'data/modelos_entrenados/v3norm/scaler_toneladas_sem_2.pkl'
    os.makedirs('data/modelos_entrenados/v3norm', exist_ok=True)
    with open(scaler_path, 'wb') as f:
        pickle.dump(scaler_tn, f)
    print(f"\n   💾 Scaler guardado en: {scaler_path}")
    print(f"      📋 Contiene parámetros aprendidos SOLO de entrenamiento")
    
    # Actualizar las variables para usar los datos normalizados
    X = X_normalized
    X_train = X_train_normalized
    X_val = X_val_normalized
    
    print(f"\n   ✅ NORMALIZACIÓN COMPLETADA CORRECTAMENTE")
    print(f"      🎯 Principio respetado: Scaler ajustado SOLO con entrenamiento")
    print(f"      🔄 Variables actualizadas: X, X_train, X_val")
    print(f"      📊 Características normalizadas: {len(tn_features_disponibles)}")
    print(f"      🚫 Data leakage: EVITADO correctamente")
    
else:
    print("   ⚠️ No se encontraron características de toneladas para normalizar")
# Out:
# NORMALIZACIÓN DE CARACTERÍSTICAS DE TONELADAS
# ============================================================
# 📊 CARACTERÍSTICAS DE TONELADAS IDENTIFICADAS:
#    ✅ Total identificadas: 52
#    ✅ Disponibles en datos: 52
#
# 📈 LAGS DE TONELADAS A NORMALIZAR: 36
#     1. tn_lag_1
#     2. tn_lag_2
#     3. tn_lag_3
#     4. tn_lag_4
#     5. tn_lag_5
#     6. tn_lag_6
#     7. tn_lag_7
#     8. tn_lag_8
#     9. tn_lag_9
#    10. tn_lag_10
#    11. tn_lag_11
#    12. tn_lag_12
#    13. tn_lag_13
#    14. tn_lag_14
#    15. tn_lag_15
#    16. tn_lag_16
#    17. tn_lag_17
#    18. tn_lag_18
#    19. tn_lag_19
#    20. tn_lag_20
#    21. tn_lag_21
#    22. tn_lag_22
#    23. tn_lag_23
#    24. tn_lag_24
#    25. tn_lag_25
#    26. tn_lag_26
#    27. tn_lag_27
#    28. tn_lag_28
#    29. tn_lag_29
#    30. tn_lag_30
#    31. tn_lag_31
#    32. tn_lag_32
#    33. tn_lag_33
#    34. tn_lag_34
#    35. tn_lag_35
#    36. tn_lag_36
#
# 📊 ROLLING FEATURES DE TONELADAS: 4
#    1. tn_rolling_mean_3
#    2. tn_rolling_mean_6
#    3. tn_rolling_std_3
#    4. tn_rolling_std_6
#
# 📦 STOCK FEATURES DE TONELADAS: 8
#    1. stock_tn_mean_lag_1
#    2. stock_tn_mean_lag_2
#    3. stock_tn_mean_lag_3
#    4. stock_tn_sum_lag_1
#    5. stock_tn_sum_lag_2
#    6. stock_tn_mean
#    7. stock_tn_sum
#    8. stock_tn_std
#
# 📋 REQUEST FEATURES DE TONELADAS: 4
#    1. total_request_tn_lag_1
#    2. total_request_tn_lag_2
#    3. total_request_tn_lag_3
#    4. total_request_tn
#
# 🔧 APLICANDO NORMALIZACIÓN STANDARDSCALER...
#    🎯 ESTRATEGIA: Ajustar scaler SOLO con datos de entrenamiento
#    📊 Características a normalizar: 52
#
#    🎓 PASO 1: Ajustando scaler con datos de entrenamiento...
#       📊 Registros de entrenamiento: 16970
#       🔍 Verificando que no hay data leakage...
#       ✅ Scaler ajustado exitosamente
#       📈 Media aprendida: [51.88155118 50.05890944 48.17594223] ... (primeras 3)
#       📏 Std aprendida:  [127.88465203 126.12752762 124.53852207] ... (primeras 3)
#
#    🔄 PASO 2: Aplicando transformación con parámetros aprendidos...
#       ✅ Transformación aplicada a:
#          📊 Dataset completo: (20789, 62)
#          🎓 Entrenamiento: (16970, 62)
#          🔍 Validación: (3819, 62)
#
#    📊 PASO 3: Verificando normalización correcta...
#       📈 Datos de entrenamiento normalizados:
#          Media promedio: -0.000000 (debe ≈ 0)
#          Std promedio:   0.826947 (debe ≈ 1)
#       🔍 Datos de validación normalizados:
#          Media promedio: 2.505710
#          Std promedio:   8.837691
#          ⚠️  Nota: Validación puede diferir de 0/1 (correcto)
#
#    📊 ESTADÍSTICAS DETALLADAS (primeras 3 características):
#
#       📈 tn_lag_1:
#          ANTES NORMALIZACIÓN:
#            Train - Media:    51.88, Std:   127.89
#            Val   - Media:    39.27, Std:   104.56
#          DESPUÉS NORMALIZACIÓN:
#            Train - Media:    -0.00, Std:     1.00
#            Val   - Media:    -0.10, Std:     0.82
#
#       📈 tn_lag_2:
#          ANTES NORMALIZACIÓN:
#            Train - Media:    50.06, Std:   126.13
#            Val   - Media:    38.81, Std:   103.73
#          DESPUÉS NORMALIZACIÓN:
#            Train - Media:    -0.00, Std:     1.00
#            Val   - Media:    -0.09, Std:     0.82
#
#       📈 tn_lag_3:
#          ANTES NORMALIZACIÓN:
#            Train - Media:    48.18, Std:   124.54
#            Val   - Media:    40.90, Std:   107.67
#          DESPUÉS NORMALIZACIÓN:
#            Train - Media:     0.00, Std:     1.00
#            Val   - Media:    -0.06, Std:     0.86
#
#    💾 Scaler guardado en: data/modelos_entrenados/v3norm/scaler_toneladas_sem_2.pkl
#       📋 Contiene parámetros aprendidos SOLO de entrenamiento
#
#    ✅ NORMALIZACIÓN COMPLETADA CORRECTAMENTE
#       🎯 Principio respetado: Scaler ajustado SOLO con entrenamiento
#       🔄 Variables actualizadas: X, X_train, X_val
#       📊 Características normalizadas: 52
#       🚫 Data leakage: EVITADO correctamente
#       📈 Datos de entrenamiento normalizados:
#          Media promedio: -0.000000 (debe ≈ 0)
#          Std promedio:   0.826947 (debe ≈ 1)
#       🔍 Datos de validación normalizados:
#          Media promedio: 2.505710
#          Std promedio:   8.837691
#          ⚠️  Nota: Validación puede diferir de 0/1 (correcto)
#
#    📊 ESTADÍSTICAS DETALLADAS (primeras 3 características):
#
#       📈 tn_lag_1:
#          ANTES NORMALIZACIÓN:
#            Train - Media:    51.88, Std:   127.89
#            Val   - Media:    39.27, Std:   104.56
#          DESPUÉS NORMALIZACIÓN:
#            Train - Media:    -0.00, Std:     1.00
#            Val   - Media:    -0.10, Std:     0.82
#
#       📈 tn_lag_2:
#          ANTES NORMALIZACIÓN:
#            Train - Media:    50.06, Std:   126.13
#            Val   - Media:    38.81, Std:   103.73
#          DESPUÉS NORMALIZACIÓN:
#            Train - Media:    -0.00, Std:     1.00
#            Val   - Media:    -0.09, Std:     0.82
#
#       📈 tn_lag_3:
#          ANTES NORMALIZACIÓN:
#            Train - Media:    48.18, Std:   124.54
#            Val   - Media:    40.90, Std:   107.67
#          DESPUÉS NORMALIZACIÓN:
#            Train - Media:     0.00, Std:     1.00
#            Val   - Media:    -0.06, Std:     0.86
#
#    💾 Scaler guardado en: data/modelos_entrenados/v3norm/scaler_toneladas_sem_2.pkl
#       📋 Contiene parámetros aprendidos SOLO de entrenamiento
#
#    ✅ NORMALIZACIÓN COMPLETADA CORRECTAMENTE
#       🎯 Principio respetado: Scaler ajustado SOLO con entrenamiento
#       🔄 Variables actualizadas: X, X_train, X_val
#       📊 Características normalizadas: 52
#       🚫 Data leakage: EVITADO correctamente

# %%
# 🔧 Optimización de hiperparámetros con Optuna para LINEAR_TREE
print("OPTIMIZACIÓN DE HIPERPARÁMETROS CON OPTUNA - LINEAR_TREE")
print("="*60)

# 🎲 Configurar semilla para Optuna y reproductibilidad
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

def objective(trial):
    """Función objetivo para optimización con Optuna incluyendo linear_tree"""
    
    # 🎲 Configurar semilla para cada trial
    np.random.seed(SEED + trial.number)
    random.seed(SEED + trial.number)
    
    # Sugerir hiperparámetros optimizados para linear_tree
    params = {
        'objective': 'regression',
        'metric': 'mae',
        'boosting_type': 'gbdt',
        'linear_tree': True,        # FIJO: Característica principal del modelo
        'lambda_l1': trial.suggest_float('lambda_l1', 0.0, 2.0),
        'lambda_l2': trial.suggest_float('lambda_l2', 0.0, 2.0),
        'num_leaves': trial.suggest_int('num_leaves', 20, 120),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.15, log=True),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 40),
        'max_bin': trial.suggest_int('max_bin', 100, 400),
        'verbose': -1,
        'random_state': SEED + trial.number,  # Semilla única por trial
        'bagging_seed': SEED + trial.number,  # Semilla para bagging
        'feature_fraction_seed': SEED + trial.number  # Semilla para feature selection
    }
    
    # Crear datasets de LightGBM
    train_dataset = lgb.Dataset(X_train, label=y_train)
    val_dataset = lgb.Dataset(X_val, label=y_val, reference=train_dataset)
    
    # Entrenar modelo con validación cruzada interna
    model = lgb.train(
        params,
        train_dataset,
        valid_sets=[val_dataset],
        num_boost_round=1000,
        callbacks=[
            lgb.early_stopping(stopping_rounds=50),
            lgb.log_evaluation(0)  # Silenciar logs
        ]
    )
    
    # Predecir en conjunto de validación
    y_pred = model.predict(X_val, num_iteration=model.best_iteration)
    
    # Calcular MAE como métrica a minimizar
    mae = mean_absolute_error(y_val, y_pred)
    
    return mae

# Crear estudio de optimización
print("🔍 Iniciando optimización de hiperparámetros con LINEAR_TREE...")
print(f"🎲 Usando semilla base {SEED} para reproducibilidad completa")

study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=SEED),  # Semilla para el sampler
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=10)
)

# Ejecutar optimización
n_trials = 700 # 500 Número de pruebas
print(f"🚀 Ejecutando {n_trials} trials de optimización para LINEAR_TREE...")
print(f"🎲 Cada trial usa semilla: SEED + trial_number para reproductibilidad")

study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

# Mostrar mejores parámetros
print(f"\n✅ Optimización completada!")
print(f"🏆 Mejor MAE encontrado: {study.best_value:.4f}")
print(f"\n🔧 HIPERPARÁMETROS OPTIMIZADOS PARA LINEAR_TREE:")
best_params = study.best_params
print("="*65)
print(f"   linear_tree:      True (FIJO - Característica principal) ⭐")
print(f"   lambda_l1:        {best_params['lambda_l1']:.4f}")
print(f"   lambda_l2:        {best_params['lambda_l2']:.4f}")
print(f"   num_leaves:       {best_params['num_leaves']}")
print(f"   feature_fraction: {best_params['feature_fraction']:.4f}")
print(f"   learning_rate:    {best_params['learning_rate']:.4f}")
print(f"   bagging_fraction: {best_params['bagging_fraction']:.4f}")
print(f"   bagging_freq:     {best_params['bagging_freq']}")
print(f"   min_child_samples: {best_params['min_child_samples']}")
print(f"   max_bin:          {best_params['max_bin']}")
print("="*65)

# Agregar parámetros fijos
best_params.update({
    'objective': 'regression',
    'metric': 'mae',
    'boosting_type': 'gbdt',
    'linear_tree': True,  # Mantener como característica principal
    'verbose': 0,
    'random_state': SEED,  # Semilla principal para el modelo final
    'bagging_seed': SEED,  # Semilla para bagging
    'feature_fraction_seed': SEED,  # Semilla para feature selection
    'data_seed': SEED  # Semilla para datos
})

print(f"\n📊 Resumen de la optimización:")
print(f"  Trials completados: {len(study.trials)}")
print(f"  Mejor trial: {study.best_trial.number}")
print(f"  Tiempo total: {sum(t.duration.total_seconds() for t in study.trials if t.duration):.1f} segundos")
print(f"🎲 Reproductibilidad garantizada con SEED={SEED}")
# Out:
# [I 2025-08-09 17:30:50,766] A new study created in memory with name: no-name-e094fb74-ecbc-4164-a694-2ccde301426c
# OPTIMIZACIÓN DE HIPERPARÁMETROS CON OPTUNA - LINEAR_TREE
# ============================================================
# 🔍 Iniciando optimización de hiperparámetros con LINEAR_TREE...
# 🎲 Usando semilla base 42 para reproducibilidad completa
# 🚀 Ejecutando 700 trials de optimización para LINEAR_TREE...
# 🎲 Cada trial usa semilla: SEED + trial_number para reproductibilidad
#   0%|          | 0/700 [00:00<?, ?it/s]
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [246]	valid_0's l1: 10.9726
# [I 2025-08-09 17:30:52,191] Trial 0 finished with value: 10.97262911529064 and parameters: {'lambda_l1': 0.749080237694725, 'lambda_l2': 1.9014286128198323, 'num_leaves': 93, 'feature_fraction': 0.8394633936788146, 'learning_rate': 0.015257808482051183, 'bagging_fraction': 0.662397808134481, 'bagging_freq': 1, 'min_child_samples': 36, 'max_bin': 280}. Best is trial 0 with value: 10.97262911529064.
# Early stopping, best iteration is:
# [246]	valid_0's l1: 10.9726
# [I 2025-08-09 17:30:52,191] Trial 0 finished with value: 10.97262911529064 and parameters: {'lambda_l1': 0.749080237694725, 'lambda_l2': 1.9014286128198323, 'num_leaves': 93, 'feature_fraction': 0.8394633936788146, 'learning_rate': 0.015257808482051183, 'bagging_fraction': 0.662397808134481, 'bagging_freq': 1, 'min_child_samples': 36, 'max_bin': 280}. Best is trial 0 with value: 10.97262911529064.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [94]	valid_0's l1: 16.6125
# [I 2025-08-09 17:30:53,079] Trial 1 finished with value: 16.61254439467977 and parameters: {'lambda_l1': 1.416145155592091, 'lambda_l2': 0.041168988591604894, 'num_leaves': 117, 'feature_fraction': 0.9329770563201687, 'learning_rate': 0.01777174904859463, 'bagging_fraction': 0.6727299868828402, 'bagging_freq': 2, 'min_child_samples': 15, 'max_bin': 257}. Best is trial 0 with value: 10.97262911529064.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [94]	valid_0's l1: 16.6125
# [I 2025-08-09 17:30:53,079] Trial 1 finished with value: 16.61254439467977 and parameters: {'lambda_l1': 1.416145155592091, 'lambda_l2': 0.041168988591604894, 'num_leaves': 117, 'feature_fraction': 0.9329770563201687, 'learning_rate': 0.01777174904859463, 'bagging_fraction': 0.6727299868828402, 'bagging_freq': 2, 'min_child_samples': 15, 'max_bin': 257}. Best is trial 0 with value: 10.97262911529064.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [194]	valid_0's l1: 11.2476
# [I 2025-08-09 17:30:54,055] Trial 2 finished with value: 11.247642072109972 and parameters: {'lambda_l1': 0.8638900372842315, 'lambda_l2': 0.5824582803960838, 'num_leaves': 81, 'feature_fraction': 0.6557975442608167, 'learning_rate': 0.022059149678071027, 'bagging_fraction': 0.7465447373174767, 'bagging_freq': 5, 'min_child_samples': 33, 'max_bin': 160}. Best is trial 0 with value: 10.97262911529064.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [194]	valid_0's l1: 11.2476
# [I 2025-08-09 17:30:54,055] Trial 2 finished with value: 11.247642072109972 and parameters: {'lambda_l1': 0.8638900372842315, 'lambda_l2': 0.5824582803960838, 'num_leaves': 81, 'feature_fraction': 0.6557975442608167, 'learning_rate': 0.022059149678071027, 'bagging_fraction': 0.7465447373174767, 'bagging_freq': 5, 'min_child_samples': 33, 'max_bin': 160}. Best is trial 0 with value: 10.97262911529064.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [325]	valid_0's l1: 10.5925
# [I 2025-08-09 17:30:54,724] Trial 3 finished with value: 10.592544300891795 and parameters: {'lambda_l1': 1.0284688768272232, 'lambda_l2': 1.184829137724085, 'num_leaves': 24, 'feature_fraction': 0.8430179407605753, 'learning_rate': 0.015869086642715014, 'bagging_fraction': 0.6260206371941118, 'bagging_freq': 10, 'min_child_samples': 39, 'max_bin': 343}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [325]	valid_0's l1: 10.5925
# [I 2025-08-09 17:30:54,724] Trial 3 finished with value: 10.592544300891795 and parameters: {'lambda_l1': 1.0284688768272232, 'lambda_l2': 1.184829137724085, 'num_leaves': 24, 'feature_fraction': 0.8430179407605753, 'learning_rate': 0.015869086642715014, 'bagging_fraction': 0.6260206371941118, 'bagging_freq': 10, 'min_child_samples': 39, 'max_bin': 343}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [257]	valid_0's l1: 11.557
# [I 2025-08-09 17:30:56,057] Trial 4 finished with value: 11.556962554248196 and parameters: {'lambda_l1': 0.6092275383467414, 'lambda_l2': 0.19534422801276774, 'num_leaves': 89, 'feature_fraction': 0.7760609974958406, 'learning_rate': 0.013916438390377948, 'bagging_fraction': 0.798070764044508, 'bagging_freq': 1, 'min_child_samples': 37, 'max_bin': 177}. Best is trial 3 with value: 10.592544300891795.
# Early stopping, best iteration is:
# [257]	valid_0's l1: 11.557
# [I 2025-08-09 17:30:56,057] Trial 4 finished with value: 11.556962554248196 and parameters: {'lambda_l1': 0.6092275383467414, 'lambda_l2': 0.19534422801276774, 'num_leaves': 89, 'feature_fraction': 0.7760609974958406, 'learning_rate': 0.013916438390377948, 'bagging_fraction': 0.798070764044508, 'bagging_freq': 1, 'min_child_samples': 37, 'max_bin': 177}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [209]	valid_0's l1: 10.8462
# [I 2025-08-09 17:30:57,208] Trial 5 finished with value: 10.846214170623803 and parameters: {'lambda_l1': 1.325044568707964, 'lambda_l2': 0.6234221521788219, 'num_leaves': 72, 'feature_fraction': 0.8186841117373118, 'learning_rate': 0.016497027917250065, 'bagging_fraction': 0.9878338511058234, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 369}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [209]	valid_0's l1: 10.8462
# [I 2025-08-09 17:30:57,208] Trial 5 finished with value: 10.846214170623803 and parameters: {'lambda_l1': 1.325044568707964, 'lambda_l2': 0.6234221521788219, 'num_leaves': 72, 'feature_fraction': 0.8186841117373118, 'learning_rate': 0.016497027917250065, 'bagging_fraction': 0.9878338511058234, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 369}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	valid_0's l1: 49.1774
# [I 2025-08-09 17:30:57,373] Trial 6 finished with value: 49.17744555645666 and parameters: {'lambda_l1': 1.1957999576221703, 'lambda_l2': 1.8437484700462337, 'num_leaves': 28, 'feature_fraction': 0.6783931449676581, 'learning_rate': 0.011302939920362371, 'bagging_fraction': 0.7301321323053057, 'bagging_freq': 4, 'min_child_samples': 14, 'max_bin': 349}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [16]	valid_0's l1: 49.1774
# [I 2025-08-09 17:30:57,373] Trial 6 finished with value: 49.17744555645666 and parameters: {'lambda_l1': 1.1957999576221703, 'lambda_l2': 1.8437484700462337, 'num_leaves': 28, 'feature_fraction': 0.6783931449676581, 'learning_rate': 0.011302939920362371, 'bagging_fraction': 0.7301321323053057, 'bagging_freq': 4, 'min_child_samples': 14, 'max_bin': 349}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	valid_0's l1: 12.4595
# [I 2025-08-09 17:30:57,732] Trial 7 finished with value: 12.459486621980346 and parameters: {'lambda_l1': 0.7135066533871786, 'lambda_l2': 0.5618690193747615, 'num_leaves': 74, 'feature_fraction': 0.6563696899899051, 'learning_rate': 0.08779238696445962, 'bagging_fraction': 0.6298202574719083, 'bagging_freq': 10, 'min_child_samples': 32, 'max_bin': 159}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	valid_0's l1: 12.4595
# [I 2025-08-09 17:30:57,732] Trial 7 finished with value: 12.459486621980346 and parameters: {'lambda_l1': 0.7135066533871786, 'lambda_l2': 0.5618690193747615, 'num_leaves': 74, 'feature_fraction': 0.6563696899899051, 'learning_rate': 0.08779238696445962, 'bagging_fraction': 0.6298202574719083, 'bagging_freq': 10, 'min_child_samples': 32, 'max_bin': 159}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	valid_0's l1: 16.7251
# [I 2025-08-09 17:30:58,108] Trial 8 finished with value: 16.725112791835112 and parameters: {'lambda_l1': 0.011044234247204798, 'lambda_l2': 1.6309228569096683, 'num_leaves': 91, 'feature_fraction': 0.8916028672163949, 'learning_rate': 0.08073917605382007, 'bagging_fraction': 0.6296178606936361, 'bagging_freq': 4, 'min_child_samples': 9, 'max_bin': 359}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [22]	valid_0's l1: 16.7251
# [I 2025-08-09 17:30:58,108] Trial 8 finished with value: 16.725112791835112 and parameters: {'lambda_l1': 0.011044234247204798, 'lambda_l2': 1.6309228569096683, 'num_leaves': 91, 'feature_fraction': 0.8916028672163949, 'learning_rate': 0.08073917605382007, 'bagging_fraction': 0.6296178606936361, 'bagging_freq': 4, 'min_child_samples': 9, 'max_bin': 359}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [223]	valid_0's l1: 11.0958
# [I 2025-08-09 17:30:58,607] Trial 9 finished with value: 11.095838878209715 and parameters: {'lambda_l1': 1.2465962536551158, 'lambda_l2': 0.6617960497052984, 'num_leaves': 26, 'feature_fraction': 0.7243929286862649, 'learning_rate': 0.02412377463500467, 'bagging_fraction': 0.8918424713352255, 'bagging_freq': 7, 'min_child_samples': 36, 'max_bin': 242}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [223]	valid_0's l1: 11.0958
# [I 2025-08-09 17:30:58,607] Trial 9 finished with value: 11.095838878209715 and parameters: {'lambda_l1': 1.2465962536551158, 'lambda_l2': 0.6617960497052984, 'num_leaves': 26, 'feature_fraction': 0.7243929286862649, 'learning_rate': 0.02412377463500467, 'bagging_fraction': 0.8918424713352255, 'bagging_freq': 7, 'min_child_samples': 36, 'max_bin': 242}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [76]	valid_0's l1: 11.4298
# [I 2025-08-09 17:30:58,991] Trial 10 finished with value: 11.429765806178349 and parameters: {'lambda_l1': 1.8902730884607737, 'lambda_l2': 1.2998974451246583, 'num_leaves': 45, 'feature_fraction': 0.9729161367647149, 'learning_rate': 0.04079065925707744, 'bagging_fraction': 0.876098829427658, 'bagging_freq': 10, 'min_child_samples': 26, 'max_bin': 298}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [76]	valid_0's l1: 11.4298
# [I 2025-08-09 17:30:58,991] Trial 10 finished with value: 11.429765806178349 and parameters: {'lambda_l1': 1.8902730884607737, 'lambda_l2': 1.2998974451246583, 'num_leaves': 45, 'feature_fraction': 0.9729161367647149, 'learning_rate': 0.04079065925707744, 'bagging_fraction': 0.876098829427658, 'bagging_freq': 10, 'min_child_samples': 26, 'max_bin': 298}. Best is trial 3 with value: 10.592544300891795.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [118]	valid_0's l1: 10.4934
# [I 2025-08-09 17:30:59,671] Trial 11 finished with value: 10.493364710653621 and parameters: {'lambda_l1': 1.7321491660980881, 'lambda_l2': 1.0605824524664802, 'num_leaves': 55, 'feature_fraction': 0.8330248516405154, 'learning_rate': 0.03911218983062053, 'bagging_fraction': 0.9831904699630575, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 400}. Best is trial 11 with value: 10.493364710653621.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [118]	valid_0's l1: 10.4934
# [I 2025-08-09 17:30:59,671] Trial 11 finished with value: 10.493364710653621 and parameters: {'lambda_l1': 1.7321491660980881, 'lambda_l2': 1.0605824524664802, 'num_leaves': 55, 'feature_fraction': 0.8330248516405154, 'learning_rate': 0.03911218983062053, 'bagging_fraction': 0.9831904699630575, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 400}. Best is trial 11 with value: 10.493364710653621.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [73]	valid_0's l1: 12.6431
# [I 2025-08-09 17:31:00,124] Trial 12 finished with value: 12.643075791723902 and parameters: {'lambda_l1': 1.8774250834551576, 'lambda_l2': 1.1440935872402411, 'num_leaves': 50, 'feature_fraction': 0.8758146404482569, 'learning_rate': 0.04659745602190729, 'bagging_fraction': 0.9683749808111854, 'bagging_freq': 8, 'min_child_samples': 26, 'max_bin': 398}. Best is trial 11 with value: 10.493364710653621.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [73]	valid_0's l1: 12.6431
# [I 2025-08-09 17:31:00,124] Trial 12 finished with value: 12.643075791723902 and parameters: {'lambda_l1': 1.8774250834551576, 'lambda_l2': 1.1440935872402411, 'num_leaves': 50, 'feature_fraction': 0.8758146404482569, 'learning_rate': 0.04659745602190729, 'bagging_fraction': 0.9683749808111854, 'bagging_freq': 8, 'min_child_samples': 26, 'max_bin': 398}. Best is trial 11 with value: 10.493364710653621.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [177]	valid_0's l1: 10.6101
# [I 2025-08-09 17:31:00,847] Trial 13 finished with value: 10.61005664612207 and parameters: {'lambda_l1': 1.6335644970284489, 'lambda_l2': 1.4041579299530662, 'num_leaves': 47, 'feature_fraction': 0.7631435327819819, 'learning_rate': 0.030550882770995692, 'bagging_fraction': 0.8610062565234518, 'bagging_freq': 9, 'min_child_samples': 40, 'max_bin': 313}. Best is trial 11 with value: 10.493364710653621.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [177]	valid_0's l1: 10.6101
# [I 2025-08-09 17:31:00,847] Trial 13 finished with value: 10.61005664612207 and parameters: {'lambda_l1': 1.6335644970284489, 'lambda_l2': 1.4041579299530662, 'num_leaves': 47, 'feature_fraction': 0.7631435327819819, 'learning_rate': 0.030550882770995692, 'bagging_fraction': 0.8610062565234518, 'bagging_freq': 9, 'min_child_samples': 40, 'max_bin': 313}. Best is trial 11 with value: 10.493364710653621.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	valid_0's l1: 10.8387
# [I 2025-08-09 17:31:01,185] Trial 14 finished with value: 10.838673579269331 and parameters: {'lambda_l1': 0.341840219128107, 'lambda_l2': 0.9751504789235237, 'num_leaves': 56, 'feature_fraction': 0.8585163447841954, 'learning_rate': 0.14722185025145784, 'bagging_fraction': 0.9318607113533273, 'bagging_freq': 7, 'min_child_samples': 29, 'max_bin': 330}. Best is trial 11 with value: 10.493364710653621.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	valid_0's l1: 10.8387
# [I 2025-08-09 17:31:01,185] Trial 14 finished with value: 10.838673579269331 and parameters: {'lambda_l1': 0.341840219128107, 'lambda_l2': 0.9751504789235237, 'num_leaves': 56, 'feature_fraction': 0.8585163447841954, 'learning_rate': 0.14722185025145784, 'bagging_fraction': 0.9318607113533273, 'bagging_freq': 7, 'min_child_samples': 29, 'max_bin': 330}. Best is trial 11 with value: 10.493364710653621.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [83]	valid_0's l1: 10.4704
# [I 2025-08-09 17:31:01,430] Trial 15 finished with value: 10.470356940649115 and parameters: {'lambda_l1': 1.6124297776467897, 'lambda_l2': 1.0779394436307772, 'num_leaves': 20, 'feature_fraction': 0.6043956756975085, 'learning_rate': 0.056650220734838636, 'bagging_fraction': 0.8099311633620502, 'bagging_freq': 9, 'min_child_samples': 40, 'max_bin': 394}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	valid_0's l1: 15.5998
# [I 2025-08-09 17:31:01,617] Trial 16 finished with value: 15.599750649917448 and parameters: {'lambda_l1': 1.6635976412675475, 'lambda_l2': 0.9062161581425037, 'num_leaves': 37, 'feature_fraction': 0.6018742527836715, 'learning_rate': 0.05983082602501389, 'bagging_fraction': 0.8121958000863819, 'bagging_freq': 6, 'min_child_samples': 18, 'max_bin': 103}. Best is trial 15 with value: 10.470356940649115.
# Early stopping, best iteration is:
# [83]	valid_0's l1: 10.4704
# [I 2025-08-09 17:31:01,430] Trial 15 finished with value: 10.470356940649115 and parameters: {'lambda_l1': 1.6124297776467897, 'lambda_l2': 1.0779394436307772, 'num_leaves': 20, 'feature_fraction': 0.6043956756975085, 'learning_rate': 0.056650220734838636, 'bagging_fraction': 0.8099311633620502, 'bagging_freq': 9, 'min_child_samples': 40, 'max_bin': 394}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	valid_0's l1: 15.5998
# [I 2025-08-09 17:31:01,617] Trial 16 finished with value: 15.599750649917448 and parameters: {'lambda_l1': 1.6635976412675475, 'lambda_l2': 0.9062161581425037, 'num_leaves': 37, 'feature_fraction': 0.6018742527836715, 'learning_rate': 0.05983082602501389, 'bagging_fraction': 0.8121958000863819, 'bagging_freq': 6, 'min_child_samples': 18, 'max_bin': 103}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	valid_0's l1: 20.9712
# [I 2025-08-09 17:31:01,910] Trial 17 finished with value: 20.97118670698566 and parameters: {'lambda_l1': 1.6334841251528995, 'lambda_l2': 0.8724123420740704, 'num_leaves': 61, 'feature_fraction': 0.7430232282115052, 'learning_rate': 0.06473215465976832, 'bagging_fraction': 0.9388526476448855, 'bagging_freq': 8, 'min_child_samples': 6, 'max_bin': 400}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [19]	valid_0's l1: 20.9712
# [I 2025-08-09 17:31:01,910] Trial 17 finished with value: 20.97118670698566 and parameters: {'lambda_l1': 1.6334841251528995, 'lambda_l2': 0.8724123420740704, 'num_leaves': 61, 'feature_fraction': 0.7430232282115052, 'learning_rate': 0.06473215465976832, 'bagging_fraction': 0.9388526476448855, 'bagging_freq': 8, 'min_child_samples': 6, 'max_bin': 400}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [110]	valid_0's l1: 12.2426
# [I 2025-08-09 17:31:02,264] Trial 18 finished with value: 12.242621621691852 and parameters: {'lambda_l1': 1.996213654518776, 'lambda_l2': 1.5596607484642069, 'num_leaves': 38, 'feature_fraction': 0.6022709997608979, 'learning_rate': 0.032056639200140076, 'bagging_fraction': 0.8005828061689467, 'bagging_freq': 9, 'min_child_samples': 22, 'max_bin': 218}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [110]	valid_0's l1: 12.2426
# [I 2025-08-09 17:31:02,264] Trial 18 finished with value: 12.242621621691852 and parameters: {'lambda_l1': 1.996213654518776, 'lambda_l2': 1.5596607484642069, 'num_leaves': 38, 'feature_fraction': 0.6022709997608979, 'learning_rate': 0.032056639200140076, 'bagging_fraction': 0.8005828061689467, 'bagging_freq': 9, 'min_child_samples': 22, 'max_bin': 218}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	valid_0's l1: 11.0448
# [I 2025-08-09 17:31:02,767] Trial 19 finished with value: 11.044832763743983 and parameters: {'lambda_l1': 1.5513924958406744, 'lambda_l2': 0.30410559478174193, 'num_leaves': 108, 'feature_fraction': 0.708672730025647, 'learning_rate': 0.11385577315040692, 'bagging_fraction': 0.7285617955673408, 'bagging_freq': 6, 'min_child_samples': 32, 'max_bin': 377}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	valid_0's l1: 11.0448
# [I 2025-08-09 17:31:02,767] Trial 19 finished with value: 11.044832763743983 and parameters: {'lambda_l1': 1.5513924958406744, 'lambda_l2': 0.30410559478174193, 'num_leaves': 108, 'feature_fraction': 0.708672730025647, 'learning_rate': 0.11385577315040692, 'bagging_fraction': 0.7285617955673408, 'bagging_freq': 6, 'min_child_samples': 32, 'max_bin': 377}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [71]	valid_0's l1: 11.6608
# [I 2025-08-09 17:31:03,264] Trial 20 finished with value: 11.66082600085486 and parameters: {'lambda_l1': 1.7977778525276005, 'lambda_l2': 0.7978063907444637, 'num_leaves': 64, 'feature_fraction': 0.9153175069788861, 'learning_rate': 0.05269426445944557, 'bagging_fraction': 0.9239667263121535, 'bagging_freq': 9, 'min_child_samples': 28, 'max_bin': 315}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [71]	valid_0's l1: 11.6608
# [I 2025-08-09 17:31:03,264] Trial 20 finished with value: 11.66082600085486 and parameters: {'lambda_l1': 1.7977778525276005, 'lambda_l2': 0.7978063907444637, 'num_leaves': 64, 'feature_fraction': 0.9153175069788861, 'learning_rate': 0.05269426445944557, 'bagging_fraction': 0.9239667263121535, 'bagging_freq': 9, 'min_child_samples': 28, 'max_bin': 315}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [150]	valid_0's l1: 10.4822
# [I 2025-08-09 17:31:03,618] Trial 21 finished with value: 10.482193131460377 and parameters: {'lambda_l1': 1.1844213930459373, 'lambda_l2': 1.2188963389547944, 'num_leaves': 22, 'feature_fraction': 0.7993115568601884, 'learning_rate': 0.03203976487648121, 'bagging_fraction': 0.8432501861805938, 'bagging_freq': 10, 'min_child_samples': 40, 'max_bin': 347}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [150]	valid_0's l1: 10.4822
# [I 2025-08-09 17:31:03,618] Trial 21 finished with value: 10.482193131460377 and parameters: {'lambda_l1': 1.1844213930459373, 'lambda_l2': 1.2188963389547944, 'num_leaves': 22, 'feature_fraction': 0.7993115568601884, 'learning_rate': 0.03203976487648121, 'bagging_fraction': 0.8432501861805938, 'bagging_freq': 10, 'min_child_samples': 40, 'max_bin': 347}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [174]	valid_0's l1: 10.6634
# [I 2025-08-09 17:31:04,183] Trial 22 finished with value: 10.663390232579276 and parameters: {'lambda_l1': 1.439174241305648, 'lambda_l2': 1.1151002697671664, 'num_leaves': 35, 'feature_fraction': 0.7993599823182003, 'learning_rate': 0.033483259098246065, 'bagging_fraction': 0.8479244788952153, 'bagging_freq': 9, 'min_child_samples': 40, 'max_bin': 380}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [174]	valid_0's l1: 10.6634
# [I 2025-08-09 17:31:04,183] Trial 22 finished with value: 10.663390232579276 and parameters: {'lambda_l1': 1.439174241305648, 'lambda_l2': 1.1151002697671664, 'num_leaves': 35, 'feature_fraction': 0.7993599823182003, 'learning_rate': 0.033483259098246065, 'bagging_fraction': 0.8479244788952153, 'bagging_freq': 9, 'min_child_samples': 40, 'max_bin': 380}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [131]	valid_0's l1: 10.7127
# [I 2025-08-09 17:31:04,512] Trial 23 finished with value: 10.71268655779735 and parameters: {'lambda_l1': 1.1398109512594812, 'lambda_l2': 1.494175198821833, 'num_leaves': 21, 'feature_fraction': 0.9997173908335091, 'learning_rate': 0.037863033404452115, 'bagging_fraction': 0.8301038148246822, 'bagging_freq': 7, 'min_child_samples': 34, 'max_bin': 379}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [131]	valid_0's l1: 10.7127
# [I 2025-08-09 17:31:04,512] Trial 23 finished with value: 10.71268655779735 and parameters: {'lambda_l1': 1.1398109512594812, 'lambda_l2': 1.494175198821833, 'num_leaves': 21, 'feature_fraction': 0.9997173908335091, 'learning_rate': 0.037863033404452115, 'bagging_fraction': 0.8301038148246822, 'bagging_freq': 7, 'min_child_samples': 34, 'max_bin': 379}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [153]	valid_0's l1: 10.9852
# [I 2025-08-09 17:31:05,001] Trial 24 finished with value: 10.98523330031284 and parameters: {'lambda_l1': 1.4751731130081511, 'lambda_l2': 1.3305792188658936, 'num_leaves': 32, 'feature_fraction': 0.8045822573961744, 'learning_rate': 0.025310686436683622, 'bagging_fraction': 0.7649011048051568, 'bagging_freq': 10, 'min_child_samples': 35, 'max_bin': 397}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [153]	valid_0's l1: 10.9852
# [I 2025-08-09 17:31:05,001] Trial 24 finished with value: 10.98523330031284 and parameters: {'lambda_l1': 1.4751731130081511, 'lambda_l2': 1.3305792188658936, 'num_leaves': 32, 'feature_fraction': 0.8045822573961744, 'learning_rate': 0.025310686436683622, 'bagging_fraction': 0.7649011048051568, 'bagging_freq': 10, 'min_child_samples': 35, 'max_bin': 397}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [63]	valid_0's l1: 10.551
# [I 2025-08-09 17:31:05,365] Trial 25 finished with value: 10.550960049799722 and parameters: {'lambda_l1': 1.7657643020840235, 'lambda_l2': 1.7180384090229972, 'num_leaves': 42, 'feature_fraction': 0.9335889985479641, 'learning_rate': 0.07751099598009435, 'bagging_fraction': 0.9998474479496084, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 328}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [63]	valid_0's l1: 10.551
# [I 2025-08-09 17:31:05,365] Trial 25 finished with value: 10.550960049799722 and parameters: {'lambda_l1': 1.7657643020840235, 'lambda_l2': 1.7180384090229972, 'num_leaves': 42, 'feature_fraction': 0.9335889985479641, 'learning_rate': 0.07751099598009435, 'bagging_fraction': 0.9998474479496084, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 328}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [116]	valid_0's l1: 10.6309
# [I 2025-08-09 17:31:05,942] Trial 26 finished with value: 10.630853890109755 and parameters: {'lambda_l1': 1.1150992725629614, 'lambda_l2': 1.064425615781415, 'num_leaves': 53, 'feature_fraction': 0.693300400165259, 'learning_rate': 0.046437847847694884, 'bagging_fraction': 0.9050263264243317, 'bagging_freq': 9, 'min_child_samples': 30, 'max_bin': 356}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [116]	valid_0's l1: 10.6309
# [I 2025-08-09 17:31:05,942] Trial 26 finished with value: 10.630853890109755 and parameters: {'lambda_l1': 1.1150992725629614, 'lambda_l2': 1.064425615781415, 'num_leaves': 53, 'feature_fraction': 0.693300400165259, 'learning_rate': 0.046437847847694884, 'bagging_fraction': 0.9050263264243317, 'bagging_freq': 9, 'min_child_samples': 30, 'max_bin': 356}. Best is trial 15 with value: 10.470356940649115.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [111]	valid_0's l1: 10.4457
# [I 2025-08-09 17:31:06,198] Trial 27 finished with value: 10.445696092203594 and parameters: {'lambda_l1': 1.3450141129453177, 'lambda_l2': 1.2406312658111043, 'num_leaves': 20, 'feature_fraction': 0.6284875056905855, 'learning_rate': 0.06373230639966587, 'bagging_fraction': 0.7724110842733133, 'bagging_freq': 10, 'min_child_samples': 21, 'max_bin': 283}. Best is trial 27 with value: 10.445696092203594.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [111]	valid_0's l1: 10.4457
# [I 2025-08-09 17:31:06,198] Trial 27 finished with value: 10.445696092203594 and parameters: {'lambda_l1': 1.3450141129453177, 'lambda_l2': 1.2406312658111043, 'num_leaves': 20, 'feature_fraction': 0.6284875056905855, 'learning_rate': 0.06373230639966587, 'bagging_fraction': 0.7724110842733133, 'bagging_freq': 10, 'min_child_samples': 21, 'max_bin': 283}. Best is trial 27 with value: 10.445696092203594.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [66]	valid_0's l1: 10.7813
# [I 2025-08-09 17:31:06,413] Trial 28 finished with value: 10.781271979545519 and parameters: {'lambda_l1': 0.9138493039429589, 'lambda_l2': 1.2449087597820148, 'num_leaves': 20, 'feature_fraction': 0.6333920496568998, 'learning_rate': 0.06318526919596812, 'bagging_fraction': 0.7761138959178793, 'bagging_freq': 10, 'min_child_samples': 23, 'max_bin': 291}. Best is trial 27 with value: 10.445696092203594.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [66]	valid_0's l1: 10.7813
# [I 2025-08-09 17:31:06,413] Trial 28 finished with value: 10.781271979545519 and parameters: {'lambda_l1': 0.9138493039429589, 'lambda_l2': 1.2449087597820148, 'num_leaves': 20, 'feature_fraction': 0.6333920496568998, 'learning_rate': 0.06318526919596812, 'bagging_fraction': 0.7761138959178793, 'bagging_freq': 10, 'min_child_samples': 23, 'max_bin': 291}. Best is trial 27 with value: 10.445696092203594.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	valid_0's l1: 10.792
# [I 2025-08-09 17:31:06,634] Trial 29 finished with value: 10.792009887253913 and parameters: {'lambda_l1': 1.3030948437999998, 'lambda_l2': 1.9481679205274576, 'num_leaves': 31, 'feature_fraction': 0.63813170638782, 'learning_rate': 0.09453121051848984, 'bagging_fraction': 0.6957765371853208, 'bagging_freq': 10, 'min_child_samples': 21, 'max_bin': 279}. Best is trial 27 with value: 10.445696092203594.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	valid_0's l1: 10.792
# [I 2025-08-09 17:31:06,634] Trial 29 finished with value: 10.792009887253913 and parameters: {'lambda_l1': 1.3030948437999998, 'lambda_l2': 1.9481679205274576, 'num_leaves': 31, 'feature_fraction': 0.63813170638782, 'learning_rate': 0.09453121051848984, 'bagging_fraction': 0.6957765371853208, 'bagging_freq': 10, 'min_child_samples': 21, 'max_bin': 279}. Best is trial 27 with value: 10.445696092203594.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [42]	valid_0's l1: 10.1843
# [I 2025-08-09 17:31:06,834] Trial 30 finished with value: 10.184332155342185 and parameters: {'lambda_l1': 1.0095100712885634, 'lambda_l2': 1.4342108520276025, 'num_leaves': 28, 'feature_fraction': 0.6827876280083923, 'learning_rate': 0.11809540943530404, 'bagging_fraction': 0.833834424861871, 'bagging_freq': 9, 'min_child_samples': 18, 'max_bin': 221}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [42]	valid_0's l1: 10.8134
# [I 2025-08-09 17:31:07,018] Trial 31 finished with value: 10.813366927711893 and parameters: {'lambda_l1': 0.9768824155075713, 'lambda_l2': 1.4132071278440494, 'num_leaves': 21, 'feature_fraction': 0.6293520536682684, 'learning_rate': 0.11420308631766675, 'bagging_fraction': 0.8356308196024687, 'bagging_freq': 9, 'min_child_samples': 18, 'max_bin': 210}. Best is trial 30 with value: 10.184332155342185.
# Early stopping, best iteration is:
# [42]	valid_0's l1: 10.1843
# [I 2025-08-09 17:31:06,834] Trial 30 finished with value: 10.184332155342185 and parameters: {'lambda_l1': 1.0095100712885634, 'lambda_l2': 1.4342108520276025, 'num_leaves': 28, 'feature_fraction': 0.6827876280083923, 'learning_rate': 0.11809540943530404, 'bagging_fraction': 0.833834424861871, 'bagging_freq': 9, 'min_child_samples': 18, 'max_bin': 221}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [42]	valid_0's l1: 10.8134
# [I 2025-08-09 17:31:07,018] Trial 31 finished with value: 10.813366927711893 and parameters: {'lambda_l1': 0.9768824155075713, 'lambda_l2': 1.4132071278440494, 'num_leaves': 21, 'feature_fraction': 0.6293520536682684, 'learning_rate': 0.11420308631766675, 'bagging_fraction': 0.8356308196024687, 'bagging_freq': 9, 'min_child_samples': 18, 'max_bin': 210}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	valid_0's l1: 11.4116
# [I 2025-08-09 17:31:07,197] Trial 32 finished with value: 11.411589364162285 and parameters: {'lambda_l1': 0.5976347875653214, 'lambda_l2': 1.4455305145526256, 'num_leaves': 28, 'feature_fraction': 0.6757717546679107, 'learning_rate': 0.10847818132718932, 'bagging_fraction': 0.7790386672290538, 'bagging_freq': 10, 'min_child_samples': 13, 'max_bin': 254}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	valid_0's l1: 11.4116
# [I 2025-08-09 17:31:07,197] Trial 32 finished with value: 11.411589364162285 and parameters: {'lambda_l1': 0.5976347875653214, 'lambda_l2': 1.4455305145526256, 'num_leaves': 28, 'feature_fraction': 0.6757717546679107, 'learning_rate': 0.10847818132718932, 'bagging_fraction': 0.7790386672290538, 'bagging_freq': 10, 'min_child_samples': 13, 'max_bin': 254}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	valid_0's l1: 12.8039
# [I 2025-08-09 17:31:07,436] Trial 33 finished with value: 12.803916180357875 and parameters: {'lambda_l1': 0.8168430066388314, 'lambda_l2': 1.783698675701915, 'num_leaves': 41, 'feature_fraction': 0.6151495700742444, 'learning_rate': 0.06752780267318138, 'bagging_fraction': 0.8216039890549256, 'bagging_freq': 9, 'min_child_samples': 17, 'max_bin': 213}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	valid_0's l1: 12.8039
# [I 2025-08-09 17:31:07,436] Trial 33 finished with value: 12.803916180357875 and parameters: {'lambda_l1': 0.8168430066388314, 'lambda_l2': 1.783698675701915, 'num_leaves': 41, 'feature_fraction': 0.6151495700742444, 'learning_rate': 0.06752780267318138, 'bagging_fraction': 0.8216039890549256, 'bagging_freq': 9, 'min_child_samples': 17, 'max_bin': 213}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [74]	valid_0's l1: 11.1629
# [I 2025-08-09 17:31:07,722] Trial 34 finished with value: 11.162931403690306 and parameters: {'lambda_l1': 1.0472848699830997, 'lambda_l2': 1.234816403015749, 'num_leaves': 32, 'feature_fraction': 0.6560425198993644, 'learning_rate': 0.05203735226160565, 'bagging_fraction': 0.8641142905991861, 'bagging_freq': 10, 'min_child_samples': 20, 'max_bin': 266}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	valid_0's l1: 11.5038
# [I 2025-08-09 17:31:07,871] Trial 35 finished with value: 11.50381003353198 and parameters: {'lambda_l1': 1.3520631990960608, 'lambda_l2': 1.6676069304690657, 'num_leaves': 20, 'feature_fraction': 0.7275419827550498, 'learning_rate': 0.14148209458017755, 'bagging_fraction': 0.6977623433287442, 'bagging_freq': 3, 'min_child_samples': 11, 'max_bin': 233}. Best is trial 30 with value: 10.184332155342185.
# Early stopping, best iteration is:
# [74]	valid_0's l1: 11.1629
# [I 2025-08-09 17:31:07,722] Trial 34 finished with value: 11.162931403690306 and parameters: {'lambda_l1': 1.0472848699830997, 'lambda_l2': 1.234816403015749, 'num_leaves': 32, 'feature_fraction': 0.6560425198993644, 'learning_rate': 0.05203735226160565, 'bagging_fraction': 0.8641142905991861, 'bagging_freq': 10, 'min_child_samples': 20, 'max_bin': 266}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	valid_0's l1: 11.5038
# [I 2025-08-09 17:31:07,871] Trial 35 finished with value: 11.50381003353198 and parameters: {'lambda_l1': 1.3520631990960608, 'lambda_l2': 1.6676069304690657, 'num_leaves': 20, 'feature_fraction': 0.7275419827550498, 'learning_rate': 0.14148209458017755, 'bagging_fraction': 0.6977623433287442, 'bagging_freq': 3, 'min_child_samples': 11, 'max_bin': 233}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [239]	valid_0's l1: 10.8889
# [I 2025-08-09 17:31:08,361] Trial 36 finished with value: 10.888920571995119 and parameters: {'lambda_l1': 1.5070943631911096, 'lambda_l2': 0.7214162594078326, 'num_leaves': 25, 'feature_fraction': 0.6896583115737493, 'learning_rate': 0.02011454143879757, 'bagging_fraction': 0.7517930871327962, 'bagging_freq': 7, 'min_child_samples': 16, 'max_bin': 275}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [239]	valid_0's l1: 10.8889
# [I 2025-08-09 17:31:08,361] Trial 36 finished with value: 10.888920571995119 and parameters: {'lambda_l1': 1.5070943631911096, 'lambda_l2': 0.7214162594078326, 'num_leaves': 25, 'feature_fraction': 0.6896583115737493, 'learning_rate': 0.02011454143879757, 'bagging_fraction': 0.7517930871327962, 'bagging_freq': 7, 'min_child_samples': 16, 'max_bin': 275}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [112]	valid_0's l1: 11.5557
# [I 2025-08-09 17:31:09,175] Trial 37 finished with value: 11.555680814111323 and parameters: {'lambda_l1': 1.2373009820076406, 'lambda_l2': 1.5581664019571404, 'num_leaves': 116, 'feature_fraction': 0.656674414150932, 'learning_rate': 0.027519435883281852, 'bagging_fraction': 0.7939883848541708, 'bagging_freq': 1, 'min_child_samples': 24, 'max_bin': 194}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [112]	valid_0's l1: 11.5557
# [I 2025-08-09 17:31:09,175] Trial 37 finished with value: 11.555680814111323 and parameters: {'lambda_l1': 1.2373009820076406, 'lambda_l2': 1.5581664019571404, 'num_leaves': 116, 'feature_fraction': 0.656674414150932, 'learning_rate': 0.027519435883281852, 'bagging_fraction': 0.7939883848541708, 'bagging_freq': 1, 'min_child_samples': 24, 'max_bin': 194}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	valid_0's l1: 12.1269
# [I 2025-08-09 17:31:09,624] Trial 38 finished with value: 12.126887216644324 and parameters: {'lambda_l1': 0.6991792912689834, 'lambda_l2': 0.48839527118437265, 'num_leaves': 81, 'feature_fraction': 0.7684289414339478, 'learning_rate': 0.07380717239901262, 'bagging_fraction': 0.7277920384427395, 'bagging_freq': 8, 'min_child_samples': 37, 'max_bin': 144}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	valid_0's l1: 12.1269
# [I 2025-08-09 17:31:09,624] Trial 38 finished with value: 12.126887216644324 and parameters: {'lambda_l1': 0.6991792912689834, 'lambda_l2': 0.48839527118437265, 'num_leaves': 81, 'feature_fraction': 0.7684289414339478, 'learning_rate': 0.07380717239901262, 'bagging_fraction': 0.7277920384427395, 'bagging_freq': 8, 'min_child_samples': 37, 'max_bin': 144}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [40]	valid_0's l1: 10.7167
# [I 2025-08-09 17:31:09,883] Trial 39 finished with value: 10.716701469308951 and parameters: {'lambda_l1': 1.4051192027292234, 'lambda_l2': 0.9828325287308819, 'num_leaves': 27, 'feature_fraction': 0.6296333248993162, 'learning_rate': 0.1008802418025183, 'bagging_fraction': 0.8495138145447407, 'bagging_freq': 5, 'min_child_samples': 25, 'max_bin': 342}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [40]	valid_0's l1: 10.7167
# [I 2025-08-09 17:31:09,883] Trial 39 finished with value: 10.716701469308951 and parameters: {'lambda_l1': 1.4051192027292234, 'lambda_l2': 0.9828325287308819, 'num_leaves': 27, 'feature_fraction': 0.6296333248993162, 'learning_rate': 0.1008802418025183, 'bagging_fraction': 0.8495138145447407, 'bagging_freq': 5, 'min_child_samples': 25, 'max_bin': 342}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [65]	valid_0's l1: 12.2863
# [I 2025-08-09 17:31:10,642] Trial 40 finished with value: 12.286301707765402 and parameters: {'lambda_l1': 0.4419903400388512, 'lambda_l2': 1.3546730751846154, 'num_leaves': 97, 'feature_fraction': 0.6715793571893272, 'learning_rate': 0.054342243876925544, 'bagging_fraction': 0.8835703839930775, 'bagging_freq': 9, 'min_child_samples': 19, 'max_bin': 299}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [65]	valid_0's l1: 12.2863
# [I 2025-08-09 17:31:10,642] Trial 40 finished with value: 12.286301707765402 and parameters: {'lambda_l1': 0.4419903400388512, 'lambda_l2': 1.3546730751846154, 'num_leaves': 97, 'feature_fraction': 0.6715793571893272, 'learning_rate': 0.054342243876925544, 'bagging_fraction': 0.8835703839930775, 'bagging_freq': 9, 'min_child_samples': 19, 'max_bin': 299}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [115]	valid_0's l1: 10.5476
# [I 2025-08-09 17:31:11,131] Trial 41 finished with value: 10.54759116081872 and parameters: {'lambda_l1': 1.7254242640645683, 'lambda_l2': 1.0574053551791733, 'num_leaves': 31, 'feature_fraction': 0.8367293333577001, 'learning_rate': 0.04144250118436898, 'bagging_fraction': 0.7882803032514696, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 373}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [115]	valid_0's l1: 10.5476
# [I 2025-08-09 17:31:11,131] Trial 41 finished with value: 10.54759116081872 and parameters: {'lambda_l1': 1.7254242640645683, 'lambda_l2': 1.0574053551791733, 'num_leaves': 31, 'feature_fraction': 0.8367293333577001, 'learning_rate': 0.04144250118436898, 'bagging_fraction': 0.7882803032514696, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 373}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [173]	valid_0's l1: 10.3713
# [I 2025-08-09 17:31:11,691] Trial 42 finished with value: 10.371307142822864 and parameters: {'lambda_l1': 1.0416160384269078, 'lambda_l2': 1.2290158146572328, 'num_leaves': 24, 'feature_fraction': 0.795183657883191, 'learning_rate': 0.03490948761641346, 'bagging_fraction': 0.8158303865860873, 'bagging_freq': 10, 'min_child_samples': 38, 'max_bin': 342}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [173]	valid_0's l1: 10.3713
# [I 2025-08-09 17:31:11,691] Trial 42 finished with value: 10.371307142822864 and parameters: {'lambda_l1': 1.0416160384269078, 'lambda_l2': 1.2290158146572328, 'num_leaves': 24, 'feature_fraction': 0.795183657883191, 'learning_rate': 0.03490948761641346, 'bagging_fraction': 0.8158303865860873, 'bagging_freq': 10, 'min_child_samples': 38, 'max_bin': 342}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [304]	valid_0's l1: 10.4948
# [I 2025-08-09 17:31:12,389] Trial 43 finished with value: 10.49482434448031 and parameters: {'lambda_l1': 0.9869305298071032, 'lambda_l2': 1.1974665755249574, 'num_leaves': 25, 'feature_fraction': 0.7909948344543705, 'learning_rate': 0.018687121521142075, 'bagging_fraction': 0.8133761216977632, 'bagging_freq': 10, 'min_child_samples': 36, 'max_bin': 335}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [304]	valid_0's l1: 10.4948
# [I 2025-08-09 17:31:12,389] Trial 43 finished with value: 10.49482434448031 and parameters: {'lambda_l1': 0.9869305298071032, 'lambda_l2': 1.1974665755249574, 'num_leaves': 25, 'feature_fraction': 0.7909948344543705, 'learning_rate': 0.018687121521142075, 'bagging_fraction': 0.8133761216977632, 'bagging_freq': 10, 'min_child_samples': 36, 'max_bin': 335}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [114]	valid_0's l1: 10.6246
# [I 2025-08-09 17:31:12,804] Trial 44 finished with value: 10.624601596208992 and parameters: {'lambda_l1': 1.0969684153711727, 'lambda_l2': 1.2493650557200913, 'num_leaves': 34, 'feature_fraction': 0.8192612216565162, 'learning_rate': 0.04494299423802025, 'bagging_fraction': 0.7557977832578588, 'bagging_freq': 10, 'min_child_samples': 38, 'max_bin': 360}. Best is trial 30 with value: 10.184332155342185.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [114]	valid_0's l1: 10.6246
# ...
# Early stopping, best iteration is:
# [413]	valid_0's l1: 10.4237
# [I 2025-08-09 17:37:22,739] Trial 686 finished with value: 10.423734860621186 and parameters: {'lambda_l1': 0.5642518027910121, 'lambda_l2': 1.1967699744729372, 'num_leaves': 25, 'feature_fraction': 0.7427018142970196, 'learning_rate': 0.01614542660793206, 'bagging_fraction': 0.9064411214476661, 'bagging_freq': 10, 'min_child_samples': 40, 'max_bin': 155}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [405]	valid_0's l1: 10.428
# [I 2025-08-09 17:37:23,799] Trial 687 finished with value: 10.427967238270668 and parameters: {'lambda_l1': 0.6344902258619887, 'lambda_l2': 1.147375653172127, 'num_leaves': 20, 'feature_fraction': 0.8068637536341334, 'learning_rate': 0.013486313682554285, 'bagging_fraction': 0.9472628852491761, 'bagging_freq': 7, 'min_child_samples': 39, 'max_bin': 150}. Best is trial 475 with value: 10.083494718461813.
# Early stopping, best iteration is:
# [405]	valid_0's l1: 10.428
# [I 2025-08-09 17:37:23,799] Trial 687 finished with value: 10.427967238270668 and parameters: {'lambda_l1': 0.6344902258619887, 'lambda_l2': 1.147375653172127, 'num_leaves': 20, 'feature_fraction': 0.8068637536341334, 'learning_rate': 0.013486313682554285, 'bagging_fraction': 0.9472628852491761, 'bagging_freq': 7, 'min_child_samples': 39, 'max_bin': 150}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [301]	valid_0's l1: 11.0082
# [I 2025-08-09 17:37:24,573] Trial 688 finished with value: 11.00824132665628 and parameters: {'lambda_l1': 0.5350281182873596, 'lambda_l2': 1.2395497550334051, 'num_leaves': 24, 'feature_fraction': 0.731475747981158, 'learning_rate': 0.011862185646825129, 'bagging_fraction': 0.9137244533143778, 'bagging_freq': 7, 'min_child_samples': 39, 'max_bin': 160}. Best is trial 475 with value: 10.083494718461813.
# Early stopping, best iteration is:
# [301]	valid_0's l1: 11.0082
# [I 2025-08-09 17:37:24,573] Trial 688 finished with value: 11.00824132665628 and parameters: {'lambda_l1': 0.5350281182873596, 'lambda_l2': 1.2395497550334051, 'num_leaves': 24, 'feature_fraction': 0.731475747981158, 'learning_rate': 0.011862185646825129, 'bagging_fraction': 0.9137244533143778, 'bagging_freq': 7, 'min_child_samples': 39, 'max_bin': 160}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	valid_0's l1: 10.6673
# [I 2025-08-09 17:37:24,887] Trial 689 finished with value: 10.66725393358238 and parameters: {'lambda_l1': 0.6146126877570637, 'lambda_l2': 1.1272784316379991, 'num_leaves': 25, 'feature_fraction': 0.7702365633989992, 'learning_rate': 0.11214388393786444, 'bagging_fraction': 0.9030936787350522, 'bagging_freq': 6, 'min_child_samples': 40, 'max_bin': 246}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	valid_0's l1: 10.6673
# [I 2025-08-09 17:37:24,887] Trial 689 finished with value: 10.66725393358238 and parameters: {'lambda_l1': 0.6146126877570637, 'lambda_l2': 1.1272784316379991, 'num_leaves': 25, 'feature_fraction': 0.7702365633989992, 'learning_rate': 0.11214388393786444, 'bagging_fraction': 0.9030936787350522, 'bagging_freq': 6, 'min_child_samples': 40, 'max_bin': 246}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [418]	valid_0's l1: 10.7692
# [I 2025-08-09 17:37:25,699] Trial 690 finished with value: 10.769174343409668 and parameters: {'lambda_l1': 0.5047211875996627, 'lambda_l2': 1.1740444145801252, 'num_leaves': 22, 'feature_fraction': 0.7515170600350182, 'learning_rate': 0.011101923320592797, 'bagging_fraction': 0.9194005613303099, 'bagging_freq': 10, 'min_child_samples': 40, 'max_bin': 173}. Best is trial 475 with value: 10.083494718461813.
# Early stopping, best iteration is:
# [418]	valid_0's l1: 10.7692
# [I 2025-08-09 17:37:25,699] Trial 690 finished with value: 10.769174343409668 and parameters: {'lambda_l1': 0.5047211875996627, 'lambda_l2': 1.1740444145801252, 'num_leaves': 22, 'feature_fraction': 0.7515170600350182, 'learning_rate': 0.011101923320592797, 'bagging_fraction': 0.9194005613303099, 'bagging_freq': 10, 'min_child_samples': 40, 'max_bin': 173}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [483]	valid_0's l1: 10.6027
# [I 2025-08-09 17:37:26,591] Trial 691 finished with value: 10.602734329583141 and parameters: {'lambda_l1': 0.5826243250144367, 'lambda_l2': 1.2484089855212646, 'num_leaves': 24, 'feature_fraction': 0.7574822056138311, 'learning_rate': 0.010438377537971739, 'bagging_fraction': 0.9075367531029267, 'bagging_freq': 10, 'min_child_samples': 32, 'max_bin': 146}. Best is trial 475 with value: 10.083494718461813.
# Early stopping, best iteration is:
# [483]	valid_0's l1: 10.6027
# [I 2025-08-09 17:37:26,591] Trial 691 finished with value: 10.602734329583141 and parameters: {'lambda_l1': 0.5826243250144367, 'lambda_l2': 1.2484089855212646, 'num_leaves': 24, 'feature_fraction': 0.7574822056138311, 'learning_rate': 0.010438377537971739, 'bagging_fraction': 0.9075367531029267, 'bagging_freq': 10, 'min_child_samples': 32, 'max_bin': 146}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [74]	valid_0's l1: 23.7918
# [I 2025-08-09 17:37:26,864] Trial 692 finished with value: 23.79182216943122 and parameters: {'lambda_l1': 0.660823324639116, 'lambda_l2': 1.1081621492918783, 'num_leaves': 20, 'feature_fraction': 0.7394619243653997, 'learning_rate': 0.01466754848575275, 'bagging_fraction': 0.9258476298190476, 'bagging_freq': 6, 'min_child_samples': 39, 'max_bin': 165}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [74]	valid_0's l1: 23.7918
# [I 2025-08-09 17:37:26,864] Trial 692 finished with value: 23.79182216943122 and parameters: {'lambda_l1': 0.660823324639116, 'lambda_l2': 1.1081621492918783, 'num_leaves': 20, 'feature_fraction': 0.7394619243653997, 'learning_rate': 0.01466754848575275, 'bagging_fraction': 0.9258476298190476, 'bagging_freq': 6, 'min_child_samples': 39, 'max_bin': 165}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [92]	valid_0's l1: 10.3903
# [I 2025-08-09 17:37:27,185] Trial 693 finished with value: 10.390261349704122 and parameters: {'lambda_l1': 0.7129122295072474, 'lambda_l2': 1.158065135200124, 'num_leaves': 25, 'feature_fraction': 0.7047040991083123, 'learning_rate': 0.06440218403312196, 'bagging_fraction': 0.9349133642030177, 'bagging_freq': 5, 'min_child_samples': 38, 'max_bin': 155}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [92]	valid_0's l1: 10.3903
# [I 2025-08-09 17:37:27,185] Trial 693 finished with value: 10.390261349704122 and parameters: {'lambda_l1': 0.7129122295072474, 'lambda_l2': 1.158065135200124, 'num_leaves': 25, 'feature_fraction': 0.7047040991083123, 'learning_rate': 0.06440218403312196, 'bagging_fraction': 0.9349133642030177, 'bagging_freq': 5, 'min_child_samples': 38, 'max_bin': 155}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [642]	valid_0's l1: 10.3141
# [I 2025-08-09 17:37:28,269] Trial 694 finished with value: 10.314085682926594 and parameters: {'lambda_l1': 0.519521817282713, 'lambda_l2': 1.197466472071961, 'num_leaves': 22, 'feature_fraction': 0.7159532747822543, 'learning_rate': 0.011238159730620674, 'bagging_fraction': 0.9012536895770316, 'bagging_freq': 7, 'min_child_samples': 40, 'max_bin': 149}. Best is trial 475 with value: 10.083494718461813.
# Early stopping, best iteration is:
# [642]	valid_0's l1: 10.3141
# [I 2025-08-09 17:37:28,269] Trial 694 finished with value: 10.314085682926594 and parameters: {'lambda_l1': 0.519521817282713, 'lambda_l2': 1.197466472071961, 'num_leaves': 22, 'feature_fraction': 0.7159532747822543, 'learning_rate': 0.011238159730620674, 'bagging_fraction': 0.9012536895770316, 'bagging_freq': 7, 'min_child_samples': 40, 'max_bin': 149}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [139]	valid_0's l1: 16.3149
# [I 2025-08-09 17:37:28,644] Trial 695 finished with value: 16.314876322674788 and parameters: {'lambda_l1': 0.7034562632316579, 'lambda_l2': 1.1247178790709984, 'num_leaves': 26, 'feature_fraction': 0.7602488300255602, 'learning_rate': 0.012522958781910565, 'bagging_fraction': 0.9137005694046941, 'bagging_freq': 10, 'min_child_samples': 25, 'max_bin': 159}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [139]	valid_0's l1: 16.3149
# [I 2025-08-09 17:37:28,644] Trial 695 finished with value: 16.314876322674788 and parameters: {'lambda_l1': 0.7034562632316579, 'lambda_l2': 1.1247178790709984, 'num_leaves': 26, 'feature_fraction': 0.7602488300255602, 'learning_rate': 0.012522958781910565, 'bagging_fraction': 0.9137005694046941, 'bagging_freq': 10, 'min_child_samples': 25, 'max_bin': 159}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [406]	valid_0's l1: 10.6205
# [I 2025-08-09 17:37:29,518] Trial 696 finished with value: 10.620547065091163 and parameters: {'lambda_l1': 0.5643573189757309, 'lambda_l2': 1.2613852157381926, 'num_leaves': 23, 'feature_fraction': 0.7343968793780101, 'learning_rate': 0.010532139788612938, 'bagging_fraction': 0.8984975902538134, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 266}. Best is trial 475 with value: 10.083494718461813.
# Early stopping, best iteration is:
# [406]	valid_0's l1: 10.6205
# [I 2025-08-09 17:37:29,518] Trial 696 finished with value: 10.620547065091163 and parameters: {'lambda_l1': 0.5643573189757309, 'lambda_l2': 1.2613852157381926, 'num_leaves': 23, 'feature_fraction': 0.7343968793780101, 'learning_rate': 0.010532139788612938, 'bagging_fraction': 0.8984975902538134, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 266}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	valid_0's l1: 12.8321
# [I 2025-08-09 17:37:29,865] Trial 697 finished with value: 12.83210783586744 and parameters: {'lambda_l1': 0.6031765458176408, 'lambda_l2': 0.3867420246855816, 'num_leaves': 26, 'feature_fraction': 0.6907722834304707, 'learning_rate': 0.03369388911262915, 'bagging_fraction': 0.9081448158875581, 'bagging_freq': 10, 'min_child_samples': 5, 'max_bin': 146}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	valid_0's l1: 12.8321
# [I 2025-08-09 17:37:29,865] Trial 697 finished with value: 12.83210783586744 and parameters: {'lambda_l1': 0.6031765458176408, 'lambda_l2': 0.3867420246855816, 'num_leaves': 26, 'feature_fraction': 0.6907722834304707, 'learning_rate': 0.03369388911262915, 'bagging_fraction': 0.9081448158875581, 'bagging_freq': 10, 'min_child_samples': 5, 'max_bin': 146}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [487]	valid_0's l1: 10.2362
# [I 2025-08-09 17:37:30,818] Trial 698 finished with value: 10.236249769390113 and parameters: {'lambda_l1': 0.6285291668889506, 'lambda_l2': 1.09345615721266, 'num_leaves': 24, 'feature_fraction': 0.7890398427634532, 'learning_rate': 0.01184223811007777, 'bagging_fraction': 0.8957401408277204, 'bagging_freq': 8, 'min_child_samples': 39, 'max_bin': 153}. Best is trial 475 with value: 10.083494718461813.
# Early stopping, best iteration is:
# [487]	valid_0's l1: 10.2362
# [I 2025-08-09 17:37:30,818] Trial 698 finished with value: 10.236249769390113 and parameters: {'lambda_l1': 0.6285291668889506, 'lambda_l2': 1.09345615721266, 'num_leaves': 24, 'feature_fraction': 0.7890398427634532, 'learning_rate': 0.01184223811007777, 'bagging_fraction': 0.8957401408277204, 'bagging_freq': 8, 'min_child_samples': 39, 'max_bin': 153}. Best is trial 475 with value: 10.083494718461813.
# Training until validation scores don't improve for 50 rounds
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [479]	valid_0's l1: 10.3245
# [I 2025-08-09 17:37:31,810] Trial 699 finished with value: 10.324498551842485 and parameters: {'lambda_l1': 0.5030026615378407, 'lambda_l2': 1.2190553417494931, 'num_leaves': 22, 'feature_fraction': 0.7181544879260985, 'learning_rate': 0.01324182437543618, 'bagging_fraction': 0.9177156226034345, 'bagging_freq': 10, 'min_child_samples': 39, 'max_bin': 162}. Best is trial 475 with value: 10.083494718461813.
#
# ✅ Optimización completada!
# 🏆 Mejor MAE encontrado: 10.0835
#
# 🔧 HIPERPARÁMETROS OPTIMIZADOS PARA LINEAR_TREE:
# =================================================================
#    linear_tree:      True (FIJO - Característica principal) ⭐
#    lambda_l1:        0.0715
#    lambda_l2:        0.0377
#    num_leaves:       22
#    feature_fraction: 0.6303
#    learning_rate:    0.0389
#    bagging_fraction: 0.9031
#    bagging_freq:     9
#    min_child_samples: 39
#    max_bin:          151
# =================================================================
#
# 📊 Resumen de la optimización:
#   Trials completados: 700
#   Mejor trial: 475
#   Tiempo total: 399.8 segundos
# 🎲 Reproductibilidad garantizada con SEED=42
# Early stopping, best iteration is:
# [479]	valid_0's l1: 10.3245
# [I 2025-08-09 17:37:31,810] Trial 699 finished with value: 10.324498551842485 and parameters: {'lambda_l1': 0.5030026615378407, 'lambda_l2': 1.2190553417494931, 'num_leaves': 22, 'feature_fraction': 0.7181544879260985, 'learning_rate': 0.01324182437543618, 'bagging_fraction': 0.9177156226034345, 'bagging_freq': 10, 'min_child_samples': 39, 'max_bin': 162}. Best is trial 475 with value: 10.083494718461813.
#
# ✅ Optimización completada!
# 🏆 Mejor MAE encontrado: 10.0835
#
# 🔧 HIPERPARÁMETROS OPTIMIZADOS PARA LINEAR_TREE:
# =================================================================
#    linear_tree:      True (FIJO - Característica principal) ⭐
#    lambda_l1:        0.0715
#    lambda_l2:        0.0377
#    num_leaves:       22
#    feature_fraction: 0.6303
#    learning_rate:    0.0389
#    bagging_fraction: 0.9031
#    bagging_freq:     9
#    min_child_samples: 39
#    max_bin:          151
# =================================================================
#
# 📊 Resumen de la optimización:
#   Trials completados: 700
#   Mejor trial: 475
#   Tiempo total: 399.8 segundos
# 🎲 Reproductibilidad garantizada con SEED=42

# %%
# 🚀 Entrenar 20 modelos LightGBM con diferentes semillas - LINEAR_TREE
print("ENTRENAMIENTO DE 20 MODELOS LIGHTGBM CON DIFERENTES SEMILLAS - LINEAR_TREE")
print("="*80)

# 🎲 Definir las 20 semillas diferentes
semillas = [42, 109, 113, 151, 167, 179, 193, 199, 211, 241,
            263, 281, 307, 331, 367, 401, 439, 487, 563, 617]

print(f"🔢 Usando {len(semillas)} semillas diferentes para entrenamiento:")
print(f"   Semillas: {semillas}")

# Usar los mejores parámetros encontrados por Optuna
lgb_params_base = best_params.copy()

# Listas para almacenar modelos y métricas
modelos = []
metricas = []
predicciones_val = []
predicciones_finales = []

# 💾 Crear directorio para guardar los modelos
import os
import pickle
modelos_dir = 'data/modelos_entrenados/v3norm'
os.makedirs(modelos_dir, exist_ok=True)

print(f"\n💾 Los modelos se guardarán en: {modelos_dir}/")
print(f"\n🚀 Iniciando entrenamiento de {len(semillas)} modelos...")

for i, seed in enumerate(semillas, 1):
    print(f"\n{'='*60}")
    print(f"🎯 ENTRENANDO MODELO {i}/20 - SEMILLA: {seed}")
    print(f"{'='*60}")
    
    # 🎲 Configurar semilla específica para este modelo
    np.random.seed(seed)
    random.seed(seed)
    
    # Crear parámetros específicos para este modelo
    lgb_params = lgb_params_base.copy()
    lgb_params.update({
        'random_state': seed,
        'bagging_seed': seed,
        'feature_fraction_seed': seed,
        'data_seed': seed
    })
    
    print(f"🔧 Parámetros para modelo {i}:")
    print(f"   linear_tree: {lgb_params['linear_tree']} ⭐")
    print(f"   random_state: {seed}")
    print(f"   learning_rate: {lgb_params['learning_rate']:.4f}")
    print(f"   num_leaves: {lgb_params['num_leaves']}")
    
    # Crear datasets de LightGBM
    train_dataset = lgb.Dataset(X_train, label=y_train)
    val_dataset = lgb.Dataset(X_val, label=y_val, reference=train_dataset)
    
    # Entrenar el modelo
    modelo = lgb.train(
        lgb_params,
        train_dataset,
        valid_sets=[train_dataset, val_dataset],
        valid_names=['train', 'eval'],
        num_boost_round=2000,
        callbacks=[
            lgb.early_stopping(stopping_rounds=150),
            lgb.log_evaluation(0)  # Silenciar logs individuales
        ]
    )
    
    # 💾 Guardar el modelo individual con su semilla
    model_filename = f"{modelos_dir}/modelo_lgbm_seed_{seed}.pkl"
    with open(model_filename, 'wb') as f:
        pickle.dump(modelo, f)
    print(f"💾 Modelo guardado en: {model_filename}")
    
    # Predicciones en validación
    y_pred_val = modelo.predict(X_val, num_iteration=modelo.best_iteration)
    
    # Calcular métricas
    mae = mean_absolute_error(y_val, y_pred_val)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred_val))
    mape = np.mean(np.abs((y_val - y_pred_val) / y_val)) * 100
    
    # Almacenar resultados (incluyendo ruta del modelo)
    modelos.append(modelo)
    metricas.append({
        'modelo': i,
        'semilla': seed,
        'mae': mae,
        'rmse': rmse,
        'mape': mape,
        'num_trees': modelo.num_trees(),
        'model_file': model_filename  # 📁 Ruta del archivo del modelo
    })
    predicciones_val.append(y_pred_val)
    
    print(f"✅ Modelo {i} entrenado exitosamente!")
    print(f"   MAE:  {mae:.4f}")
    print(f"   RMSE: {rmse:.4f}")
    print(f"   MAPE: {mape:.2f}%")
    print(f"   Árboles: {modelo.num_trees()}")

print(f"\n🎉 ¡TODOS LOS {len(semillas)} MODELOS ENTRENADOS EXITOSAMENTE!")
print(f"⭐ Cada modelo usa árboles lineales híbridos con parámetros optimizados por Optuna")
print(f"💾 Todos los modelos han sido guardados en: {modelos_dir}/")

# Crear DataFrame con métricas (incluyendo rutas de archivos)
df_metricas = pd.DataFrame(metricas)
print(f"\n📊 RESUMEN DE MÉTRICAS DE LOS {len(semillas)} MODELOS:")
print(f"{'='*60}")
print(df_metricas[['modelo', 'semilla', 'mae', 'rmse', 'mape', 'num_trees']])  # Mostrar sin la ruta por claridad

print(f"\n📈 ESTADÍSTICAS DE LAS MÉTRICAS:")
print(f"   MAE  - Promedio: {df_metricas['mae'].mean():.4f}, Std: {df_metricas['mae'].std():.4f}")
print(f"   RMSE - Promedio: {df_metricas['rmse'].mean():.4f}, Std: {df_metricas['rmse'].std():.4f}")
print(f"   MAPE - Promedio: {df_metricas['mape'].mean():.2f}%, Std: {df_metricas['mape'].std():.2f}%")

# Encontrar el mejor modelo
mejor_modelo_idx = df_metricas['mae'].idxmin()
mejor_modelo = modelos[mejor_modelo_idx]
mejor_semilla = semillas[mejor_modelo_idx]
mejor_model_file = df_metricas.loc[mejor_modelo_idx, 'model_file']

print(f"\n🏆 MEJOR MODELO:")
print(f"   Modelo: {mejor_modelo_idx + 1}")
print(f"   Semilla: {mejor_semilla}")
print(f"   MAE: {df_metricas.loc[mejor_modelo_idx, 'mae']:.4f}")
print(f"   RMSE: {df_metricas.loc[mejor_modelo_idx, 'rmse']:.4f}")
print(f"   MAPE: {df_metricas.loc[mejor_modelo_idx, 'mape']:.2f}%")
print(f"   📁 Archivo: {mejor_model_file}")

print(f"\n📁 LISTA DE MODELOS GUARDADOS:")
for i, row in df_metricas.iterrows():
    print(f"   Modelo {row['modelo']:2d} (seed {row['semilla']:3d}): {row['model_file']}")
# Out:
# ENTRENAMIENTO DE 20 MODELOS LIGHTGBM CON DIFERENTES SEMILLAS - LINEAR_TREE
# ================================================================================
# 🔢 Usando 20 semillas diferentes para entrenamiento:
#    Semillas: [42, 109, 113, 151, 167, 179, 193, 199, 211, 241, 263, 281, 307, 331, 367, 401, 439, 487, 563, 617]
#
# 💾 Los modelos se guardarán en: data/modelos_entrenados/v3norm/
#
# 🚀 Iniciando entrenamiento de 20 modelos...
#
# ============================================================
# 🎯 ENTRENANDO MODELO 1/20 - SEMILLA: 42
# ============================================================
# 🔧 Parámetros para modelo 1:
#    linear_tree: True ⭐
#    random_state: 42
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [162]	train's l1: 9.04546	eval's l1: 10.2293
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_42.pkl
# ✅ Modelo 1 entrenado exitosamente!
#    MAE:  10.2293
#    RMSE: 32.1721
#    MAPE: 159.76%
#    Árboles: 162
#
# ============================================================
# 🎯 ENTRENANDO MODELO 2/20 - SEMILLA: 109
# ============================================================
# 🔧 Parámetros para modelo 2:
#    linear_tree: True ⭐
#    random_state: 109
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [162]	train's l1: 9.04546	eval's l1: 10.2293
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_42.pkl
# ✅ Modelo 1 entrenado exitosamente!
#    MAE:  10.2293
#    RMSE: 32.1721
#    MAPE: 159.76%
#    Árboles: 162
#
# ============================================================
# 🎯 ENTRENANDO MODELO 2/20 - SEMILLA: 109
# ============================================================
# 🔧 Parámetros para modelo 2:
#    linear_tree: True ⭐
#    random_state: 109
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [126]	train's l1: 9.9059	eval's l1: 10.4415
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_109.pkl
# ✅ Modelo 2 entrenado exitosamente!
#    MAE:  10.4415
#    RMSE: 32.2283
#    MAPE: 210.23%
#    Árboles: 126
#
# ============================================================
# 🎯 ENTRENANDO MODELO 3/20 - SEMILLA: 113
# ============================================================
# 🔧 Parámetros para modelo 3:
#    linear_tree: True ⭐
#    random_state: 113
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [126]	train's l1: 9.9059	eval's l1: 10.4415
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_109.pkl
# ✅ Modelo 2 entrenado exitosamente!
#    MAE:  10.4415
#    RMSE: 32.2283
#    MAPE: 210.23%
#    Árboles: 126
#
# ============================================================
# 🎯 ENTRENANDO MODELO 3/20 - SEMILLA: 113
# ============================================================
# 🔧 Parámetros para modelo 3:
#    linear_tree: True ⭐
#    random_state: 113
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [182]	train's l1: 8.7306	eval's l1: 10.2748
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_113.pkl
# ✅ Modelo 3 entrenado exitosamente!
#    MAE:  10.2748
#    RMSE: 31.9643
#    MAPE: 181.26%
#    Árboles: 182
#
# ============================================================
# 🎯 ENTRENANDO MODELO 4/20 - SEMILLA: 151
# ============================================================
# 🔧 Parámetros para modelo 4:
#    linear_tree: True ⭐
#    random_state: 151
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [182]	train's l1: 8.7306	eval's l1: 10.2748
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_113.pkl
# ✅ Modelo 3 entrenado exitosamente!
#    MAE:  10.2748
#    RMSE: 31.9643
#    MAPE: 181.26%
#    Árboles: 182
#
# ============================================================
# 🎯 ENTRENANDO MODELO 4/20 - SEMILLA: 151
# ============================================================
# 🔧 Parámetros para modelo 4:
#    linear_tree: True ⭐
#    random_state: 151
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [150]	train's l1: 9.26807	eval's l1: 10.3349
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_151.pkl
# ✅ Modelo 4 entrenado exitosamente!
#    MAE:  10.3349
#    RMSE: 32.3443
#    MAPE: 241.91%
#    Árboles: 150
#
# ============================================================
# 🎯 ENTRENANDO MODELO 5/20 - SEMILLA: 167
# ============================================================
# 🔧 Parámetros para modelo 5:
#    linear_tree: True ⭐
#    random_state: 167
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [150]	train's l1: 9.26807	eval's l1: 10.3349
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_151.pkl
# ✅ Modelo 4 entrenado exitosamente!
#    MAE:  10.3349
#    RMSE: 32.3443
#    MAPE: 241.91%
#    Árboles: 150
#
# ============================================================
# 🎯 ENTRENANDO MODELO 5/20 - SEMILLA: 167
# ============================================================
# 🔧 Parámetros para modelo 5:
#    linear_tree: True ⭐
#    random_state: 167
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [127]	train's l1: 9.72043	eval's l1: 10.5379
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_167.pkl
# ✅ Modelo 5 entrenado exitosamente!
#    MAE:  10.5379
#    RMSE: 33.3231
#    MAPE: 201.90%
#    Árboles: 127
#
# ============================================================
# 🎯 ENTRENANDO MODELO 6/20 - SEMILLA: 179
# ============================================================
# 🔧 Parámetros para modelo 6:
#    linear_tree: True ⭐
#    random_state: 179
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [127]	train's l1: 9.72043	eval's l1: 10.5379
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_167.pkl
# ✅ Modelo 5 entrenado exitosamente!
#    MAE:  10.5379
#    RMSE: 33.3231
#    MAPE: 201.90%
#    Árboles: 127
#
# ============================================================
# 🎯 ENTRENANDO MODELO 6/20 - SEMILLA: 179
# ============================================================
# 🔧 Parámetros para modelo 6:
#    linear_tree: True ⭐
#    random_state: 179
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [249]	train's l1: 7.95683	eval's l1: 10.337
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_179.pkl
# ✅ Modelo 6 entrenado exitosamente!
#    MAE:  10.3370
#    RMSE: 32.3683
#    MAPE: 155.77%
#    Árboles: 249
#
# ============================================================
# 🎯 ENTRENANDO MODELO 7/20 - SEMILLA: 193
# ============================================================
# 🔧 Parámetros para modelo 7:
#    linear_tree: True ⭐
#    random_state: 193
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [249]	train's l1: 7.95683	eval's l1: 10.337
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_179.pkl
# ✅ Modelo 6 entrenado exitosamente!
#    MAE:  10.3370
#    RMSE: 32.3683
#    MAPE: 155.77%
#    Árboles: 249
#
# ============================================================
# 🎯 ENTRENANDO MODELO 7/20 - SEMILLA: 193
# ============================================================
# 🔧 Parámetros para modelo 7:
#    linear_tree: True ⭐
#    random_state: 193
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [116]	train's l1: 10.0035	eval's l1: 10.644
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_193.pkl
# ✅ Modelo 7 entrenado exitosamente!
#    MAE:  10.6440
#    RMSE: 35.1477
#    MAPE: 262.19%
#    Árboles: 116
#
# ============================================================
# 🎯 ENTRENANDO MODELO 8/20 - SEMILLA: 199
# ============================================================
# 🔧 Parámetros para modelo 8:
#    linear_tree: True ⭐
#    random_state: 199
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [116]	train's l1: 10.0035	eval's l1: 10.644
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_193.pkl
# ✅ Modelo 7 entrenado exitosamente!
#    MAE:  10.6440
#    RMSE: 35.1477
#    MAPE: 262.19%
#    Árboles: 116
#
# ============================================================
# 🎯 ENTRENANDO MODELO 8/20 - SEMILLA: 199
# ============================================================
# 🔧 Parámetros para modelo 8:
#    linear_tree: True ⭐
#    random_state: 199
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [196]	train's l1: 8.60859	eval's l1: 10.3246
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_199.pkl
# ✅ Modelo 8 entrenado exitosamente!
#    MAE:  10.3246
#    RMSE: 33.2277
#    MAPE: 151.48%
#    Árboles: 196
#
# ============================================================
# 🎯 ENTRENANDO MODELO 9/20 - SEMILLA: 211
# ============================================================
# 🔧 Parámetros para modelo 9:
#    linear_tree: True ⭐
#    random_state: 211
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [196]	train's l1: 8.60859	eval's l1: 10.3246
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_199.pkl
# ✅ Modelo 8 entrenado exitosamente!
#    MAE:  10.3246
#    RMSE: 33.2277
#    MAPE: 151.48%
#    Árboles: 196
#
# ============================================================
# 🎯 ENTRENANDO MODELO 9/20 - SEMILLA: 211
# ============================================================
# 🔧 Parámetros para modelo 9:
#    linear_tree: True ⭐
#    random_state: 211
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [100]	train's l1: 10.4907	eval's l1: 10.7987
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_211.pkl
# ✅ Modelo 9 entrenado exitosamente!
#    MAE:  10.7987
#    RMSE: 32.4781
#    MAPE: 350.24%
#    Árboles: 100
#
# ============================================================
# 🎯 ENTRENANDO MODELO 10/20 - SEMILLA: 241
# ============================================================
# 🔧 Parámetros para modelo 10:
#    linear_tree: True ⭐
#    random_state: 241
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [100]	train's l1: 10.4907	eval's l1: 10.7987
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_211.pkl
# ✅ Modelo 9 entrenado exitosamente!
#    MAE:  10.7987
#    RMSE: 32.4781
#    MAPE: 350.24%
#    Árboles: 100
#
# ============================================================
# 🎯 ENTRENANDO MODELO 10/20 - SEMILLA: 241
# ============================================================
# 🔧 Parámetros para modelo 10:
#    linear_tree: True ⭐
#    random_state: 241
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [137]	train's l1: 9.56259	eval's l1: 10.5528
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_241.pkl
# ✅ Modelo 10 entrenado exitosamente!
#    MAE:  10.5528
#    RMSE: 33.1944
#    MAPE: 217.50%
#    Árboles: 137
#
# ============================================================
# 🎯 ENTRENANDO MODELO 11/20 - SEMILLA: 263
# ============================================================
# 🔧 Parámetros para modelo 11:
#    linear_tree: True ⭐
#    random_state: 263
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [137]	train's l1: 9.56259	eval's l1: 10.5528
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_241.pkl
# ✅ Modelo 10 entrenado exitosamente!
#    MAE:  10.5528
#    RMSE: 33.1944
#    MAPE: 217.50%
#    Árboles: 137
#
# ============================================================
# 🎯 ENTRENANDO MODELO 11/20 - SEMILLA: 263
# ============================================================
# 🔧 Parámetros para modelo 11:
#    linear_tree: True ⭐
#    random_state: 263
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [130]	train's l1: 9.6558	eval's l1: 10.4054
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_263.pkl
# ✅ Modelo 11 entrenado exitosamente!
#    MAE:  10.4054
#    RMSE: 32.1757
#    MAPE: 191.98%
#    Árboles: 130
#
# ============================================================
# 🎯 ENTRENANDO MODELO 12/20 - SEMILLA: 281
# ============================================================
# 🔧 Parámetros para modelo 12:
#    linear_tree: True ⭐
#    random_state: 281
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [130]	train's l1: 9.6558	eval's l1: 10.4054
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_263.pkl
# ✅ Modelo 11 entrenado exitosamente!
#    MAE:  10.4054
#    RMSE: 32.1757
#    MAPE: 191.98%
#    Árboles: 130
#
# ============================================================
# 🎯 ENTRENANDO MODELO 12/20 - SEMILLA: 281
# ============================================================
# 🔧 Parámetros para modelo 12:
#    linear_tree: True ⭐
#    random_state: 281
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [122]	train's l1: 9.92694	eval's l1: 10.4975
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_281.pkl
# ✅ Modelo 12 entrenado exitosamente!
#    MAE:  10.4975
#    RMSE: 32.1896
#    MAPE: 222.20%
#    Árboles: 122
#
# ============================================================
# 🎯 ENTRENANDO MODELO 13/20 - SEMILLA: 307
# ============================================================
# 🔧 Parámetros para modelo 13:
#    linear_tree: True ⭐
#    random_state: 307
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [122]	train's l1: 9.92694	eval's l1: 10.4975
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_281.pkl
# ✅ Modelo 12 entrenado exitosamente!
#    MAE:  10.4975
#    RMSE: 32.1896
#    MAPE: 222.20%
#    Árboles: 122
#
# ============================================================
# 🎯 ENTRENANDO MODELO 13/20 - SEMILLA: 307
# ============================================================
# 🔧 Parámetros para modelo 13:
#    linear_tree: True ⭐
#    random_state: 307
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [197]	train's l1: 8.50505	eval's l1: 10.2215
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_307.pkl
# ✅ Modelo 13 entrenado exitosamente!
#    MAE:  10.2215
#    RMSE: 31.8052
#    MAPE: 150.67%
#    Árboles: 197
#
# ============================================================
# 🎯 ENTRENANDO MODELO 14/20 - SEMILLA: 331
# ============================================================
# 🔧 Parámetros para modelo 14:
#    linear_tree: True ⭐
#    random_state: 331
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [197]	train's l1: 8.50505	eval's l1: 10.2215
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_307.pkl
# ✅ Modelo 13 entrenado exitosamente!
#    MAE:  10.2215
#    RMSE: 31.8052
#    MAPE: 150.67%
#    Árboles: 197
#
# ============================================================
# 🎯 ENTRENANDO MODELO 14/20 - SEMILLA: 331
# ============================================================
# 🔧 Parámetros para modelo 14:
#    linear_tree: True ⭐
#    random_state: 331
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [95]	train's l1: 10.7937	eval's l1: 10.7919
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_331.pkl
# ✅ Modelo 14 entrenado exitosamente!
#    MAE:  10.7919
#    RMSE: 32.0151
#    MAPE: 406.22%
#    Árboles: 95
#
# ============================================================
# 🎯 ENTRENANDO MODELO 15/20 - SEMILLA: 367
# ============================================================
# 🔧 Parámetros para modelo 15:
#    linear_tree: True ⭐
#    random_state: 367
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [95]	train's l1: 10.7937	eval's l1: 10.7919
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_331.pkl
# ✅ Modelo 14 entrenado exitosamente!
#    MAE:  10.7919
#    RMSE: 32.0151
#    MAPE: 406.22%
#    Árboles: 95
#
# ============================================================
# 🎯 ENTRENANDO MODELO 15/20 - SEMILLA: 367
# ============================================================
# 🔧 Parámetros para modelo 15:
#    linear_tree: True ⭐
#    random_state: 367
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [216]	train's l1: 8.39611	eval's l1: 10.2783
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_367.pkl
# ✅ Modelo 15 entrenado exitosamente!
#    MAE:  10.2783
#    RMSE: 32.1454
#    MAPE: 156.01%
#    Árboles: 216
#
# ============================================================
# 🎯 ENTRENANDO MODELO 16/20 - SEMILLA: 401
# ============================================================
# 🔧 Parámetros para modelo 16:
#    linear_tree: True ⭐
#    random_state: 401
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [216]	train's l1: 8.39611	eval's l1: 10.2783
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_367.pkl
# ✅ Modelo 15 entrenado exitosamente!
#    MAE:  10.2783
#    RMSE: 32.1454
#    MAPE: 156.01%
#    Árboles: 216
#
# ============================================================
# 🎯 ENTRENANDO MODELO 16/20 - SEMILLA: 401
# ============================================================
# 🔧 Parámetros para modelo 16:
#    linear_tree: True ⭐
#    random_state: 401
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [162]	train's l1: 9.09263	eval's l1: 10.2865
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_401.pkl
# ✅ Modelo 16 entrenado exitosamente!
#    MAE:  10.2865
#    RMSE: 31.9021
#    MAPE: 173.15%
#    Árboles: 162
#
# ============================================================
# 🎯 ENTRENANDO MODELO 17/20 - SEMILLA: 439
# ============================================================
# 🔧 Parámetros para modelo 17:
#    linear_tree: True ⭐
#    random_state: 439
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [162]	train's l1: 9.09263	eval's l1: 10.2865
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_401.pkl
# ✅ Modelo 16 entrenado exitosamente!
#    MAE:  10.2865
#    RMSE: 31.9021
#    MAPE: 173.15%
#    Árboles: 162
#
# ============================================================
# 🎯 ENTRENANDO MODELO 17/20 - SEMILLA: 439
# ============================================================
# 🔧 Parámetros para modelo 17:
#    linear_tree: True ⭐
#    random_state: 439
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [159]	train's l1: 9.15897	eval's l1: 10.2053
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_439.pkl
# ✅ Modelo 17 entrenado exitosamente!
#    MAE:  10.2053
#    RMSE: 31.8740
#    MAPE: 205.33%
#    Árboles: 159
#
# ============================================================
# 🎯 ENTRENANDO MODELO 18/20 - SEMILLA: 487
# ============================================================
# 🔧 Parámetros para modelo 18:
#    linear_tree: True ⭐
#    random_state: 487
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [159]	train's l1: 9.15897	eval's l1: 10.2053
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_439.pkl
# ✅ Modelo 17 entrenado exitosamente!
#    MAE:  10.2053
#    RMSE: 31.8740
#    MAPE: 205.33%
#    Árboles: 159
#
# ============================================================
# 🎯 ENTRENANDO MODELO 18/20 - SEMILLA: 487
# ============================================================
# 🔧 Parámetros para modelo 18:
#    linear_tree: True ⭐
#    random_state: 487
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [160]	train's l1: 9.04888	eval's l1: 10.3345
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_487.pkl
# ✅ Modelo 18 entrenado exitosamente!
#    MAE:  10.3345
#    RMSE: 32.3450
#    MAPE: 176.12%
#    Árboles: 160
#
# ============================================================
# 🎯 ENTRENANDO MODELO 19/20 - SEMILLA: 563
# ============================================================
# 🔧 Parámetros para modelo 19:
#    linear_tree: True ⭐
#    random_state: 563
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [160]	train's l1: 9.04888	eval's l1: 10.3345
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_487.pkl
# ✅ Modelo 18 entrenado exitosamente!
#    MAE:  10.3345
#    RMSE: 32.3450
#    MAPE: 176.12%
#    Árboles: 160
#
# ============================================================
# 🎯 ENTRENANDO MODELO 19/20 - SEMILLA: 563
# ============================================================
# 🔧 Parámetros para modelo 19:
#    linear_tree: True ⭐
#    random_state: 563
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [163]	train's l1: 9.03007	eval's l1: 10.344
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_563.pkl
# ✅ Modelo 19 entrenado exitosamente!
#    MAE:  10.3440
#    RMSE: 32.1653
#    MAPE: 153.16%
#    Árboles: 163
#
# ============================================================
# 🎯 ENTRENANDO MODELO 20/20 - SEMILLA: 617
# ============================================================
# 🔧 Parámetros para modelo 20:
#    linear_tree: True ⭐
#    random_state: 617
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [163]	train's l1: 9.03007	eval's l1: 10.344
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_563.pkl
# ✅ Modelo 19 entrenado exitosamente!
#    MAE:  10.3440
#    RMSE: 32.1653
#    MAPE: 153.16%
#    Árboles: 163
#
# ============================================================
# 🎯 ENTRENANDO MODELO 20/20 - SEMILLA: 617
# ============================================================
# 🔧 Parámetros para modelo 20:
#    linear_tree: True ⭐
#    random_state: 617
#    learning_rate: 0.0389
#    num_leaves: 22
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [114]	train's l1: 10.1118	eval's l1: 10.5246
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_617.pkl
# ✅ Modelo 20 entrenado exitosamente!
#    MAE:  10.5246
#    RMSE: 32.4996
#    MAPE: 245.41%
#    Árboles: 114
#
# 🎉 ¡TODOS LOS 20 MODELOS ENTRENADOS EXITOSAMENTE!
# ⭐ Cada modelo usa árboles lineales híbridos con parámetros optimizados por Optuna
# 💾 Todos los modelos han sido guardados en: data/modelos_entrenados/v3norm/
#
# 📊 RESUMEN DE MÉTRICAS DE LOS 20 MODELOS:
# ============================================================
#     modelo  semilla        mae       rmse        mape  num_trees
# 0        1       42  10.229257  32.172061  159.757465        162
# 1        2      109  10.441462  32.228309  210.229408        126
# 2        3      113  10.274767  31.964304  181.262071        182
# 3        4      151  10.334924  32.344340  241.907907        150
# 4        5      167  10.537917  33.323070  201.896057        127
# 5        6      179  10.336981  32.368335  155.774848        249
# 6        7      193  10.643993  35.147693  262.185333        116
# 7        8      199  10.324622  33.227685  151.484061        196
# 8        9      211  10.798743  32.478122  350.235934        100
# 9       10      241  10.552776  33.194363  217.496603        137
# 10      11      263  10.405434  32.175724  191.984471        130
# 11      12      281  10.497493  32.189573  222.204824        122
# 12      13      307  10.221540  31.805205  150.670647        197
# 13      14      331  10.791895  32.015115  406.217791         95
# 14      15      367  10.278274  32.145363  156.011323        216
# 15      16      401  10.286506  31.902148  173.153710        162
# 16      17      439  10.205325  31.873990  205.328930        159
# 17      18      487  10.334474  32.345014  176.115855        160
# 18      19      563  10.344036  32.165299  153.158788        163
# 19      20      617  10.524564  32.499558  245.411737        114
#
# 📈 ESTADÍSTICAS DE LAS MÉTRICAS:
#    MAE  - Promedio: 10.4182, Std: 0.1774
#    RMSE - Promedio: 32.4783, Std: 0.7654
#    MAPE - Promedio: 210.62%, Std: 67.14%
#
# 🏆 MEJOR MODELO:
#    Modelo: 17
#    Semilla: 439
#    MAE: 10.2053
#    RMSE: 31.8740
#    MAPE: 205.33%
#    📁 Archivo: data/modelos_entrenados/v3norm/modelo_lgbm_seed_439.pkl
#
# 📁 LISTA DE MODELOS GUARDADOS:
#    Modelo  1 (seed  42): data/modelos_entrenados/v3norm/modelo_lgbm_seed_42.pkl
#    Modelo  2 (seed 109): data/modelos_entrenados/v3norm/modelo_lgbm_seed_109.pkl
#    Modelo  3 (seed 113): data/modelos_entrenados/v3norm/modelo_lgbm_seed_113.pkl
#    Modelo  4 (seed 151): data/modelos_entrenados/v3norm/modelo_lgbm_seed_151.pkl
#    Modelo  5 (seed 167): data/modelos_entrenados/v3norm/modelo_lgbm_seed_167.pkl
#    Modelo  6 (seed 179): data/modelos_entrenados/v3norm/modelo_lgbm_seed_179.pkl
#    Modelo  7 (seed 193): data/modelos_entrenados/v3norm/modelo_lgbm_seed_193.pkl
#    Modelo  8 (seed 199): data/modelos_entrenados/v3norm/modelo_lgbm_seed_199.pkl
#    Modelo  9 (seed 211): data/modelos_entrenados/v3norm/modelo_lgbm_seed_211.pkl
#    Modelo 10 (seed 241): data/modelos_entrenados/v3norm/modelo_lgbm_seed_241.pkl
#    Modelo 11 (seed 263): data/modelos_entrenados/v3norm/modelo_lgbm_seed_263.pkl
#    Modelo 12 (seed 281): data/modelos_entrenados/v3norm/modelo_lgbm_seed_281.pkl
#    Modelo 13 (seed 307): data/modelos_entrenados/v3norm/modelo_lgbm_seed_307.pkl
#    Modelo 14 (seed 331): data/modelos_entrenados/v3norm/modelo_lgbm_seed_331.pkl
#    Modelo 15 (seed 367): data/modelos_entrenados/v3norm/modelo_lgbm_seed_367.pkl
#    Modelo 16 (seed 401): data/modelos_entrenados/v3norm/modelo_lgbm_seed_401.pkl
#    Modelo 17 (seed 439): data/modelos_entrenados/v3norm/modelo_lgbm_seed_439.pkl
#    Modelo 18 (seed 487): data/modelos_entrenados/v3norm/modelo_lgbm_seed_487.pkl
#    Modelo 19 (seed 563): data/modelos_entrenados/v3norm/modelo_lgbm_seed_563.pkl
#    Modelo 20 (seed 617): data/modelos_entrenados/v3norm/modelo_lgbm_seed_617.pkl
# Early stopping, best iteration is:
# [114]	train's l1: 10.1118	eval's l1: 10.5246
# 💾 Modelo guardado en: data/modelos_entrenados/v3norm/modelo_lgbm_seed_617.pkl
# ✅ Modelo 20 entrenado exitosamente!
#    MAE:  10.5246
#    RMSE: 32.4996
#    MAPE: 245.41%
#    Árboles: 114
#
# 🎉 ¡TODOS LOS 20 MODELOS ENTRENADOS EXITOSAMENTE!
# ⭐ Cada modelo usa árboles lineales híbridos con parámetros optimizados por Optuna
# 💾 Todos los modelos han sido guardados en: data/modelos_entrenados/v3norm/
#
# 📊 RESUMEN DE MÉTRICAS DE LOS 20 MODELOS:
# ============================================================
#     modelo  semilla        mae       rmse        mape  num_trees
# 0        1       42  10.229257  32.172061  159.757465        162
# 1        2      109  10.441462  32.228309  210.229408        126
# 2        3      113  10.274767  31.964304  181.262071        182
# 3        4      151  10.334924  32.344340  241.907907        150
# 4        5      167  10.537917  33.323070  201.896057        127
# 5        6      179  10.336981  32.368335  155.774848        249
# 6        7      193  10.643993  35.147693  262.185333        116
# 7        8      199  10.324622  33.227685  151.484061        196
# 8        9      211  10.798743  32.478122  350.235934        100
# 9       10      241  10.552776  33.194363  217.496603        137
# 10      11      263  10.405434  32.175724  191.984471        130
# 11      12      281  10.497493  32.189573  222.204824        122
# 12      13      307  10.221540  31.805205  150.670647        197
# 13      14      331  10.791895  32.015115  406.217791         95
# 14      15      367  10.278274  32.145363  156.011323        216
# 15      16      401  10.286506  31.902148  173.153710        162
# 16      17      439  10.205325  31.873990  205.328930        159
# 17      18      487  10.334474  32.345014  176.115855        160
# 18      19      563  10.344036  32.165299  153.158788        163
# 19      20      617  10.524564  32.499558  245.411737        114
#
# 📈 ESTADÍSTICAS DE LAS MÉTRICAS:
#    MAE  - Promedio: 10.4182, Std: 0.1774
#    RMSE - Promedio: 32.4783, Std: 0.7654
#    MAPE - Promedio: 210.62%, Std: 67.14%
#
# 🏆 MEJOR MODELO:
#    Modelo: 17
#    Semilla: 439
#    MAE: 10.2053
#    RMSE: 31.8740
#    MAPE: 205.33%
#    📁 Archivo: data/modelos_entrenados/v3norm/modelo_lgbm_seed_439.pkl
#
# 📁 LISTA DE MODELOS GUARDADOS:
#    Modelo  1 (seed  42): data/modelos_entrenados/v3norm/modelo_lgbm_seed_42.pkl
#    Modelo  2 (seed 109): data/modelos_entrenados/v3norm/modelo_lgbm_seed_109.pkl
#    Modelo  3 (seed 113): data/modelos_entrenados/v3norm/modelo_lgbm_seed_113.pkl
#    Modelo  4 (seed 151): data/modelos_entrenados/v3norm/modelo_lgbm_seed_151.pkl
#    Modelo  5 (seed 167): data/modelos_entrenados/v3norm/modelo_lgbm_seed_167.pkl
#    Modelo  6 (seed 179): data/modelos_entrenados/v3norm/modelo_lgbm_seed_179.pkl
#    Modelo  7 (seed 193): data/modelos_entrenados/v3norm/modelo_lgbm_seed_193.pkl
#    Modelo  8 (seed 199): data/modelos_entrenados/v3norm/modelo_lgbm_seed_199.pkl
#    Modelo  9 (seed 211): data/modelos_entrenados/v3norm/modelo_lgbm_seed_211.pkl
#    Modelo 10 (seed 241): data/modelos_entrenados/v3norm/modelo_lgbm_seed_241.pkl
#    Modelo 11 (seed 263): data/modelos_entrenados/v3norm/modelo_lgbm_seed_263.pkl
#    Modelo 12 (seed 281): data/modelos_entrenados/v3norm/modelo_lgbm_seed_281.pkl
#    Modelo 13 (seed 307): data/modelos_entrenados/v3norm/modelo_lgbm_seed_307.pkl
#    Modelo 14 (seed 331): data/modelos_entrenados/v3norm/modelo_lgbm_seed_331.pkl
#    Modelo 15 (seed 367): data/modelos_entrenados/v3norm/modelo_lgbm_seed_367.pkl
#    Modelo 16 (seed 401): data/modelos_entrenados/v3norm/modelo_lgbm_seed_401.pkl
#    Modelo 17 (seed 439): data/modelos_entrenados/v3norm/modelo_lgbm_seed_439.pkl
#    Modelo 18 (seed 487): data/modelos_entrenados/v3norm/modelo_lgbm_seed_487.pkl
#    Modelo 19 (seed 563): data/modelos_entrenados/v3norm/modelo_lgbm_seed_563.pkl
#    Modelo 20 (seed 617): data/modelos_entrenados/v3norm/modelo_lgbm_seed_617.pkl

# %%
# # 📊 Análisis de importancia de features
# print("ANÁLISIS DE IMPORTANCIA DE FEATURES")
# print("="*50)

# # Obtener importancia de features
# feature_importance = model.feature_importance(importance_type='gain')
# feature_names = feature_columns

# # Crear DataFrame con importancias
# importance_df = pd.DataFrame({
#     'feature': feature_names,
#     'importance': feature_importance
# }).sort_values('importance', ascending=False)

# print("🔝 Top 10 features más importantes:")
# print(importance_df.head(10))

# # Visualizar importancia
# plt.figure(figsize=(10, 8))
# top_features = importance_df.head(15)
# plt.barh(range(len(top_features)), top_features['importance'])
# plt.yticks(range(len(top_features)), top_features['feature'])
# plt.xlabel('Importancia')
# plt.title('Top 15 Features - Importancia LightGBM')
# plt.gca().invert_yaxis()
# plt.tight_layout()
# plt.show()

# # Análisis de predicciones
# print(f"\n🎯 ANÁLISIS DE PREDICCIONES:")
# print(f"Predicciones mínimas: {y_pred_val.min():.2f}")
# print(f"Predicciones máximas: {y_pred_val.max():.2f}")
# print(f"Predicciones promedio: {y_pred_val.mean():.2f}")
# print(f"Valores reales promedio: {y_val.mean():.2f}")

# # Verificar predicciones negativas
# negative_preds = (y_pred_val < 0).sum()
# print(f"Predicciones negativas: {negative_preds} ({negative_preds/len(y_pred_val)*100:.1f}%)")

# %%
# 🔧 Funciones de utilidad para cargar modelos guardados
import pickle
import os

def cargar_modelo_por_semilla(semilla, modelos_dir='data/modelos_entrenados/v3norm'):
    """
    Cargar un modelo específico por su semilla
    
    Args:
        semilla (int): La semilla del modelo a cargar
        modelos_dir (str): Directorio donde están guardados los modelos
    
    Returns:
        lightgbm.Booster: El modelo cargado
    """
    model_path = f"{modelos_dir}/modelo_lgbm_seed_{semilla}.pkl"
    if os.path.exists(model_path):
        with open(model_path, 'rb') as f:
            modelo = pickle.load(f)
        print(f"✅ Modelo con semilla {semilla} cargado desde: {model_path}")
        return modelo
    else:
        raise FileNotFoundError(f"❌ No se encontró el modelo con semilla {semilla} en {model_path}")

def cargar_todos_los_modelos(semillas, modelos_dir='data/modelos_entrenados/v3norm'):
    """
    Cargar todos los modelos por sus semillas
    
    Args:
        semillas (list): Lista de semillas de los modelos a cargar
        modelos_dir (str): Directorio donde están guardados los modelos
    
    Returns:
        list: Lista de modelos cargados
    """
    modelos_cargados = []
    print(f"🔄 Cargando {len(semillas)} modelos desde {modelos_dir}/...")
    
    for i, semilla in enumerate(semillas, 1):
        try:
            modelo = cargar_modelo_por_semilla(semilla, modelos_dir)
            modelos_cargados.append(modelo)
            print(f"   {i:2d}/20 - Modelo semilla {semilla} ✅")
        except FileNotFoundError as e:
            print(f"   {i:2d}/20 - Error: {e}")
            return None
    
    print(f"🎉 Todos los {len(modelos_cargados)} modelos cargados exitosamente!")
    return modelos_cargados

def cargar_mejor_modelo(df_metricas, modelos_dir='data/modelos_entrenados/v3norm'):
    """
    Cargar el mejor modelo basado en las métricas
    
    Args:
        df_metricas (pd.DataFrame): DataFrame con las métricas de los modelos
        modelos_dir (str): Directorio donde están guardados los modelos
    
    Returns:
        tuple: (modelo, semilla, mae)
    """
    mejor_idx = df_metricas['mae'].idxmin()
    mejor_semilla = df_metricas.loc[mejor_idx, 'semilla']
    mejor_mae = df_metricas.loc[mejor_idx, 'mae']
    
    mejor_modelo = cargar_modelo_por_semilla(mejor_semilla, modelos_dir)
    print(f"🏆 Mejor modelo cargado: Semilla {mejor_semilla} (MAE: {mejor_mae:.4f})")
    
    return mejor_modelo, mejor_semilla, mejor_mae

def generar_predicciones_ensemble(modelos_cargados, X_pred, estrategia='promedio'):
    """
    Generar predicciones usando ensemble de modelos
    
    Args:
        modelos_cargados (list): Lista de modelos cargados
        X_pred (pd.DataFrame): Features para predecir
        estrategia (str): 'promedio', 'mediana', o 'weighted'
    
    Returns:
        np.array: Predicciones del ensemble
    """
    print(f"🔮 Generando predicciones con ensemble de {len(modelos_cargados)} modelos...")
    
    todas_predicciones = []
    for i, modelo in enumerate(modelos_cargados, 1):
        predicciones = modelo.predict(X_pred, num_iteration=modelo.best_iteration)
        predicciones = np.maximum(predicciones, 0)  # Eliminar predicciones negativas
        todas_predicciones.append(predicciones)
        print(f"   Predicciones modelo {i}/20 generadas ✅")
    
    todas_predicciones = np.array(todas_predicciones)
    
    if estrategia == 'promedio':
        resultado = np.mean(todas_predicciones, axis=0)
        print(f"📊 Ensemble promedio calculado")
    elif estrategia == 'mediana':
        resultado = np.median(todas_predicciones, axis=0)
        print(f"📊 Ensemble mediana calculado")
    else:
        # Por defecto usar promedio
        resultado = np.mean(todas_predicciones, axis=0)
        print(f"📊 Ensemble promedio calculado (estrategia por defecto)")
    
    return resultado, todas_predicciones

print("🔧 Funciones de utilidad para manejo de modelos definidas:")
print("   - cargar_modelo_por_semilla(semilla)")
print("   - cargar_todos_los_modelos(semillas)")
print("   - cargar_mejor_modelo(df_metricas)")
print("   - generar_predicciones_ensemble(modelos, X_pred, estrategia)")
print("✅ Ahora puedes cargar y usar los modelos individuales para ensembles")
# Out:
# 🔧 Funciones de utilidad para manejo de modelos definidas:
#    - cargar_modelo_por_semilla(semilla)
#    - cargar_todos_los_modelos(semillas)
#    - cargar_mejor_modelo(df_metricas)
#    - generar_predicciones_ensemble(modelos, X_pred, estrategia)
# ✅ Ahora puedes cargar y usar los modelos individuales para ensembles

# %%
# 🔮 Generar predicciones finales cargando los modelos guardados
print("GENERACIÓN DE PREDICCIONES FINALES CARGANDO MODELOS GUARDADOS")
print("="*70)

# Preparar datos para predicción (últimos datos disponibles de cada producto)
ultimo_periodo = data_combined.groupby('product_id')['fecha'].max().reset_index()
ultimo_periodo.columns = ['product_id', 'ultima_fecha']

# Unir con datos completos para obtener features más recientes
datos_prediccion = pd.merge(data_combined, ultimo_periodo, on='product_id')
datos_prediccion = datos_prediccion[datos_prediccion['fecha'] == datos_prediccion['ultima_fecha']].copy()

print(f"📊 Productos para predicción: {len(datos_prediccion)}")
print(f"📅 Período base para predicción: {datos_prediccion['periodo'].value_counts().head()}")

# Preparar features para predicción
X_pred = datos_prediccion[feature_columns].copy()
X_pred = X_pred.fillna(0)

print(f"🔍 Shape de datos de predicción: {X_pred.shape}")
print(f"🔍 Valores nulos en predicción: {X_pred.isnull().sum().sum()}")

# 💾 OPCIÓN 1: Cargar todos los modelos desde disco para ensemble completo
print(f"\n💾 CARGANDO MODELOS DESDE DISCO PARA ENSEMBLE...")
modelos_cargados = cargar_todos_los_modelos(semillas)

if modelos_cargados is not None:
    # Generar predicciones con ensemble
    predicciones_promedio, todas_las_predicciones = generar_predicciones_ensemble(
        modelos_cargados, X_pred, estrategia='promedio'
    )
    
    predicciones_mediana, _ = generar_predicciones_ensemble(
        modelos_cargados, X_pred, estrategia='mediana'
    )
    
    print(f"✅ Ensemble completo generado con {len(modelos_cargados)} modelos")
else:
    # Fallback: usar modelos en memoria si fallan las cargas
    print("⚠️ Fallback: Usando modelos en memoria...")
    todas_las_predicciones = []
    for i, modelo in enumerate(modelos, 1):
        print(f"   Generando predicciones con modelo {i} (semilla {semillas[i-1]})...")
        predicciones = modelo.predict(X_pred, num_iteration=modelo.best_iteration)
        predicciones = np.maximum(predicciones, 0)
        todas_las_predicciones.append(predicciones)
    
    todas_las_predicciones = np.array(todas_las_predicciones)
    predicciones_promedio = np.mean(todas_las_predicciones, axis=0)
    predicciones_mediana = np.median(todas_las_predicciones, axis=0)

# 🏆 OPCIÓN 2: Cargar solo el mejor modelo
print(f"\n🏆 CARGANDO MEJOR MODELO INDIVIDUAL...")
mejor_modelo_cargado, mejor_semilla_cargada, mejor_mae_cargado = cargar_mejor_modelo(df_metricas)
mejor_predicciones = mejor_modelo_cargado.predict(X_pred, num_iteration=mejor_modelo_cargado.best_iteration)
mejor_predicciones = np.maximum(mejor_predicciones, 0)

# Calcular estadísticas adicionales
predicciones_std = np.std(todas_las_predicciones, axis=0)
predicciones_min = np.min(todas_las_predicciones, axis=0)
predicciones_max = np.max(todas_las_predicciones, axis=0)

print(f"\n📊 ESTADÍSTICAS DE LAS PREDICCIONES:")
print(f"   Promedio de ensemble promedio: {predicciones_promedio.mean():.2f}")
print(f"   Promedio de ensemble mediana: {predicciones_mediana.mean():.2f}")
print(f"   Promedio de desviación estándar: {predicciones_std.mean():.2f}")
print(f"   Promedio del mejor modelo: {mejor_predicciones.mean():.2f}")

# Crear DataFrames de resultados
print(f"\n💾 Creando DataFrames de resultados...")

# DataFrame con todas las predicciones individuales
df_predicciones_individuales = pd.DataFrame({
    'product_id': datos_prediccion['product_id'].values
})

for i, semilla in enumerate(semillas):
    df_predicciones_individuales[f'pred_modelo_{i+1}_seed_{semilla}'] = todas_las_predicciones[i]

# DataFrame con estadísticas agregadas
resultado_lgbm_estadisticas = pd.DataFrame({
    'product_id': datos_prediccion['product_id'].values,
    'tn_promedio': predicciones_promedio,
    'tn_mediana': predicciones_mediana,
    'tn_std': predicciones_std,
    'tn_min': predicciones_min,
    'tn_max': predicciones_max,
    'tn_mejor_modelo': mejor_predicciones
})

# DataFrame principal (para compatibilidad) - usando promedio
resultado_lgbm = pd.DataFrame({
    'product_id': datos_prediccion['product_id'].values,
    'tn': predicciones_promedio
})

print(f"✅ Predicciones generadas para {len(resultado_lgbm)} productos")
print(f"\n📊 Estadísticas del ensemble promedio:")
print(f"  Promedio: {resultado_lgbm['tn'].mean():.2f}")
print(f"  Mediana:  {resultado_lgbm['tn'].median():.2f}")
print(f"  Mínimo:   {resultado_lgbm['tn'].min():.2f}")
print(f"  Máximo:   {resultado_lgbm['tn'].max():.2f}")
print(f"  Std:      {resultado_lgbm['tn'].std():.2f}")

print(f"\n📊 Estadísticas del mejor modelo:")
print(f"  Promedio: {mejor_predicciones.mean():.2f}")
print(f"  Mediana:  {np.median(mejor_predicciones):.2f}")
print(f"  Mínimo:   {mejor_predicciones.min():.2f}")
print(f"  Máximo:   {mejor_predicciones.max():.2f}")
print(f"  Std:      {mejor_predicciones.std():.2f}")

print(f"\n💾 DEMOSTRACIÓN DE FUNCIONALIDAD:")
print(f"✅ Modelos guardados individualmente por semilla")
print(f"✅ Ensemble promedio generado cargando modelos desde disco")
print(f"✅ Mejor modelo individual cargado por semilla {mejor_semilla_cargada}")
print(f"✅ Funciones disponibles para cargar cualquier modelo específico")

print(f"\nPrimeras 10 predicciones (ensemble promedio):")
print(resultado_lgbm.head(10))
# Out:
# GENERACIÓN DE PREDICCIONES FINALES CARGANDO MODELOS GUARDADOS
# ======================================================================
# 📊 Productos para predicción: 780
# 📅 Período base para predicción: periodo
# 201912    780
# Name: count, dtype: int64
# 🔍 Shape de datos de predicción: (780, 62)
# 🔍 Valores nulos en predicción: 0
#
# 💾 CARGANDO MODELOS DESDE DISCO PARA ENSEMBLE...
# 🔄 Cargando 20 modelos desde data/modelos_entrenados/v3norm/...
# ✅ Modelo con semilla 42 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_42.pkl
#     1/20 - Modelo semilla 42 ✅
# ✅ Modelo con semilla 109 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_109.pkl
#     2/20 - Modelo semilla 109 ✅
# ✅ Modelo con semilla 113 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_113.pkl
#     3/20 - Modelo semilla 113 ✅
# ✅ Modelo con semilla 151 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_151.pkl
#     4/20 - Modelo semilla 151 ✅
# ✅ Modelo con semilla 167 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_167.pkl
#     5/20 - Modelo semilla 167 ✅
# ✅ Modelo con semilla 179 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_179.pkl
#     6/20 - Modelo semilla 179 ✅
# ✅ Modelo con semilla 193 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_193.pkl
#     7/20 - Modelo semilla 193 ✅
# ✅ Modelo con semilla 199 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_199.pkl
#     8/20 - Modelo semilla 199 ✅
# ✅ Modelo con semilla 211 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_211.pkl
#     9/20 - Modelo semilla 211 ✅
# ✅ Modelo con semilla 241 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_241.pkl
#    10/20 - Modelo semilla 241 ✅
# ✅ Modelo con semilla 263 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_263.pkl
#    11/20 - Modelo semilla 263 ✅
# ✅ Modelo con semilla 281 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_281.pkl
#    12/20 - Modelo semilla 281 ✅
# ✅ Modelo con semilla 307 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_307.pkl
#    13/20 - Modelo semilla 307 ✅
# ✅ Modelo con semilla 331 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_331.pkl
#    14/20 - Modelo semilla 331 ✅
# ✅ Modelo con semilla 367 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_367.pkl
#    15/20 - Modelo semilla 367 ✅
# ✅ Modelo con semilla 401 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_401.pkl
#    16/20 - Modelo semilla 401 ✅
# ✅ Modelo con semilla 439 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_439.pkl
#    17/20 - Modelo semilla 439 ✅
# ✅ Modelo con semilla 487 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_487.pkl
#    18/20 - Modelo semilla 487 ✅
# ✅ Modelo con semilla 563 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_563.pkl
#    19/20 - Modelo semilla 563 ✅
# ✅ Modelo con semilla 617 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_617.pkl
#    20/20 - Modelo semilla 617 ✅
# 🎉 Todos los 20 modelos cargados exitosamente!
# 🔮 Generando predicciones con ensemble de 20 modelos...
#    Predicciones modelo 1/20 generadas ✅
#    Predicciones modelo 2/20 generadas ✅
#    Predicciones modelo 3/20 generadas ✅
#    Predicciones modelo 4/20 generadas ✅
#    Predicciones modelo 5/20 generadas ✅
#    Predicciones modelo 6/20 generadas ✅
#    Predicciones modelo 7/20 generadas ✅
#    Predicciones modelo 8/20 generadas ✅
#    Predicciones modelo 9/20 generadas ✅
#    Predicciones modelo 10/20 generadas ✅
#    Predicciones modelo 11/20 generadas ✅
#    Predicciones modelo 12/20 generadas ✅
#    Predicciones modelo 13/20 generadas ✅
#    Predicciones modelo 14/20 generadas ✅
#    Predicciones modelo 15/20 generadas ✅
#    Predicciones modelo 16/20 generadas ✅
#    Predicciones modelo 17/20 generadas ✅
#    Predicciones modelo 18/20 generadas ✅
#    Predicciones modelo 19/20 generadas ✅
#    Predicciones modelo 20/20 generadas ✅
# 📊 Ensemble promedio calculado
# 🔮 Generando predicciones con ensemble de 20 modelos...
#    Predicciones modelo 1/20 generadas ✅
#    Predicciones modelo 2/20 generadas ✅
#    Predicciones modelo 3/20 generadas ✅
#    Predicciones modelo 4/20 generadas ✅
#    Predicciones modelo 5/20 generadas ✅
#    Predicciones modelo 6/20 generadas ✅
#    Predicciones modelo 7/20 generadas ✅
#    Predicciones modelo 8/20 generadas ✅
#    Predicciones modelo 9/20 generadas ✅
#    Predicciones modelo 10/20 generadas ✅
#    Predicciones modelo 11/20 generadas ✅
#    Predicciones modelo 12/20 generadas ✅
#    Predicciones modelo 13/20 generadas ✅
#    Predicciones modelo 14/20 generadas ✅
#    Predicciones modelo 15/20 generadas ✅
#    Predicciones modelo 16/20 generadas ✅
#    Predicciones modelo 17/20 generadas ✅
#    Predicciones modelo 18/20 generadas ✅
#    Predicciones modelo 19/20 generadas ✅
#    Predicciones modelo 20/20 generadas ✅
# 📊 Ensemble mediana calculado
# ✅ Ensemble completo generado con 20 modelos
#
# 🏆 CARGANDO MEJOR MODELO INDIVIDUAL...
# ✅ Modelo con semilla 439 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_439.pkl
# 🏆 Mejor modelo cargado: Semilla 439 (MAE: 10.2053)
#
# 📊 ESTADÍSTICAS DE LAS PREDICCIONES:
#    Promedio de ensemble promedio: 2713.68
#    Promedio de ensemble mediana: 2709.10
#    Promedio de desviación estándar: 273.17
#    Promedio del mejor modelo: 2887.07
#
# 💾 Creando DataFrames de resultados...
# ✅ Predicciones generadas para 780 productos
#
# 📊 Estadísticas del ensemble promedio:
#   Promedio: 2713.68
#   Mediana:  998.73
#   Mínimo:   53.74
#   Máximo:   107833.22
#   Std:      7003.10
#
# 📊 Estadísticas del mejor modelo:
#   Promedio: 2887.07
#   Mediana:  1026.95
#   Mínimo:   0.00
#   Máximo:   109743.81
#   Std:      7369.70
#
# 💾 DEMOSTRACIÓN DE FUNCIONALIDAD:
# ✅ Modelos guardados individualmente por semilla
# ✅ Ensemble promedio generado cargando modelos desde disco
# ✅ Mejor modelo individual cargado por semilla 439
# ✅ Funciones disponibles para cargar cualquier modelo específico
#
# Primeras 10 predicciones (ensemble promedio):
#    product_id             tn
# 0       20001  107833.224591
# 1       20002   79944.867104
# 2       20003   60181.653416
# 3       20004   46369.992206
# 4       20005   45727.020590
# 5       20006   34838.559320
# 6       20007   28739.917468
# 7       20008   26156.130834
# 8       20009   30519.663612
# 9       20010   24042.369574
#    Predicciones modelo 6/20 generadas ✅
#    Predicciones modelo 7/20 generadas ✅
#    Predicciones modelo 8/20 generadas ✅
#    Predicciones modelo 9/20 generadas ✅
#    Predicciones modelo 10/20 generadas ✅
#    Predicciones modelo 11/20 generadas ✅
#    Predicciones modelo 12/20 generadas ✅
#    Predicciones modelo 13/20 generadas ✅
#    Predicciones modelo 14/20 generadas ✅
#    Predicciones modelo 15/20 generadas ✅
#    Predicciones modelo 16/20 generadas ✅
#    Predicciones modelo 17/20 generadas ✅
#    Predicciones modelo 18/20 generadas ✅
#    Predicciones modelo 19/20 generadas ✅
#    Predicciones modelo 20/20 generadas ✅
# 📊 Ensemble promedio calculado
# 🔮 Generando predicciones con ensemble de 20 modelos...
#    Predicciones modelo 1/20 generadas ✅
#    Predicciones modelo 2/20 generadas ✅
#    Predicciones modelo 3/20 generadas ✅
#    Predicciones modelo 4/20 generadas ✅
#    Predicciones modelo 5/20 generadas ✅
#    Predicciones modelo 6/20 generadas ✅
#    Predicciones modelo 7/20 generadas ✅
#    Predicciones modelo 8/20 generadas ✅
#    Predicciones modelo 9/20 generadas ✅
#    Predicciones modelo 10/20 generadas ✅
#    Predicciones modelo 11/20 generadas ✅
#    Predicciones modelo 12/20 generadas ✅
#    Predicciones modelo 13/20 generadas ✅
#    Predicciones modelo 14/20 generadas ✅
#    Predicciones modelo 15/20 generadas ✅
#    Predicciones modelo 16/20 generadas ✅
#    Predicciones modelo 17/20 generadas ✅
#    Predicciones modelo 18/20 generadas ✅
#    Predicciones modelo 19/20 generadas ✅
#    Predicciones modelo 20/20 generadas ✅
# 📊 Ensemble mediana calculado
# ✅ Ensemble completo generado con 20 modelos
#
# 🏆 CARGANDO MEJOR MODELO INDIVIDUAL...
# ✅ Modelo con semilla 439 cargado desde: data/modelos_entrenados/v3norm/modelo_lgbm_seed_439.pkl
# 🏆 Mejor modelo cargado: Semilla 439 (MAE: 10.2053)
#
# 📊 ESTADÍSTICAS DE LAS PREDICCIONES:
#    Promedio de ensemble promedio: 2713.68
#    Promedio de ensemble mediana: 2709.10
#    Promedio de desviación estándar: 273.17
#    Promedio del mejor modelo: 2887.07
#
# 💾 Creando DataFrames de resultados...
# ✅ Predicciones generadas para 780 productos
#
# 📊 Estadísticas del ensemble promedio:
#   Promedio: 2713.68
#   Mediana:  998.73
#   Mínimo:   53.74
#   Máximo:   107833.22
#   Std:      7003.10
#
# 📊 Estadísticas del mejor modelo:
#   Promedio: 2887.07
#   Mediana:  1026.95
#   Mínimo:   0.00
#   Máximo:   109743.81
#   Std:      7369.70
#
# 💾 DEMOSTRACIÓN DE FUNCIONALIDAD:
# ✅ Modelos guardados individualmente por semilla
# ✅ Ensemble promedio generado cargando modelos desde disco
# ✅ Mejor modelo individual cargado por semilla 439
# ✅ Funciones disponibles para cargar cualquier modelo específico
#
# Primeras 10 predicciones (ensemble promedio):
#    product_id             tn
# 0       20001  107833.224591
# 1       20002   79944.867104
# 2       20003   60181.653416
# 3       20004   46369.992206
# 4       20005   45727.020590
# 5       20006   34838.559320
# 6       20007   28739.917468
# 7       20008   26156.130834
# 8       20009   30519.663612
# 9       20010   24042.369574

# %%
# 🔧 APLICAR NORMALIZACIÓN A DATOS DE PREDICCIÓN
print("\n🔧 APLICANDO NORMALIZACIÓN A DATOS DE PREDICCIÓN")
print("="*60)

# Cargar el scaler de toneladas guardado
import pickle
scaler_path = 'data/modelos_entrenados/v3norm/scaler_toneladas_sem_2.pkl'

try:
    with open(scaler_path, 'rb') as f:
        scaler_tn_cargado = pickle.load(f)
    print(f"✅ Scaler de toneladas cargado desde: {scaler_path}")
    
    # Identificar las mismas características de toneladas que se normalizaron en entrenamiento
    tn_features_pred = []
    tn_features_pred.extend([f for f in feature_columns if f.startswith('tn_lag_')])
    tn_features_pred.extend([f for f in feature_columns if f.startswith('tn_rolling_')])
    tn_features_pred.extend([f for f in feature_columns if f.startswith('stock_tn_')])
    tn_features_pred.extend([f for f in feature_columns if f.startswith('total_request_tn')])
    
    # Verificar que las características existen en los datos de predicción
    tn_features_pred_disponibles = [f for f in tn_features_pred if f in X_pred.columns]
    
    print(f"📊 Características de toneladas a normalizar en predicción: {len(tn_features_pred_disponibles)}")
    
    if tn_features_pred_disponibles:
        # Aplicar la misma normalización a los datos de predicción
        X_pred_normalized = X_pred.copy()
        X_pred_normalized[tn_features_pred_disponibles] = scaler_tn_cargado.transform(X_pred[tn_features_pred_disponibles])
        
        # Actualizar X_pred con los datos normalizados
        X_pred = X_pred_normalized
        
        print(f"✅ Normalización aplicada a datos de predicción")
        print(f"   📊 {len(tn_features_pred_disponibles)} características de toneladas normalizadas")
        
        # Mostrar estadísticas después de la normalización (primeras 3 características)
        muestra_features_pred = tn_features_pred_disponibles[:3]
        for feat in muestra_features_pred:
            print(f"   📈 {feat} - Media: {X_pred[feat].mean():.2f}, Std: {X_pred[feat].std():.2f}")
            
    else:
        print("⚠️ No se encontraron características de toneladas en datos de predicción")
        
except FileNotFoundError:
    print(f"❌ No se pudo cargar el scaler desde: {scaler_path}")
    print("⚠️ Continuando sin normalización en datos de predicción")
except Exception as e:
    print(f"❌ Error al aplicar normalización: {str(e)}")
    print("⚠️ Continuando sin normalización en datos de predicción")

print(f"🔍 Shape final de datos de predicción: {X_pred.shape}")
print(f"✅ Datos de predicción preparados y normalizados")
# Out:
# 🔧 APLICANDO NORMALIZACIÓN A DATOS DE PREDICCIÓN
# ============================================================
# ✅ Scaler de toneladas cargado desde: data/modelos_entrenados/v3norm/scaler_toneladas_sem_2.pkl
# 📊 Características de toneladas a normalizar en predicción: 52
# ✅ Normalización aplicada a datos de predicción
#    📊 52 características de toneladas normalizadas
#    📈 tn_lag_1 - Media: -0.08, Std: 0.89
#    📈 tn_lag_2 - Media: -0.04, Std: 1.05
#    📈 tn_lag_3 - Media: -0.05, Std: 0.92
# 🔍 Shape final de datos de predicción: (780, 62)
# ✅ Datos de predicción preparados y normalizados

# %%
# 💾 Guardar todos los archivos de predicciones y información de modelos
import os
os.makedirs('data', exist_ok=True)

print("GUARDANDO ARCHIVOS DE PREDICCIONES Y MODELOS")
print("="*60)

# 1. Guardar predicciones promedio (archivo principal)
archivo_promedio = 'data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_promedio.csv'
resultado_lgbm.to_csv(archivo_promedio, index=False)
print(f"✅ Predicciones promedio guardadas en: {archivo_promedio}")

# 2. Guardar predicciones del mejor modelo
archivo_mejor = 'data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_mejor.csv'
resultado_mejor = pd.DataFrame({
    'product_id': datos_prediccion['product_id'].values,
    'tn': mejor_predicciones
})
resultado_mejor.to_csv(archivo_mejor, index=False)
print(f"✅ Predicciones del mejor modelo guardadas en: {archivo_mejor}")

# 3. Guardar estadísticas completas
archivo_estadisticas = 'data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_estadisticas.csv'
resultado_lgbm_estadisticas.to_csv(archivo_estadisticas, index=False)
print(f"✅ Estadísticas completas guardadas en: {archivo_estadisticas}")

# 4. Guardar todas las predicciones individuales
archivo_individuales = 'data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_individuales.csv'
df_predicciones_individuales.to_csv(archivo_individuales, index=False)
print(f"✅ Predicciones individuales guardadas en: {archivo_individuales}")

# 5. Guardar métricas de los modelos (incluyendo rutas de archivos)
archivo_metricas = 'data/metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_norm.csv'
df_metricas.to_csv(archivo_metricas, index=False)
print(f"✅ Métricas de los modelos guardadas en: {archivo_metricas}")

# 6. Guardar inventario de modelos guardados
archivo_inventario = 'data/inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_norm.csv'
inventario_modelos = df_metricas[['modelo', 'semilla', 'mae', 'rmse', 'mape', 'model_file']].copy()
inventario_modelos['modelo_existe'] = inventario_modelos['model_file'].apply(os.path.exists)
inventario_modelos.to_csv(archivo_inventario, index=False)
print(f"✅ Inventario de modelos guardado en: {archivo_inventario}")

print(f"\n📁 RESUMEN DE ARCHIVOS GUARDADOS:")
print(f"   1. {archivo_promedio} - Predicciones promedio de los 20 modelos")
print(f"   2. {archivo_mejor} - Predicciones del mejor modelo (semilla {mejor_semilla})")
print(f"   3. {archivo_estadisticas} - Estadísticas completas (promedio, mediana, std, min, max)")
print(f"   4. {archivo_individuales} - Predicciones de cada uno de los 20 modelos")
print(f"   5. {archivo_metricas} - Métricas de rendimiento de cada modelo")
print(f"   6. {archivo_inventario} - Inventario de modelos guardados con ubicaciones")

print(f"\n🤖 MODELOS INDIVIDUALES GUARDADOS:")
print(f"   Directorio: {modelos_dir}/")
for i, row in df_metricas.iterrows():
    existe = "✅" if os.path.exists(row['model_file']) else "❌"
    print(f"   {existe} modelo_lgbm_seed_{row['semilla']}.pkl (MAE: {row['mae']:.4f})")

print(f"\n🎯 INSTRUCCIONES DE USO:")
print(f"   📖 Para cargar un modelo específico:")
print(f"      modelo = cargar_modelo_por_semilla(semilla)")
print(f"   📖 Para cargar el mejor modelo:")
print(f"      mejor_modelo, semilla, mae = cargar_mejor_modelo(df_metricas)")
print(f"   📖 Para generar ensemble personalizado:")
print(f"      semillas_subset = [42, 113, 241]  # Ejemplo")
print(f"      modelos_subset = cargar_todos_los_modelos(semillas_subset)")
print(f"      predicciones = generar_predicciones_ensemble(modelos_subset, X_pred)")

print(f"\n✅ SISTEMA DE MODELOS PERSISTENTES IMPLEMENTADO EXITOSAMENTE!")
print(f"🔄 Los modelos están disponibles para reutilización y experimentos futuros")
# Out:
# GUARDANDO ARCHIVOS DE PREDICCIONES Y MODELOS
# ============================================================
# ✅ Predicciones promedio guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_promedio.csv
# ✅ Predicciones del mejor modelo guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_mejor.csv
# ✅ Estadísticas completas guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_estadisticas.csv
# ✅ Predicciones individuales guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_individuales.csv
# ✅ Métricas de los modelos guardadas en: data/metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_norm.csv
# ✅ Inventario de modelos guardado en: data/inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_norm.csv
#
# 📁 RESUMEN DE ARCHIVOS GUARDADOS:
#    1. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_promedio.csv - Predicciones promedio de los 20 modelos
#    2. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_mejor.csv - Predicciones del mejor modelo (semilla 439)
#    3. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_estadisticas.csv - Estadísticas completas (promedio, mediana, std, min, max)
#    4. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_individuales.csv - Predicciones de cada uno de los 20 modelos
#    5. data/metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_norm.csv - Métricas de rendimiento de cada modelo
#    6. data/inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_norm.csv - Inventario de modelos guardados con ubicaciones
#
# 🤖 MODELOS INDIVIDUALES GUARDADOS:
#    Directorio: data/modelos_entrenados/v3norm/
#    ✅ modelo_lgbm_seed_42.pkl (MAE: 10.2293)
#    ✅ modelo_lgbm_seed_109.pkl (MAE: 10.4415)
#    ✅ modelo_lgbm_seed_113.pkl (MAE: 10.2748)
#    ✅ modelo_lgbm_seed_151.pkl (MAE: 10.3349)
#    ✅ modelo_lgbm_seed_167.pkl (MAE: 10.5379)
#    ✅ modelo_lgbm_seed_179.pkl (MAE: 10.3370)
#    ✅ modelo_lgbm_seed_193.pkl (MAE: 10.6440)
#    ✅ modelo_lgbm_seed_199.pkl (MAE: 10.3246)
#    ✅ modelo_lgbm_seed_211.pkl (MAE: 10.7987)
#    ✅ modelo_lgbm_seed_241.pkl (MAE: 10.5528)
#    ✅ modelo_lgbm_seed_263.pkl (MAE: 10.4054)
#    ✅ modelo_lgbm_seed_281.pkl (MAE: 10.4975)
#    ✅ modelo_lgbm_seed_307.pkl (MAE: 10.2215)
#    ✅ modelo_lgbm_seed_331.pkl (MAE: 10.7919)
#    ✅ modelo_lgbm_seed_367.pkl (MAE: 10.2783)
#    ✅ modelo_lgbm_seed_401.pkl (MAE: 10.2865)
#    ✅ modelo_lgbm_seed_439.pkl (MAE: 10.2053)
#    ✅ modelo_lgbm_seed_487.pkl (MAE: 10.3345)
#    ✅ modelo_lgbm_seed_563.pkl (MAE: 10.3440)
#    ✅ modelo_lgbm_seed_617.pkl (MAE: 10.5246)
#
# 🎯 INSTRUCCIONES DE USO:
#    📖 Para cargar un modelo específico:
#       modelo = cargar_modelo_por_semilla(semilla)
#    📖 Para cargar el mejor modelo:
#       mejor_modelo, semilla, mae = cargar_mejor_modelo(df_metricas)
#    📖 Para generar ensemble personalizado:
#       semillas_subset = [42, 113, 241]  # Ejemplo
#       modelos_subset = cargar_todos_los_modelos(semillas_subset)
#       predicciones = generar_predicciones_ensemble(modelos_subset, X_pred)
#
# ✅ SISTEMA DE MODELOS PERSISTENTES IMPLEMENTADO EXITOSAMENTE!
# 🔄 Los modelos están disponibles para reutilización y experimentos futuros

# %%
print(f"🎉 ¡SISTEMA DE ENSEMBLE CON MODELOS PERSISTENTES COMPLETADO!")
print(f"⭐ Cada modelo usa árboles lineales híbridos con optimización Optuna")
print(f"🔢 20 modelos entrenados con semillas diferentes para mayor robustez")
print(f"💾 Todos los modelos guardados individualmente para reutilización")
print(f"🏆 Mejor modelo individual: Semilla {mejor_semilla} (MAE: {df_metricas.loc[mejor_modelo_idx, 'mae']:.4f})")
print(f"📊 MAE promedio del conjunto: {df_metricas['mae'].mean():.4f} (±{df_metricas['mae'].std():.4f})")
print(f"📁 6 archivos de predicciones + 20 modelos individuales guardados")
print(f"🔧 Funciones de utilidad disponibles para cargar modelos por semilla")
print(f"🎲 Semillas utilizadas: {semillas}")
print(f"🏆 Tecnología: LINEAR_TREE + OPTUNA + 36 LAGS + ENSEMBLE PERSISTENTE DE 20 MODELOS")
print(f"")
print(f"🎯 NUEVAS CAPACIDADES DISPONIBLES:")
print(f"   🔄 Cargar cualquier modelo por su semilla")
print(f"   🏆 Cargar automáticamente el mejor modelo")
print(f"   📊 Generar ensembles personalizados con subconjuntos de modelos")
print(f"   💾 Reutilizar modelos sin re-entrenar")
print(f"   🔬 Experimentar con diferentes estrategias de ensemble")
# Out:
# 🎉 ¡SISTEMA DE ENSEMBLE CON MODELOS PERSISTENTES COMPLETADO!
# ⭐ Cada modelo usa árboles lineales híbridos con optimización Optuna
# 🔢 20 modelos entrenados con semillas diferentes para mayor robustez
# 💾 Todos los modelos guardados individualmente para reutilización
# 🏆 Mejor modelo individual: Semilla 439 (MAE: 10.2053)
# 📊 MAE promedio del conjunto: 10.4182 (±0.1774)
# 📁 6 archivos de predicciones + 20 modelos individuales guardados
# 🔧 Funciones de utilidad disponibles para cargar modelos por semilla
# 🎲 Semillas utilizadas: [42, 109, 113, 151, 167, 179, 193, 199, 211, 241, 263, 281, 307, 331, 367, 401, 439, 487, 563, 617]
# 🏆 Tecnología: LINEAR_TREE + OPTUNA + 36 LAGS + ENSEMBLE PERSISTENTE DE 20 MODELOS
#
# 🎯 NUEVAS CAPACIDADES DISPONIBLES:
#    🔄 Cargar cualquier modelo por su semilla
#    🏆 Cargar automáticamente el mejor modelo
#    📊 Generar ensembles personalizados con subconjuntos de modelos
#    💾 Reutilizar modelos sin re-entrenar
#    🔬 Experimentar con diferentes estrategias de ensemble

# %%
# Guardar información de reproductibilidad del conjunto de modelos con persistencia
import json
os.makedirs('data', exist_ok=True)

# Crear información detallada de reproductibilidad
reproducibility_info_ensemble = {
    'experimento': 'LGBM_v3_FE_02_v3_linear_tree_opt_03_36lags_semillerio_persistente',
    'descripcion': 'Conjunto de 20 modelos LightGBM con linear_tree, parámetros optimizados por Optuna y persistencia individual',
    'numero_modelos': len(semillas),
    'semillas_utilizadas': semillas,
    'semilla_optuna': 42,
    'modelos_guardados': {
        'directorio': modelos_dir,
        'formato': 'pickle (.pkl)',
        'patron_nombre': 'modelo_lgbm_seed_{semilla}.pkl',
        'total_archivos': len(semillas)
    },
    'mejor_modelo': {
        'indice': int(mejor_modelo_idx + 1),
        'semilla': int(mejor_semilla),
        'mae': float(df_metricas.loc[mejor_modelo_idx, 'mae']),
        'rmse': float(df_metricas.loc[mejor_modelo_idx, 'rmse']),
        'mape': float(df_metricas.loc[mejor_modelo_idx, 'mape']),
        'archivo': mejor_model_file
    },
    'estadisticas_conjunto': {
        'mae_promedio': float(df_metricas['mae'].mean()),
        'mae_std': float(df_metricas['mae'].std()),
        'rmse_promedio': float(df_metricas['rmse'].mean()),
        'rmse_std': float(df_metricas['rmse'].std()),
        'mape_promedio': float(df_metricas['mape'].mean()),
        'mape_std': float(df_metricas['mape'].std())
    },
    'parametros_optimizados': {
        'linear_tree': lgb_params_base['linear_tree'],
        'lambda_l1': lgb_params_base['lambda_l1'],
        'lambda_l2': lgb_params_base['lambda_l2'],
        'num_leaves': lgb_params_base['num_leaves'],
        'feature_fraction': lgb_params_base['feature_fraction'],
        'learning_rate': lgb_params_base['learning_rate'],
        'bagging_fraction': lgb_params_base['bagging_fraction'],
        'bagging_freq': lgb_params_base['bagging_freq'],
        'min_child_samples': lgb_params_base['min_child_samples'],
        'max_bin': lgb_params_base['max_bin']
    },
    'configuracion_entrenamiento': {
        'num_boost_round': 2000,
        'early_stopping_rounds': 150,
        'validation_split': 0.8
    },
    'features_utilizadas': len(feature_columns),
    'lags_toneladas': 36,
    'funciones_utilidad': [
        'cargar_modelo_por_semilla(semilla)',
        'cargar_todos_los_modelos(semillas)',
        'cargar_mejor_modelo(df_metricas)',
        'generar_predicciones_ensemble(modelos, X_pred, estrategia)'
    ],
    'archivos_generados': [
        'pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_promedio.csv',
        'pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_mejor.csv',
        'pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_estadisticas.csv',
        'pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_norm_individuales.csv',
        'metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_norm.csv',
        'inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_norm.csv'
    ],
    'modelos_individuales': [f"modelo_lgbm_seed_{seed}.pkl" for seed in semillas]
}

# Guardar archivo de reproductibilidad
archivo_reproducibilidad = 'data/reproducibility_info_lgbm_v3_FE_02_v3_linear_tree_opt_36lags_sem_1_norm_ensemble_persistente.json'
with open(archivo_reproducibilidad, 'w') as f:
    json.dump(reproducibility_info_ensemble, f, indent=2)

print("🎲 INFORMACIÓN DE REPRODUCTIBILIDAD DEL CONJUNTO PERSISTENTE:")
print(f"   Experimento: {reproducibility_info_ensemble['experimento']}")
print(f"   Número de modelos: {len(semillas)}")
print(f"   Semillas utilizadas: {semillas}")
print(f"   Semilla para Optuna: 42")
print(f"   Mejor modelo: #{mejor_modelo_idx + 1} (semilla {mejor_semilla})")
print(f"   MAE promedio: {df_metricas['mae'].mean():.4f} (±{df_metricas['mae'].std():.4f})")
print(f"   Modelos guardados en: {modelos_dir}/")

print(f"\n✅ Información de reproductibilidad guardada en:")
print(f"   {archivo_reproducibilidad}")

print(f"\n📊 RESUMEN FINAL DEL EXPERIMENTO CON PERSISTENCIA:")
print(f"   🔬 Estrategia: Conjunto de {len(semillas)} modelos LightGBM persistentes")
print(f"   ⭐ Tecnología: LINEAR_TREE + OPTUNA + 36 LAGS + PERSISTENCIA")
print(f"   🎯 Objetivo: Máxima robustez, precisión y reutilización")
print(f"   📁 Archivos: 6 archivos CSV + 20 modelos .pkl + 1 JSON reproductibilidad")
print(f"   🏆 Resultado: Sistema completo de ensemble reutilizable")
print(f"   🔄 Capacidad: Cargar y usar cualquier modelo individual por semilla")
print(f"   🎛️ Flexibilidad: Crear ensembles personalizados sin re-entrenar")

print(f"\n🎉 ¡SISTEMA DE MACHINE LEARNING PERSISTENTE COMPLETADO EXITOSAMENTE!")
print(f"💪 Máxima robustez, flexibilidad y capacidad de experimentación")
# Out:
# 🎲 INFORMACIÓN DE REPRODUCTIBILIDAD DEL CONJUNTO PERSISTENTE:
#    Experimento: LGBM_v3_FE_02_v3_linear_tree_opt_03_36lags_semillerio_persistente
#    Número de modelos: 20
#    Semillas utilizadas: [42, 109, 113, 151, 167, 179, 193, 199, 211, 241, 263, 281, 307, 331, 367, 401, 439, 487, 563, 617]
#    Semilla para Optuna: 42
#    Mejor modelo: #17 (semilla 439)
#    MAE promedio: 10.4182 (±0.1774)
#    Modelos guardados en: data/modelos_entrenados/v3norm/
#
# ✅ Información de reproductibilidad guardada en:
#    data/reproducibility_info_lgbm_v3_FE_02_v3_linear_tree_opt_36lags_sem_1_norm_ensemble_persistente.json
#
# 📊 RESUMEN FINAL DEL EXPERIMENTO CON PERSISTENCIA:
#    🔬 Estrategia: Conjunto de 20 modelos LightGBM persistentes
#    ⭐ Tecnología: LINEAR_TREE + OPTUNA + 36 LAGS + PERSISTENCIA
#    🎯 Objetivo: Máxima robustez, precisión y reutilización
#    📁 Archivos: 6 archivos CSV + 20 modelos .pkl + 1 JSON reproductibilidad
#    🏆 Resultado: Sistema completo de ensemble reutilizable
#    🔄 Capacidad: Cargar y usar cualquier modelo individual por semilla
#    🎛️ Flexibilidad: Crear ensembles personalizados sin re-entrenar
#
# 🎉 ¡SISTEMA DE MACHINE LEARNING PERSISTENTE COMPLETADO EXITOSAMENTE!
# 💪 Máxima robustez, flexibilidad y capacidad de experimentación
