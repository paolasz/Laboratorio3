# %% [markdown]
# LGBM 01 con linear_tree = true
#
# lags 1 al 36 (3 años)
#
# cantidad de clientes que compraron un producto
#
# meses de vida

# %%
# 📦 Importar librerías necesarias
import pandas as pd
import numpy as np
import random

# 🎲 Configurar semillas para reproductibilidad
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

print("✅ Librerías importadas correctamente")
print(f"🎲 Semilla configurada: {SEED} para reproductibilidad total")
# Out:
# ✅ Librerías importadas correctamente
# 🎲 Semilla configurada: 42 para reproductibilidad total

# %%
# 📄 Cargar todos los datasets
print("Cargando datasets...")

# Load the sales data (tab-delimited)
sales = pd.read_csv("datasets/sell-in.txt", sep="\t", dtype={"periodo": str})
print(f"✅ Sales data cargado: {sales.shape}")

# Load the stocks data (tab-delimited) 
stocks = pd.read_csv("datasets/tb_stocks.txt", sep="\t", dtype={"periodo": str})
print(f"✅ Stocks data cargado: {stocks.shape}")

# Load the product information data (tab-delimited)
product_info = pd.read_csv("datasets/tb_productos.txt", sep="\t")
print(f"✅ Product info cargado: {product_info.shape}")

# Carga productos a predecir
product_predict = pd.read_csv("datasets/product_id_apredecir201912.txt", sep="\t", header=0)
print(f"✅ Productos a predecir cargados: {product_predict.shape}")

print("\n🎯 Todos los datasets cargados exitosamente")
# Out:
# Cargando datasets...
# ✅ Sales data cargado: (2945818, 7)
# ✅ Stocks data cargado: (13691, 3)
# ✅ Product info cargado: (1251, 7)
# ✅ Productos a predecir cargados: (780, 1)
#
# 🎯 Todos los datasets cargados exitosamente

# %%
# 🔍 Explorar estructura de los datos
print("EXPLORACIÓN DE DATOS")
print("="*50)

print("\n📊 SALES DATA:")
print(f"Columnas: {list(sales.columns)}")
print(f"Períodos únicos: {sales['periodo'].nunique()}")
print(f"Productos únicos: {sales['product_id'].nunique()}")
print("Primeras filas:")
print(sales.head())

print("\n📦 STOCKS DATA:")
print(f"Columnas: {list(stocks.columns)}")
print(f"Períodos únicos: {stocks['periodo'].nunique()}")
print(f"Productos únicos: {stocks['product_id'].nunique()}")
print("Primeras filas:")
print(stocks.head())

print("\n🏷️ PRODUCT INFO:")
print(f"Columnas: {list(product_info.columns)}")
print(f"Productos únicos: {product_info['product_id'].nunique()}")
print("Primeras filas:")
print(product_info.head())

print("\n🎯 PRODUCTOS A PREDECIR:")
print(f"Columnas: {list(product_predict.columns)}")
print(f"Total productos a predecir: {len(product_predict)}")
print("Primeras filas:")
print(product_predict.head())
# Out:
# EXPLORACIÓN DE DATOS
# ==================================================
#
# 📊 SALES DATA:
# Columnas: ['periodo', 'customer_id', 'product_id', 'plan_precios_cuidados', 'cust_request_qty', 'cust_request_tn', 'tn']
# Períodos únicos: 36
# Productos únicos: 1233
# Primeras filas:
#   periodo  customer_id  product_id  plan_precios_cuidados  cust_request_qty  \
# 0  201701        10234       20524                      0                 2
# 1  201701        10032       20524                      0                 1
# 2  201701        10217       20524                      0                 1
# 3  201701        10125       20524                      0                 1
# 4  201701        10012       20524                      0                11
#
#    cust_request_tn       tn
# 0          0.05300  0.05300
# 1          0.13628  0.13628
# 2          0.03028  0.03028
# 3          0.02271  0.02271
# 4          1.54452  1.54452
#
# 📦 STOCKS DATA:
# Columnas: ['periodo', 'product_id', 'stock_final']
# Períodos únicos: 15
# Productos únicos: 1095
# Primeras filas:
#   periodo  product_id  stock_final
# 0  201810       20524      1.61267
# 1  201810       20311      2.93657
# 2  201810       20654      6.83269
# 3  201810       21005      1.01338
# 4  201810       20974      0.34595
#
# 🏷️ PRODUCT INFO:
# Columnas: ['cat1', 'cat2', 'cat3', 'brand', 'sku_size', 'product_id', 'descripcion']
# Productos únicos: 1251
# Primeras filas:
#     cat1      cat2         cat3   brand  sku_size  product_id  \
# 0  FOODS  ADEREZOS  Aji Picante  NATURA       240       20609
# 1  FOODS  ADEREZOS     Barbacoa  NATURA       250       20266
# 2  FOODS  ADEREZOS     Barbacoa  NATURA       400       20325
# 3  FOODS  ADEREZOS     Barbacoa  NATURA       500       20503
# 4  FOODS  ADEREZOS  Chimichurri  NATURA       350       20797
#
#          descripcion
# 0  Salsa Aji Picante
# 1     Salsa Barbacoa
# 2     Salsa Barbacoa
# 3     Salsa Barbacoa
# 4        Chimichurri
#
# 🎯 PRODUCTOS A PREDECIR:
# Columnas: ['product_id']
# Total productos a predecir: 780
# Primeras filas:
#    product_id
# 0       20001
# 1       20002
# 2       20003
# 3       20004
# 4       20005

# %%
# 🔗 Verificar consistencia entre datasets
print("VERIFICACIÓN DE CONSISTENCIA")
print("="*50)

# Productos únicos en cada dataset
productos_sales = set(sales['product_id'].unique())
productos_stocks = set(stocks['product_id'].unique())
productos_info = set(product_info['product_id'].unique())

# Si product_predict tiene columna product_id
if 'product_id' in product_predict.columns:
    productos_predict = set(product_predict['product_id'].unique())
else:
    # Si la primera columna contiene los product_ids
    primera_columna = product_predict.columns[0]
    productos_predict = set(product_predict[primera_columna].unique())
    print(f"⚠️ Usando columna '{primera_columna}' como product_id")

print(f"📊 Productos en sales: {len(productos_sales)}")
print(f"📦 Productos en stocks: {len(productos_stocks)}")
print(f"🏷️ Productos en product_info: {len(productos_info)}")
print(f"🎯 Productos a predecir: {len(productos_predict)}")

# Verificar intersecciones
print(f"\n🔍 INTERSECCIONES:")
print(f"Sales ∩ Stocks: {len(productos_sales & productos_stocks)}")
print(f"Sales ∩ Product_info: {len(productos_sales & productos_info)}")
print(f"Sales ∩ Productos_predict: {len(productos_sales & productos_predict)}")
print(f"Stocks ∩ Productos_predict: {len(productos_stocks & productos_predict)}")
print(f"Product_info ∩ Productos_predict: {len(productos_info & productos_predict)}")

# Verificar rangos de fechas
print(f"\n📅 RANGOS DE FECHAS:")
print(f"Sales - períodos: {sales['periodo'].min()} a {sales['periodo'].max()}")
print(f"Stocks - períodos: {stocks['periodo'].min()} a {stocks['periodo'].max()}")
# Out:
# VERIFICACIÓN DE CONSISTENCIA
# ==================================================
# 📊 Productos en sales: 1233
# 📦 Productos en stocks: 1095
# 🏷️ Productos en product_info: 1251
# 🎯 Productos a predecir: 780
#
# 🔍 INTERSECCIONES:
# Sales ∩ Stocks: 1095
# Sales ∩ Product_info: 1188
# Sales ∩ Productos_predict: 780
# Stocks ∩ Productos_predict: 779
# Product_info ∩ Productos_predict: 780
#
# 📅 RANGOS DE FECHAS:
# Sales - períodos: 201701 a 201912
# Stocks - períodos: 201810 a 201912

# %%
# 📦 Instalar e importar LightGBM, Optuna y librerías adicionales
# %pip install lightgbm optuna

import lightgbm as lgb
import optuna
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# 🎲 Configurar semillas adicionales para reproductibilidad
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

# Configurar semilla para matplotlib (si se usa)
plt.rcParams['figure.max_open_warning'] = 0

print("✅ LightGBM, Optuna y librerías ML importadas correctamente")
print(f"🎲 Todas las semillas configuradas con SEED={SEED} para reproductibilidad")
# Out:
# ✅ LightGBM, Optuna y librerías ML importadas correctamente
# 🎲 Todas las semillas configuradas con SEED=42 para reproductibilidad

# %%
# 🧹 Preparación de datos para el modelo LightGBM
print("PREPARACIÓN DE DATOS PARA LGBM - GRANULARIDAD POR PRODUCTO")
print("="*60)

# Convertir período a datetime para facilitar manipulación
sales['fecha'] = pd.to_datetime(sales['periodo'], format='%Y%m')
stocks['fecha'] = pd.to_datetime(stocks['periodo'], format='%Y%m')

# Filtrar solo productos que necesitamos predecir
if 'product_id' in product_predict.columns:
    productos_objetivo = product_predict['product_id'].tolist()
else:
    productos_objetivo = product_predict[product_predict.columns[0]].tolist()

print(f"🎯 Productos objetivo: {len(productos_objetivo)}")

# Filtrar sales y stocks para productos objetivo
sales_filtered = sales[sales['product_id'].isin(productos_objetivo)].copy()
stocks_filtered = stocks[stocks['product_id'].isin(productos_objetivo)].copy()

print(f"📊 Sales filtradas: {sales_filtered.shape}")
print(f"📦 Stocks filtradas: {stocks_filtered.shape}")

# AGREGACIÓN POR PRODUCTO: Sumar por producto y período (agregando todos los clientes)
sales_agg = sales_filtered.groupby(['product_id', 'fecha', 'periodo']).agg({
    'tn': 'sum',                    # Total toneladas por producto
    'customer_id': 'nunique',       # Número de clientes únicos
    'cust_request_qty': 'sum',      # Total cantidad solicitada
    'cust_request_tn': 'sum'        # Total toneladas solicitadas
}).reset_index()

# Renombrar columnas para claridad
sales_agg.rename(columns={
    'customer_id': 'num_customers',
    'cust_request_qty': 'total_request_qty', 
    'cust_request_tn': 'total_request_tn'
}, inplace=True)

print(f"📈 Sales agregadas por producto: {sales_agg.shape}")
print("Primeras filas de sales agregadas:")
print(sales_agg.head())

print(f"\n📊 Estadísticas por producto:")
print(f"  Promedio tn por producto-período: {sales_agg['tn'].mean():.2f}")
print(f"  Promedio clientes por producto-período: {sales_agg['num_customers'].mean():.2f}")
print(f"  Productos únicos: {sales_agg['product_id'].nunique()}")
print(f"  Períodos únicos: {sales_agg['periodo'].nunique()}")
# Out:
# PREPARACIÓN DE DATOS PARA LGBM - GRANULARIDAD POR PRODUCTO
# ============================================================
# 🎯 Productos objetivo: 780
# 📊 Sales filtradas: (2293481, 8)
# 📦 Stocks filtradas: (10727, 4)
# 📈 Sales agregadas por producto: (22349, 7)
# Primeras filas de sales agregadas:
#    product_id      fecha periodo          tn  num_customers  \
# 0       20001 2017-01-01  201701   934.77222            186
# 1       20001 2017-02-01  201702   798.01620            185
# 2       20001 2017-03-01  201703  1303.35771            188
# 3       20001 2017-04-01  201704  1069.96130            104
# 4       20001 2017-05-01  201705  1502.20132            238
#
#    total_request_qty  total_request_tn
# 0                479         937.72717
# 1                432         833.72187
# 2                509        1330.74697
# 3                279        1132.94430
# 4                701        1550.68936
#
# 📊 Estadísticas por producto:
#   Promedio tn por producto-período: 50.23
#   Promedio clientes por producto-período: 102.62
#   Productos únicos: 780
#   Períodos únicos: 36

# %%
# 🔧 Crear features de lag y combinar con stocks - GRANULARIDAD POR PRODUCTO
print("CREACIÓN DE FEATURES POR PRODUCTO")
print("="*50)

# Crear features de lag para cada producto
def create_lag_features(df, product_col, value_col, date_col, lags=[1, 2, 3, 6, 12]):
    """Crear features de lag para series temporales por producto"""
    df_features = df.copy()
    df_features = df_features.sort_values([product_col, date_col])
    
    for lag in lags:
        df_features[f'{value_col}_lag_{lag}'] = df_features.groupby(product_col)[value_col].shift(lag)
    
    return df_features

# Crear lags para ventas (tn) por producto - EXPANDIDO HASTA LAG 36
sales_with_lags = create_lag_features(
    sales_agg, 
    'product_id', 
    'tn', 
    'fecha', 
    lags=list(range(1, 37))  # Todos los lags de 1 a 36 meses (3 años completos)
)

# Crear lags para número de clientes por producto
sales_with_lags = create_lag_features(
    sales_with_lags, 
    'product_id', 
    'num_customers', 
    'fecha', 
    lags=[1, 2, 3]
)

# Crear lags para solicitudes de clientes
sales_with_lags = create_lag_features(
    sales_with_lags, 
    'product_id', 
    'total_request_tn', 
    'fecha', 
    lags=[1, 2, 3]
)

print(f"📊 Sales con lags por producto: {sales_with_lags.shape}")

# Agregar datos de stock por producto
stocks_agg = stocks_filtered.groupby(['product_id', 'fecha', 'periodo']).agg({
    'stock_final': ['mean', 'sum', 'std']  # Stock promedio, total y desviación estándar por producto
}).reset_index()

# Aplanar columnas multinivel
stocks_agg.columns = ['product_id', 'fecha', 'periodo', 'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std']
stocks_agg['stock_tn_std'] = stocks_agg['stock_tn_std'].fillna(0)  # Rellenar NaN en std

# Combinar sales y stocks por producto
data_combined = pd.merge(
    sales_with_lags, 
    stocks_agg[['product_id', 'fecha', 'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std']], 
    on=['product_id', 'fecha'], 
    how='left'
)

# Crear lags para stock por producto
data_combined = create_lag_features(
    data_combined, 
    'product_id', 
    'stock_tn_mean', 
    'fecha', 
    lags=[1, 2, 3]
)

data_combined = create_lag_features(
    data_combined, 
    'product_id', 
    'stock_tn_sum', 
    'fecha', 
    lags=[1, 2]
)

print(f"📦 Datos combinados con stock por producto: {data_combined.shape}")
print(f"Columnas disponibles: {len(data_combined.columns)}")
print("\nPrimeras columnas:")
print(data_combined.columns.tolist()[:15])
print("Últimas columnas:")
print(data_combined.columns.tolist()[-10:])
# Out:
# CREACIÓN DE FEATURES POR PRODUCTO
# ==================================================
# 📊 Sales con lags por producto: (22349, 49)
# 📦 Datos combinados con stock por producto: (22349, 57)
# Columnas disponibles: 57
#
# Primeras columnas:
# ['product_id', 'fecha', 'periodo', 'tn', 'num_customers', 'total_request_qty', 'total_request_tn', 'tn_lag_1', 'tn_lag_2', 'tn_lag_3', 'tn_lag_4', 'tn_lag_5', 'tn_lag_6', 'tn_lag_7', 'tn_lag_8']
# Últimas columnas:
# ['total_request_tn_lag_2', 'total_request_tn_lag_3', 'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std', 'stock_tn_mean_lag_1', 'stock_tn_mean_lag_2', 'stock_tn_mean_lag_3', 'stock_tn_sum_lag_1', 'stock_tn_sum_lag_2']

# %%
# 🎯 Crear target y features adicionales
print("CREACIÓN DE TARGET Y FEATURES ADICIONALES")
print("="*50)

# Crear target: tn de 2 períodos a futuro
data_combined = data_combined.sort_values(['product_id', 'fecha'])
data_combined['target'] = data_combined.groupby('product_id')['tn'].shift(-2)

# Crear features temporales
data_combined['mes'] = data_combined['fecha'].dt.month
data_combined['trimestre'] = data_combined['fecha'].dt.quarter
data_combined['año'] = data_combined['fecha'].dt.year

# 🔢 Crear feature de clientes únicos por producto
print(f"\n🔍 Creando feature de clientes únicos por producto...")
# Calcular cantidad total de clientes únicos que compraron cada producto
clientes_unicos_por_producto = sales_filtered.groupby('product_id')['customer_id'].nunique().reset_index()
clientes_unicos_por_producto.rename(columns={'customer_id': 'cant_clientes_unicos'}, inplace=True)

# Agregar esta información a data_combined
data_combined = pd.merge(
    data_combined,
    clientes_unicos_por_producto,
    on='product_id',
    how='left'
)

print(f"✅ Feature 'cant_clientes_unicos' agregada")
print(f"📊 Estadísticas de clientes únicos por producto:")
print(f"   Promedio: {data_combined['cant_clientes_unicos'].mean():.1f}")
print(f"   Mediana:  {data_combined['cant_clientes_unicos'].median():.1f}")
print(f"   Mínimo:   {data_combined['cant_clientes_unicos'].min()}")
print(f"   Máximo:   {data_combined['cant_clientes_unicos'].max()}")

# 🗓️ Crear feature de meses de vida por producto
print(f"\n🔍 Creando feature de meses de vida por producto...")
# Calcular primer y último período de compra para cada producto
vida_producto = sales_filtered.groupby('product_id')['fecha'].agg(['min', 'max']).reset_index()
vida_producto.columns = ['product_id', 'primer_periodo', 'ultimo_periodo']

# Calcular diferencia en meses
vida_producto['meses_vida'] = ((vida_producto['ultimo_periodo'] - vida_producto['primer_periodo']).dt.days / 30.44).round().astype(int)

# Asegurar que el mínimo sea 1 (productos con una sola compra tienen 1 mes de vida)
vida_producto['meses_vida'] = vida_producto['meses_vida'].apply(lambda x: max(1, x))

# Agregar esta información a data_combined
data_combined = pd.merge(
    data_combined,
    vida_producto[['product_id', 'meses_vida']],
    on='product_id',
    how='left'
)

print(f"✅ Feature 'meses_vida' agregada")
print(f"📊 Estadísticas de meses de vida por producto:")
print(f"   Promedio: {data_combined['meses_vida'].mean():.1f} meses")
print(f"   Mediana:  {data_combined['meses_vida'].median():.1f} meses")
print(f"   Mínimo:   {data_combined['meses_vida'].min()} meses")
print(f"   Máximo:   {data_combined['meses_vida'].max()} meses")
print(f"   Productos con > 24 meses: {(data_combined['meses_vida'] > 24).sum()}")
print(f"   Productos con > 36 meses: {(data_combined['meses_vida'] > 36).sum()}")

# Crear features estadísticas móviles
def create_rolling_features(df, product_col, value_col, date_col, windows=[3, 6, 12]):
    """Crear features de ventanas móviles"""
    df = df.sort_values([product_col, date_col])
    
    for window in windows:
        df[f'{value_col}_rolling_mean_{window}'] = df.groupby(product_col)[value_col].rolling(window, min_periods=1).mean().reset_index(level=0, drop=True)
        df[f'{value_col}_rolling_std_{window}'] = df.groupby(product_col)[value_col].rolling(window, min_periods=1).std().reset_index(level=0, drop=True)
    
    return df

# Crear rolling features para ventas
data_combined = create_rolling_features(data_combined, 'product_id', 'tn', 'fecha', windows=[3, 6])

# 📊 Verificar features de lags de toneladas creados
print(f"\n📈 FEATURES DE LAGS DE TONELADAS DISPONIBLES:")
tn_lag_features = [col for col in data_combined.columns if col.startswith('tn_lag_')]
tn_lag_features.sort(key=lambda x: int(x.split('_')[-1]))  # Ordenar por número de lag
print(f"   Total de lags de toneladas: {len(tn_lag_features)}")
for i, feature in enumerate(tn_lag_features, 1):
    lag_num = feature.split('_')[-1]
    print(f"   {i:2d}. {feature} (toneladas de {lag_num} mes{'es' if int(lag_num) > 1 else ''} atrás)")

print(f"\n✅ Features expandidas: Lags de toneladas desde 1 hasta 36 meses")
print(f"🎯 Esto permite al modelo capturar patrones estacionales multi-anuales")

# Agregar información de productos si está disponible
if len(product_info) > 0:
    data_combined = pd.merge(
        data_combined, 
        product_info, 
        on='product_id', 
        how='left'
    )
    print(f"✅ Información de productos agregada")

print(f"📊 Dataset final: {data_combined.shape}")
print(f"📈 Registros con target válido: {data_combined['target'].notna().sum()}")

# Mostrar algunas estadísticas del target
target_stats = data_combined['target'].describe()
print(f"\n📊 Estadísticas del target:")
print(target_stats)
# Out:
# CREACIÓN DE TARGET Y FEATURES ADICIONALES
# ==================================================
#
# 🔍 Creando feature de clientes únicos por producto...
# ✅ Feature 'cant_clientes_unicos' agregada
# 📊 Estadísticas de clientes únicos por producto:
#    Promedio: 359.6
#    Mediana:  372.0
#    Mínimo:   22
#    Máximo:   521
#
# 🔍 Creando feature de meses de vida por producto...
# ✅ Feature 'meses_vida' agregada
# 📊 Estadísticas de meses de vida por producto:
#    Promedio: 31.9 meses
#    Mediana:  35.0 meses
#    Mínimo:   3 meses
#    Máximo:   35 meses
#    Productos con > 24 meses: 19798
#    Productos con > 36 meses: 0
#
# 📈 FEATURES DE LAGS DE TONELADAS DISPONIBLES:
#    Total de lags de toneladas: 36
#     1. tn_lag_1 (toneladas de 1 mes atrás)
#     2. tn_lag_2 (toneladas de 2 meses atrás)
#     3. tn_lag_3 (toneladas de 3 meses atrás)
#     4. tn_lag_4 (toneladas de 4 meses atrás)
#     5. tn_lag_5 (toneladas de 5 meses atrás)
#     6. tn_lag_6 (toneladas de 6 meses atrás)
#     7. tn_lag_7 (toneladas de 7 meses atrás)
#     8. tn_lag_8 (toneladas de 8 meses atrás)
#     9. tn_lag_9 (toneladas de 9 meses atrás)
#    10. tn_lag_10 (toneladas de 10 meses atrás)
#    11. tn_lag_11 (toneladas de 11 meses atrás)
#    12. tn_lag_12 (toneladas de 12 meses atrás)
#    13. tn_lag_13 (toneladas de 13 meses atrás)
#    14. tn_lag_14 (toneladas de 14 meses atrás)
#    15. tn_lag_15 (toneladas de 15 meses atrás)
#    16. tn_lag_16 (toneladas de 16 meses atrás)
#    17. tn_lag_17 (toneladas de 17 meses atrás)
#    18. tn_lag_18 (toneladas de 18 meses atrás)
#    19. tn_lag_19 (toneladas de 19 meses atrás)
#    20. tn_lag_20 (toneladas de 20 meses atrás)
#    21. tn_lag_21 (toneladas de 21 meses atrás)
#    22. tn_lag_22 (toneladas de 22 meses atrás)
#    23. tn_lag_23 (toneladas de 23 meses atrás)
#    24. tn_lag_24 (toneladas de 24 meses atrás)
#    25. tn_lag_25 (toneladas de 25 meses atrás)
#    26. tn_lag_26 (toneladas de 26 meses atrás)
#    27. tn_lag_27 (toneladas de 27 meses atrás)
#    28. tn_lag_28 (toneladas de 28 meses atrás)
#    29. tn_lag_29 (toneladas de 29 meses atrás)
#    30. tn_lag_30 (toneladas de 30 meses atrás)
#    31. tn_lag_31 (toneladas de 31 meses atrás)
#    32. tn_lag_32 (toneladas de 32 meses atrás)
#    33. tn_lag_33 (toneladas de 33 meses atrás)
#    34. tn_lag_34 (toneladas de 34 meses atrás)
#    35. tn_lag_35 (toneladas de 35 meses atrás)
#    36. tn_lag_36 (toneladas de 36 meses atrás)
#
# ✅ Features expandidas: Lags de toneladas desde 1 hasta 36 meses
# 🎯 Esto permite al modelo capturar patrones estacionales multi-anuales
# ✅ Información de productos agregada
# 📊 Dataset final: (22349, 73)
# 📈 Registros con target válido: 20789
#
# 📊 Estadísticas del target:
# count    20789.000000
# mean        50.931444
# std        127.140873
# min          0.000890
# 25%          3.009870
# 50%         11.928920
# 75%         36.636220
# max       2295.198320
# Name: target, dtype: float64

# %%
# 📋 Preparar datos para entrenamiento - GRANULARIDAD POR PRODUCTO
print("PREPARACIÓN DE DATOS DE ENTRENAMIENTO POR PRODUCTO")
print("="*60)

# Filtrar registros con target válido
train_data = data_combined[data_combined['target'].notna()].copy()
print(f"📊 Registros válidos para entrenamiento: {len(train_data)}")

# Seleccionar features para el modelo con granularidad por producto
feature_columns = [
    # Lags de ventas (tn) por producto - EXPANDIDO A 36 LAGS (3 AÑOS)
    'tn_lag_1', 'tn_lag_2', 'tn_lag_3', 'tn_lag_4', 'tn_lag_5', 'tn_lag_6',
    'tn_lag_7', 'tn_lag_8', 'tn_lag_9', 'tn_lag_10', 'tn_lag_11', 'tn_lag_12',
    'tn_lag_13', 'tn_lag_14', 'tn_lag_15', 'tn_lag_16', 'tn_lag_17', 'tn_lag_18',
    'tn_lag_19', 'tn_lag_20', 'tn_lag_21', 'tn_lag_22', 'tn_lag_23', 'tn_lag_24',
    'tn_lag_25', 'tn_lag_26', 'tn_lag_27', 'tn_lag_28', 'tn_lag_29', 'tn_lag_30',
    'tn_lag_31', 'tn_lag_32', 'tn_lag_33', 'tn_lag_34', 'tn_lag_35', 'tn_lag_36',
    
    # Lags de clientes por producto
    'num_customers_lag_1', 'num_customers_lag_2', 'num_customers_lag_3',
    
    # Lags de solicitudes por producto
    'total_request_tn_lag_1', 'total_request_tn_lag_2', 'total_request_tn_lag_3',
    
    # Lags de stock por producto
    'stock_tn_mean_lag_1', 'stock_tn_mean_lag_2', 'stock_tn_mean_lag_3',
    'stock_tn_sum_lag_1', 'stock_tn_sum_lag_2',
    
    # Features temporales
    'mes', 'trimestre', 'año',
    
    # Rolling features por producto
    'tn_rolling_mean_3', 'tn_rolling_mean_6',
    'tn_rolling_std_3', 'tn_rolling_std_6',
    
    # Features actuales por producto
    'num_customers', 'total_request_qty', 'total_request_tn',
    'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std',
    
    # Feature de diversidad de clientes
    'cant_clientes_unicos',
    
    # Feature de longevidad del producto
    'meses_vida'
]

# Verificar qué features existen
available_features = [col for col in feature_columns if col in train_data.columns]
missing_features = [col for col in feature_columns if col not in train_data.columns]

print(f"✅ Features disponibles: {len(available_features)}")
print(f"⚠️ Features faltantes: {len(missing_features)}")
if missing_features:
    print(f"Features faltantes: {missing_features}")

# Usar solo features disponibles
feature_columns = available_features

# Preparar X e y
X = train_data[feature_columns].copy()
y = train_data['target'].copy()

# Rellenar valores nulos con 0 (para lags iniciales y stocks faltantes)
X = X.fillna(0)

print(f"📊 Shape de X: {X.shape}")
print(f"📈 Shape de y: {y.shape}")
print(f"🔍 Valores nulos en X: {X.isnull().sum().sum()}")
print(f"🔍 Valores nulos en y: {y.isnull().sum()}")

# # División temporal para validación (últimos períodos como validación)
# train_data_sorted = train_data.sort_values('fecha')
# split_date = train_data_sorted['fecha'].quantile(0.8)  # 80% entrenamiento, 20% validación

# train_mask = train_data_sorted['fecha'] <= split_date

# División temporal para validación usando fecha 201908
split_date = pd.to_datetime('201908', format='%Y%m')
train_mask = train_data['fecha'] < split_date
X_train = X.loc[train_mask]
X_val = X.loc[~train_mask] 
y_train = y.loc[train_mask]
y_val = y.loc[~train_mask]


print(f"\n📊 DIVISIÓN TEMPORAL:")
print(f"Entrenamiento: {len(X_train)} registros (hasta {split_date.strftime('%Y-%m')})")
print(f"Validación: {len(X_val)} registros (desde {split_date.strftime('%Y-%m')})")

print(f"\n🎯 PRODUCTOS EN ENTRENAMIENTO:")
productos_train = train_data.loc[train_mask, 'product_id'].nunique()
productos_val = train_data.loc[~train_mask, 'product_id'].nunique()
print(f"Productos únicos en entrenamiento: {productos_train}")
print(f"Productos únicos en validación: {productos_val}")

print(f"\nFeatures seleccionadas para granularidad por producto:")
for i, feat in enumerate(feature_columns):
    print(f"  {i+1:2d}. {feat}")
# Out:
# PREPARACIÓN DE DATOS DE ENTRENAMIENTO POR PRODUCTO
# ============================================================
# 📊 Registros válidos para entrenamiento: 20789
# ✅ Features disponibles: 62
# ⚠️ Features faltantes: 0
# 📊 Shape de X: (20789, 62)
# 📈 Shape de y: (20789,)
# 🔍 Valores nulos en X: 0
# 🔍 Valores nulos en y: 0
#
# 📊 DIVISIÓN TEMPORAL:
# Entrenamiento: 18458 registros (hasta 2019-08)
# Validación: 2331 registros (desde 2019-08)
#
# 🎯 PRODUCTOS EN ENTRENAMIENTO:
# Productos únicos en entrenamiento: 756
# Productos únicos en validación: 780
#
# Features seleccionadas para granularidad por producto:
#    1. tn_lag_1
#    2. tn_lag_2
#    3. tn_lag_3
#    4. tn_lag_4
#    5. tn_lag_5
#    6. tn_lag_6
#    7. tn_lag_7
#    8. tn_lag_8
#    9. tn_lag_9
#   10. tn_lag_10
#   11. tn_lag_11
#   12. tn_lag_12
#   13. tn_lag_13
#   14. tn_lag_14
#   15. tn_lag_15
#   16. tn_lag_16
#   17. tn_lag_17
#   18. tn_lag_18
#   19. tn_lag_19
#   20. tn_lag_20
#   21. tn_lag_21
#   22. tn_lag_22
#   23. tn_lag_23
#   24. tn_lag_24
#   25. tn_lag_25
#   26. tn_lag_26
#   27. tn_lag_27
#   28. tn_lag_28
#   29. tn_lag_29
#   30. tn_lag_30
#   31. tn_lag_31
#   32. tn_lag_32
#   33. tn_lag_33
#   34. tn_lag_34
#   35. tn_lag_35
#   36. tn_lag_36
#   37. num_customers_lag_1
#   38. num_customers_lag_2
#   39. num_customers_lag_3
#   40. total_request_tn_lag_1
#   41. total_request_tn_lag_2
#   42. total_request_tn_lag_3
#   43. stock_tn_mean_lag_1
#   44. stock_tn_mean_lag_2
#   45. stock_tn_mean_lag_3
#   46. stock_tn_sum_lag_1
#   47. stock_tn_sum_lag_2
#   48. mes
#   49. trimestre
#   50. año
#   51. tn_rolling_mean_3
#   52. tn_rolling_mean_6
#   53. tn_rolling_std_3
#   54. tn_rolling_std_6
#   55. num_customers
#   56. total_request_qty
#   57. total_request_tn
#   58. stock_tn_mean
#   59. stock_tn_sum
#   60. stock_tn_std
#   61. cant_clientes_unicos
#   62. meses_vida

# %%
# 📊 Resumen detallado de features con lags de toneladas expandidos
print("RESUMEN DETALLADO DE FEATURES CON LAGS EXPANDIDOS")
print("="*60)

# Agrupar features por categoría
tn_lags = [f for f in feature_columns if f.startswith('tn_lag_')]
customer_lags = [f for f in feature_columns if f.startswith('num_customers_lag_')]
request_lags = [f for f in feature_columns if f.startswith('total_request_tn_lag_')]
stock_lags = [f for f in feature_columns if f.startswith('stock_tn_')]
temporal_features = [f for f in feature_columns if f in ['mes', 'trimestre', 'año']]
rolling_features = [f for f in feature_columns if 'rolling' in f]
current_features = [f for f in feature_columns if f in ['num_customers', 'total_request_qty', 'total_request_tn', 'stock_tn_mean', 'stock_tn_sum', 'stock_tn_std', 'cant_clientes_unicos', 'meses_vida']]

print(f"📈 LAGS DE TONELADAS (EXPANDIDOS A 36): {len(tn_lags)} features")
tn_lags_sorted = sorted(tn_lags, key=lambda x: int(x.split('_')[-1]))
for i, lag in enumerate(tn_lags_sorted, 1):
    lag_num = lag.split('_')[-1]
    print(f"   {i:2d}. {lag} (ventas de {lag_num} mes{'es' if int(lag_num) > 1 else ''} atrás)")

print(f"\n👥 LAGS DE CLIENTES: {len(customer_lags)} features")
for i, lag in enumerate(customer_lags, 1):
    print(f"   {i}. {lag}")

print(f"\n📋 LAGS DE SOLICITUDES: {len(request_lags)} features")
for i, lag in enumerate(request_lags, 1):
    print(f"   {i}. {lag}")

print(f"\n📦 FEATURES DE STOCK: {len(stock_lags)} features")
for i, lag in enumerate(stock_lags, 1):
    print(f"   {i}. {lag}")

print(f"\n📅 FEATURES TEMPORALES: {len(temporal_features)} features")
for i, feat in enumerate(temporal_features, 1):
    print(f"   {i}. {feat}")

print(f"\n📊 FEATURES ROLLING: {len(rolling_features)} features")
for i, feat in enumerate(rolling_features, 1):
    print(f"   {i}. {feat}")

print(f"\n🔄 FEATURES ACTUALES: {len(current_features)} features")
for i, feat in enumerate(current_features, 1):
    print(f"   {i}. {feat}")

print(f"\n✅ TOTAL DE FEATURES: {len(feature_columns)}")
print(f"🎯 MEJORA PRINCIPAL: Lags de toneladas expandidos de 12 → 36 features")
print(f"🔢 NUEVA FEATURE: cant_clientes_unicos (diversidad de base de clientes)")
print(f"🗓️ NUEVA FEATURE: meses_vida (longevidad del producto en el mercado)")
print(f"📈 Esto permite capturar:")
print(f"   • Patrones estacionales anuales completos (12 meses)")
print(f"   • Patrones estacionales bi-anuales (24 meses)")
print(f"   • Patrones estacionales tri-anuales (36 meses)")
print(f"   • Tendencias de corto plazo (1-6 meses)")
print(f"   • Tendencias de mediano plazo (7-18 meses)")
print(f"   • Tendencias de largo plazo (19-36 meses)")
print(f"   • Ciclos multi-anuales y efectos estacionales profundos")
print(f"   • Diversidad de base de clientes por producto")
print(f"   • Madurez y longevidad del producto en el mercado")
# Out:
# RESUMEN DETALLADO DE FEATURES CON LAGS EXPANDIDOS
# ============================================================
# 📈 LAGS DE TONELADAS (EXPANDIDOS A 36): 36 features
#     1. tn_lag_1 (ventas de 1 mes atrás)
#     2. tn_lag_2 (ventas de 2 meses atrás)
#     3. tn_lag_3 (ventas de 3 meses atrás)
#     4. tn_lag_4 (ventas de 4 meses atrás)
#     5. tn_lag_5 (ventas de 5 meses atrás)
#     6. tn_lag_6 (ventas de 6 meses atrás)
#     7. tn_lag_7 (ventas de 7 meses atrás)
#     8. tn_lag_8 (ventas de 8 meses atrás)
#     9. tn_lag_9 (ventas de 9 meses atrás)
#    10. tn_lag_10 (ventas de 10 meses atrás)
#    11. tn_lag_11 (ventas de 11 meses atrás)
#    12. tn_lag_12 (ventas de 12 meses atrás)
#    13. tn_lag_13 (ventas de 13 meses atrás)
#    14. tn_lag_14 (ventas de 14 meses atrás)
#    15. tn_lag_15 (ventas de 15 meses atrás)
#    16. tn_lag_16 (ventas de 16 meses atrás)
#    17. tn_lag_17 (ventas de 17 meses atrás)
#    18. tn_lag_18 (ventas de 18 meses atrás)
#    19. tn_lag_19 (ventas de 19 meses atrás)
#    20. tn_lag_20 (ventas de 20 meses atrás)
#    21. tn_lag_21 (ventas de 21 meses atrás)
#    22. tn_lag_22 (ventas de 22 meses atrás)
#    23. tn_lag_23 (ventas de 23 meses atrás)
#    24. tn_lag_24 (ventas de 24 meses atrás)
#    25. tn_lag_25 (ventas de 25 meses atrás)
#    26. tn_lag_26 (ventas de 26 meses atrás)
#    27. tn_lag_27 (ventas de 27 meses atrás)
#    28. tn_lag_28 (ventas de 28 meses atrás)
#    29. tn_lag_29 (ventas de 29 meses atrás)
#    30. tn_lag_30 (ventas de 30 meses atrás)
#    31. tn_lag_31 (ventas de 31 meses atrás)
#    32. tn_lag_32 (ventas de 32 meses atrás)
#    33. tn_lag_33 (ventas de 33 meses atrás)
#    34. tn_lag_34 (ventas de 34 meses atrás)
#    35. tn_lag_35 (ventas de 35 meses atrás)
#    36. tn_lag_36 (ventas de 36 meses atrás)
#
# 👥 LAGS DE CLIENTES: 3 features
#    1. num_customers_lag_1
#    2. num_customers_lag_2
#    3. num_customers_lag_3
#
# 📋 LAGS DE SOLICITUDES: 3 features
#    1. total_request_tn_lag_1
#    2. total_request_tn_lag_2
#    3. total_request_tn_lag_3
#
# 📦 FEATURES DE STOCK: 8 features
#    1. stock_tn_mean_lag_1
#    2. stock_tn_mean_lag_2
#    3. stock_tn_mean_lag_3
#    4. stock_tn_sum_lag_1
#    5. stock_tn_sum_lag_2
#    6. stock_tn_mean
#    7. stock_tn_sum
#    8. stock_tn_std
#
# 📅 FEATURES TEMPORALES: 3 features
#    1. mes
#    2. trimestre
#    3. año
#
# 📊 FEATURES ROLLING: 4 features
#    1. tn_rolling_mean_3
#    2. tn_rolling_mean_6
#    3. tn_rolling_std_3
#    4. tn_rolling_std_6
#
# 🔄 FEATURES ACTUALES: 8 features
#    1. num_customers
#    2. total_request_qty
#    3. total_request_tn
#    4. stock_tn_mean
#    5. stock_tn_sum
#    6. stock_tn_std
#    7. cant_clientes_unicos
#    8. meses_vida
#
# ✅ TOTAL DE FEATURES: 62
# 🎯 MEJORA PRINCIPAL: Lags de toneladas expandidos de 12 → 36 features
# 🔢 NUEVA FEATURE: cant_clientes_unicos (diversidad de base de clientes)
# 🗓️ NUEVA FEATURE: meses_vida (longevidad del producto en el mercado)
# 📈 Esto permite capturar:
#    • Patrones estacionales anuales completos (12 meses)
#    • Patrones estacionales bi-anuales (24 meses)
#    • Patrones estacionales tri-anuales (36 meses)
#    • Tendencias de corto plazo (1-6 meses)
#    • Tendencias de mediano plazo (7-18 meses)
#    • Tendencias de largo plazo (19-36 meses)
#    • Ciclos multi-anuales y efectos estacionales profundos
#    • Diversidad de base de clientes por producto
#    • Madurez y longevidad del producto en el mercado

# %%
# 🔧 Optimización de hiperparámetros con Optuna para LINEAR_TREE
print("OPTIMIZACIÓN DE HIPERPARÁMETROS CON OPTUNA - LINEAR_TREE")
print("="*60)

# 🎲 Configurar semilla para Optuna y reproductibilidad
SEED = 42
np.random.seed(SEED)
random.seed(SEED)

def objective(trial):
    """Función objetivo para optimización con Optuna incluyendo linear_tree"""
    
    # 🎲 Configurar semilla para cada trial
    np.random.seed(SEED + trial.number)
    random.seed(SEED + trial.number)
    
    # Sugerir hiperparámetros optimizados para linear_tree
    params = {
        'objective': 'regression',
        'metric': 'mae',
        'boosting_type': 'gbdt',
        'linear_tree': True,        # FIJO: Característica principal del modelo
        'lambda_l1': trial.suggest_float('lambda_l1', 0.0, 2.0),
        'lambda_l2': trial.suggest_float('lambda_l2', 0.0, 2.0),
        'num_leaves': trial.suggest_int('num_leaves', 20, 120),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.15, log=True),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 10),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 40),
        'max_bin': trial.suggest_int('max_bin', 100, 400),
        'verbose': -1,
        'random_state': SEED + trial.number,  # Semilla única por trial
        'bagging_seed': SEED + trial.number,  # Semilla para bagging
        'feature_fraction_seed': SEED + trial.number  # Semilla para feature selection
    }
    
    # Crear datasets de LightGBM
    train_dataset = lgb.Dataset(X_train, label=y_train)
    val_dataset = lgb.Dataset(X_val, label=y_val, reference=train_dataset)
    
    # Entrenar modelo con validación cruzada interna
    model = lgb.train(
        params,
        train_dataset,
        valid_sets=[val_dataset],
        num_boost_round=1000,
        callbacks=[
            lgb.early_stopping(stopping_rounds=50),
            lgb.log_evaluation(0)  # Silenciar logs
        ]
    )
    
    # Predecir en conjunto de validación
    y_pred = model.predict(X_val, num_iteration=model.best_iteration)
    
    # Calcular MAE como métrica a minimizar
    mae = mean_absolute_error(y_val, y_pred)
    
    return mae

# Crear estudio de optimización
print("🔍 Iniciando optimización de hiperparámetros con LINEAR_TREE...")
print(f"🎲 Usando semilla base {SEED} para reproducibilidad completa")

study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=SEED),  # Semilla para el sampler
    pruner=optuna.pruners.MedianPruner(n_warmup_steps=10)
)

# Ejecutar optimización
n_trials = 700 # 500 Número de pruebas
print(f"🚀 Ejecutando {n_trials} trials de optimización para LINEAR_TREE...")
print(f"🎲 Cada trial usa semilla: SEED + trial_number para reproductibilidad")

study.optimize(objective, n_trials=n_trials, show_progress_bar=True)

# Mostrar mejores parámetros
print(f"\n✅ Optimización completada!")
print(f"🏆 Mejor MAE encontrado: {study.best_value:.4f}")
print(f"\n🔧 HIPERPARÁMETROS OPTIMIZADOS PARA LINEAR_TREE:")
best_params = study.best_params
print("="*65)
print(f"   linear_tree:      True (FIJO - Característica principal) ⭐")
print(f"   lambda_l1:        {best_params['lambda_l1']:.4f}")
print(f"   lambda_l2:        {best_params['lambda_l2']:.4f}")
print(f"   num_leaves:       {best_params['num_leaves']}")
print(f"   feature_fraction: {best_params['feature_fraction']:.4f}")
print(f"   learning_rate:    {best_params['learning_rate']:.4f}")
print(f"   bagging_fraction: {best_params['bagging_fraction']:.4f}")
print(f"   bagging_freq:     {best_params['bagging_freq']}")
print(f"   min_child_samples: {best_params['min_child_samples']}")
print(f"   max_bin:          {best_params['max_bin']}")
print("="*65)

# Agregar parámetros fijos
best_params.update({
    'objective': 'regression',
    'metric': 'mae',
    'boosting_type': 'gbdt',
    'linear_tree': True,  # Mantener como característica principal
    'verbose': 0,
    'random_state': SEED,  # Semilla principal para el modelo final
    'bagging_seed': SEED,  # Semilla para bagging
    'feature_fraction_seed': SEED,  # Semilla para feature selection
    'data_seed': SEED  # Semilla para datos
})

print(f"\n📊 Resumen de la optimización:")
print(f"  Trials completados: {len(study.trials)}")
print(f"  Mejor trial: {study.best_trial.number}")
print(f"  Tiempo total: {sum(t.duration.total_seconds() for t in study.trials if t.duration):.1f} segundos")
print(f"🎲 Reproductibilidad garantizada con SEED={SEED}")
# Out:
# [I 2025-08-10 10:56:22,229] A new study created in memory with name: no-name-84cdf0a7-93a8-4093-b613-7e73f3cb3c7e
# OPTIMIZACIÓN DE HIPERPARÁMETROS CON OPTUNA - LINEAR_TREE
# ============================================================
# 🔍 Iniciando optimización de hiperparámetros con LINEAR_TREE...
# 🎲 Usando semilla base 42 para reproducibilidad completa
# 🚀 Ejecutando 700 trials de optimización para LINEAR_TREE...
# 🎲 Cada trial usa semilla: SEED + trial_number para reproductibilidad
#   0%|          | 0/700 [00:00<?, ?it/s]
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [244]	valid_0's l1: 11.712
# [I 2025-08-10 10:56:24,365] Trial 0 finished with value: 11.711975409604069 and parameters: {'lambda_l1': 0.749080237694725, 'lambda_l2': 1.9014286128198323, 'num_leaves': 93, 'feature_fraction': 0.8394633936788146, 'learning_rate': 0.015257808482051183, 'bagging_fraction': 0.662397808134481, 'bagging_freq': 1, 'min_child_samples': 36, 'max_bin': 280}. Best is trial 0 with value: 11.711975409604069.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [164]	valid_0's l1: 12.9138
# [I 2025-08-10 10:56:26,348] Trial 1 finished with value: 12.913777756791822 and parameters: {'lambda_l1': 1.416145155592091, 'lambda_l2': 0.041168988591604894, 'num_leaves': 117, 'feature_fraction': 0.9329770563201687, 'learning_rate': 0.01777174904859463, 'bagging_fraction': 0.6727299868828402, 'bagging_freq': 2, 'min_child_samples': 15, 'max_bin': 257}. Best is trial 0 with value: 11.711975409604069.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [195]	valid_0's l1: 10.5547
# [I 2025-08-10 10:56:27,857] Trial 2 finished with value: 10.554663572761209 and parameters: {'lambda_l1': 0.8638900372842315, 'lambda_l2': 0.5824582803960838, 'num_leaves': 81, 'feature_fraction': 0.6557975442608167, 'learning_rate': 0.022059149678071027, 'bagging_fraction': 0.7465447373174767, 'bagging_freq': 5, 'min_child_samples': 33, 'max_bin': 160}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [223]	valid_0's l1: 11.2014
# [I 2025-08-10 10:56:28,612] Trial 3 finished with value: 11.201430941746517 and parameters: {'lambda_l1': 1.0284688768272232, 'lambda_l2': 1.184829137724085, 'num_leaves': 24, 'feature_fraction': 0.8430179407605753, 'learning_rate': 0.015869086642715014, 'bagging_fraction': 0.6260206371941118, 'bagging_freq': 10, 'min_child_samples': 39, 'max_bin': 343}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [271]	valid_0's l1: 10.9332
# [I 2025-08-10 10:56:30,712] Trial 4 finished with value: 10.933207055188216 and parameters: {'lambda_l1': 0.6092275383467414, 'lambda_l2': 0.19534422801276774, 'num_leaves': 89, 'feature_fraction': 0.7760609974958406, 'learning_rate': 0.013916438390377948, 'bagging_fraction': 0.798070764044508, 'bagging_freq': 1, 'min_child_samples': 37, 'max_bin': 177}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [203]	valid_0's l1: 11.0982
# [I 2025-08-10 10:56:32,314] Trial 5 finished with value: 11.09820454115783 and parameters: {'lambda_l1': 1.325044568707964, 'lambda_l2': 0.6234221521788219, 'num_leaves': 72, 'feature_fraction': 0.8186841117373118, 'learning_rate': 0.016497027917250065, 'bagging_fraction': 0.9878338511058234, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 369}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [367]	valid_0's l1: 11.0388
# [I 2025-08-10 10:56:33,280] Trial 6 finished with value: 11.038783058943972 and parameters: {'lambda_l1': 1.1957999576221703, 'lambda_l2': 1.8437484700462337, 'num_leaves': 28, 'feature_fraction': 0.6783931449676581, 'learning_rate': 0.011302939920362371, 'bagging_fraction': 0.7301321323053057, 'bagging_freq': 4, 'min_child_samples': 14, 'max_bin': 349}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	valid_0's l1: 10.6178
# [I 2025-08-10 10:56:33,685] Trial 7 finished with value: 10.617846354209211 and parameters: {'lambda_l1': 0.7135066533871786, 'lambda_l2': 0.5618690193747615, 'num_leaves': 74, 'feature_fraction': 0.6563696899899051, 'learning_rate': 0.08779238696445962, 'bagging_fraction': 0.6298202574719083, 'bagging_freq': 10, 'min_child_samples': 32, 'max_bin': 159}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [33]	valid_0's l1: 13.9859
# [I 2025-08-10 10:56:34,208] Trial 8 finished with value: 13.985887133568099 and parameters: {'lambda_l1': 0.011044234247204798, 'lambda_l2': 1.6309228569096683, 'num_leaves': 91, 'feature_fraction': 0.8916028672163949, 'learning_rate': 0.08073917605382007, 'bagging_fraction': 0.6296178606936361, 'bagging_freq': 4, 'min_child_samples': 9, 'max_bin': 359}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [124]	valid_0's l1: 11.6694
# [I 2025-08-10 10:56:34,559] Trial 9 finished with value: 11.669419695530507 and parameters: {'lambda_l1': 1.2465962536551158, 'lambda_l2': 0.6617960497052984, 'num_leaves': 26, 'feature_fraction': 0.7243929286862649, 'learning_rate': 0.02412377463500467, 'bagging_fraction': 0.8918424713352255, 'bagging_freq': 7, 'min_child_samples': 36, 'max_bin': 242}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [45]	valid_0's l1: 16.0271
# [I 2025-08-10 10:56:34,881] Trial 10 finished with value: 16.027120613875564 and parameters: {'lambda_l1': 1.8902730884607737, 'lambda_l2': 1.1288517476886413, 'num_leaves': 51, 'feature_fraction': 0.6071847502459278, 'learning_rate': 0.03899622544867073, 'bagging_fraction': 0.8084932353340201, 'bagging_freq': 5, 'min_child_samples': 26, 'max_bin': 112}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	valid_0's l1: 11.1109
# [I 2025-08-10 10:56:35,219] Trial 11 finished with value: 11.11092828097007 and parameters: {'lambda_l1': 0.4630037443067063, 'lambda_l2': 0.5615219084794084, 'num_leaves': 64, 'feature_fraction': 0.6080164944969302, 'learning_rate': 0.11152092037370537, 'bagging_fraction': 0.7448209034956987, 'bagging_freq': 10, 'min_child_samples': 29, 'max_bin': 138}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	valid_0's l1: 10.8417
# [I 2025-08-10 10:56:35,824] Trial 12 finished with value: 10.841725404086638 and parameters: {'lambda_l1': 0.28369089250529766, 'lambda_l2': 0.4059151190121654, 'num_leaves': 73, 'feature_fraction': 0.6829145420490432, 'learning_rate': 0.05170314190911824, 'bagging_fraction': 0.7102700824842679, 'bagging_freq': 7, 'min_child_samples': 29, 'max_bin': 190}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [29]	valid_0's l1: 11.1407
# [I 2025-08-10 10:56:36,154] Trial 13 finished with value: 11.140688906344023 and parameters: {'lambda_l1': 0.9282318580513729, 'lambda_l2': 0.9853514729063059, 'num_leaves': 53, 'feature_fraction': 0.9997449754566204, 'learning_rate': 0.1383211134148635, 'bagging_fraction': 0.7987586652315627, 'bagging_freq': 8, 'min_child_samples': 22, 'max_bin': 190}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [167]	valid_0's l1: 11.2588
# [I 2025-08-10 10:56:37,417] Trial 14 finished with value: 11.25880056221216 and parameters: {'lambda_l1': 1.6683813004694612, 'lambda_l2': 0.8302037771543154, 'num_leaves': 107, 'feature_fraction': 0.6783715954207381, 'learning_rate': 0.027247018577019697, 'bagging_fraction': 0.8604911724169197, 'bagging_freq': 6, 'min_child_samples': 31, 'max_bin': 144}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [59]	valid_0's l1: 11.4085
# [I 2025-08-10 10:56:37,986] Trial 15 finished with value: 11.408548134585471 and parameters: {'lambda_l1': 0.8201303597756717, 'lambda_l2': 0.36493091669246763, 'num_leaves': 80, 'feature_fraction': 0.7483790886847563, 'learning_rate': 0.060203926872369834, 'bagging_fraction': 0.699263852533394, 'bagging_freq': 3, 'min_child_samples': 21, 'max_bin': 223}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [130]	valid_0's l1: 10.864
# [I 2025-08-10 10:56:38,537] Trial 16 finished with value: 10.863962308651502 and parameters: {'lambda_l1': 0.4431267588724457, 'lambda_l2': 1.2789369325417557, 'num_leaves': 51, 'feature_fraction': 0.6458762543229707, 'learning_rate': 0.03043286042010038, 'bagging_fraction': 0.6064906384617162, 'bagging_freq': 9, 'min_child_samples': 31, 'max_bin': 103}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [41]	valid_0's l1: 11.2085
# [I 2025-08-10 10:56:39,204] Trial 17 finished with value: 11.208450937596826 and parameters: {'lambda_l1': 0.19572969761350456, 'lambda_l2': 0.8724123420740704, 'num_leaves': 106, 'feature_fraction': 0.7296577010203166, 'learning_rate': 0.09209546629930444, 'bagging_fraction': 0.7520730905544443, 'bagging_freq': 5, 'min_child_samples': 33, 'max_bin': 302}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [75]	valid_0's l1: 10.9485
# [I 2025-08-10 10:56:39,564] Trial 18 finished with value: 10.948545288061993 and parameters: {'lambda_l1': 1.078017267868785, 'lambda_l2': 0.3293662450607484, 'num_leaves': 40, 'feature_fraction': 0.6472685120737562, 'learning_rate': 0.04561633594796998, 'bagging_fraction': 0.930746924386335, 'bagging_freq': 6, 'min_child_samples': 26, 'max_bin': 163}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	valid_0's l1: 17.5989
# [I 2025-08-10 10:56:39,876] Trial 19 finished with value: 17.59893107771619 and parameters: {'lambda_l1': 0.6477633998399199, 'lambda_l2': 0.024511835587034403, 'num_leaves': 61, 'feature_fraction': 0.7727431143998708, 'learning_rate': 0.0674952236158446, 'bagging_fraction': 0.6676878695621966, 'bagging_freq': 3, 'min_child_samples': 17, 'max_bin': 213}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [162]	valid_0's l1: 13.7044
# [I 2025-08-10 10:56:41,081] Trial 20 finished with value: 13.70442389045886 and parameters: {'lambda_l1': 1.5836747777840576, 'lambda_l2': 1.4068155972569396, 'num_leaves': 82, 'feature_fraction': 0.7075496061281158, 'learning_rate': 0.021875342137582975, 'bagging_fraction': 0.8424441877746577, 'bagging_freq': 8, 'min_child_samples': 5, 'max_bin': 399}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [96]	valid_0's l1: 10.9234
# [I 2025-08-10 10:56:41,766] Trial 21 finished with value: 10.923409200581723 and parameters: {'lambda_l1': 0.30819447160890123, 'lambda_l2': 0.4103952864210703, 'num_leaves': 72, 'feature_fraction': 0.6563990716703957, 'learning_rate': 0.04923634898505029, 'bagging_fraction': 0.7065916059622793, 'bagging_freq': 7, 'min_child_samples': 27, 'max_bin': 200}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [128]	valid_0's l1: 10.7216
# [I 2025-08-10 10:56:42,612] Trial 22 finished with value: 10.721555960588503 and parameters: {'lambda_l1': 0.12301308564105762, 'lambda_l2': 0.6812860237162084, 'num_leaves': 79, 'feature_fraction': 0.698015737676511, 'learning_rate': 0.03520064889954414, 'bagging_fraction': 0.7593636695419108, 'bagging_freq': 9, 'min_child_samples': 33, 'max_bin': 158}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [128]	valid_0's l1: 10.6862
# [I 2025-08-10 10:56:43,602] Trial 23 finished with value: 10.68622818180028 and parameters: {'lambda_l1': 0.05747443720553247, 'lambda_l2': 0.7657212973584887, 'num_leaves': 99, 'feature_fraction': 0.6287319708545874, 'learning_rate': 0.03555227267256427, 'bagging_fraction': 0.7699873130001514, 'bagging_freq': 9, 'min_child_samples': 34, 'max_bin': 137}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [122]	valid_0's l1: 11.0183
# [I 2025-08-10 10:56:44,557] Trial 24 finished with value: 11.01832993163371 and parameters: {'lambda_l1': 0.5316214539678323, 'lambda_l2': 0.8279724168054036, 'num_leaves': 99, 'feature_fraction': 0.6265659171067944, 'learning_rate': 0.032460803383689334, 'bagging_fraction': 0.7789836087457328, 'bagging_freq': 10, 'min_child_samples': 40, 'max_bin': 124}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [166]	valid_0's l1: 10.8784
# [I 2025-08-10 10:56:45,881] Trial 25 finished with value: 10.878397107329626 and parameters: {'lambda_l1': 0.8666807775826961, 'lambda_l2': 0.5096452188863143, 'num_leaves': 116, 'feature_fraction': 0.6366048702191087, 'learning_rate': 0.02081052754039066, 'bagging_fraction': 0.8458988067140565, 'bagging_freq': 9, 'min_child_samples': 34, 'max_bin': 137}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [63]	valid_0's l1: 11.5695
# [I 2025-08-10 10:56:46,561] Trial 26 finished with value: 11.56945556646543 and parameters: {'lambda_l1': 0.7299517266832937, 'lambda_l2': 0.7506152318733339, 'num_leaves': 102, 'feature_fraction': 0.6012516964622934, 'learning_rate': 0.07239732862004969, 'bagging_fraction': 0.823007060629123, 'bagging_freq': 9, 'min_child_samples': 25, 'max_bin': 167}. Best is trial 2 with value: 10.554663572761209.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [111]	valid_0's l1: 10.4332
# [I 2025-08-10 10:56:47,457] Trial 27 finished with value: 10.433230934093654 and parameters: {'lambda_l1': 0.36518773905725377, 'lambda_l2': 0.9233902469317162, 'num_leaves': 88, 'feature_fraction': 0.6675899857182831, 'learning_rate': 0.03980000354747352, 'bagging_fraction': 0.8947202058335308, 'bagging_freq': 6, 'min_child_samples': 34, 'max_bin': 230}. Best is trial 27 with value: 10.433230934093654.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [49]	valid_0's l1: 10.4005
# [I 2025-08-10 10:56:47,932] Trial 28 finished with value: 10.400494186803199 and parameters: {'lambda_l1': 0.3877754751073516, 'lambda_l2': 0.20926053001756645, 'num_leaves': 61, 'feature_fraction': 0.7472708366696561, 'learning_rate': 0.10186110427916095, 'bagging_fraction': 0.8899560843002041, 'bagging_freq': 4, 'min_child_samples': 30, 'max_bin': 245}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	valid_0's l1: 10.8754
# [I 2025-08-10 10:56:48,345] Trial 29 finished with value: 10.875424423795499 and parameters: {'lambda_l1': 0.32198659661054785, 'lambda_l2': 0.15905113451236486, 'num_leaves': 61, 'feature_fraction': 0.7532124652410543, 'learning_rate': 0.14650749464358465, 'bagging_fraction': 0.9127113033993868, 'bagging_freq': 4, 'min_child_samples': 29, 'max_bin': 280}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [419]	valid_0's l1: 10.5856
# [I 2025-08-10 10:56:51,137] Trial 30 finished with value: 10.585618638196806 and parameters: {'lambda_l1': 0.4138460138202746, 'lambda_l2': 0.2084412305568195, 'num_leaves': 87, 'feature_fraction': 0.8595849191581005, 'learning_rate': 0.010150234448889782, 'bagging_fraction': 0.9593421257448587, 'bagging_freq': 5, 'min_child_samples': 36, 'max_bin': 305}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [384]	valid_0's l1: 10.5277
# [I 2025-08-10 10:56:53,770] Trial 31 finished with value: 10.527734900411604 and parameters: {'lambda_l1': 0.4018375607152763, 'lambda_l2': 0.23067384672203037, 'num_leaves': 86, 'feature_fraction': 0.8576116072317456, 'learning_rate': 0.01287722907581299, 'bagging_fraction': 0.9686180512956244, 'bagging_freq': 5, 'min_child_samples': 35, 'max_bin': 317}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [207]	valid_0's l1: 12.0844
# [I 2025-08-10 10:56:55,195] Trial 32 finished with value: 12.08439413999953 and parameters: {'lambda_l1': 0.19963619970892682, 'lambda_l2': 0.2628574923668408, 'num_leaves': 85, 'feature_fraction': 0.8031912272095859, 'learning_rate': 0.013611312730526135, 'bagging_fraction': 0.9993492072620787, 'bagging_freq': 6, 'min_child_samples': 35, 'max_bin': 258}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [263]	valid_0's l1: 10.4681
# [I 2025-08-10 10:56:57,184] Trial 33 finished with value: 10.46810203815671 and parameters: {'lambda_l1': 0.5629529421410588, 'lambda_l2': 0.06157327211650698, 'num_leaves': 95, 'feature_fraction': 0.8912221777415388, 'learning_rate': 0.01816581268523426, 'bagging_fraction': 0.876414706384602, 'bagging_freq': 3, 'min_child_samples': 40, 'max_bin': 234}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [352]	valid_0's l1: 10.777
# [I 2025-08-10 10:56:59,715] Trial 34 finished with value: 10.777045344407755 and parameters: {'lambda_l1': 0.5651121278110444, 'lambda_l2': 0.12127171650469877, 'num_leaves': 96, 'feature_fraction': 0.9261903749842317, 'learning_rate': 0.012427333110675216, 'bagging_fraction': 0.8832949195897802, 'bagging_freq': 3, 'min_child_samples': 39, 'max_bin': 237}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [210]	valid_0's l1: 10.6667
# [I 2025-08-10 10:57:01,428] Trial 35 finished with value: 10.666687342186183 and parameters: {'lambda_l1': 0.43117743805168146, 'lambda_l2': 0.04435861262345908, 'num_leaves': 93, 'feature_fraction': 0.8786329337168968, 'learning_rate': 0.019613980927355425, 'bagging_fraction': 0.9411424424439351, 'bagging_freq': 2, 'min_child_samples': 40, 'max_bin': 266}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [250]	valid_0's l1: 10.9387
# [I 2025-08-10 10:57:03,851] Trial 36 finished with value: 10.938746045934495 and parameters: {'lambda_l1': 0.22237963508628542, 'lambda_l2': 0.017011690320733686, 'num_leaves': 112, 'feature_fraction': 0.9201664338456621, 'learning_rate': 0.017432290837192152, 'bagging_fraction': 0.9633004823313482, 'bagging_freq': 2, 'min_child_samples': 37, 'max_bin': 317}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [186]	valid_0's l1: 11.9287
# [I 2025-08-10 10:57:05,009] Trial 37 finished with value: 11.928696262542688 and parameters: {'lambda_l1': 0.612502165031444, 'lambda_l2': 0.26912700899354486, 'num_leaves': 66, 'feature_fraction': 0.9578432785632325, 'learning_rate': 0.015086416285093805, 'bagging_fraction': 0.8936390582160753, 'bagging_freq': 4, 'min_child_samples': 38, 'max_bin': 282}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	valid_0's l1: 10.637
# [I 2025-08-10 10:57:05,348] Trial 38 finished with value: 10.636975930541341 and parameters: {'lambda_l1': 0.3210146109750544, 'lambda_l2': 1.6054558263690801, 'num_leaves': 41, 'feature_fraction': 0.837742404075165, 'learning_rate': 0.1164271563932854, 'bagging_fraction': 0.9210206329436235, 'bagging_freq': 1, 'min_child_samples': 36, 'max_bin': 222}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [193]	valid_0's l1: 10.8939
# [I 2025-08-10 10:57:06,945] Trial 39 finished with value: 10.893936966465615 and parameters: {'lambda_l1': 0.5152943280092577, 'lambda_l2': 0.13442397681501245, 'num_leaves': 92, 'feature_fraction': 0.8944628155247061, 'learning_rate': 0.026720857072217403, 'bagging_fraction': 0.9752381556323789, 'bagging_freq': 3, 'min_child_samples': 24, 'max_bin': 267}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [347]	valid_0's l1: 10.8358
# [I 2025-08-10 10:57:10,015] Trial 40 finished with value: 10.835817805316665 and parameters: {'lambda_l1': 0.12940059046304625, 'lambda_l2': 1.9943403424313613, 'num_leaves': 120, 'feature_fraction': 0.8182113177714887, 'learning_rate': 0.010682290795302373, 'bagging_fraction': 0.8672113500722916, 'bagging_freq': 5, 'min_child_samples': 31, 'max_bin': 328}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [266]	valid_0's l1: 10.6854
# [I 2025-08-10 10:57:11,721] Trial 41 finished with value: 10.685447693282795 and parameters: {'lambda_l1': 1.039591550107623, 'lambda_l2': 0.4800059847795635, 'num_leaves': 78, 'feature_fraction': 0.8621935999623962, 'learning_rate': 0.01856967350711722, 'bagging_fraction': 0.9061543921422256, 'bagging_freq': 4, 'min_child_samples': 38, 'max_bin': 234}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [333]	valid_0's l1: 10.8846
# [I 2025-08-10 10:57:13,824] Trial 42 finished with value: 10.884570135721127 and parameters: {'lambda_l1': 0.6689973327316774, 'lambda_l2': 0.9932488648409485, 'num_leaves': 86, 'feature_fraction': 0.7847171344987907, 'learning_rate': 0.012238863820224979, 'bagging_fraction': 0.9454926055409767, 'bagging_freq': 5, 'min_child_samples': 35, 'max_bin': 246}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [322]	valid_0's l1: 10.4905
# [I 2025-08-10 10:57:15,445] Trial 43 finished with value: 10.490497823198448 and parameters: {'lambda_l1': 0.8000707956936327, 'lambda_l2': 0.2937068648525115, 'num_leaves': 67, 'feature_fraction': 0.8342746329082968, 'learning_rate': 0.014375118653704671, 'bagging_fraction': 0.8706363626250454, 'bagging_freq': 6, 'min_child_samples': 32, 'max_bin': 207}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [248]	valid_0's l1: 10.628
# [I 2025-08-10 10:57:16,741] Trial 44 finished with value: 10.627951155528908 and parameters: {'lambda_l1': 0.8250155159906449, 'lambda_l2': 0.2948216821719505, 'num_leaves': 68, 'feature_fraction': 0.834719872233702, 'learning_rate': 0.015016726716349162, 'bagging_fraction': 0.8756881322039092, 'bagging_freq': 6, 'min_child_samples': 28, 'max_bin': 208}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [257]	valid_0's l1: 11.507
# [I 2025-08-10 10:57:17,847] Trial 45 finished with value: 11.50697095236288 and parameters: {'lambda_l1': 0.385961656265335, 'lambda_l2': 0.10185793493849113, 'num_leaves': 55, 'feature_fraction': 0.8592810334037723, 'learning_rate': 0.0130238526945101, 'bagging_fraction': 0.8360490057930112, 'bagging_freq': 7, 'min_child_samples': 32, 'max_bin': 186}. Best is trial 28 with value: 10.400494186803199.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [318]	valid_0's l1: 10.3939
# [I 2025-08-10 10:57:19,801] Trial 46 finished with value: 10.393916443431618 and parameters: {'lambda_l1': 0.5414774103025572, 'lambda_l2': 0.460008127277554, 'num_leaves': 74, 'feature_fraction': 0.8973337147881429, 'learning_rate': 0.01640769941982549, 'bagging_fraction': 0.9003448904134775, 'bagging_freq': 4, 'min_child_samples': 19, 'max_bin': 287}. Best is trial 46 with value: 10.393916443431618.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [190]	valid_0's l1: 11.017
# [I 2025-08-10 10:57:21,068] Trial 47 finished with value: 11.016956882323392 and parameters: {'lambda_l1': 0.7330394014407322, 'lambda_l2': 0.4224781913392499, 'num_leaves': 75, 'feature_fraction': 0.9064461831608766, 'learning_rate': 0.025559464741652375, 'bagging_fraction': 0.8996088225196752, 'bagging_freq': 4, 'min_child_samples': 19, 'max_bin': 252}. Best is trial 46 with value: 10.393916443431618.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [88]	valid_0's l1: 11.8642
# [I 2025-08-10 10:57:21,560] Trial 48 finished with value: 11.86422469487864 and parameters: {'lambda_l1': 0.9294703539312176, 'lambda_l2': 0.5972785974473804, 'num_leaves': 44, 'feature_fraction': 0.9491957261549783, 'learning_rate': 0.0409689607513287, 'bagging_fraction': 0.8535836098097226, 'bagging_freq': 3, 'min_child_samples': 14, 'max_bin': 227}. Best is trial 46 with value: 10.393916443431618.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [236]	valid_0's l1: 11.956
# [I 2025-08-10 10:57:22,771] Trial 49 finished with value: 11.95600416502151 and parameters: {'lambda_l1': 0.5237219750214304, 'lambda_l2': 1.117997246626369, 'num_leaves': 57, 'feature_fraction': 0.8814578080899114, 'learning_rate': 0.01648107037172161, 'bagging_fraction': 0.8212612492714427, 'bagging_freq': 4, 'min_child_samples': 20, 'max_bin': 285}. Best is trial 46 with value: 10.393916443431618.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [50]	valid_0's l1: 12.0936
# [I 2025-08-10 10:57:23,236] Trial 50 finished with value: 12.093640452922642 and parameters: {'lambda_l1': 1.1630328599172233, 'lambda_l2': 0.5060058897858923, 'num_leaves': 70, 'feature_fraction': 0.815673403374023, 'learning_rate': 0.05879981639469385, 'bagging_fraction': 0.8755761359633222, 'bagging_freq': 6, 'min_child_samples': 17, 'max_bin': 198}. Best is trial 46 with value: 10.393916443431618.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [304]	valid_0's l1: 10.331
# [I 2025-08-10 10:57:25,306] Trial 51 finished with value: 10.330970456011663 and parameters: {'lambda_l1': 0.6133481752429246, 'lambda_l2': 0.2309118393466851, 'num_leaves': 83, 'feature_fraction': 0.9098364853447956, 'learning_rate': 0.014369687318892845, 'bagging_fraction': 0.9231230125715001, 'bagging_freq': 5, 'min_child_samples': 30, 'max_bin': 301}. Best is trial 51 with value: 10.330970456011663.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [261]	valid_0's l1: 10.6888
# [I 2025-08-10 10:57:26,983] Trial 52 finished with value: 10.688808392368987 and parameters: {'lambda_l1': 0.787788670464749, 'lambda_l2': 0.33602499971231276, 'num_leaves': 76, 'feature_fraction': 0.9720209564652231, 'learning_rate': 0.014683131690379107, 'bagging_fraction': 0.9204192381495022, 'bagging_freq': 7, 'min_child_samples': 30, 'max_bin': 292}. Best is trial 51 with value: 10.330970456011663.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [143]	valid_0's l1: 11.4169
# [I 2025-08-10 10:57:28,072] Trial 53 finished with value: 11.41685501220048 and parameters: {'lambda_l1': 0.6200081588137347, 'lambda_l2': 0.19643814952280875, 'num_leaves': 81, 'feature_fraction': 0.9117380194392556, 'learning_rate': 0.02262629213761754, 'bagging_fraction': 0.943425668561918, 'bagging_freq': 4, 'min_child_samples': 23, 'max_bin': 263}. Best is trial 51 with value: 10.330970456011663.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [276]	valid_0's l1: 10.5887
# [I 2025-08-10 10:57:29,635] Trial 54 finished with value: 10.588690200810666 and parameters: {'lambda_l1': 0.701019928098433, 'lambda_l2': 0.09658009090523229, 'num_leaves': 61, 'feature_fraction': 0.9403201192081337, 'learning_rate': 0.017421556113606906, 'bagging_fraction': 0.8898705283830923, 'bagging_freq': 6, 'min_child_samples': 27, 'max_bin': 336}. Best is trial 51 with value: 10.330970456011663.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [391]	valid_0's l1: 10.3158
# [I 2025-08-10 10:57:31,161] Trial 55 finished with value: 10.315781279540074 and parameters: {'lambda_l1': 0.49576058342685947, 'lambda_l2': 0.44449674664469696, 'num_leaves': 48, 'feature_fraction': 0.8915931377134583, 'learning_rate': 0.011428622852013584, 'bagging_fraction': 0.8686125222772512, 'bagging_freq': 5, 'min_child_samples': 32, 'max_bin': 215}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [402]	valid_0's l1: 12.047
# [I 2025-08-10 10:57:32,690] Trial 56 finished with value: 12.046999342126231 and parameters: {'lambda_l1': 0.4905956085089106, 'lambda_l2': 0.43674060072189985, 'num_leaves': 47, 'feature_fraction': 0.9693773878390166, 'learning_rate': 0.011083796479175097, 'bagging_fraction': 0.9349796228586136, 'bagging_freq': 3, 'min_child_samples': 17, 'max_bin': 217}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [423]	valid_0's l1: 10.4547
# [I 2025-08-10 10:57:34,087] Trial 57 finished with value: 10.454671283534237 and parameters: {'lambda_l1': 0.2583673711761721, 'lambda_l2': 0.6620088565135204, 'num_leaves': 37, 'feature_fraction': 0.8940735804415726, 'learning_rate': 0.011505933305538764, 'bagging_fraction': 0.9042911426256085, 'bagging_freq': 5, 'min_child_samples': 30, 'max_bin': 271}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [414]	valid_0's l1: 10.3468
# [I 2025-08-10 10:57:35,348] Trial 58 finished with value: 10.34679357707033 and parameters: {'lambda_l1': 0.23727826010338499, 'lambda_l2': 0.7022319709004402, 'num_leaves': 33, 'feature_fraction': 0.7250087154489351, 'learning_rate': 0.012128071492516972, 'bagging_fraction': 0.908834670868304, 'bagging_freq': 5, 'min_child_samples': 30, 'max_bin': 297}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [339]	valid_0's l1: 11.3258
# [I 2025-08-10 10:57:36,385] Trial 59 finished with value: 11.325815469998602 and parameters: {'lambda_l1': 0.03323994788452822, 'lambda_l2': 0.7417566242891953, 'num_leaves': 32, 'feature_fraction': 0.7307123206565574, 'learning_rate': 0.010079309731225592, 'bagging_fraction': 0.9213903697806589, 'bagging_freq': 5, 'min_child_samples': 11, 'max_bin': 299}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [46]	valid_0's l1: 10.4052
# [I 2025-08-10 10:57:36,631] Trial 60 finished with value: 10.40520060260477 and parameters: {'lambda_l1': 0.14295295138426933, 'lambda_l2': 0.9228976752742317, 'num_leaves': 21, 'feature_fraction': 0.7050716121288149, 'learning_rate': 0.1008825425227686, 'bagging_fraction': 0.8565860797628877, 'bagging_freq': 4, 'min_child_samples': 28, 'max_bin': 369}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [67]	valid_0's l1: 10.8391
# [I 2025-08-10 10:57:36,955] Trial 61 finished with value: 10.839090725607168 and parameters: {'lambda_l1': 0.16848447761161048, 'lambda_l2': 1.0860970113992339, 'num_leaves': 23, 'feature_fraction': 0.699151802757524, 'learning_rate': 0.0976989037999694, 'bagging_fraction': 0.8551282236795623, 'bagging_freq': 4, 'min_child_samples': 28, 'max_bin': 391}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [35]	valid_0's l1: 10.7259
# [I 2025-08-10 10:57:37,238] Trial 62 finished with value: 10.72593701586016 and parameters: {'lambda_l1': 0.3571037786499952, 'lambda_l2': 0.9237045948827738, 'num_leaves': 29, 'feature_fraction': 0.7164121224077147, 'learning_rate': 0.12024347972224281, 'bagging_fraction': 0.8312648953921717, 'bagging_freq': 5, 'min_child_samples': 30, 'max_bin': 359}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [55]	valid_0's l1: 10.638
# [I 2025-08-10 10:57:37,501] Trial 63 finished with value: 10.637998186619656 and parameters: {'lambda_l1': 0.0982955717746486, 'lambda_l2': 1.2129696902219123, 'num_leaves': 20, 'feature_fraction': 0.7608531223260273, 'learning_rate': 0.10147604795784136, 'bagging_fraction': 0.8894669185807088, 'bagging_freq': 4, 'min_child_samples': 25, 'max_bin': 320}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [69]	valid_0's l1: 11.5994
# [I 2025-08-10 10:57:37,911] Trial 64 finished with value: 11.599437598820966 and parameters: {'lambda_l1': 0.24769424088512407, 'lambda_l2': 0.9172680223351191, 'num_leaves': 33, 'feature_fraction': 0.6644917433608977, 'learning_rate': 0.08384393974015993, 'bagging_fraction': 0.8562905642680726, 'bagging_freq': 5, 'min_child_samples': 33, 'max_bin': 383}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [60]	valid_0's l1: 10.664
# [I 2025-08-10 10:57:38,214] Trial 65 finished with value: 10.664023817485274 and parameters: {'lambda_l1': 0.4589664005061802, 'lambda_l2': 0.5752287433450631, 'num_leaves': 26, 'feature_fraction': 0.6789273920865002, 'learning_rate': 0.07793702522966618, 'bagging_fraction': 0.8077101227378631, 'bagging_freq': 5, 'min_child_samples': 28, 'max_bin': 366}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [73]	valid_0's l1: 10.9365
# [I 2025-08-10 10:57:38,731] Trial 66 finished with value: 10.93654294432319 and parameters: {'lambda_l1': 0.30052296135329, 'lambda_l2': 0.774363183332716, 'num_leaves': 47, 'feature_fraction': 0.7313790879301414, 'learning_rate': 0.05811807608724647, 'bagging_fraction': 0.9140115995193943, 'bagging_freq': 4, 'min_child_samples': 31, 'max_bin': 352}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [161]	valid_0's l1: 11.6052
# [I 2025-08-10 10:57:39,325] Trial 67 finished with value: 11.605204281973624 and parameters: {'lambda_l1': 0.3617046802212882, 'lambda_l2': 1.0594173178256394, 'num_leaves': 34, 'feature_fraction': 0.6897569772951647, 'learning_rate': 0.02926409709499966, 'bagging_fraction': 0.9018681934911155, 'bagging_freq': 5, 'min_child_samples': 26, 'max_bin': 251}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [36]	valid_0's l1: 10.387
# [I 2025-08-10 10:57:39,722] Trial 68 finished with value: 10.3869528803878 and parameters: {'lambda_l1': 1.9171276336448275, 'lambda_l2': 0.8442046600258544, 'num_leaves': 50, 'feature_fraction': 0.7391805057819463, 'learning_rate': 0.1348325727996631, 'bagging_fraction': 0.9551960340661338, 'bagging_freq': 6, 'min_child_samples': 29, 'max_bin': 338}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [23]	valid_0's l1: 13.537
# [I 2025-08-10 10:57:40,074] Trial 69 finished with value: 13.536978090861972 and parameters: {'lambda_l1': 1.9099552923694905, 'lambda_l2': 0.6689908191391726, 'num_leaves': 50, 'feature_fraction': 0.7791087732573514, 'learning_rate': 0.10883613485819012, 'bagging_fraction': 0.9554529315116885, 'bagging_freq': 7, 'min_child_samples': 27, 'max_bin': 343}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [28]	valid_0's l1: 10.8088
# [I 2025-08-10 10:57:40,471] Trial 70 finished with value: 10.808801016684322 and parameters: {'lambda_l1': 1.7645559891453504, 'lambda_l2': 0.3766419676388024, 'num_leaves': 57, 'feature_fraction': 0.7438578170204345, 'learning_rate': 0.13348240136320905, 'bagging_fraction': 0.930099908639513, 'bagging_freq': 4, 'min_child_samples': 29, 'max_bin': 307}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [38]	valid_0's l1: 10.7071
# [I 2025-08-10 10:57:40,845] Trial 71 finished with value: 10.707118395245354 and parameters: {'lambda_l1': 1.9827782867911425, 'lambda_l2': 0.837505156485523, 'num_leaves': 43, 'feature_fraction': 0.7138127728859616, 'learning_rate': 0.12804188188187737, 'bagging_fraction': 0.8849540119548395, 'bagging_freq': 6, 'min_child_samples': 33, 'max_bin': 377}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [384]	valid_0's l1: 10.411
# [I 2025-08-10 10:57:43,518] Trial 72 finished with value: 10.41101181201225 and parameters: {'lambda_l1': 0.19257084370944377, 'lambda_l2': 0.9659524410613441, 'num_leaves': 84, 'feature_fraction': 0.6653504810069275, 'learning_rate': 0.011752782533708072, 'bagging_fraction': 0.928408422684732, 'bagging_freq': 6, 'min_child_samples': 32, 'max_bin': 335}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [372]	valid_0's l1: 10.6143
# [I 2025-08-10 10:57:46,025] Trial 73 finished with value: 10.614260810233723 and parameters: {'lambda_l1': 6.176062542156968e-05, 'lambda_l2': 1.0270240756097666, 'num_leaves': 83, 'feature_fraction': 0.7608899281170092, 'learning_rate': 0.011830006022979744, 'bagging_fraction': 0.9853058558000931, 'bagging_freq': 6, 'min_child_samples': 30, 'max_bin': 334}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [26]	valid_0's l1: 10.5637
# [I 2025-08-10 10:57:46,478] Trial 74 finished with value: 10.563707288655976 and parameters: {'lambda_l1': 1.5701453143968318, 'lambda_l2': 0.7206574974730233, 'num_leaves': 71, 'feature_fraction': 0.7007290145322695, 'learning_rate': 0.14997764575375527, 'bagging_fraction': 0.9470991885573334, 'bagging_freq': 5, 'min_child_samples': 32, 'max_bin': 325}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [357]	valid_0's l1: 10.5453
# [I 2025-08-10 10:57:48,464] Trial 75 finished with value: 10.54529188116845 and parameters: {'lambda_l1': 0.16659489188869978, 'lambda_l2': 0.8740562233145246, 'num_leaves': 64, 'feature_fraction': 0.7971029327677646, 'learning_rate': 0.0135646847479914, 'bagging_fraction': 0.9757767901104675, 'bagging_freq': 5, 'min_child_samples': 22, 'max_bin': 348}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [329]	valid_0's l1: 10.8525
# [I 2025-08-10 10:57:49,426] Trial 76 finished with value: 10.852466985067316 and parameters: {'lambda_l1': 1.3726338864718082, 'lambda_l2': 1.1636125252050915, 'num_leaves': 30, 'feature_fraction': 0.7199283915842879, 'learning_rate': 0.01605455759343812, 'bagging_fraction': 0.9309698243906871, 'bagging_freq': 7, 'min_child_samples': 31, 'max_bin': 291}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [399]	valid_0's l1: 10.9835
# [I 2025-08-10 10:57:50,733] Trial 77 finished with value: 10.983453591146626 and parameters: {'lambda_l1': 0.10072420879079075, 'lambda_l2': 0.6185874844305684, 'num_leaves': 37, 'feature_fraction': 0.6703870181767102, 'learning_rate': 0.010786021897513437, 'bagging_fraction': 0.9117263243327431, 'bagging_freq': 6, 'min_child_samples': 24, 'max_bin': 311}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [53]	valid_0's l1: 10.5813
# [I 2025-08-10 10:57:51,322] Trial 78 finished with value: 10.581255501502062 and parameters: {'lambda_l1': 1.4724274305583298, 'lambda_l2': 0.5314549659854473, 'num_leaves': 77, 'feature_fraction': 0.7436767566242236, 'learning_rate': 0.08975216057951828, 'bagging_fraction': 0.9568258175179615, 'bagging_freq': 4, 'min_child_samples': 19, 'max_bin': 273}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [56]	valid_0's l1: 10.6667
# [I 2025-08-10 10:57:51,633] Trial 79 finished with value: 10.66666199001563 and parameters: {'lambda_l1': 0.20789369689903567, 'lambda_l2': 0.9454202649495941, 'num_leaves': 23, 'feature_fraction': 0.6859314447360045, 'learning_rate': 0.10307488411519165, 'bagging_fraction': 0.8645423616942879, 'bagging_freq': 3, 'min_child_samples': 29, 'max_bin': 370}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [34]	valid_0's l1: 11.0112
# [I 2025-08-10 10:57:51,872] Trial 80 finished with value: 11.011232119705507 and parameters: {'lambda_l1': 0.5807893457236442, 'lambda_l2': 0.46336402858010817, 'num_leaves': 20, 'feature_fraction': 0.7376191939323375, 'learning_rate': 0.12485998897582624, 'bagging_fraction': 0.9268951627244728, 'bagging_freq': 8, 'min_child_samples': 34, 'max_bin': 334}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	valid_0's l1: 10.7651
# [I 2025-08-10 10:57:52,651] Trial 81 finished with value: 10.765122354207334 and parameters: {'lambda_l1': 0.27031814538463295, 'lambda_l2': 0.8334683785038931, 'num_leaves': 89, 'feature_fraction': 0.6425878136539085, 'learning_rate': 0.07309935789740457, 'bagging_fraction': 0.901188408352165, 'bagging_freq': 6, 'min_child_samples': 34, 'max_bin': 300}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [289]	valid_0's l1: 10.5012
# [I 2025-08-10 10:57:54,436] Trial 82 finished with value: 10.501157770290638 and parameters: {'lambda_l1': 0.46094264446214495, 'lambda_l2': 0.9670837567687408, 'num_leaves': 82, 'feature_fraction': 0.6529440566039358, 'learning_rate': 0.013242376957288056, 'bagging_fraction': 0.8460230548225827, 'bagging_freq': 6, 'min_child_samples': 32, 'max_bin': 243}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [358]	valid_0's l1: 11.0029
# [I 2025-08-10 10:57:57,234] Trial 83 finished with value: 11.00290472339755 and parameters: {'lambda_l1': 0.3489643028615872, 'lambda_l2': 1.2792957022988816, 'num_leaves': 89, 'feature_fraction': 0.8730730244143391, 'learning_rate': 0.011764938569613761, 'bagging_fraction': 0.6433224983687339, 'bagging_freq': 5, 'min_child_samples': 29, 'max_bin': 359}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [104]	valid_0's l1: 10.9066
# [I 2025-08-10 10:57:58,024] Trial 84 finished with value: 10.906641691620143 and parameters: {'lambda_l1': 0.4136396838203027, 'lambda_l2': 0.8828590811570567, 'num_leaves': 74, 'feature_fraction': 0.6669324811913937, 'learning_rate': 0.04629486323077221, 'bagging_fraction': 0.8806470442471662, 'bagging_freq': 6, 'min_child_samples': 31, 'max_bin': 228}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [40]	valid_0's l1: 10.6965
# [I 2025-08-10 10:57:58,462] Trial 85 finished with value: 10.6965173370193 and parameters: {'lambda_l1': 0.16971553292304062, 'lambda_l2': 0.3808760471461613, 'num_leaves': 59, 'feature_fraction': 0.7637631436282036, 'learning_rate': 0.11195173144861134, 'bagging_fraction': 0.8942736182792616, 'bagging_freq': 5, 'min_child_samples': 28, 'max_bin': 256}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [370]	valid_0's l1: 10.6051
# [I 2025-08-10 10:58:00,181] Trial 86 finished with value: 10.605109012360892 and parameters: {'lambda_l1': 0.07190446383398434, 'lambda_l2': 1.018353029442929, 'num_leaves': 53, 'feature_fraction': 0.9088907304149957, 'learning_rate': 0.012424897646127609, 'bagging_fraction': 0.9091168207259924, 'bagging_freq': 7, 'min_child_samples': 35, 'max_bin': 312}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [32]	valid_0's l1: 10.4965
# [I 2025-08-10 10:58:00,633] Trial 87 finished with value: 10.49646020835417 and parameters: {'lambda_l1': 1.2549242808116006, 'lambda_l2': 0.8118666108150787, 'num_leaves': 64, 'feature_fraction': 0.7112512594295236, 'learning_rate': 0.14067399332537858, 'bagging_fraction': 0.9376862572255316, 'bagging_freq': 4, 'min_child_samples': 33, 'max_bin': 275}. Best is trial 55 with value: 10.315781279540074.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [291]	valid_0's l1: 10.267
# [I 2025-08-10 10:58:01,872] Trial 88 finished with value: 10.267049519479137 and parameters: {'lambda_l1': 0.48604260976285385, 'lambda_l2': 0.17084385925113513, 'num_leaves': 47, 'feature_fraction': 0.6137877295064871, 'learning_rate': 0.020388520543510546, 'bagging_fraction': 0.9525969253204025, 'bagging_freq': 6, 'min_child_samples': 30, 'max_bin': 291}. Best is trial 88 with value: 10.267049519479137.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [420]	valid_0's l1: 10.2826
# ...
# [504]	valid_0's l1: 10.3575
# [I 2025-08-10 11:09:30,360] Trial 671 finished with value: 10.357534750818774 and parameters: {'lambda_l1': 1.4097901253370033, 'lambda_l2': 0.93899694386924, 'num_leaves': 30, 'feature_fraction': 0.6132426843991651, 'learning_rate': 0.012154572355233423, 'bagging_fraction': 0.9233663502503937, 'bagging_freq': 8, 'min_child_samples': 9, 'max_bin': 110}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [243]	valid_0's l1: 10.9747
# [I 2025-08-10 11:09:31,005] Trial 672 finished with value: 10.974730944032189 and parameters: {'lambda_l1': 1.5113020027908515, 'lambda_l2': 0.9781673350108567, 'num_leaves': 28, 'feature_fraction': 0.6411431434760494, 'learning_rate': 0.015009281474286564, 'bagging_fraction': 0.9164451148204235, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 121}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [440]	valid_0's l1: 10.5173
# [I 2025-08-10 11:09:32,173] Trial 673 finished with value: 10.517265339009604 and parameters: {'lambda_l1': 1.3102167901074029, 'lambda_l2': 0.8001022616257253, 'num_leaves': 30, 'feature_fraction': 0.6214197609521714, 'learning_rate': 0.013321539209442903, 'bagging_fraction': 0.9302112590505506, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 180}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [426]	valid_0's l1: 10.3556
# [I 2025-08-10 11:09:33,120] Trial 674 finished with value: 10.355594294675301 and parameters: {'lambda_l1': 1.3543401029740119, 'lambda_l2': 1.0768794927720335, 'num_leaves': 25, 'feature_fraction': 0.6316809003909539, 'learning_rate': 0.011607627860950199, 'bagging_fraction': 0.95336476899504, 'bagging_freq': 9, 'min_child_samples': 39, 'max_bin': 115}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [390]	valid_0's l1: 10.6495
# [I 2025-08-10 11:09:34,747] Trial 675 finished with value: 10.649503711413168 and parameters: {'lambda_l1': 1.066238374646439, 'lambda_l2': 1.0048986440566618, 'num_leaves': 48, 'feature_fraction': 0.6063153694141556, 'learning_rate': 0.012538848066976487, 'bagging_fraction': 0.9097967854744398, 'bagging_freq': 8, 'min_child_samples': 39, 'max_bin': 387}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [437]	valid_0's l1: 10.7943
# [I 2025-08-10 11:09:35,930] Trial 676 finished with value: 10.794300684431288 and parameters: {'lambda_l1': 1.3993501533707686, 'lambda_l2': 0.7099458937966228, 'num_leaves': 27, 'feature_fraction': 0.6494131247086361, 'learning_rate': 0.010468279309075654, 'bagging_fraction': 0.9396839513344704, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 393}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [150]	valid_0's l1: 10.1772
# [I 2025-08-10 11:09:37,163] Trial 677 finished with value: 10.177167993113526 and parameters: {'lambda_l1': 0.999715490056139, 'lambda_l2': 0.8795904867565506, 'num_leaves': 68, 'feature_fraction': 0.8371048095531493, 'learning_rate': 0.032577626081495205, 'bagging_fraction': 0.8912588956598679, 'bagging_freq': 9, 'min_child_samples': 39, 'max_bin': 261}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [243]	valid_0's l1: 11.2566
# [I 2025-08-10 11:09:38,059] Trial 678 finished with value: 11.256594779169294 and parameters: {'lambda_l1': 1.3040002019700663, 'lambda_l2': 1.1089459296214115, 'num_leaves': 45, 'feature_fraction': 0.6146577906329733, 'learning_rate': 0.029307148668052566, 'bagging_fraction': 0.9260874716253062, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 106}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [408]	valid_0's l1: 10.4663
# [I 2025-08-10 11:09:39,170] Trial 679 finished with value: 10.466339797821098 and parameters: {'lambda_l1': 0.008652966685070984, 'lambda_l2': 1.0112385740056888, 'num_leaves': 31, 'feature_fraction': 0.6383380301845984, 'learning_rate': 0.011646760607387, 'bagging_fraction': 0.9160587272305363, 'bagging_freq': 8, 'min_child_samples': 39, 'max_bin': 143}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [447]	valid_0's l1: 10.2858
# [I 2025-08-10 11:09:41,018] Trial 680 finished with value: 10.285800525635507 and parameters: {'lambda_l1': 1.441593600353706, 'lambda_l2': 1.749789523645115, 'num_leaves': 56, 'feature_fraction': 0.6257793436815771, 'learning_rate': 0.010978776270129735, 'bagging_fraction': 0.9499408147434238, 'bagging_freq': 10, 'min_child_samples': 40, 'max_bin': 241}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [361]	valid_0's l1: 10.3435
# [I 2025-08-10 11:09:41,911] Trial 681 finished with value: 10.343472544357333 and parameters: {'lambda_l1': 1.2848156327072584, 'lambda_l2': 1.0572674165824694, 'num_leaves': 29, 'feature_fraction': 0.6593582492854492, 'learning_rate': 0.01289439656663629, 'bagging_fraction': 0.8797653492771811, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 126}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [86]	valid_0's l1: 10.8233
# [I 2025-08-10 11:09:42,459] Trial 682 finished with value: 10.823349599001654 and parameters: {'lambda_l1': 1.3485872160547558, 'lambda_l2': 1.9020776788317326, 'num_leaves': 42, 'feature_fraction': 0.6167079516002485, 'learning_rate': 0.041681304335117755, 'bagging_fraction': 0.9056614745786459, 'bagging_freq': 8, 'min_child_samples': 16, 'max_bin': 118}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [462]	valid_0's l1: 10.609
# [I 2025-08-10 11:09:43,790] Trial 683 finished with value: 10.609043716883498 and parameters: {'lambda_l1': 1.145246039401364, 'lambda_l2': 0.6371013880548346, 'num_leaves': 28, 'feature_fraction': 0.6319564873002438, 'learning_rate': 0.01042825449500277, 'bagging_fraction': 0.9315355063158559, 'bagging_freq': 9, 'min_child_samples': 24, 'max_bin': 246}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [506]	valid_0's l1: 10.2195
# [I 2025-08-10 11:09:45,106] Trial 684 finished with value: 10.219477051406178 and parameters: {'lambda_l1': 1.3889504210224504, 'lambda_l2': 0.20683353624250403, 'num_leaves': 31, 'feature_fraction': 0.6823502302312004, 'learning_rate': 0.012068672506220374, 'bagging_fraction': 0.9221204375130124, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 111}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [303]	valid_0's l1: 10.3909
# [I 2025-08-10 11:09:45,802] Trial 685 finished with value: 10.39090730403085 and parameters: {'lambda_l1': 1.4781654896467693, 'lambda_l2': 1.2975308565166421, 'num_leaves': 24, 'feature_fraction': 0.6074453712851452, 'learning_rate': 0.01395591877449308, 'bagging_fraction': 0.9398508782041295, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 122}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [518]	valid_0's l1: 10.3644
# [I 2025-08-10 11:09:47,076] Trial 686 finished with value: 10.364381741383944 and parameters: {'lambda_l1': 1.2556107580164737, 'lambda_l2': 0.8486833501979619, 'num_leaves': 32, 'feature_fraction': 0.641881129770276, 'learning_rate': 0.010003770186737385, 'bagging_fraction': 0.9107477196205244, 'bagging_freq': 8, 'min_child_samples': 39, 'max_bin': 136}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [428]	valid_0's l1: 10.1936
# [I 2025-08-10 11:09:48,460] Trial 687 finished with value: 10.19355738201827 and parameters: {'lambda_l1': 1.9971655924711211, 'lambda_l2': 0.15745937801705004, 'num_leaves': 46, 'feature_fraction': 0.6226518250884252, 'learning_rate': 0.011298647703209711, 'bagging_fraction': 0.8991995140140018, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 115}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [457]	valid_0's l1: 10.3394
# [I 2025-08-10 11:09:50,012] Trial 688 finished with value: 10.339412401480585 and parameters: {'lambda_l1': 1.3326762878224974, 'lambda_l2': 0.7609482291241642, 'num_leaves': 43, 'feature_fraction': 0.6522087648858923, 'learning_rate': 0.010835250354018468, 'bagging_fraction': 0.9182625218026473, 'bagging_freq': 9, 'min_child_samples': 39, 'max_bin': 130}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [400]	valid_0's l1: 10.1819
# [I 2025-08-10 11:09:50,829] Trial 689 finished with value: 10.181857456759667 and parameters: {'lambda_l1': 1.4379177870486166, 'lambda_l2': 1.0938490541796744, 'num_leaves': 22, 'feature_fraction': 0.6277850871318016, 'learning_rate': 0.015767819022924755, 'bagging_fraction': 0.9277205622997404, 'bagging_freq': 8, 'min_child_samples': 39, 'max_bin': 105}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [444]	valid_0's l1: 10.3296
# [I 2025-08-10 11:09:52,001] Trial 690 finished with value: 10.329624060210179 and parameters: {'lambda_l1': 1.1866216692499973, 'lambda_l2': 0.9713407672684838, 'num_leaves': 27, 'feature_fraction': 0.6136789415073066, 'learning_rate': 0.011877993853442908, 'bagging_fraction': 0.8881981042680668, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 100}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [376]	valid_0's l1: 10.4287
# [I 2025-08-10 11:09:53,178] Trial 691 finished with value: 10.428749381143584 and parameters: {'lambda_l1': 1.110300281800005, 'lambda_l2': 0.2648622809368628, 'num_leaves': 40, 'feature_fraction': 0.6002743939282628, 'learning_rate': 0.013251449765584468, 'bagging_fraction': 0.9348172605461069, 'bagging_freq': 9, 'min_child_samples': 40, 'max_bin': 122}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [379]	valid_0's l1: 10.1851
# [I 2025-08-10 11:09:54,098] Trial 692 finished with value: 10.18513651540505 and parameters: {'lambda_l1': 1.3757326744681293, 'lambda_l2': 0.23341973983561703, 'num_leaves': 30, 'feature_fraction': 0.6390058323905123, 'learning_rate': 0.012500832327902008, 'bagging_fraction': 0.9067442901587508, 'bagging_freq': 8, 'min_child_samples': 39, 'max_bin': 113}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [380]	valid_0's l1: 10.2492
# [I 2025-08-10 11:09:55,077] Trial 693 finished with value: 10.249163698382084 and parameters: {'lambda_l1': 1.2731207862335492, 'lambda_l2': 0.185990135864962, 'num_leaves': 32, 'feature_fraction': 0.6207192933611904, 'learning_rate': 0.011405994574504542, 'bagging_fraction': 0.9889177439286134, 'bagging_freq': 9, 'min_child_samples': 40, 'max_bin': 119}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [398]	valid_0's l1: 10.6052
# [I 2025-08-10 11:09:56,327] Trial 694 finished with value: 10.60516089447713 and parameters: {'lambda_l1': 1.5311251067122693, 'lambda_l2': 1.0045454828409826, 'num_leaves': 42, 'feature_fraction': 0.6308025382376702, 'learning_rate': 0.010622283670906226, 'bagging_fraction': 0.9177051861036782, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 167}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [434]	valid_0's l1: 10.1719
# [I 2025-08-10 11:09:57,554] Trial 695 finished with value: 10.171947158440021 and parameters: {'lambda_l1': 1.3119356974110399, 'lambda_l2': 0.12878924664491848, 'num_leaves': 38, 'feature_fraction': 0.6455698977363704, 'learning_rate': 0.011966511788349088, 'bagging_fraction': 0.9476142553360533, 'bagging_freq': 8, 'min_child_samples': 37, 'max_bin': 110}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [500]	valid_0's l1: 10.3164
# [I 2025-08-10 11:09:58,643] Trial 696 finished with value: 10.316360101529254 and parameters: {'lambda_l1': 1.2101182919414608, 'lambda_l2': 0.9137755061487995, 'num_leaves': 26, 'feature_fraction': 0.6675644299562409, 'learning_rate': 0.010841528333834874, 'bagging_fraction': 0.9257207635837488, 'bagging_freq': 8, 'min_child_samples': 39, 'max_bin': 127}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [491]	valid_0's l1: 10.2308
# [I 2025-08-10 11:10:00,192] Trial 697 finished with value: 10.230849160497327 and parameters: {'lambda_l1': 1.402997630845793, 'lambda_l2': 1.836407196501664, 'num_leaves': 36, 'feature_fraction': 0.6086671271727895, 'learning_rate': 0.01000607718517625, 'bagging_fraction': 0.893744472475499, 'bagging_freq': 8, 'min_child_samples': 40, 'max_bin': 116}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [415]	valid_0's l1: 10.2276
# [I 2025-08-10 11:10:01,423] Trial 698 finished with value: 10.227633900758574 and parameters: {'lambda_l1': 1.1629062779628774, 'lambda_l2': 1.0686193145208898, 'num_leaves': 40, 'feature_fraction': 0.6211835368061839, 'learning_rate': 0.012646551656026862, 'bagging_fraction': 0.9977221969930261, 'bagging_freq': 8, 'min_child_samples': 38, 'max_bin': 108}. Best is trial 411 with value: 9.98910193942928.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [299]	valid_0's l1: 10.4974
# [I 2025-08-10 11:10:02,192] Trial 699 finished with value: 10.497444978681562 and parameters: {'lambda_l1': 1.4593486984882624, 'lambda_l2': 0.15921397803243195, 'num_leaves': 29, 'feature_fraction': 0.6361997171623159, 'learning_rate': 0.014484139743273963, 'bagging_fraction': 0.9113798580330592, 'bagging_freq': 8, 'min_child_samples': 39, 'max_bin': 124}. Best is trial 411 with value: 9.98910193942928.
#
# ✅ Optimización completada!
# 🏆 Mejor MAE encontrado: 9.9891
#
# 🔧 HIPERPARÁMETROS OPTIMIZADOS PARA LINEAR_TREE:
# =================================================================
#    linear_tree:      True (FIJO - Característica principal) ⭐
#    lambda_l1:        1.1007
#    lambda_l2:        0.1252
#    num_leaves:       42
#    feature_fraction: 0.6176
#    learning_rate:    0.0123
#    bagging_fraction: 0.9165
#    bagging_freq:     8
#    min_child_samples: 40
#    max_bin:          118
# =================================================================
#
# 📊 Resumen de la optimización:
#   Trials completados: 700
#   Mejor trial: 411
#   Tiempo total: 818.5 segundos
# 🎲 Reproductibilidad garantizada con SEED=42

# %%
# 🚀 Entrenar 20 modelos LightGBM con diferentes semillas - LINEAR_TREE
print("ENTRENAMIENTO DE 20 MODELOS LIGHTGBM CON DIFERENTES SEMILLAS - LINEAR_TREE")
print("="*80)

# 🎲 Definir las 20 semillas diferentes
semillas = [42, 109, 113, 151, 167, 179, 193, 199, 211, 241,
            263, 281, 307, 331, 367, 401, 439, 487, 563, 617]

print(f"🔢 Usando {len(semillas)} semillas diferentes para entrenamiento:")
print(f"   Semillas: {semillas}")

# Usar los mejores parámetros encontrados por Optuna
lgb_params_base = best_params.copy()

# Listas para almacenar modelos y métricas
modelos = []
metricas = []
predicciones_val = []
predicciones_finales = []

# 💾 Crear directorio para guardar los modelos
import os
import pickle
modelos_dir = 'data/modelos_entrenados/sem_1_e2'
os.makedirs(modelos_dir, exist_ok=True)

print(f"\n💾 Los modelos se guardarán en: {modelos_dir}/")
print(f"\n🚀 Iniciando entrenamiento de {len(semillas)} modelos...")

for i, seed in enumerate(semillas, 1):
    print(f"\n{'='*60}")
    print(f"🎯 ENTRENANDO MODELO {i}/20 - SEMILLA: {seed}")
    print(f"{'='*60}")
    
    # 🎲 Configurar semilla específica para este modelo
    np.random.seed(seed)
    random.seed(seed)
    
    # Crear parámetros específicos para este modelo
    lgb_params = lgb_params_base.copy()
    lgb_params.update({
        'random_state': seed,
        'bagging_seed': seed,
        'feature_fraction_seed': seed,
        'data_seed': seed
    })
    
    print(f"🔧 Parámetros para modelo {i}:")
    print(f"   linear_tree: {lgb_params['linear_tree']} ⭐")
    print(f"   random_state: {seed}")
    print(f"   learning_rate: {lgb_params['learning_rate']:.4f}")
    print(f"   num_leaves: {lgb_params['num_leaves']}")
    
    # Crear datasets de LightGBM
    train_dataset = lgb.Dataset(X_train, label=y_train)
    val_dataset = lgb.Dataset(X_val, label=y_val, reference=train_dataset)
    
    # Entrenar el modelo
    modelo = lgb.train(
        lgb_params,
        train_dataset,
        valid_sets=[train_dataset, val_dataset],
        valid_names=['train', 'eval'],
        num_boost_round=2000,
        callbacks=[
            lgb.early_stopping(stopping_rounds=150),
            lgb.log_evaluation(0)  # Silenciar logs individuales
        ]
    )
    
    # 💾 Guardar el modelo individual con su semilla
    model_filename = f"{modelos_dir}/modelo_lgbm_seed_{seed}.pkl"
    with open(model_filename, 'wb') as f:
        pickle.dump(modelo, f)
    print(f"💾 Modelo guardado en: {model_filename}")
    
    # Predicciones en validación
    y_pred_val = modelo.predict(X_val, num_iteration=modelo.best_iteration)
    
    # Calcular métricas
    mae = mean_absolute_error(y_val, y_pred_val)
    rmse = np.sqrt(mean_squared_error(y_val, y_pred_val))
    mape = np.mean(np.abs((y_val - y_pred_val) / y_val)) * 100
    
    # Almacenar resultados (incluyendo ruta del modelo)
    modelos.append(modelo)
    metricas.append({
        'modelo': i,
        'semilla': seed,
        'mae': mae,
        'rmse': rmse,
        'mape': mape,
        'num_trees': modelo.num_trees(),
        'model_file': model_filename  # 📁 Ruta del archivo del modelo
    })
    predicciones_val.append(y_pred_val)
    
    print(f"✅ Modelo {i} entrenado exitosamente!")
    print(f"   MAE:  {mae:.4f}")
    print(f"   RMSE: {rmse:.4f}")
    print(f"   MAPE: {mape:.2f}%")
    print(f"   Árboles: {modelo.num_trees()}")

print(f"\n🎉 ¡TODOS LOS {len(semillas)} MODELOS ENTRENADOS EXITOSAMENTE!")
print(f"⭐ Cada modelo usa árboles lineales híbridos con parámetros optimizados por Optuna")
print(f"💾 Todos los modelos han sido guardados en: {modelos_dir}/")

# Crear DataFrame con métricas (incluyendo rutas de archivos)
df_metricas = pd.DataFrame(metricas)
print(f"\n📊 RESUMEN DE MÉTRICAS DE LOS {len(semillas)} MODELOS:")
print(f"{'='*60}")
print(df_metricas[['modelo', 'semilla', 'mae', 'rmse', 'mape', 'num_trees']])  # Mostrar sin la ruta por claridad

print(f"\n📈 ESTADÍSTICAS DE LAS MÉTRICAS:")
print(f"   MAE  - Promedio: {df_metricas['mae'].mean():.4f}, Std: {df_metricas['mae'].std():.4f}")
print(f"   RMSE - Promedio: {df_metricas['rmse'].mean():.4f}, Std: {df_metricas['rmse'].std():.4f}")
print(f"   MAPE - Promedio: {df_metricas['mape'].mean():.2f}%, Std: {df_metricas['mape'].std():.2f}%")

# Encontrar el mejor modelo
mejor_modelo_idx = df_metricas['mae'].idxmin()
mejor_modelo = modelos[mejor_modelo_idx]
mejor_semilla = semillas[mejor_modelo_idx]
mejor_model_file = df_metricas.loc[mejor_modelo_idx, 'model_file']

print(f"\n🏆 MEJOR MODELO:")
print(f"   Modelo: {mejor_modelo_idx + 1}")
print(f"   Semilla: {mejor_semilla}")
print(f"   MAE: {df_metricas.loc[mejor_modelo_idx, 'mae']:.4f}")
print(f"   RMSE: {df_metricas.loc[mejor_modelo_idx, 'rmse']:.4f}")
print(f"   MAPE: {df_metricas.loc[mejor_modelo_idx, 'mape']:.2f}%")
print(f"   📁 Archivo: {mejor_model_file}")

print(f"\n📁 LISTA DE MODELOS GUARDADOS:")
for i, row in df_metricas.iterrows():
    print(f"   Modelo {row['modelo']:2d} (seed {row['semilla']:3d}): {row['model_file']}")
# Out:
# ENTRENAMIENTO DE 20 MODELOS LIGHTGBM CON DIFERENTES SEMILLAS - LINEAR_TREE
# ================================================================================
# 🔢 Usando 20 semillas diferentes para entrenamiento:
#    Semillas: [42, 109, 113, 151, 167, 179, 193, 199, 211, 241, 263, 281, 307, 331, 367, 401, 439, 487, 563, 617]
#
# 💾 Los modelos se guardarán en: data/modelos_entrenados/sem_1_e2/
#
# 🚀 Iniciando entrenamiento de 20 modelos...
#
# ============================================================
# 🎯 ENTRENANDO MODELO 1/20 - SEMILLA: 42
# ============================================================
# 🔧 Parámetros para modelo 1:
#    linear_tree: True ⭐
#    random_state: 42
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [318]	train's l1: 9.14008	eval's l1: 10.6756
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_42.pkl
# ✅ Modelo 1 entrenado exitosamente!
#    MAE:  10.6756
#    RMSE: 34.9125
#    MAPE: 323.70%
#    Árboles: 318
#
# ============================================================
# 🎯 ENTRENANDO MODELO 2/20 - SEMILLA: 109
# ============================================================
# 🔧 Parámetros para modelo 2:
#    linear_tree: True ⭐
#    random_state: 109
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [397]	train's l1: 8.20284	eval's l1: 10.1447
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_109.pkl
# ✅ Modelo 2 entrenado exitosamente!
#    MAE:  10.1447
#    RMSE: 33.4349
#    MAPE: 215.26%
#    Árboles: 397
#
# ============================================================
# 🎯 ENTRENANDO MODELO 3/20 - SEMILLA: 113
# ============================================================
# 🔧 Parámetros para modelo 3:
#    linear_tree: True ⭐
#    random_state: 113
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [312]	train's l1: 9.21208	eval's l1: 10.6368
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_113.pkl
# ✅ Modelo 3 entrenado exitosamente!
#    MAE:  10.6368
#    RMSE: 33.8864
#    MAPE: 343.18%
#    Árboles: 312
#
# ============================================================
# 🎯 ENTRENANDO MODELO 4/20 - SEMILLA: 151
# ============================================================
# 🔧 Parámetros para modelo 4:
#    linear_tree: True ⭐
#    random_state: 151
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [412]	train's l1: 8.13803	eval's l1: 10.4702
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_151.pkl
# ✅ Modelo 4 entrenado exitosamente!
#    MAE:  10.4702
#    RMSE: 35.3853
#    MAPE: 208.55%
#    Árboles: 412
#
# ============================================================
# 🎯 ENTRENANDO MODELO 5/20 - SEMILLA: 167
# ============================================================
# 🔧 Parámetros para modelo 5:
#    linear_tree: True ⭐
#    random_state: 167
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [383]	train's l1: 8.39642	eval's l1: 10.1629
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_167.pkl
# ✅ Modelo 5 entrenado exitosamente!
#    MAE:  10.1629
#    RMSE: 32.9859
#    MAPE: 231.42%
#    Árboles: 383
#
# ============================================================
# 🎯 ENTRENANDO MODELO 6/20 - SEMILLA: 179
# ============================================================
# 🔧 Parámetros para modelo 6:
#    linear_tree: True ⭐
#    random_state: 179
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [325]	train's l1: 9.05511	eval's l1: 10.5038
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_179.pkl
# ✅ Modelo 6 entrenado exitosamente!
#    MAE:  10.5038
#    RMSE: 34.2987
#    MAPE: 304.47%
#    Árboles: 325
#
# ============================================================
# 🎯 ENTRENANDO MODELO 7/20 - SEMILLA: 193
# ============================================================
# 🔧 Parámetros para modelo 7:
#    linear_tree: True ⭐
#    random_state: 193
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [482]	train's l1: 7.57608	eval's l1: 10.258
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_193.pkl
# ✅ Modelo 7 entrenado exitosamente!
#    MAE:  10.2580
#    RMSE: 33.7448
#    MAPE: 168.54%
#    Árboles: 482
#
# ============================================================
# 🎯 ENTRENANDO MODELO 8/20 - SEMILLA: 199
# ============================================================
# 🔧 Parámetros para modelo 8:
#    linear_tree: True ⭐
#    random_state: 199
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [411]	train's l1: 8.12595	eval's l1: 10.1665
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_199.pkl
# ✅ Modelo 8 entrenado exitosamente!
#    MAE:  10.1665
#    RMSE: 33.7717
#    MAPE: 213.72%
#    Árboles: 411
#
# ============================================================
# 🎯 ENTRENANDO MODELO 9/20 - SEMILLA: 211
# ============================================================
# 🔧 Parámetros para modelo 9:
#    linear_tree: True ⭐
#    random_state: 211
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [370]	train's l1: 8.48229	eval's l1: 10.3289
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_211.pkl
# ✅ Modelo 9 entrenado exitosamente!
#    MAE:  10.3289
#    RMSE: 33.6581
#    MAPE: 232.66%
#    Árboles: 370
#
# ============================================================
# 🎯 ENTRENANDO MODELO 10/20 - SEMILLA: 241
# ============================================================
# 🔧 Parámetros para modelo 10:
#    linear_tree: True ⭐
#    random_state: 241
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [394]	train's l1: 8.28468	eval's l1: 10.2676
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_241.pkl
# ✅ Modelo 10 entrenado exitosamente!
#    MAE:  10.2676
#    RMSE: 33.2460
#    MAPE: 230.12%
#    Árboles: 394
#
# ============================================================
# 🎯 ENTRENANDO MODELO 11/20 - SEMILLA: 263
# ============================================================
# 🔧 Parámetros para modelo 11:
#    linear_tree: True ⭐
#    random_state: 263
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [393]	train's l1: 8.37807	eval's l1: 10.2256
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_263.pkl
# ✅ Modelo 11 entrenado exitosamente!
#    MAE:  10.2256
#    RMSE: 33.4600
#    MAPE: 227.77%
#    Árboles: 393
#
# ============================================================
# 🎯 ENTRENANDO MODELO 12/20 - SEMILLA: 281
# ============================================================
# 🔧 Parámetros para modelo 12:
#    linear_tree: True ⭐
#    random_state: 281
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [497]	train's l1: 7.46366	eval's l1: 10.2123
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_281.pkl
# ✅ Modelo 12 entrenado exitosamente!
#    MAE:  10.2123
#    RMSE: 33.3367
#    MAPE: 158.65%
#    Árboles: 497
#
# ============================================================
# 🎯 ENTRENANDO MODELO 13/20 - SEMILLA: 307
# ============================================================
# 🔧 Parámetros para modelo 13:
#    linear_tree: True ⭐
#    random_state: 307
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [373]	train's l1: 8.50226	eval's l1: 10.1211
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_307.pkl
# ✅ Modelo 13 entrenado exitosamente!
#    MAE:  10.1211
#    RMSE: 33.3051
#    MAPE: 253.98%
#    Árboles: 373
#
# ============================================================
# 🎯 ENTRENANDO MODELO 14/20 - SEMILLA: 331
# ============================================================
# 🔧 Parámetros para modelo 14:
#    linear_tree: True ⭐
#    random_state: 331
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [364]	train's l1: 8.59015	eval's l1: 10.3622
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_331.pkl
# ✅ Modelo 14 entrenado exitosamente!
#    MAE:  10.3622
#    RMSE: 33.9573
#    MAPE: 271.10%
#    Árboles: 364
#
# ============================================================
# 🎯 ENTRENANDO MODELO 15/20 - SEMILLA: 367
# ============================================================
# 🔧 Parámetros para modelo 15:
#    linear_tree: True ⭐
#    random_state: 367
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [439]	train's l1: 7.8813	eval's l1: 10.1015
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_367.pkl
# ✅ Modelo 15 entrenado exitosamente!
#    MAE:  10.1015
#    RMSE: 33.2441
#    MAPE: 193.21%
#    Árboles: 439
#
# ============================================================
# 🎯 ENTRENANDO MODELO 16/20 - SEMILLA: 401
# ============================================================
# 🔧 Parámetros para modelo 16:
#    linear_tree: True ⭐
#    random_state: 401
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [357]	train's l1: 8.74919	eval's l1: 10.3663
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_401.pkl
# ✅ Modelo 16 entrenado exitosamente!
#    MAE:  10.3663
#    RMSE: 33.5168
#    MAPE: 264.60%
#    Árboles: 357
#
# ============================================================
# 🎯 ENTRENANDO MODELO 17/20 - SEMILLA: 439
# ============================================================
# 🔧 Parámetros para modelo 17:
#    linear_tree: True ⭐
#    random_state: 439
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [409]	train's l1: 8.14035	eval's l1: 10.0941
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_439.pkl
# ✅ Modelo 17 entrenado exitosamente!
#    MAE:  10.0941
#    RMSE: 33.0593
#    MAPE: 210.74%
#    Árboles: 409
#
# ============================================================
# 🎯 ENTRENANDO MODELO 18/20 - SEMILLA: 487
# ============================================================
# 🔧 Parámetros para modelo 18:
#    linear_tree: True ⭐
#    random_state: 487
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [310]	train's l1: 9.28402	eval's l1: 11.4389
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_487.pkl
# ✅ Modelo 18 entrenado exitosamente!
#    MAE:  11.4389
#    RMSE: 50.0960
#    MAPE: 357.23%
#    Árboles: 310
#
# ============================================================
# 🎯 ENTRENANDO MODELO 19/20 - SEMILLA: 563
# ============================================================
# 🔧 Parámetros para modelo 19:
#    linear_tree: True ⭐
#    random_state: 563
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [369]	train's l1: 8.51728	eval's l1: 10.187
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_563.pkl
# ✅ Modelo 19 entrenado exitosamente!
#    MAE:  10.1870
#    RMSE: 33.2469
#    MAPE: 244.60%
#    Árboles: 369
#
# ============================================================
# 🎯 ENTRENANDO MODELO 20/20 - SEMILLA: 617
# ============================================================
# 🔧 Parámetros para modelo 20:
#    linear_tree: True ⭐
#    random_state: 617
#    learning_rate: 0.0123
#    num_leaves: 42
# Training until validation scores don't improve for 150 rounds
# Early stopping, best iteration is:
# [443]	train's l1: 7.84871	eval's l1: 10.2387
# 💾 Modelo guardado en: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_617.pkl
# ✅ Modelo 20 entrenado exitosamente!
#    MAE:  10.2387
#    RMSE: 33.3666
#    MAPE: 180.14%
#    Árboles: 443
#
# 🎉 ¡TODOS LOS 20 MODELOS ENTRENADOS EXITOSAMENTE!
# ⭐ Cada modelo usa árboles lineales híbridos con parámetros optimizados por Optuna
# 💾 Todos los modelos han sido guardados en: data/modelos_entrenados/sem_1_e2/
#
# 📊 RESUMEN DE MÉTRICAS DE LOS 20 MODELOS:
# ============================================================
#     modelo  semilla        mae       rmse        mape  num_trees
# 0        1       42  10.675617  34.912464  323.702301        318
# 1        2      109  10.144734  33.434925  215.256001        397
# 2        3      113  10.636761  33.886403  343.183501        312
# 3        4      151  10.470153  35.385259  208.545935        412
# 4        5      167  10.162877  32.985893  231.417109        383
# 5        6      179  10.503765  34.298714  304.469971        325
# 6        7      193  10.258008  33.744830  168.541450        482
# 7        8      199  10.166496  33.771716  213.716053        411
# 8        9      211  10.328859  33.658130  232.656524        370
# 9       10      241  10.267617  33.245988  230.124543        394
# 10      11      263  10.225633  33.460016  227.773718        393
# 11      12      281  10.212271  33.336657  158.648308        497
# 12      13      307  10.121140  33.305056  253.975234        373
# 13      14      331  10.362227  33.957326  271.100072        364
# 14      15      367  10.101520  33.244090  193.208276        439
# 15      16      401  10.366287  33.516751  264.595655        357
# 16      17      439  10.094107  33.059309  210.739441        409
# 17      18      487  11.438931  50.095958  357.228441        310
# 18      19      563  10.187024  33.246888  244.601116        369
# 19      20      617  10.238725  33.366564  180.144227        443
#
# 📈 ESTADÍSTICAS DE LAS MÉTRICAS:
#    MAE  - Promedio: 10.3481, Std: 0.3071
#    RMSE - Promedio: 34.4956, Std: 3.7208
#    MAPE - Promedio: 241.68%, Std: 55.40%
#
# 🏆 MEJOR MODELO:
#    Modelo: 17
#    Semilla: 439
#    MAE: 10.0941
#    RMSE: 33.0593
#    MAPE: 210.74%
#    📁 Archivo: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_439.pkl
#
# 📁 LISTA DE MODELOS GUARDADOS:
#    Modelo  1 (seed  42): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_42.pkl
#    Modelo  2 (seed 109): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_109.pkl
#    Modelo  3 (seed 113): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_113.pkl
#    Modelo  4 (seed 151): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_151.pkl
#    Modelo  5 (seed 167): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_167.pkl
#    Modelo  6 (seed 179): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_179.pkl
#    Modelo  7 (seed 193): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_193.pkl
#    Modelo  8 (seed 199): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_199.pkl
#    Modelo  9 (seed 211): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_211.pkl
#    Modelo 10 (seed 241): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_241.pkl
#    Modelo 11 (seed 263): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_263.pkl
#    Modelo 12 (seed 281): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_281.pkl
#    Modelo 13 (seed 307): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_307.pkl
#    Modelo 14 (seed 331): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_331.pkl
#    Modelo 15 (seed 367): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_367.pkl
#    Modelo 16 (seed 401): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_401.pkl
#    Modelo 17 (seed 439): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_439.pkl
#    Modelo 18 (seed 487): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_487.pkl
#    Modelo 19 (seed 563): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_563.pkl
#    Modelo 20 (seed 617): data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_617.pkl

# %%
# # 📊 Análisis de importancia de features
# print("ANÁLISIS DE IMPORTANCIA DE FEATURES")
# print("="*50)

# # Obtener importancia de features
# feature_importance = model.feature_importance(importance_type='gain')
# feature_names = feature_columns

# # Crear DataFrame con importancias
# importance_df = pd.DataFrame({
#     'feature': feature_names,
#     'importance': feature_importance
# }).sort_values('importance', ascending=False)

# print("🔝 Top 10 features más importantes:")
# print(importance_df.head(10))

# # Visualizar importancia
# plt.figure(figsize=(10, 8))
# top_features = importance_df.head(15)
# plt.barh(range(len(top_features)), top_features['importance'])
# plt.yticks(range(len(top_features)), top_features['feature'])
# plt.xlabel('Importancia')
# plt.title('Top 15 Features - Importancia LightGBM')
# plt.gca().invert_yaxis()
# plt.tight_layout()
# plt.show()

# # Análisis de predicciones
# print(f"\n🎯 ANÁLISIS DE PREDICCIONES:")
# print(f"Predicciones mínimas: {y_pred_val.min():.2f}")
# print(f"Predicciones máximas: {y_pred_val.max():.2f}")
# print(f"Predicciones promedio: {y_pred_val.mean():.2f}")
# print(f"Valores reales promedio: {y_val.mean():.2f}")

# # Verificar predicciones negativas
# negative_preds = (y_pred_val < 0).sum()
# print(f"Predicciones negativas: {negative_preds} ({negative_preds/len(y_pred_val)*100:.1f}%)")

# %%
# 🔧 Funciones de utilidad para cargar modelos guardados
import pickle
import os

def cargar_modelo_por_semilla(semilla, modelos_dir='data/modelos_entrenados/sem_1_e2'):
    """
    Cargar un modelo específico por su semilla
    
    Args:
        semilla (int): La semilla del modelo a cargar
        modelos_dir (str): Directorio donde están guardados los modelos
    
    Returns:
        lightgbm.Booster: El modelo cargado
    """
    model_path = f"{modelos_dir}/modelo_lgbm_seed_{semilla}.pkl"
    if os.path.exists(model_path):
        with open(model_path, 'rb') as f:
            modelo = pickle.load(f)
        print(f"✅ Modelo con semilla {semilla} cargado desde: {model_path}")
        return modelo
    else:
        raise FileNotFoundError(f"❌ No se encontró el modelo con semilla {semilla} en {model_path}")

def cargar_todos_los_modelos(semillas, modelos_dir='data/modelos_entrenados/sem_1_e2'):
    """
    Cargar todos los modelos por sus semillas
    
    Args:
        semillas (list): Lista de semillas de los modelos a cargar
        modelos_dir (str): Directorio donde están guardados los modelos
    
    Returns:
        list: Lista de modelos cargados
    """
    modelos_cargados = []
    print(f"🔄 Cargando {len(semillas)} modelos desde {modelos_dir}/...")
    
    for i, semilla in enumerate(semillas, 1):
        try:
            modelo = cargar_modelo_por_semilla(semilla, modelos_dir)
            modelos_cargados.append(modelo)
            print(f"   {i:2d}/20 - Modelo semilla {semilla} ✅")
        except FileNotFoundError as e:
            print(f"   {i:2d}/20 - Error: {e}")
            return None
    
    print(f"🎉 Todos los {len(modelos_cargados)} modelos cargados exitosamente!")
    return modelos_cargados

def cargar_mejor_modelo(df_metricas, modelos_dir='data/modelos_entrenados/sem_1_e2'):
    """
    Cargar el mejor modelo basado en las métricas
    
    Args:
        df_metricas (pd.DataFrame): DataFrame con las métricas de los modelos
        modelos_dir (str): Directorio donde están guardados los modelos
    
    Returns:
        tuple: (modelo, semilla, mae)
    """
    mejor_idx = df_metricas['mae'].idxmin()
    mejor_semilla = df_metricas.loc[mejor_idx, 'semilla']
    mejor_mae = df_metricas.loc[mejor_idx, 'mae']
    
    mejor_modelo = cargar_modelo_por_semilla(mejor_semilla, modelos_dir)
    print(f"🏆 Mejor modelo cargado: Semilla {mejor_semilla} (MAE: {mejor_mae:.4f})")
    
    return mejor_modelo, mejor_semilla, mejor_mae

def generar_predicciones_ensemble(modelos_cargados, X_pred, estrategia='promedio'):
    """
    Generar predicciones usando ensemble de modelos
    
    Args:
        modelos_cargados (list): Lista de modelos cargados
        X_pred (pd.DataFrame): Features para predecir
        estrategia (str): 'promedio', 'mediana', o 'weighted'
    
    Returns:
        np.array: Predicciones del ensemble
    """
    print(f"🔮 Generando predicciones con ensemble de {len(modelos_cargados)} modelos...")
    
    todas_predicciones = []
    for i, modelo in enumerate(modelos_cargados, 1):
        predicciones = modelo.predict(X_pred, num_iteration=modelo.best_iteration)
        predicciones = np.maximum(predicciones, 0)  # Eliminar predicciones negativas
        todas_predicciones.append(predicciones)
        print(f"   Predicciones modelo {i}/20 generadas ✅")
    
    todas_predicciones = np.array(todas_predicciones)
    
    if estrategia == 'promedio':
        resultado = np.mean(todas_predicciones, axis=0)
        print(f"📊 Ensemble promedio calculado")
    elif estrategia == 'mediana':
        resultado = np.median(todas_predicciones, axis=0)
        print(f"📊 Ensemble mediana calculado")
    else:
        # Por defecto usar promedio
        resultado = np.mean(todas_predicciones, axis=0)
        print(f"📊 Ensemble promedio calculado (estrategia por defecto)")
    
    return resultado, todas_predicciones

print("🔧 Funciones de utilidad para manejo de modelos definidas:")
print("   - cargar_modelo_por_semilla(semilla)")
print("   - cargar_todos_los_modelos(semillas)")
print("   - cargar_mejor_modelo(df_metricas)")
print("   - generar_predicciones_ensemble(modelos, X_pred, estrategia)")
print("✅ Ahora puedes cargar y usar los modelos individuales para ensembles")
# Out:
# 🔧 Funciones de utilidad para manejo de modelos definidas:
#    - cargar_modelo_por_semilla(semilla)
#    - cargar_todos_los_modelos(semillas)
#    - cargar_mejor_modelo(df_metricas)
#    - generar_predicciones_ensemble(modelos, X_pred, estrategia)
# ✅ Ahora puedes cargar y usar los modelos individuales para ensembles

# %%
# 🔮 Generar predicciones finales cargando los modelos guardados
print("GENERACIÓN DE PREDICCIONES FINALES CARGANDO MODELOS GUARDADOS")
print("="*70)

# Preparar datos para predicción (últimos datos disponibles de cada producto)
ultimo_periodo = data_combined.groupby('product_id')['fecha'].max().reset_index()
ultimo_periodo.columns = ['product_id', 'ultima_fecha']

# Unir con datos completos para obtener features más recientes
datos_prediccion = pd.merge(data_combined, ultimo_periodo, on='product_id')
datos_prediccion = datos_prediccion[datos_prediccion['fecha'] == datos_prediccion['ultima_fecha']].copy()

print(f"📊 Productos para predicción: {len(datos_prediccion)}")
print(f"📅 Período base para predicción: {datos_prediccion['periodo'].value_counts().head()}")

# Preparar features para predicción
X_pred = datos_prediccion[feature_columns].copy()
X_pred = X_pred.fillna(0)

print(f"🔍 Shape de datos de predicción: {X_pred.shape}")
print(f"🔍 Valores nulos en predicción: {X_pred.isnull().sum().sum()}")

# 💾 OPCIÓN 1: Cargar todos los modelos desde disco para ensemble completo
print(f"\n💾 CARGANDO MODELOS DESDE DISCO PARA ENSEMBLE...")
modelos_cargados = cargar_todos_los_modelos(semillas)

if modelos_cargados is not None:
    # Generar predicciones con ensemble
    predicciones_promedio, todas_las_predicciones = generar_predicciones_ensemble(
        modelos_cargados, X_pred, estrategia='promedio'
    )
    
    predicciones_mediana, _ = generar_predicciones_ensemble(
        modelos_cargados, X_pred, estrategia='mediana'
    )
    
    print(f"✅ Ensemble completo generado con {len(modelos_cargados)} modelos")
else:
    # Fallback: usar modelos en memoria si fallan las cargas
    print("⚠️ Fallback: Usando modelos en memoria...")
    todas_las_predicciones = []
    for i, modelo in enumerate(modelos, 1):
        print(f"   Generando predicciones con modelo {i} (semilla {semillas[i-1]})...")
        predicciones = modelo.predict(X_pred, num_iteration=modelo.best_iteration)
        predicciones = np.maximum(predicciones, 0)
        todas_las_predicciones.append(predicciones)
    
    todas_las_predicciones = np.array(todas_las_predicciones)
    predicciones_promedio = np.mean(todas_las_predicciones, axis=0)
    predicciones_mediana = np.median(todas_las_predicciones, axis=0)

# 🏆 OPCIÓN 2: Cargar solo el mejor modelo
print(f"\n🏆 CARGANDO MEJOR MODELO INDIVIDUAL...")
mejor_modelo_cargado, mejor_semilla_cargada, mejor_mae_cargado = cargar_mejor_modelo(df_metricas)
mejor_predicciones = mejor_modelo_cargado.predict(X_pred, num_iteration=mejor_modelo_cargado.best_iteration)
mejor_predicciones = np.maximum(mejor_predicciones, 0)

# Calcular estadísticas adicionales
predicciones_std = np.std(todas_las_predicciones, axis=0)
predicciones_min = np.min(todas_las_predicciones, axis=0)
predicciones_max = np.max(todas_las_predicciones, axis=0)

print(f"\n📊 ESTADÍSTICAS DE LAS PREDICCIONES:")
print(f"   Promedio de ensemble promedio: {predicciones_promedio.mean():.2f}")
print(f"   Promedio de ensemble mediana: {predicciones_mediana.mean():.2f}")
print(f"   Promedio de desviación estándar: {predicciones_std.mean():.2f}")
print(f"   Promedio del mejor modelo: {mejor_predicciones.mean():.2f}")

# Crear DataFrames de resultados
print(f"\n💾 Creando DataFrames de resultados...")

# DataFrame con todas las predicciones individuales
df_predicciones_individuales = pd.DataFrame({
    'product_id': datos_prediccion['product_id'].values
})

for i, semilla in enumerate(semillas):
    df_predicciones_individuales[f'pred_modelo_{i+1}_seed_{semilla}'] = todas_las_predicciones[i]

# DataFrame con estadísticas agregadas
resultado_lgbm_estadisticas = pd.DataFrame({
    'product_id': datos_prediccion['product_id'].values,
    'tn_promedio': predicciones_promedio,
    'tn_mediana': predicciones_mediana,
    'tn_std': predicciones_std,
    'tn_min': predicciones_min,
    'tn_max': predicciones_max,
    'tn_mejor_modelo': mejor_predicciones
})

# DataFrame principal (para compatibilidad) - usando promedio
resultado_lgbm = pd.DataFrame({
    'product_id': datos_prediccion['product_id'].values,
    'tn': predicciones_promedio
})

print(f"✅ Predicciones generadas para {len(resultado_lgbm)} productos")
print(f"\n📊 Estadísticas del ensemble promedio:")
print(f"  Promedio: {resultado_lgbm['tn'].mean():.2f}")
print(f"  Mediana:  {resultado_lgbm['tn'].median():.2f}")
print(f"  Mínimo:   {resultado_lgbm['tn'].min():.2f}")
print(f"  Máximo:   {resultado_lgbm['tn'].max():.2f}")
print(f"  Std:      {resultado_lgbm['tn'].std():.2f}")

print(f"\n📊 Estadísticas del mejor modelo:")
print(f"  Promedio: {mejor_predicciones.mean():.2f}")
print(f"  Mediana:  {np.median(mejor_predicciones):.2f}")
print(f"  Mínimo:   {mejor_predicciones.min():.2f}")
print(f"  Máximo:   {mejor_predicciones.max():.2f}")
print(f"  Std:      {mejor_predicciones.std():.2f}")

print(f"\n💾 DEMOSTRACIÓN DE FUNCIONALIDAD:")
print(f"✅ Modelos guardados individualmente por semilla")
print(f"✅ Ensemble promedio generado cargando modelos desde disco")
print(f"✅ Mejor modelo individual cargado por semilla {mejor_semilla_cargada}")
print(f"✅ Funciones disponibles para cargar cualquier modelo específico")

print(f"\nPrimeras 10 predicciones (ensemble promedio):")
print(resultado_lgbm.head(10))
# Out:
# GENERACIÓN DE PREDICCIONES FINALES CARGANDO MODELOS GUARDADOS
# ======================================================================
# 📊 Productos para predicción: 780
# 📅 Período base para predicción: periodo
# 201912    780
# Name: count, dtype: int64
# 🔍 Shape de datos de predicción: (780, 62)
# 🔍 Valores nulos en predicción: 0
#
# 💾 CARGANDO MODELOS DESDE DISCO PARA ENSEMBLE...
# 🔄 Cargando 20 modelos desde data/modelos_entrenados/sem_1_e2/...
# ✅ Modelo con semilla 42 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_42.pkl
#     1/20 - Modelo semilla 42 ✅
# ✅ Modelo con semilla 109 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_109.pkl
#     2/20 - Modelo semilla 109 ✅
# ✅ Modelo con semilla 113 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_113.pkl
#     3/20 - Modelo semilla 113 ✅
# ✅ Modelo con semilla 151 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_151.pkl
#     4/20 - Modelo semilla 151 ✅
# ✅ Modelo con semilla 167 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_167.pkl
#     5/20 - Modelo semilla 167 ✅
# ✅ Modelo con semilla 179 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_179.pkl
#     6/20 - Modelo semilla 179 ✅
# ✅ Modelo con semilla 193 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_193.pkl
#     7/20 - Modelo semilla 193 ✅
# ✅ Modelo con semilla 199 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_199.pkl
#     8/20 - Modelo semilla 199 ✅
# ✅ Modelo con semilla 211 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_211.pkl
#     9/20 - Modelo semilla 211 ✅
# ✅ Modelo con semilla 241 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_241.pkl
#    10/20 - Modelo semilla 241 ✅
# ✅ Modelo con semilla 263 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_263.pkl
#    11/20 - Modelo semilla 263 ✅
# ✅ Modelo con semilla 281 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_281.pkl
#    12/20 - Modelo semilla 281 ✅
# ✅ Modelo con semilla 307 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_307.pkl
#    13/20 - Modelo semilla 307 ✅
# ✅ Modelo con semilla 331 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_331.pkl
#    14/20 - Modelo semilla 331 ✅
# ✅ Modelo con semilla 367 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_367.pkl
#    15/20 - Modelo semilla 367 ✅
# ✅ Modelo con semilla 401 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_401.pkl
#    16/20 - Modelo semilla 401 ✅
# ✅ Modelo con semilla 439 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_439.pkl
#    17/20 - Modelo semilla 439 ✅
# ✅ Modelo con semilla 487 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_487.pkl
#    18/20 - Modelo semilla 487 ✅
# ✅ Modelo con semilla 563 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_563.pkl
#    19/20 - Modelo semilla 563 ✅
# ✅ Modelo con semilla 617 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_617.pkl
#    20/20 - Modelo semilla 617 ✅
# 🎉 Todos los 20 modelos cargados exitosamente!
# 🔮 Generando predicciones con ensemble de 20 modelos...
#    Predicciones modelo 1/20 generadas ✅
#    Predicciones modelo 2/20 generadas ✅
#    Predicciones modelo 3/20 generadas ✅
#    Predicciones modelo 4/20 generadas ✅
#    Predicciones modelo 5/20 generadas ✅
#    Predicciones modelo 6/20 generadas ✅
#    Predicciones modelo 7/20 generadas ✅
#    Predicciones modelo 8/20 generadas ✅
#    Predicciones modelo 9/20 generadas ✅
#    Predicciones modelo 10/20 generadas ✅
#    Predicciones modelo 11/20 generadas ✅
#    Predicciones modelo 12/20 generadas ✅
#    Predicciones modelo 13/20 generadas ✅
#    Predicciones modelo 14/20 generadas ✅
#    Predicciones modelo 15/20 generadas ✅
#    Predicciones modelo 16/20 generadas ✅
#    Predicciones modelo 17/20 generadas ✅
#    Predicciones modelo 18/20 generadas ✅
#    Predicciones modelo 19/20 generadas ✅
#    Predicciones modelo 20/20 generadas ✅
# 📊 Ensemble promedio calculado
# 🔮 Generando predicciones con ensemble de 20 modelos...
#    Predicciones modelo 1/20 generadas ✅
#    Predicciones modelo 2/20 generadas ✅
#    Predicciones modelo 3/20 generadas ✅
#    Predicciones modelo 4/20 generadas ✅
#    Predicciones modelo 5/20 generadas ✅
#    Predicciones modelo 6/20 generadas ✅
#    Predicciones modelo 7/20 generadas ✅
#    Predicciones modelo 8/20 generadas ✅
#    Predicciones modelo 9/20 generadas ✅
#    Predicciones modelo 10/20 generadas ✅
#    Predicciones modelo 11/20 generadas ✅
#    Predicciones modelo 12/20 generadas ✅
#    Predicciones modelo 13/20 generadas ✅
#    Predicciones modelo 14/20 generadas ✅
#    Predicciones modelo 15/20 generadas ✅
#    Predicciones modelo 16/20 generadas ✅
#    Predicciones modelo 17/20 generadas ✅
#    Predicciones modelo 18/20 generadas ✅
#    Predicciones modelo 19/20 generadas ✅
#    Predicciones modelo 20/20 generadas ✅
# 📊 Ensemble mediana calculado
# ✅ Ensemble completo generado con 20 modelos
#
# 🏆 CARGANDO MEJOR MODELO INDIVIDUAL...
# ✅ Modelo con semilla 439 cargado desde: data/modelos_entrenados/sem_1_e2/modelo_lgbm_seed_439.pkl
# 🏆 Mejor modelo cargado: Semilla 439 (MAE: 10.0941)
#
# 📊 ESTADÍSTICAS DE LAS PREDICCIONES:
#    Promedio de ensemble promedio: 35.63
#    Promedio de ensemble mediana: 35.43
#    Promedio de desviación estándar: 1.94
#    Promedio del mejor modelo: 35.66
#
# 💾 Creando DataFrames de resultados...
# ✅ Predicciones generadas para 780 productos
#
# 📊 Estadísticas del ensemble promedio:
#   Promedio: 35.63
#   Mediana:  8.75
#   Mínimo:   0.66
#   Máximo:   1289.02
#   Std:      88.70
#
# 📊 Estadísticas del mejor modelo:
#   Promedio: 35.66
#   Mediana:  8.62
#   Mínimo:   0.36
#   Máximo:   1289.06
#   Std:      88.85
#
# 💾 DEMOSTRACIÓN DE FUNCIONALIDAD:
# ✅ Modelos guardados individualmente por semilla
# ✅ Ensemble promedio generado cargando modelos desde disco
# ✅ Mejor modelo individual cargado por semilla 439
# ✅ Funciones disponibles para cargar cualquier modelo específico
#
# Primeras 10 predicciones (ensemble promedio):
#    product_id           tn
# 0       20001  1289.023963
# 1       20002  1045.010231
# 2       20003   677.885162
# 3       20004   503.147855
# 4       20005   571.186751
# 5       20006   427.605872
# 6       20007   366.498077
# 7       20008   335.802180
# 8       20009   407.271226
# 9       20010   362.075414

# %%
# 💾 Guardar todos los archivos de predicciones y información de modelos
import os
os.makedirs('data', exist_ok=True)

print("GUARDANDO ARCHIVOS DE PREDICCIONES Y MODELOS")
print("="*60)

# 1. Guardar predicciones promedio (archivo principal)
archivo_promedio = 'data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_promedio_e2.csv'
resultado_lgbm.to_csv(archivo_promedio, index=False)
print(f"✅ Predicciones promedio guardadas en: {archivo_promedio}")

# 2. Guardar predicciones del mejor modelo
archivo_mejor = 'data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_mejor_e2.csv'
resultado_mejor = pd.DataFrame({
    'product_id': datos_prediccion['product_id'].values,
    'tn': mejor_predicciones
})
resultado_mejor.to_csv(archivo_mejor, index=False)
print(f"✅ Predicciones del mejor modelo guardadas en: {archivo_mejor}")

# 3. Guardar estadísticas completas
archivo_estadisticas = 'data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_estadisticas_e2.csv'
resultado_lgbm_estadisticas.to_csv(archivo_estadisticas, index=False)
print(f"✅ Estadísticas completas guardadas en: {archivo_estadisticas}")

# 4. Guardar todas las predicciones individuales
archivo_individuales = 'data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_individuales_e2.csv'
df_predicciones_individuales.to_csv(archivo_individuales, index=False)
print(f"✅ Predicciones individuales guardadas en: {archivo_individuales}")

# 5. Guardar métricas de los modelos (incluyendo rutas de archivos)
archivo_metricas = 'data/metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_e2.csv'
df_metricas.to_csv(archivo_metricas, index=False)
print(f"✅ Métricas de los modelos guardadas en: {archivo_metricas}")

# 6. Guardar inventario de modelos guardados
archivo_inventario = 'data/inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_e2.csv'
inventario_modelos = df_metricas[['modelo', 'semilla', 'mae', 'rmse', 'mape', 'model_file']].copy()
inventario_modelos['modelo_existe'] = inventario_modelos['model_file'].apply(os.path.exists)
inventario_modelos.to_csv(archivo_inventario, index=False)
print(f"✅ Inventario de modelos guardado en: {archivo_inventario}")

print(f"\n📁 RESUMEN DE ARCHIVOS GUARDADOS:")
print(f"   1. {archivo_promedio} - Predicciones promedio de los 20 modelos")
print(f"   2. {archivo_mejor} - Predicciones del mejor modelo (semilla {mejor_semilla})")
print(f"   3. {archivo_estadisticas} - Estadísticas completas (promedio, mediana, std, min, max)")
print(f"   4. {archivo_individuales} - Predicciones de cada uno de los 20 modelos")
print(f"   5. {archivo_metricas} - Métricas de rendimiento de cada modelo")
print(f"   6. {archivo_inventario} - Inventario de modelos guardados con ubicaciones")

print(f"\n🤖 MODELOS INDIVIDUALES GUARDADOS:")
print(f"   Directorio: {modelos_dir}/")
for i, row in df_metricas.iterrows():
    existe = "✅" if os.path.exists(row['model_file']) else "❌"
    print(f"   {existe} modelo_lgbm_seed_{row['semilla']}.pkl (MAE: {row['mae']:.4f})")

print(f"\n🎯 INSTRUCCIONES DE USO:")
print(f"   📖 Para cargar un modelo específico:")
print(f"      modelo = cargar_modelo_por_semilla(semilla)")
print(f"   📖 Para cargar el mejor modelo:")
print(f"      mejor_modelo, semilla, mae = cargar_mejor_modelo(df_metricas)")
print(f"   📖 Para generar ensemble personalizado:")
print(f"      semillas_subset = [42, 113, 241]  # Ejemplo")
print(f"      modelos_subset = cargar_todos_los_modelos(semillas_subset)")
print(f"      predicciones = generar_predicciones_ensemble(modelos_subset, X_pred)")

print(f"\n✅ SISTEMA DE MODELOS PERSISTENTES IMPLEMENTADO EXITOSAMENTE!")
print(f"🔄 Los modelos están disponibles para reutilización y experimentos futuros")
# Out:
# GUARDANDO ARCHIVOS DE PREDICCIONES Y MODELOS
# ============================================================
# ✅ Predicciones promedio guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_promedio_e2.csv
# ✅ Predicciones del mejor modelo guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_mejor_e2.csv
# ✅ Estadísticas completas guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_estadisticas_e2.csv
# ✅ Predicciones individuales guardadas en: data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_individuales_e2.csv
# ✅ Métricas de los modelos guardadas en: data/metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_e2.csv
# ✅ Inventario de modelos guardado en: data/inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_e2.csv
#
# 📁 RESUMEN DE ARCHIVOS GUARDADOS:
#    1. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_promedio_e2.csv - Predicciones promedio de los 20 modelos
#    2. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_mejor_e2.csv - Predicciones del mejor modelo (semilla 439)
#    3. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_estadisticas_e2.csv - Estadísticas completas (promedio, mediana, std, min, max)
#    4. data/pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_individuales_e2.csv - Predicciones de cada uno de los 20 modelos
#    5. data/metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_e2.csv - Métricas de rendimiento de cada modelo
#    6. data/inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_e2.csv - Inventario de modelos guardados con ubicaciones
#
# 🤖 MODELOS INDIVIDUALES GUARDADOS:
#    Directorio: data/modelos_entrenados/sem_1_e2/
#    ✅ modelo_lgbm_seed_42.pkl (MAE: 10.6756)
#    ✅ modelo_lgbm_seed_109.pkl (MAE: 10.1447)
#    ✅ modelo_lgbm_seed_113.pkl (MAE: 10.6368)
#    ✅ modelo_lgbm_seed_151.pkl (MAE: 10.4702)
#    ✅ modelo_lgbm_seed_167.pkl (MAE: 10.1629)
#    ✅ modelo_lgbm_seed_179.pkl (MAE: 10.5038)
#    ✅ modelo_lgbm_seed_193.pkl (MAE: 10.2580)
#    ✅ modelo_lgbm_seed_199.pkl (MAE: 10.1665)
#    ✅ modelo_lgbm_seed_211.pkl (MAE: 10.3289)
#    ✅ modelo_lgbm_seed_241.pkl (MAE: 10.2676)
#    ✅ modelo_lgbm_seed_263.pkl (MAE: 10.2256)
#    ✅ modelo_lgbm_seed_281.pkl (MAE: 10.2123)
#    ✅ modelo_lgbm_seed_307.pkl (MAE: 10.1211)
#    ✅ modelo_lgbm_seed_331.pkl (MAE: 10.3622)
#    ✅ modelo_lgbm_seed_367.pkl (MAE: 10.1015)
#    ✅ modelo_lgbm_seed_401.pkl (MAE: 10.3663)
#    ✅ modelo_lgbm_seed_439.pkl (MAE: 10.0941)
#    ✅ modelo_lgbm_seed_487.pkl (MAE: 11.4389)
#    ✅ modelo_lgbm_seed_563.pkl (MAE: 10.1870)
#    ✅ modelo_lgbm_seed_617.pkl (MAE: 10.2387)
#
# 🎯 INSTRUCCIONES DE USO:
#    📖 Para cargar un modelo específico:
#       modelo = cargar_modelo_por_semilla(semilla)
#    📖 Para cargar el mejor modelo:
#       mejor_modelo, semilla, mae = cargar_mejor_modelo(df_metricas)
#    📖 Para generar ensemble personalizado:
#       semillas_subset = [42, 113, 241]  # Ejemplo
#       modelos_subset = cargar_todos_los_modelos(semillas_subset)
#       predicciones = generar_predicciones_ensemble(modelos_subset, X_pred)
#
# ✅ SISTEMA DE MODELOS PERSISTENTES IMPLEMENTADO EXITOSAMENTE!
# 🔄 Los modelos están disponibles para reutilización y experimentos futuros

# %%
print(f"🎉 ¡SISTEMA DE ENSEMBLE CON MODELOS PERSISTENTES COMPLETADO!")
print(f"⭐ Cada modelo usa árboles lineales híbridos con optimización Optuna")
print(f"🔢 20 modelos entrenados con semillas diferentes para mayor robustez")
print(f"💾 Todos los modelos guardados individualmente para reutilización")
print(f"🏆 Mejor modelo individual: Semilla {mejor_semilla} (MAE: {df_metricas.loc[mejor_modelo_idx, 'mae']:.4f})")
print(f"📊 MAE promedio del conjunto: {df_metricas['mae'].mean():.4f} (±{df_metricas['mae'].std():.4f})")
print(f"📁 6 archivos de predicciones + 20 modelos individuales guardados")
print(f"🔧 Funciones de utilidad disponibles para cargar modelos por semilla")
print(f"🎲 Semillas utilizadas: {semillas}")
print(f"🏆 Tecnología: LINEAR_TREE + OPTUNA + 36 LAGS + ENSEMBLE PERSISTENTE DE 20 MODELOS")
print(f"")
print(f"🎯 NUEVAS CAPACIDADES DISPONIBLES:")
print(f"   🔄 Cargar cualquier modelo por su semilla")
print(f"   🏆 Cargar automáticamente el mejor modelo")
print(f"   📊 Generar ensembles personalizados con subconjuntos de modelos")
print(f"   💾 Reutilizar modelos sin re-entrenar")
print(f"   🔬 Experimentar con diferentes estrategias de ensemble")
# Out:
# 🎉 ¡SISTEMA DE ENSEMBLE CON MODELOS PERSISTENTES COMPLETADO!
# ⭐ Cada modelo usa árboles lineales híbridos con optimización Optuna
# 🔢 20 modelos entrenados con semillas diferentes para mayor robustez
# 💾 Todos los modelos guardados individualmente para reutilización
# 🏆 Mejor modelo individual: Semilla 439 (MAE: 10.0941)
# 📊 MAE promedio del conjunto: 10.3481 (±0.3071)
# 📁 6 archivos de predicciones + 20 modelos individuales guardados
# 🔧 Funciones de utilidad disponibles para cargar modelos por semilla
# 🎲 Semillas utilizadas: [42, 109, 113, 151, 167, 179, 193, 199, 211, 241, 263, 281, 307, 331, 367, 401, 439, 487, 563, 617]
# 🏆 Tecnología: LINEAR_TREE + OPTUNA + 36 LAGS + ENSEMBLE PERSISTENTE DE 20 MODELOS
#
# 🎯 NUEVAS CAPACIDADES DISPONIBLES:
#    🔄 Cargar cualquier modelo por su semilla
#    🏆 Cargar automáticamente el mejor modelo
#    📊 Generar ensembles personalizados con subconjuntos de modelos
#    💾 Reutilizar modelos sin re-entrenar
#    🔬 Experimentar con diferentes estrategias de ensemble

# %%
# Guardar información de reproductibilidad del conjunto de modelos con persistencia
import json
os.makedirs('data', exist_ok=True)

# Crear información detallada de reproductibilidad
reproducibility_info_ensemble = {
    'experimento': 'LGBM_v3_FE_02_v3_linear_tree_opt_03_36lags_semillerio_persistente',
    'descripcion': 'Conjunto de 20 modelos LightGBM con linear_tree, parámetros optimizados por Optuna y persistencia individual',
    'numero_modelos': len(semillas),
    'semillas_utilizadas': semillas,
    'semilla_optuna': 42,
    'modelos_guardados': {
        'directorio': modelos_dir,
        'formato': 'pickle (.pkl)',
        'patron_nombre': 'modelo_lgbm_seed_{semilla}.pkl',
        'total_archivos': len(semillas)
    },
    'mejor_modelo': {
        'indice': int(mejor_modelo_idx + 1),
        'semilla': int(mejor_semilla),
        'mae': float(df_metricas.loc[mejor_modelo_idx, 'mae']),
        'rmse': float(df_metricas.loc[mejor_modelo_idx, 'rmse']),
        'mape': float(df_metricas.loc[mejor_modelo_idx, 'mape']),
        'archivo': mejor_model_file
    },
    'estadisticas_conjunto': {
        'mae_promedio': float(df_metricas['mae'].mean()),
        'mae_std': float(df_metricas['mae'].std()),
        'rmse_promedio': float(df_metricas['rmse'].mean()),
        'rmse_std': float(df_metricas['rmse'].std()),
        'mape_promedio': float(df_metricas['mape'].mean()),
        'mape_std': float(df_metricas['mape'].std())
    },
    'parametros_optimizados': {
        'linear_tree': lgb_params_base['linear_tree'],
        'lambda_l1': lgb_params_base['lambda_l1'],
        'lambda_l2': lgb_params_base['lambda_l2'],
        'num_leaves': lgb_params_base['num_leaves'],
        'feature_fraction': lgb_params_base['feature_fraction'],
        'learning_rate': lgb_params_base['learning_rate'],
        'bagging_fraction': lgb_params_base['bagging_fraction'],
        'bagging_freq': lgb_params_base['bagging_freq'],
        'min_child_samples': lgb_params_base['min_child_samples'],
        'max_bin': lgb_params_base['max_bin']
    },
    'configuracion_entrenamiento': {
        'num_boost_round': 2000,
        'early_stopping_rounds': 150,
        'validation_split': 0.8
    },
    'features_utilizadas': len(feature_columns),
    'lags_toneladas': 36,
    'funciones_utilidad': [
        'cargar_modelo_por_semilla(semilla)',
        'cargar_todos_los_modelos(semillas)',
        'cargar_mejor_modelo(df_metricas)',
        'generar_predicciones_ensemble(modelos, X_pred, estrategia)'
    ],
    'archivos_generados': [
        'pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_promedio_e2.csv',
        'pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_mejor_e2.csv',
        'pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_estadisticas_e2.csv',
        'pred_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_producto_sem_1_individuales_e2.csv',
        'metricas_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_e2.csv',
        'inventario_modelos_lgbm_v3_FE_02_v3_linear_tree_opt_03_36lags_sem_1_e2.csv'
    ],
    'modelos_individuales': [f"modelo_lgbm_seed_{seed}.pkl" for seed in semillas]
}

# Guardar archivo de reproductibilidad
archivo_reproducibilidad = 'data/reproducibility_info_lgbm_v3_FE_02_v3_linear_tree_opt_36lags_sem_1_ensemble_persistente_e2.json'
with open(archivo_reproducibilidad, 'w') as f:
    json.dump(reproducibility_info_ensemble, f, indent=2)

print("🎲 INFORMACIÓN DE REPRODUCTIBILIDAD DEL CONJUNTO PERSISTENTE:")
print(f"   Experimento: {reproducibility_info_ensemble['experimento']}")
print(f"   Número de modelos: {len(semillas)}")
print(f"   Semillas utilizadas: {semillas}")
print(f"   Semilla para Optuna: 42")
print(f"   Mejor modelo: #{mejor_modelo_idx + 1} (semilla {mejor_semilla})")
print(f"   MAE promedio: {df_metricas['mae'].mean():.4f} (±{df_metricas['mae'].std():.4f})")
print(f"   Modelos guardados en: {modelos_dir}/")

print(f"\n✅ Información de reproductibilidad guardada en:")
print(f"   {archivo_reproducibilidad}")

print(f"\n📊 RESUMEN FINAL DEL EXPERIMENTO CON PERSISTENCIA:")
print(f"   🔬 Estrategia: Conjunto de {len(semillas)} modelos LightGBM persistentes")
print(f"   ⭐ Tecnología: LINEAR_TREE + OPTUNA + 36 LAGS + PERSISTENCIA")
print(f"   🎯 Objetivo: Máxima robustez, precisión y reutilización")
print(f"   📁 Archivos: 6 archivos CSV + 20 modelos .pkl + 1 JSON reproductibilidad")
print(f"   🏆 Resultado: Sistema completo de ensemble reutilizable")
print(f"   🔄 Capacidad: Cargar y usar cualquier modelo individual por semilla")
print(f"   🎛️ Flexibilidad: Crear ensembles personalizados sin re-entrenar")

print(f"\n🎉 ¡SISTEMA DE MACHINE LEARNING PERSISTENTE COMPLETADO EXITOSAMENTE!")
print(f"💪 Máxima robustez, flexibilidad y capacidad de experimentación")
# Out:
# 🎲 INFORMACIÓN DE REPRODUCTIBILIDAD DEL CONJUNTO PERSISTENTE:
#    Experimento: LGBM_v3_FE_02_v3_linear_tree_opt_03_36lags_semillerio_persistente
#    Número de modelos: 20
#    Semillas utilizadas: [42, 109, 113, 151, 167, 179, 193, 199, 211, 241, 263, 281, 307, 331, 367, 401, 439, 487, 563, 617]
#    Semilla para Optuna: 42
#    Mejor modelo: #17 (semilla 439)
#    MAE promedio: 10.3481 (±0.3071)
#    Modelos guardados en: data/modelos_entrenados/sem_1_e2/
#
# ✅ Información de reproductibilidad guardada en:
#    data/reproducibility_info_lgbm_v3_FE_02_v3_linear_tree_opt_36lags_sem_1_ensemble_persistente_e2.json
#
# 📊 RESUMEN FINAL DEL EXPERIMENTO CON PERSISTENCIA:
#    🔬 Estrategia: Conjunto de 20 modelos LightGBM persistentes
#    ⭐ Tecnología: LINEAR_TREE + OPTUNA + 36 LAGS + PERSISTENCIA
#    🎯 Objetivo: Máxima robustez, precisión y reutilización
#    📁 Archivos: 6 archivos CSV + 20 modelos .pkl + 1 JSON reproductibilidad
#    🏆 Resultado: Sistema completo de ensemble reutilizable
#    🔄 Capacidad: Cargar y usar cualquier modelo individual por semilla
#    🎛️ Flexibilidad: Crear ensembles personalizados sin re-entrenar
#
# 🎉 ¡SISTEMA DE MACHINE LEARNING PERSISTENTE COMPLETADO EXITOSAMENTE!
# 💪 Máxima robustez, flexibilidad y capacidad de experimentación
